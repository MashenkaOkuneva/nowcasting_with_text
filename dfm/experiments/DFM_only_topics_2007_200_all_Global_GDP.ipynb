# %% [markdown]
# # Out-of-sample forecasting experiments
#
# I conduct out-of-sample forecasting experiments to understand what kind of text data (topics, sentiment, or uncertainty) helps improve forecasts of three quarterly variables (GDP, Investment, and Consumption) more.
#
# In this notebook, I evaluate the performance of the dynamic factor model (DFM) using only 10 topics most highly correlated with GDP growth (out of 200 topics estimated on articles published before 2008 using all sources). I use text data to forecast GDP growth.
#
# ## Experiment Details
#
# - **Data Sources:** 10 topics (<=2007, 200 topics, all sources).
# - **Forecast Target:** GDP growth.
# - **Model:** Dynamic Factor Models (DFM).
# - **Parameters Explored:**
#   - **Number of Global Factors:** 1 to 2
#   - **Factor Order:** 3

# %%
import os
import time
import datetime
import pandas as pd
import DFM_function

# Define inputs common to all models
q_var = 'GDP'                      # quarterly variable being forecasted
additional_factors = None          # or "all" or e.g. ['Labor market'] or 'HardSurveys+Text'
start = '1991-04'
text_type = "topics"
estimation_period = "2007"
num_topics = "200"
source = "all"
with_text = True
only_text = True

# Generate list of forecast_month strings for quarters from 2008Q1 to 2018Q4
# forecast_month is set to the month corresponding to quarter-end:
# Q1: 'YYYY-03', Q2: 'YYYY-06', Q3: 'YYYY-09', Q4: 'YYYY-12'
forecast_months = []
for year in range(2008, 2019):
    forecast_months.extend([f"{year}-03", f"{year}-06", f"{year}-09", f"{year}-12"])
    
# Define the vintage column names 
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Create directories to save forecasts and MSE results
os.makedirs(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
os.makedirs(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)

# Load the actual growth data
actual_growth_file = f"../{q_var}_growth_actual.csv"
actual_growth = pd.read_csv(actual_growth_file)

# Record overall start time
overall_start = time.time()

# Loop over the number of factors from 1 to 2
for num_factors in range(1, 3):  # Varying number of Global factors: 1, 2
    
    order = 3

    # Define model-specific parameters
    factor_multiplicities = {'Global': num_factors}
    factor_orders = {'Global': order}

    # Prepare lists to store each quarter's forecasts and row labels
    forecasts_all_quarters = []
    row_labels = []

    # Start timing for this model
    start_time = time.time()

    # Loop over each forecast month, get the forecasts, and store the results
    for fm in forecast_months:
        # Use the forecast_month string as the row label
        row_labels.append(fm)

        # Run the forecast function for this quarter
        forecasts_dict = DFM_function.get_forecasts(
            forecast_month = fm,
            q_var = q_var,
            additional_factors = additional_factors,
            factor_multiplicities = factor_multiplicities,
            factor_orders = factor_orders,
            start = start,
            text_type = text_type,
            estimation_period = estimation_period,
            num_topics = num_topics,
            source = source,
            with_text = with_text,
            only_text = only_text
        )

        # Obtain the correct ordering of vintages
        vintages_order = DFM_function.vintage_dates(fm)
        # Extract the forecast value for each vintage in that order
        quarter_forecasts = [forecasts_dict[vint] for vint in vintages_order]
        forecasts_all_quarters.append(quarter_forecasts)

    # Create a DataFrame with rows labeled by the forecast_month strings and columns as vintage names
    results = pd.DataFrame(forecasts_all_quarters, index=row_labels, columns=vintage_col_names)

    # Stop timing for this model and print elapsed time
    elapsed = time.time() - start_time
    elapsed_time = datetime.timedelta(seconds=elapsed)
    print(f"Model with Global factors = {num_factors} and order = {order} estimated in {elapsed_time}.")

    # Construct the output file name
    factors_str = "_".join([
        f"{factor.replace(' ', '_')}_{factor_multiplicities[factor]}_{factor_orders[factor]}"
        for factor in factor_multiplicities])
    file_name = f"forecasts_{q_var}_{factors_str}.csv"

    # Save the CSV file in a subfolder 
    output_path = os.path.join(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", file_name)
    results.to_csv(output_path, index=True)

    # ----- MSE Calculation -----
    # Load forecasts
    forecasts = pd.read_csv(output_path, index_col=0)
    # Make sure the index is a column named "date"
    forecasts.index.name = "date"
    forecasts.reset_index(inplace=True)

    # Merge dfs by date 
    merged = pd.merge(forecasts, actual_growth, on="date", how="inner")

    # Calculate the Mean Squared Error (MSE) for each vintage column
    mse_dict = {}
    for col in vintage_col_names:
        mse = ((merged[col] - merged["growth"]) ** 2).mean()
        mse_dict[col] = mse

    # Create a df with one row (the MSE values for each forecasting horizon)
    mse_df = pd.DataFrame(mse_dict, index=[0])

    # Save MSE results to CSV
    mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
    mse_output_path = os.path.join(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", mse_file_name)
    mse_df.to_csv(mse_output_path, index=False)
    
# Stop overall timing and print overall elapsed time
overall_elapsed = time.time() - overall_start
overall_elapsed_time = datetime.timedelta(seconds=overall_elapsed)
print(f"Overall time taken for running all models: {overall_elapsed_time}.")
# Out:
# EM start iterations, llf=-2404.3
# EM iteration 50, llf=-2351.1, convergence criterion=7.133e-06
# EM iteration 100, llf=-2350.7, convergence criterion=2.1297e-06
# EM iteration 150, llf=-2350.5, convergence criterion=1.0552e-06
# EM converged at iteration 155, llf=-2350.5, convergence criterion=9.9573e-07 < tolerance=1e-06
# EM start iterations, llf=-2404.3
# EM iteration 50, llf=-2351.1, convergence criterion=7.133e-06
# EM iteration 100, llf=-2350.7, convergence criterion=2.1297e-06
# EM iteration 150, llf=-2350.5, convergence criterion=1.0552e-06
# EM converged at iteration 155, llf=-2350.5, convergence criterion=9.9573e-07 < tolerance=1e-06
# EM start iterations, llf=-2417.1
# EM iteration 50, llf=-2363.8, convergence criterion=7.1011e-06
# EM iteration 100, llf=-2363.3, convergence criterion=2.1368e-06
# EM iteration 150, llf=-2363.2, convergence criterion=1.056e-06
# EM converged at iteration 155, llf=-2363.2, convergence criterion=9.9609e-07 < tolerance=1e-06
# EM start iterations, llf=-2418.6
# EM iteration 50, llf=-2365.2, convergence criterion=7.0597e-06
# EM iteration 100, llf=-2364.8, convergence criterion=2.1188e-06
# EM iteration 150, llf=-2364.6, convergence criterion=1.0451e-06
# EM converged at iteration 154, llf=-2364.6, convergence criterion=9.9715e-07 < tolerance=1e-06
# EM start iterations, llf=-2434.7
# EM iteration 50, llf=-2381.1, convergence criterion=7.0196e-06
# EM iteration 100, llf=-2380.7, convergence criterion=2.0854e-06
# EM iteration 150, llf=-2380.5, convergence criterion=1.036e-06
# EM converged at iteration 154, llf=-2380.5, convergence criterion=9.8915e-07 < tolerance=1e-06
# EM start iterations, llf=-2434.7
# EM iteration 50, llf=-2381.1, convergence criterion=7.0196e-06
# EM iteration 100, llf=-2380.7, convergence criterion=2.0854e-06
# EM iteration 150, llf=-2380.5, convergence criterion=1.036e-06
# EM converged at iteration 154, llf=-2380.5, convergence criterion=9.8915e-07 < tolerance=1e-06
# EM start iterations, llf=-2446.9
# EM iteration 50, llf=-2393.4, convergence criterion=6.9648e-06
# EM iteration 100, llf=-2392.9, convergence criterion=2.0951e-06
# EM iteration 150, llf=-2392.7, convergence criterion=1.0182e-06
# EM converged at iteration 152, llf=-2392.7, convergence criterion=9.9392e-07 < tolerance=1e-06
# EM start iterations, llf=-2446.9
# EM iteration 50, llf=-2393.4, convergence criterion=6.9648e-06
# EM iteration 100, llf=-2392.9, convergence criterion=2.0951e-06
# EM iteration 150, llf=-2392.7, convergence criterion=1.0182e-06
# EM converged at iteration 152, llf=-2392.7, convergence criterion=9.9392e-07 < tolerance=1e-06
# EM start iterations, llf=-2446.9
# EM iteration 50, llf=-2393.4, convergence criterion=6.9648e-06
# EM iteration 100, llf=-2392.9, convergence criterion=2.0951e-06
# EM iteration 150, llf=-2392.7, convergence criterion=1.0182e-06
# EM converged at iteration 152, llf=-2392.7, convergence criterion=9.9392e-07 < tolerance=1e-06
# EM start iterations, llf=-2460.1
# EM iteration 50, llf=-2406.6, convergence criterion=6.5189e-06
# EM iteration 100, llf=-2406.2, convergence criterion=1.9713e-06
# EM converged at iteration 149, llf=-2406, convergence criterion=9.9239e-07 < tolerance=1e-06
# EM start iterations, llf=-2461.5
# EM iteration 50, llf=-2407.9, convergence criterion=5.7962e-06
# EM iteration 100, llf=-2407.5, convergence criterion=1.741e-06
# EM converged at iteration 139, llf=-2407.4, convergence criterion=9.8961e-07 < tolerance=1e-06
# EM start iterations, llf=-2475.8
# EM iteration 50, llf=-2422.1, convergence criterion=5.5918e-06
# EM iteration 100, llf=-2421.7, convergence criterion=1.6657e-06
# EM converged at iteration 136, llf=-2421.6, convergence criterion=9.9668e-07 < tolerance=1e-06
# EM start iterations, llf=-2475.8
# EM iteration 50, llf=-2422.1, convergence criterion=5.5918e-06
# EM iteration 100, llf=-2421.7, convergence criterion=1.6657e-06
# EM converged at iteration 136, llf=-2421.6, convergence criterion=9.9668e-07 < tolerance=1e-06
# EM start iterations, llf=-2489.2
# EM iteration 50, llf=-2435.2, convergence criterion=5.4497e-06
# EM iteration 100, llf=-2434.9, convergence criterion=1.6013e-06
# EM converged at iteration 133, llf=-2434.8, convergence criterion=9.964e-07 < tolerance=1e-06
# EM start iterations, llf=-2489.2
# EM iteration 50, llf=-2435.2, convergence criterion=5.4497e-06
# EM iteration 100, llf=-2434.9, convergence criterion=1.6013e-06
# EM converged at iteration 133, llf=-2434.8, convergence criterion=9.964e-07 < tolerance=1e-06
# EM start iterations, llf=-2489.2
# EM iteration 50, llf=-2435.2, convergence criterion=5.4497e-06
# EM iteration 100, llf=-2434.9, convergence criterion=1.6013e-06
# EM converged at iteration 133, llf=-2434.8, convergence criterion=9.964e-07 < tolerance=1e-06
# EM start iterations, llf=-2501.4
# EM iteration 50, llf=-2447.9, convergence criterion=5.5241e-06
# EM iteration 100, llf=-2447.6, convergence criterion=1.643e-06
# EM converged at iteration 136, llf=-2447.4, convergence criterion=9.889e-07 < tolerance=1e-06
# EM start iterations, llf=-2502.5
# EM iteration 50, llf=-2449.4, convergence criterion=3.1266e-06
# EM converged at iteration 97, llf=-2449.2, convergence criterion=9.894e-07 < tolerance=1e-06
# EM start iterations, llf=-2520
# EM iteration 50, llf=-2466.9, convergence criterion=3.055e-06
# EM converged at iteration 95, llf=-2466.7, convergence criterion=9.8465e-07 < tolerance=1e-06
# EM start iterations, llf=-2520
# EM iteration 50, llf=-2466.9, convergence criterion=3.055e-06
# EM converged at iteration 95, llf=-2466.7, convergence criterion=9.8465e-07 < tolerance=1e-06
# EM start iterations, llf=-2533.3
# EM iteration 50, llf=-2480.2, convergence criterion=3.1823e-06
# EM converged at iteration 99, llf=-2480, convergence criterion=9.9627e-07 < tolerance=1e-06
# EM start iterations, llf=-2533.3
# EM iteration 50, llf=-2480.2, convergence criterion=3.1823e-06
# EM converged at iteration 99, llf=-2480, convergence criterion=9.9627e-07 < tolerance=1e-06
# EM start iterations, llf=-2533.3
# EM iteration 50, llf=-2480.2, convergence criterion=3.1823e-06
# EM converged at iteration 99, llf=-2480, convergence criterion=9.9627e-07 < tolerance=1e-06
# EM start iterations, llf=-2550.6
# EM iteration 50, llf=-2494.7, convergence criterion=2.5638e-06
# EM converged at iteration 84, llf=-2494.6, convergence criterion=9.9216e-07 < tolerance=1e-06
# EM start iterations, llf=-2551.8
# EM iteration 50, llf=-2495.8, convergence criterion=3.1237e-06
# EM converged at iteration 95, llf=-2495.7, convergence criterion=9.9477e-07 < tolerance=1e-06
# EM start iterations, llf=-2526.3
# EM iteration 50, llf=-2471.2, convergence criterion=3.3364e-06
# EM iteration 100, llf=-2471, convergence criterion=1.0185e-06
# EM converged at iteration 102, llf=-2471, convergence criterion=9.8868e-07 < tolerance=1e-06
# EM start iterations, llf=-2526.3
# EM iteration 50, llf=-2471.2, convergence criterion=3.3364e-06
# EM iteration 100, llf=-2471, convergence criterion=1.0185e-06
# EM converged at iteration 102, llf=-2471, convergence criterion=9.8868e-07 < tolerance=1e-06
# EM start iterations, llf=-2514.5
# EM iteration 50, llf=-2460.3, convergence criterion=3.4385e-06
# EM converged at iteration 98, llf=-2460.1, convergence criterion=9.9815e-07 < tolerance=1e-06
# EM start iterations, llf=-2514.5
# EM iteration 50, llf=-2460.3, convergence criterion=3.4385e-06
# EM converged at iteration 98, llf=-2460.1, convergence criterion=9.9815e-07 < tolerance=1e-06
# EM start iterations, llf=-2514.5
# EM iteration 50, llf=-2460.3, convergence criterion=3.4385e-06
# EM converged at iteration 98, llf=-2460.1, convergence criterion=9.9815e-07 < tolerance=1e-06
# EM start iterations, llf=-2506.5
# EM iteration 50, llf=-2453.2, convergence criterion=3.4822e-06
# EM converged at iteration 97, llf=-2453, convergence criterion=9.8745e-07 < tolerance=1e-06
# EM start iterations, llf=-2502.2
# EM iteration 50, llf=-2449.1, convergence criterion=2.7238e-06
# EM converged at iteration 84, llf=-2449, convergence criterion=9.8531e-07 < tolerance=1e-06
# EM start iterations, llf=-2496.3
# EM iteration 50, llf=-2443.3, convergence criterion=2.7514e-06
# EM converged at iteration 85, llf=-2443.2, convergence criterion=9.8487e-07 < tolerance=1e-06
# EM start iterations, llf=-2496.3
# EM iteration 50, llf=-2443.3, convergence criterion=2.7514e-06
# EM converged at iteration 85, llf=-2443.2, convergence criterion=9.8487e-07 < tolerance=1e-06
# EM start iterations, llf=-2494.7
# EM iteration 50, llf=-2441.8, convergence criterion=2.6491e-06
# EM converged at iteration 81, llf=-2441.7, convergence criterion=9.9321e-07 < tolerance=1e-06
# EM start iterations, llf=-2494.7
# EM iteration 50, llf=-2441.8, convergence criterion=2.6491e-06
# EM converged at iteration 81, llf=-2441.7, convergence criterion=9.9321e-07 < tolerance=1e-06
# EM start iterations, llf=-2494.7
# EM iteration 50, llf=-2441.8, convergence criterion=2.6491e-06
# EM converged at iteration 81, llf=-2441.7, convergence criterion=9.9321e-07 < tolerance=1e-06
# EM start iterations, llf=-2494
# EM iteration 50, llf=-2441.3, convergence criterion=2.6665e-06
# EM converged at iteration 82, llf=-2441.2, convergence criterion=9.8294e-07 < tolerance=1e-06
# EM start iterations, llf=-2485.4
# EM iteration 50, llf=-2432.9, convergence criterion=2.629e-06
# EM converged at iteration 81, llf=-2432.8, convergence criterion=9.905e-07 < tolerance=1e-06
# EM start iterations, llf=-2487.9
# EM iteration 50, llf=-2435.8, convergence criterion=2.732e-06
# EM converged at iteration 83, llf=-2435.6, convergence criterion=9.9339e-07 < tolerance=1e-06
# EM start iterations, llf=-2487.9
# EM iteration 50, llf=-2435.8, convergence criterion=2.732e-06
# EM converged at iteration 83, llf=-2435.6, convergence criterion=9.9339e-07 < tolerance=1e-06
# EM start iterations, llf=-2502.1
# EM iteration 50, llf=-2449.5, convergence criterion=2.5625e-06
# EM converged at iteration 77, llf=-2449.4, convergence criterion=9.9289e-07 < tolerance=1e-06
# EM start iterations, llf=-2502.1
# EM iteration 50, llf=-2449.5, convergence criterion=2.5625e-06
# EM converged at iteration 77, llf=-2449.4, convergence criterion=9.9289e-07 < tolerance=1e-06
# EM start iterations, llf=-2502.1
# EM iteration 50, llf=-2449.5, convergence criterion=2.5625e-06
# EM converged at iteration 77, llf=-2449.4, convergence criterion=9.9289e-07 < tolerance=1e-06
# EM start iterations, llf=-2511.4
# EM iteration 50, llf=-2458.7, convergence criterion=2.576e-06
# EM converged at iteration 78, llf=-2458.6, convergence criterion=9.8804e-07 < tolerance=1e-06
# EM start iterations, llf=-2516.1
# EM iteration 50, llf=-2463.9, convergence criterion=2.0019e-06
# EM converged at iteration 68, llf=-2463.8, convergence criterion=9.9777e-07 < tolerance=1e-06
# EM start iterations, llf=-2527
# EM iteration 50, llf=-2475.7, convergence criterion=2.1164e-06
# EM converged at iteration 71, llf=-2475.7, convergence criterion=9.8969e-07 < tolerance=1e-06
# EM start iterations, llf=-2527
# EM iteration 50, llf=-2475.7, convergence criterion=2.1164e-06
# EM converged at iteration 71, llf=-2475.7, convergence criterion=9.8969e-07 < tolerance=1e-06
# EM start iterations, llf=-2534.5
# EM iteration 50, llf=-2483.2, convergence criterion=2.0776e-06
# EM converged at iteration 70, llf=-2483.1, convergence criterion=9.9042e-07 < tolerance=1e-06
# EM start iterations, llf=-2534.5
# EM iteration 50, llf=-2483.2, convergence criterion=2.0776e-06
# EM converged at iteration 70, llf=-2483.1, convergence criterion=9.9042e-07 < tolerance=1e-06
# EM start iterations, llf=-2534.5
# EM iteration 50, llf=-2483.2, convergence criterion=2.0776e-06
# EM converged at iteration 70, llf=-2483.1, convergence criterion=9.9042e-07 < tolerance=1e-06
# EM start iterations, llf=-2544.9
# EM iteration 50, llf=-2493.8, convergence criterion=2.0474e-06
# EM converged at iteration 70, llf=-2493.7, convergence criterion=9.7251e-07 < tolerance=1e-06
# EM start iterations, llf=-2548.1
# EM iteration 50, llf=-2497.3, convergence criterion=3.0718e-06
# EM converged at iteration 90, llf=-2497.1, convergence criterion=9.8875e-07 < tolerance=1e-06
# EM start iterations, llf=-2559
# EM iteration 50, llf=-2508, convergence criterion=3.077e-06
# EM converged at iteration 90, llf=-2507.8, convergence criterion=9.8989e-07 < tolerance=1e-06
# EM start iterations, llf=-2559
# EM iteration 50, llf=-2508, convergence criterion=3.077e-06
# EM converged at iteration 90, llf=-2507.8, convergence criterion=9.8989e-07 < tolerance=1e-06
# EM start iterations, llf=-2571
# EM iteration 50, llf=-2519.9, convergence criterion=3.0659e-06
# EM converged at iteration 89, llf=-2519.7, convergence criterion=9.9901e-07 < tolerance=1e-06
# EM start iterations, llf=-2571
# EM iteration 50, llf=-2519.9, convergence criterion=3.0659e-06
# EM converged at iteration 89, llf=-2519.7, convergence criterion=9.9901e-07 < tolerance=1e-06
# EM start iterations, llf=-2571
# EM iteration 50, llf=-2519.9, convergence criterion=3.0659e-06
# EM converged at iteration 89, llf=-2519.7, convergence criterion=9.9901e-07 < tolerance=1e-06
# EM start iterations, llf=-2583.3
# EM iteration 50, llf=-2531.9, convergence criterion=3.0721e-06
# EM converged at iteration 90, llf=-2531.8, convergence criterion=9.8766e-07 < tolerance=1e-06
# EM start iterations, llf=-2584.5
# EM iteration 50, llf=-2533.1, convergence criterion=3.1136e-06
# EM converged at iteration 91, llf=-2533, convergence criterion=9.8645e-07 < tolerance=1e-06
# EM start iterations, llf=-2597
# EM iteration 50, llf=-2546.2, convergence criterion=3.1535e-06
# EM converged at iteration 92, llf=-2546.1, convergence criterion=9.9693e-07 < tolerance=1e-06
# EM start iterations, llf=-2597
# EM iteration 50, llf=-2546.2, convergence criterion=3.1535e-06
# EM converged at iteration 92, llf=-2546.1, convergence criterion=9.9693e-07 < tolerance=1e-06
# EM start iterations, llf=-2607.4
# EM iteration 50, llf=-2556.3, convergence criterion=3.1569e-06
# EM converged at iteration 94, llf=-2556.2, convergence criterion=9.8353e-07 < tolerance=1e-06
# EM start iterations, llf=-2607.4
# EM iteration 50, llf=-2556.3, convergence criterion=3.1569e-06
# EM converged at iteration 94, llf=-2556.2, convergence criterion=9.8353e-07 < tolerance=1e-06
# EM start iterations, llf=-2607.4
# EM iteration 50, llf=-2556.3, convergence criterion=3.1569e-06
# EM converged at iteration 94, llf=-2556.2, convergence criterion=9.8353e-07 < tolerance=1e-06
# EM start iterations, llf=-2618.3
# EM iteration 50, llf=-2567.1, convergence criterion=3.1066e-06
# EM converged at iteration 91, llf=-2566.9, convergence criterion=9.9183e-07 < tolerance=1e-06
# EM start iterations, llf=-2619.5
# EM iteration 50, llf=-2568.3, convergence criterion=3.1241e-06
# EM converged at iteration 91, llf=-2568.1, convergence criterion=9.9619e-07 < tolerance=1e-06
# EM start iterations, llf=-2635.4
# EM iteration 50, llf=-2584.6, convergence criterion=3.1227e-06
# EM converged at iteration 93, llf=-2584.4, convergence criterion=9.95e-07 < tolerance=1e-06
# EM start iterations, llf=-2635.4
# EM iteration 50, llf=-2584.6, convergence criterion=3.1227e-06
# EM converged at iteration 93, llf=-2584.4, convergence criterion=9.95e-07 < tolerance=1e-06
# EM start iterations, llf=-2647.7
# EM iteration 50, llf=-2596.9, convergence criterion=3.024e-06
# EM converged at iteration 90, llf=-2596.7, convergence criterion=9.9537e-07 < tolerance=1e-06
# EM start iterations, llf=-2647.7
# EM iteration 50, llf=-2596.9, convergence criterion=3.024e-06
# EM converged at iteration 90, llf=-2596.7, convergence criterion=9.9537e-07 < tolerance=1e-06
# EM start iterations, llf=-2647.7
# EM iteration 50, llf=-2596.9, convergence criterion=3.024e-06
# EM converged at iteration 90, llf=-2596.7, convergence criterion=9.9537e-07 < tolerance=1e-06
# EM start iterations, llf=-2661.6
# EM iteration 50, llf=-2610.8, convergence criterion=3.0429e-06
# EM converged at iteration 90, llf=-2610.6, convergence criterion=9.9963e-07 < tolerance=1e-06
# EM start iterations, llf=-2663.5
# EM iteration 50, llf=-2612.5, convergence criterion=3.1753e-06
# EM converged at iteration 92, llf=-2612.3, convergence criterion=9.8798e-07 < tolerance=1e-06
# EM start iterations, llf=-2676.6
# EM iteration 50, llf=-2625.6, convergence criterion=3.159e-06
# EM converged at iteration 91, llf=-2625.4, convergence criterion=9.9565e-07 < tolerance=1e-06
# EM start iterations, llf=-2676.6
# EM iteration 50, llf=-2625.6, convergence criterion=3.159e-06
# EM converged at iteration 91, llf=-2625.4, convergence criterion=9.9565e-07 < tolerance=1e-06
# EM start iterations, llf=-2685.6
# EM iteration 50, llf=-2634.3, convergence criterion=3.1685e-06
# EM converged at iteration 92, llf=-2634.1, convergence criterion=9.8491e-07 < tolerance=1e-06
# EM start iterations, llf=-2685.6
# EM iteration 50, llf=-2634.3, convergence criterion=3.1685e-06
# EM converged at iteration 92, llf=-2634.1, convergence criterion=9.8491e-07 < tolerance=1e-06
# EM start iterations, llf=-2685.6
# EM iteration 50, llf=-2634.3, convergence criterion=3.1685e-06
# EM converged at iteration 92, llf=-2634.1, convergence criterion=9.8491e-07 < tolerance=1e-06
# EM start iterations, llf=-2694.3
# EM iteration 50, llf=-2643, convergence criterion=3.15e-06
# EM converged at iteration 91, llf=-2642.8, convergence criterion=9.9836e-07 < tolerance=1e-06
# EM start iterations, llf=-2695.5
# EM iteration 50, llf=-2644.1, convergence criterion=3.5458e-06
# EM converged at iteration 98, llf=-2643.8, convergence criterion=9.8749e-07 < tolerance=1e-06
# EM start iterations, llf=-2705.1
# EM iteration 50, llf=-2653.5, convergence criterion=3.5278e-06
# EM converged at iteration 97, llf=-2653.3, convergence criterion=9.9486e-07 < tolerance=1e-06
# EM start iterations, llf=-2705.1
# EM iteration 50, llf=-2653.5, convergence criterion=3.5278e-06
# EM converged at iteration 97, llf=-2653.3, convergence criterion=9.9486e-07 < tolerance=1e-06
# EM start iterations, llf=-2714.5
# EM iteration 50, llf=-2662.9, convergence criterion=3.5288e-06
# EM converged at iteration 97, llf=-2662.7, convergence criterion=9.9606e-07 < tolerance=1e-06
# EM start iterations, llf=-2714.5
# EM iteration 50, llf=-2662.9, convergence criterion=3.5288e-06
# EM converged at iteration 97, llf=-2662.7, convergence criterion=9.9606e-07 < tolerance=1e-06
# EM start iterations, llf=-2714.5
# EM iteration 50, llf=-2662.9, convergence criterion=3.5288e-06
# EM converged at iteration 97, llf=-2662.7, convergence criterion=9.9606e-07 < tolerance=1e-06
# EM start iterations, llf=-2723
# EM iteration 50, llf=-2671.4, convergence criterion=3.4682e-06
# EM converged at iteration 97, llf=-2671.2, convergence criterion=9.8314e-07 < tolerance=1e-06
# EM start iterations, llf=-2724.6
# EM iteration 50, llf=-2673.1, convergence criterion=3.8761e-06
# EM iteration 100, llf=-2672.8, convergence criterion=1.0688e-06
# EM converged at iteration 105, llf=-2672.8, convergence criterion=9.8452e-07 < tolerance=1e-06
# EM start iterations, llf=-2735.8
# EM iteration 50, llf=-2684.2, convergence criterion=3.896e-06
# EM iteration 100, llf=-2684, convergence criterion=1.0741e-06
# EM converged at iteration 105, llf=-2684, convergence criterion=9.8964e-07 < tolerance=1e-06
# EM start iterations, llf=-2735.8
# EM iteration 50, llf=-2684.2, convergence criterion=3.896e-06
# EM iteration 100, llf=-2684, convergence criterion=1.0741e-06
# EM converged at iteration 105, llf=-2684, convergence criterion=9.8964e-07 < tolerance=1e-06
# EM start iterations, llf=-2745.4
# EM iteration 50, llf=-2693.3, convergence criterion=3.8734e-06
# EM iteration 100, llf=-2693, convergence criterion=1.0634e-06
# EM converged at iteration 104, llf=-2693, convergence criterion=9.9517e-07 < tolerance=1e-06
# EM start iterations, llf=-2745.4
# EM iteration 50, llf=-2693.3, convergence criterion=3.8734e-06
# EM iteration 100, llf=-2693, convergence criterion=1.0634e-06
# EM converged at iteration 104, llf=-2693, convergence criterion=9.9517e-07 < tolerance=1e-06
# EM start iterations, llf=-2745.4
# EM iteration 50, llf=-2693.3, convergence criterion=3.8734e-06
# EM iteration 100, llf=-2693, convergence criterion=1.0634e-06
# EM converged at iteration 104, llf=-2693, convergence criterion=9.9517e-07 < tolerance=1e-06
# EM start iterations, llf=-2751.8
# EM iteration 50, llf=-2699.8, convergence criterion=3.8268e-06
# EM iteration 100, llf=-2699.5, convergence criterion=1.032e-06
# EM converged at iteration 102, llf=-2699.5, convergence criterion=9.9727e-07 < tolerance=1e-06
# EM start iterations, llf=-2752.5
# EM iteration 50, llf=-2700.4, convergence criterion=3.2221e-06
# EM converged at iteration 92, llf=-2700.2, convergence criterion=9.8861e-07 < tolerance=1e-06
# EM start iterations, llf=-2759.8
# EM iteration 50, llf=-2707.7, convergence criterion=3.2298e-06
# EM converged at iteration 92, llf=-2707.5, convergence criterion=9.8838e-07 < tolerance=1e-06
# EM start iterations, llf=-2759.8
# EM iteration 50, llf=-2707.7, convergence criterion=3.2298e-06
# EM converged at iteration 92, llf=-2707.5, convergence criterion=9.8838e-07 < tolerance=1e-06
# EM start iterations, llf=-2771
# EM iteration 50, llf=-2718.9, convergence criterion=3.1753e-06
# EM converged at iteration 91, llf=-2718.8, convergence criterion=9.8456e-07 < tolerance=1e-06
# EM start iterations, llf=-2771
# EM iteration 50, llf=-2718.9, convergence criterion=3.1753e-06
# EM converged at iteration 91, llf=-2718.8, convergence criterion=9.8456e-07 < tolerance=1e-06
# EM start iterations, llf=-2771
# EM iteration 50, llf=-2718.9, convergence criterion=3.1753e-06
# EM converged at iteration 91, llf=-2718.8, convergence criterion=9.8456e-07 < tolerance=1e-06
# EM start iterations, llf=-2782.8
# EM iteration 50, llf=-2730.8, convergence criterion=3.1554e-06
# EM converged at iteration 91, llf=-2730.7, convergence criterion=9.8783e-07 < tolerance=1e-06
# EM start iterations, llf=-2782.8
# EM iteration 50, llf=-2730.8, convergence criterion=3.1554e-06
# EM converged at iteration 91, llf=-2730.7, convergence criterion=9.8783e-07 < tolerance=1e-06
# EM start iterations, llf=-2806
# EM iteration 50, llf=-2753.6, convergence criterion=3.325e-06
# EM converged at iteration 91, llf=-2753.4, convergence criterion=9.9587e-07 < tolerance=1e-06
# EM start iterations, llf=-2806
# EM iteration 50, llf=-2753.6, convergence criterion=3.325e-06
# EM converged at iteration 91, llf=-2753.4, convergence criterion=9.9587e-07 < tolerance=1e-06
# EM start iterations, llf=-2815.9
# EM iteration 50, llf=-2763.2, convergence criterion=3.3323e-06
# EM converged at iteration 91, llf=-2763, convergence criterion=9.9641e-07 < tolerance=1e-06
# EM start iterations, llf=-2815.9
# EM iteration 50, llf=-2763.2, convergence criterion=3.3323e-06
# EM converged at iteration 91, llf=-2763, convergence criterion=9.9641e-07 < tolerance=1e-06
# EM start iterations, llf=-2815.9
# EM iteration 50, llf=-2763.2, convergence criterion=3.3323e-06
# EM converged at iteration 91, llf=-2763, convergence criterion=9.9641e-07 < tolerance=1e-06
# EM start iterations, llf=-2830.5
# EM iteration 50, llf=-2777.8, convergence criterion=3.3256e-06
# EM converged at iteration 90, llf=-2777.6, convergence criterion=9.9473e-07 < tolerance=1e-06
# EM start iterations, llf=-2831.4
# EM iteration 50, llf=-2778.7, convergence criterion=3.3525e-06
# EM converged at iteration 91, llf=-2778.5, convergence criterion=9.8085e-07 < tolerance=1e-06
# EM start iterations, llf=-2839.1
# EM iteration 50, llf=-2786.7, convergence criterion=3.3347e-06
# EM converged at iteration 90, llf=-2786.5, convergence criterion=9.8906e-07 < tolerance=1e-06
# EM start iterations, llf=-2839.1
# EM iteration 50, llf=-2786.7, convergence criterion=3.3347e-06
# EM converged at iteration 90, llf=-2786.5, convergence criterion=9.8906e-07 < tolerance=1e-06
# EM start iterations, llf=-2847.1
# EM iteration 50, llf=-2795.3, convergence criterion=3.3506e-06
# EM converged at iteration 90, llf=-2795.1, convergence criterion=9.9894e-07 < tolerance=1e-06
# EM start iterations, llf=-2847.1
# EM iteration 50, llf=-2795.3, convergence criterion=3.3506e-06
# EM converged at iteration 90, llf=-2795.1, convergence criterion=9.9894e-07 < tolerance=1e-06
# EM start iterations, llf=-2847.1
# EM iteration 50, llf=-2795.3, convergence criterion=3.3506e-06
# EM converged at iteration 90, llf=-2795.1, convergence criterion=9.9894e-07 < tolerance=1e-06
# EM start iterations, llf=-2862.8
# EM iteration 50, llf=-2810.7, convergence criterion=3.3236e-06
# EM converged at iteration 90, llf=-2810.5, convergence criterion=9.9921e-07 < tolerance=1e-06
# EM start iterations, llf=-2863.8
# EM iteration 50, llf=-2811.7, convergence criterion=3.2974e-06
# EM converged at iteration 90, llf=-2811.5, convergence criterion=9.8998e-07 < tolerance=1e-06
# EM start iterations, llf=-2878.4
# EM iteration 50, llf=-2826, convergence criterion=3.3296e-06
# EM converged at iteration 90, llf=-2825.8, convergence criterion=9.9882e-07 < tolerance=1e-06
# EM start iterations, llf=-2878.4
# EM iteration 50, llf=-2826, convergence criterion=3.3296e-06
# EM converged at iteration 90, llf=-2825.8, convergence criterion=9.9882e-07 < tolerance=1e-06
# EM start iterations, llf=-2890.8
# EM iteration 50, llf=-2838.1, convergence criterion=3.2923e-06
# EM converged at iteration 90, llf=-2837.9, convergence criterion=9.8968e-07 < tolerance=1e-06
# EM start iterations, llf=-2890.8
# EM iteration 50, llf=-2838.1, convergence criterion=3.2923e-06
# EM converged at iteration 90, llf=-2837.9, convergence criterion=9.8968e-07 < tolerance=1e-06
# EM start iterations, llf=-2890.8
# EM iteration 50, llf=-2838.1, convergence criterion=3.2923e-06
# EM converged at iteration 90, llf=-2837.9, convergence criterion=9.8968e-07 < tolerance=1e-06
# EM start iterations, llf=-2900.5
# EM iteration 50, llf=-2847.5, convergence criterion=3.2471e-06
# EM converged at iteration 89, llf=-2847.4, convergence criterion=9.9693e-07 < tolerance=1e-06
# EM start iterations, llf=-2901.7
# EM iteration 50, llf=-2848.8, convergence criterion=3.2437e-06
# EM converged at iteration 89, llf=-2848.6, convergence criterion=9.9286e-07 < tolerance=1e-06
# EM start iterations, llf=-2916.7
# EM iteration 50, llf=-2863.8, convergence criterion=3.0731e-06
# EM converged at iteration 88, llf=-2863.7, convergence criterion=9.8605e-07 < tolerance=1e-06
# EM start iterations, llf=-2916.7
# EM iteration 50, llf=-2863.8, convergence criterion=3.0731e-06
# EM converged at iteration 88, llf=-2863.7, convergence criterion=9.8605e-07 < tolerance=1e-06
# EM start iterations, llf=-2928.5
# EM iteration 50, llf=-2876.4, convergence criterion=3.0709e-06
# EM converged at iteration 89, llf=-2876.2, convergence criterion=9.9419e-07 < tolerance=1e-06
# EM start iterations, llf=-2928.5
# EM iteration 50, llf=-2876.4, convergence criterion=3.0709e-06
# EM converged at iteration 89, llf=-2876.2, convergence criterion=9.9419e-07 < tolerance=1e-06
# EM start iterations, llf=-2928.5
# EM iteration 50, llf=-2876.4, convergence criterion=3.0709e-06
# EM converged at iteration 89, llf=-2876.2, convergence criterion=9.9419e-07 < tolerance=1e-06
# EM start iterations, llf=-2936.9
# EM iteration 50, llf=-2885.2, convergence criterion=3.0719e-06
# EM converged at iteration 90, llf=-2885, convergence criterion=9.8137e-07 < tolerance=1e-06
# EM start iterations, llf=-2938.3
# EM iteration 50, llf=-2886.5, convergence criterion=3.1869e-06
# EM converged at iteration 91, llf=-2886.3, convergence criterion=9.9939e-07 < tolerance=1e-06
# EM start iterations, llf=-2949.7
# EM iteration 50, llf=-2897.7, convergence criterion=3.1968e-06
# EM converged at iteration 91, llf=-2897.5, convergence criterion=9.9816e-07 < tolerance=1e-06
# EM start iterations, llf=-2949.7
# EM iteration 50, llf=-2897.7, convergence criterion=3.1968e-06
# EM converged at iteration 91, llf=-2897.5, convergence criterion=9.9816e-07 < tolerance=1e-06
# EM start iterations, llf=-2963.6
# EM iteration 50, llf=-2911.7, convergence criterion=3.211e-06
# EM converged at iteration 92, llf=-2911.5, convergence criterion=9.91e-07 < tolerance=1e-06
# EM start iterations, llf=-2963.6
# EM iteration 50, llf=-2911.7, convergence criterion=3.211e-06
# EM converged at iteration 92, llf=-2911.5, convergence criterion=9.91e-07 < tolerance=1e-06
# EM start iterations, llf=-2963.6
# EM iteration 50, llf=-2911.7, convergence criterion=3.211e-06
# EM converged at iteration 92, llf=-2911.5, convergence criterion=9.91e-07 < tolerance=1e-06
# EM start iterations, llf=-2973.6
# EM iteration 50, llf=-2921.6, convergence criterion=3.161e-06
# EM converged at iteration 91, llf=-2921.4, convergence criterion=9.9306e-07 < tolerance=1e-06
# EM start iterations, llf=-2974.9
# EM iteration 50, llf=-2922.9, convergence criterion=3.1499e-06
# EM converged at iteration 91, llf=-2922.7, convergence criterion=9.8772e-07 < tolerance=1e-06
# EM start iterations, llf=-2987.6
# EM iteration 50, llf=-2935.7, convergence criterion=3.1637e-06
# EM converged at iteration 91, llf=-2935.5, convergence criterion=9.873e-07 < tolerance=1e-06
# EM start iterations, llf=-2987.6
# EM iteration 50, llf=-2935.7, convergence criterion=3.1637e-06
# EM converged at iteration 91, llf=-2935.5, convergence criterion=9.873e-07 < tolerance=1e-06
# EM start iterations, llf=-3000.8
# EM iteration 50, llf=-2948.5, convergence criterion=3.1908e-06
# EM converged at iteration 91, llf=-2948.3, convergence criterion=9.9122e-07 < tolerance=1e-06
# EM start iterations, llf=-3000.8
# EM iteration 50, llf=-2948.5, convergence criterion=3.1908e-06
# EM converged at iteration 91, llf=-2948.3, convergence criterion=9.9122e-07 < tolerance=1e-06
# EM start iterations, llf=-3000.8
# EM iteration 50, llf=-2948.5, convergence criterion=3.1908e-06
# EM converged at iteration 91, llf=-2948.3, convergence criterion=9.9122e-07 < tolerance=1e-06
# EM start iterations, llf=-3014.2
# EM iteration 50, llf=-2962.2, convergence criterion=3.2178e-06
# EM converged at iteration 91, llf=-2962, convergence criterion=9.9973e-07 < tolerance=1e-06
# EM start iterations, llf=-3015.3
# EM iteration 50, llf=-2963.2, convergence criterion=3.0799e-06
# EM converged at iteration 89, llf=-2963, convergence criterion=9.9356e-07 < tolerance=1e-06
# EM start iterations, llf=-3027.1
# EM iteration 50, llf=-2974.8, convergence criterion=3.0598e-06
# EM converged at iteration 89, llf=-2974.6, convergence criterion=9.8966e-07 < tolerance=1e-06
# EM start iterations, llf=-3027.1
# EM iteration 50, llf=-2974.8, convergence criterion=3.0598e-06
# EM converged at iteration 89, llf=-2974.6, convergence criterion=9.8966e-07 < tolerance=1e-06
# EM start iterations, llf=-3039.7
# EM iteration 50, llf=-2987.2, convergence criterion=3.048e-06
# EM converged at iteration 88, llf=-2987, convergence criterion=9.9792e-07 < tolerance=1e-06
# EM start iterations, llf=-3039.7
# EM iteration 50, llf=-2987.2, convergence criterion=3.048e-06
# EM converged at iteration 88, llf=-2987, convergence criterion=9.9792e-07 < tolerance=1e-06
# EM start iterations, llf=-3039.7
# EM iteration 50, llf=-2987.2, convergence criterion=3.048e-06
# EM converged at iteration 88, llf=-2987, convergence criterion=9.9792e-07 < tolerance=1e-06
# EM start iterations, llf=-3051.5
# EM iteration 50, llf=-2999, convergence criterion=3.0472e-06
# EM converged at iteration 88, llf=-2998.8, convergence criterion=9.9767e-07 < tolerance=1e-06
# EM start iterations, llf=-3052.7
# EM iteration 50, llf=-3000.2, convergence criterion=2.8855e-06
# EM converged at iteration 86, llf=-3000, convergence criterion=9.8913e-07 < tolerance=1e-06
# EM start iterations, llf=-3066.6
# EM iteration 50, llf=-3013.8, convergence criterion=2.8619e-06
# EM converged at iteration 85, llf=-3013.6, convergence criterion=9.9839e-07 < tolerance=1e-06
# EM start iterations, llf=-3066.6
# EM iteration 50, llf=-3013.8, convergence criterion=2.8619e-06
# EM converged at iteration 85, llf=-3013.6, convergence criterion=9.9839e-07 < tolerance=1e-06
# EM start iterations, llf=-3080.6
# EM iteration 50, llf=-3027.5, convergence criterion=2.8679e-06
# EM converged at iteration 85, llf=-3027.3, convergence criterion=9.9142e-07 < tolerance=1e-06
# EM start iterations, llf=-3080.6
# EM iteration 50, llf=-3027.5, convergence criterion=2.8679e-06
# EM converged at iteration 85, llf=-3027.3, convergence criterion=9.9142e-07 < tolerance=1e-06
# EM start iterations, llf=-3080.6
# EM iteration 50, llf=-3027.5, convergence criterion=2.8679e-06
# EM converged at iteration 85, llf=-3027.3, convergence criterion=9.9142e-07 < tolerance=1e-06
# EM start iterations, llf=-3093.2
# EM iteration 50, llf=-3040.1, convergence criterion=2.8768e-06
# EM converged at iteration 85, llf=-3040, convergence criterion=9.9232e-07 < tolerance=1e-06
# EM start iterations, llf=-3094.7
# EM iteration 50, llf=-3041.7, convergence criterion=2.5518e-06
# EM converged at iteration 79, llf=-3041.6, convergence criterion=9.8757e-07 < tolerance=1e-06
# EM start iterations, llf=-3107.8
# EM iteration 50, llf=-3054.8, convergence criterion=2.5258e-06
# EM converged at iteration 79, llf=-3054.6, convergence criterion=9.7843e-07 < tolerance=1e-06
# EM start iterations, llf=-3107.8
# EM iteration 50, llf=-3054.8, convergence criterion=2.5258e-06
# EM converged at iteration 79, llf=-3054.6, convergence criterion=9.7843e-07 < tolerance=1e-06
# EM start iterations, llf=-3119.7
# EM iteration 50, llf=-3066.6, convergence criterion=2.5376e-06
# EM converged at iteration 79, llf=-3066.5, convergence criterion=9.8351e-07 < tolerance=1e-06
# EM start iterations, llf=-3119.7
# EM iteration 50, llf=-3066.6, convergence criterion=2.5376e-06
# EM converged at iteration 79, llf=-3066.5, convergence criterion=9.8351e-07 < tolerance=1e-06
# EM start iterations, llf=-3119.7
# EM iteration 50, llf=-3066.6, convergence criterion=2.5376e-06
# EM converged at iteration 79, llf=-3066.5, convergence criterion=9.8351e-07 < tolerance=1e-06
# EM start iterations, llf=-3131.1
# EM iteration 50, llf=-3077.9, convergence criterion=2.5303e-06
# EM converged at iteration 78, llf=-3077.8, convergence criterion=9.9832e-07 < tolerance=1e-06
# EM start iterations, llf=-3132.3
# EM iteration 50, llf=-3079.1, convergence criterion=2.585e-06
# EM converged at iteration 79, llf=-3078.9, convergence criterion=9.933e-07 < tolerance=1e-06
# EM start iterations, llf=-3145.3
# EM iteration 50, llf=-3092, convergence criterion=2.5894e-06
# EM converged at iteration 79, llf=-3091.8, convergence criterion=9.9928e-07 < tolerance=1e-06
# EM start iterations, llf=-3145.3
# EM iteration 50, llf=-3092, convergence criterion=2.5894e-06
# EM converged at iteration 79, llf=-3091.8, convergence criterion=9.9928e-07 < tolerance=1e-06
# EM start iterations, llf=-3156.7
# EM iteration 50, llf=-3103.6, convergence criterion=2.5839e-06
# EM converged at iteration 80, llf=-3103.4, convergence criterion=9.8801e-07 < tolerance=1e-06
# EM start iterations, llf=-3156.7
# EM iteration 50, llf=-3103.6, convergence criterion=2.5839e-06
# EM converged at iteration 80, llf=-3103.4, convergence criterion=9.8801e-07 < tolerance=1e-06
# EM start iterations, llf=-3156.7
# EM iteration 50, llf=-3103.6, convergence criterion=2.5839e-06
# EM converged at iteration 80, llf=-3103.4, convergence criterion=9.8801e-07 < tolerance=1e-06
# EM start iterations, llf=-3165.3
# EM iteration 50, llf=-3112.2, convergence criterion=2.5915e-06
# EM converged at iteration 81, llf=-3112.1, convergence criterion=9.7904e-07 < tolerance=1e-06
# EM start iterations, llf=-3166.5
# EM iteration 50, llf=-3113.4, convergence criterion=2.6226e-06
# EM converged at iteration 81, llf=-3113.3, convergence criterion=9.9139e-07 < tolerance=1e-06
# EM start iterations, llf=-3179.8
# EM iteration 50, llf=-3126.4, convergence criterion=2.6375e-06
# EM converged at iteration 81, llf=-3126.2, convergence criterion=9.8129e-07 < tolerance=1e-06
# EM start iterations, llf=-3179.8
# EM iteration 50, llf=-3126.4, convergence criterion=2.6375e-06
# EM converged at iteration 81, llf=-3126.2, convergence criterion=9.8129e-07 < tolerance=1e-06
# EM start iterations, llf=-3191.6
# EM iteration 50, llf=-3137.9, convergence criterion=2.657e-06
# EM converged at iteration 81, llf=-3137.7, convergence criterion=9.915e-07 < tolerance=1e-06
# EM start iterations, llf=-3191.6
# EM iteration 50, llf=-3137.9, convergence criterion=2.657e-06
# EM converged at iteration 81, llf=-3137.7, convergence criterion=9.915e-07 < tolerance=1e-06
# EM start iterations, llf=-3191.6
# EM iteration 50, llf=-3137.9, convergence criterion=2.657e-06
# EM converged at iteration 81, llf=-3137.7, convergence criterion=9.915e-07 < tolerance=1e-06
# EM start iterations, llf=-3201
# EM iteration 50, llf=-3147.3, convergence criterion=2.6491e-06
# EM converged at iteration 81, llf=-3147.2, convergence criterion=9.9802e-07 < tolerance=1e-06
# EM start iterations, llf=-3202.1
# EM iteration 50, llf=-3148.3, convergence criterion=2.4802e-06
# EM converged at iteration 79, llf=-3148.2, convergence criterion=9.8367e-07 < tolerance=1e-06
# EM start iterations, llf=-3211.4
# EM iteration 50, llf=-3157.8, convergence criterion=2.5077e-06
# EM converged at iteration 80, llf=-3157.7, convergence criterion=9.7981e-07 < tolerance=1e-06
# EM start iterations, llf=-3211.4
# EM iteration 50, llf=-3157.8, convergence criterion=2.5077e-06
# EM converged at iteration 80, llf=-3157.7, convergence criterion=9.7981e-07 < tolerance=1e-06
# EM start iterations, llf=-3222.4
# EM iteration 50, llf=-3168.8, convergence criterion=2.5256e-06
# EM converged at iteration 79, llf=-3168.6, convergence criterion=9.9635e-07 < tolerance=1e-06
# EM start iterations, llf=-3222.4
# EM iteration 50, llf=-3168.8, convergence criterion=2.5256e-06
# EM converged at iteration 79, llf=-3168.6, convergence criterion=9.9635e-07 < tolerance=1e-06
# EM start iterations, llf=-3222.4
# EM iteration 50, llf=-3168.8, convergence criterion=2.5256e-06
# EM converged at iteration 79, llf=-3168.6, convergence criterion=9.9635e-07 < tolerance=1e-06
# EM start iterations, llf=-3232.1
# EM iteration 50, llf=-3178.4, convergence criterion=2.5222e-06
# EM converged at iteration 79, llf=-3178.3, convergence criterion=9.9607e-07 < tolerance=1e-06
# EM start iterations, llf=-3232.3
# EM iteration 50, llf=-3179, convergence criterion=2.097e-06
# EM converged at iteration 71, llf=-3178.9, convergence criterion=9.793e-07 < tolerance=1e-06
# EM start iterations, llf=-3244.3
# EM iteration 50, llf=-3191, convergence criterion=2.0618e-06
# EM converged at iteration 70, llf=-3190.9, convergence criterion=9.9211e-07 < tolerance=1e-06
# EM start iterations, llf=-3244.3
# EM iteration 50, llf=-3191, convergence criterion=2.0618e-06
# EM converged at iteration 70, llf=-3190.9, convergence criterion=9.9211e-07 < tolerance=1e-06
# EM start iterations, llf=-3256.5
# EM iteration 50, llf=-3203.2, convergence criterion=2.0408e-06
# EM converged at iteration 70, llf=-3203.1, convergence criterion=9.8264e-07 < tolerance=1e-06
# EM start iterations, llf=-3256.5
# EM iteration 50, llf=-3203.2, convergence criterion=2.0408e-06
# EM converged at iteration 70, llf=-3203.1, convergence criterion=9.8264e-07 < tolerance=1e-06
# EM start iterations, llf=-3256.5
# EM iteration 50, llf=-3203.2, convergence criterion=2.0408e-06
# EM converged at iteration 70, llf=-3203.1, convergence criterion=9.8264e-07 < tolerance=1e-06
# EM start iterations, llf=-3267.2
# EM iteration 50, llf=-3213.8, convergence criterion=2.0243e-06
# EM converged at iteration 70, llf=-3213.7, convergence criterion=9.7096e-07 < tolerance=1e-06
# EM start iterations, llf=-3268.4
# EM iteration 50, llf=-3215, convergence criterion=2.0719e-06
# EM converged at iteration 70, llf=-3214.9, convergence criterion=9.9892e-07 < tolerance=1e-06
# EM start iterations, llf=-3280.1
# EM iteration 50, llf=-3226.5, convergence criterion=2.0656e-06
# EM converged at iteration 70, llf=-3226.4, convergence criterion=9.9316e-07 < tolerance=1e-06
# EM start iterations, llf=-3280.1
# EM iteration 50, llf=-3226.5, convergence criterion=2.0656e-06
# EM converged at iteration 70, llf=-3226.4, convergence criterion=9.9316e-07 < tolerance=1e-06
# EM start iterations, llf=-3292.2
# EM iteration 50, llf=-3238.4, convergence criterion=2.0104e-06
# EM converged at iteration 70, llf=-3238.3, convergence criterion=9.7508e-07 < tolerance=1e-06
# EM start iterations, llf=-3292.2
# EM iteration 50, llf=-3238.4, convergence criterion=2.0104e-06
# EM converged at iteration 70, llf=-3238.3, convergence criterion=9.7508e-07 < tolerance=1e-06
# EM start iterations, llf=-3292.2
# EM iteration 50, llf=-3238.4, convergence criterion=2.0104e-06
# EM converged at iteration 70, llf=-3238.3, convergence criterion=9.7508e-07 < tolerance=1e-06
# EM start iterations, llf=-3304.9
# EM iteration 50, llf=-3251, convergence criterion=2.0544e-06
# EM converged at iteration 70, llf=-3251, convergence criterion=9.9495e-07 < tolerance=1e-06
# EM start iterations, llf=-3306.2
# EM iteration 50, llf=-3252.3, convergence criterion=2.0741e-06
# EM converged at iteration 71, llf=-3252.2, convergence criterion=9.7735e-07 < tolerance=1e-06
# EM start iterations, llf=-3318.1
# EM iteration 50, llf=-3263.8, convergence criterion=2.09e-06
# EM converged at iteration 71, llf=-3263.7, convergence criterion=9.8083e-07 < tolerance=1e-06
# EM start iterations, llf=-3318.1
# EM iteration 50, llf=-3263.8, convergence criterion=2.09e-06
# EM converged at iteration 71, llf=-3263.7, convergence criterion=9.8083e-07 < tolerance=1e-06
# EM start iterations, llf=-3330.3
# EM iteration 50, llf=-3275.7, convergence criterion=2.1044e-06
# EM converged at iteration 71, llf=-3275.6, convergence criterion=9.8701e-07 < tolerance=1e-06
# EM start iterations, llf=-3330.3
# EM iteration 50, llf=-3275.7, convergence criterion=2.1044e-06
# EM converged at iteration 71, llf=-3275.6, convergence criterion=9.8701e-07 < tolerance=1e-06
# EM start iterations, llf=-3330.3
# EM iteration 50, llf=-3275.7, convergence criterion=2.1044e-06
# EM converged at iteration 71, llf=-3275.6, convergence criterion=9.8701e-07 < tolerance=1e-06
# EM start iterations, llf=-3341.3
# EM iteration 50, llf=-3286.7, convergence criterion=2.1136e-06
# EM converged at iteration 71, llf=-3286.6, convergence criterion=9.9303e-07 < tolerance=1e-06
# EM start iterations, llf=-3342.5
# EM iteration 50, llf=-3287.9, convergence criterion=2.1093e-06
# EM converged at iteration 71, llf=-3287.8, convergence criterion=9.8926e-07 < tolerance=1e-06
# EM start iterations, llf=-3353.7
# EM iteration 50, llf=-3299.3, convergence criterion=2.1305e-06
# EM converged at iteration 72, llf=-3299.2, convergence criterion=9.738e-07 < tolerance=1e-06
# EM start iterations, llf=-3353.7
# EM iteration 50, llf=-3299.3, convergence criterion=2.1305e-06
# EM converged at iteration 72, llf=-3299.2, convergence criterion=9.738e-07 < tolerance=1e-06
# EM start iterations, llf=-3363.5
# EM iteration 50, llf=-3309.1, convergence criterion=2.1303e-06
# EM converged at iteration 72, llf=-3309, convergence criterion=9.7467e-07 < tolerance=1e-06
# EM start iterations, llf=-3363.5
# EM iteration 50, llf=-3309.1, convergence criterion=2.1303e-06
# EM converged at iteration 72, llf=-3309, convergence criterion=9.7467e-07 < tolerance=1e-06
# EM start iterations, llf=-3363.5
# EM iteration 50, llf=-3309.1, convergence criterion=2.1303e-06
# EM converged at iteration 72, llf=-3309, convergence criterion=9.7467e-07 < tolerance=1e-06
# EM start iterations, llf=-3375.4
# EM iteration 50, llf=-3320.9, convergence criterion=2.1511e-06
# EM converged at iteration 72, llf=-3320.8, convergence criterion=9.7886e-07 < tolerance=1e-06
# EM start iterations, llf=-3376.4
# EM iteration 50, llf=-3321.8, convergence criterion=2.3668e-06
# EM converged at iteration 76, llf=-3321.7, convergence criterion=9.7408e-07 < tolerance=1e-06
# EM start iterations, llf=-3389.5
# EM iteration 50, llf=-3335.2, convergence criterion=2.3838e-06
# EM converged at iteration 76, llf=-3335, convergence criterion=9.8147e-07 < tolerance=1e-06
# EM start iterations, llf=-3389.5
# EM iteration 50, llf=-3335.2, convergence criterion=2.3838e-06
# EM converged at iteration 76, llf=-3335, convergence criterion=9.8147e-07 < tolerance=1e-06
# EM start iterations, llf=-3400.1
# EM iteration 50, llf=-3347.8, convergence criterion=2.3978e-06
# EM converged at iteration 75, llf=-3347.6, convergence criterion=9.9811e-07 < tolerance=1e-06
# EM start iterations, llf=-3400.1
# EM iteration 50, llf=-3347.8, convergence criterion=2.3978e-06
# EM converged at iteration 75, llf=-3347.6, convergence criterion=9.9811e-07 < tolerance=1e-06
# EM start iterations, llf=-3400.1
# EM iteration 50, llf=-3347.8, convergence criterion=2.3978e-06
# EM converged at iteration 75, llf=-3347.6, convergence criterion=9.9811e-07 < tolerance=1e-06
# EM start iterations, llf=-3402.5
# EM iteration 50, llf=-3351.9, convergence criterion=2.412e-06
# EM converged at iteration 75, llf=-3351.7, convergence criterion=9.8369e-07 < tolerance=1e-06
# EM start iterations, llf=-3403.7
# EM iteration 50, llf=-3353.1, convergence criterion=2.431e-06
# EM converged at iteration 75, llf=-3353, convergence criterion=9.9267e-07 < tolerance=1e-06
# EM start iterations, llf=-3408.2
# EM iteration 50, llf=-3358.4, convergence criterion=2.4177e-06
# EM converged at iteration 75, llf=-3358.3, convergence criterion=9.7426e-07 < tolerance=1e-06
# EM start iterations, llf=-3408.2
# EM iteration 50, llf=-3358.4, convergence criterion=2.4177e-06
# EM converged at iteration 75, llf=-3358.3, convergence criterion=9.7426e-07 < tolerance=1e-06
# EM start iterations, llf=-3422.6
# EM iteration 50, llf=-3372.2, convergence criterion=2.3852e-06
# EM converged at iteration 75, llf=-3372.1, convergence criterion=9.7445e-07 < tolerance=1e-06
# EM start iterations, llf=-3422.6
# EM iteration 50, llf=-3372.2, convergence criterion=2.3852e-06
# EM converged at iteration 75, llf=-3372.1, convergence criterion=9.7445e-07 < tolerance=1e-06
# EM start iterations, llf=-3422.6
# EM iteration 50, llf=-3372.2, convergence criterion=2.3852e-06
# EM converged at iteration 75, llf=-3372.1, convergence criterion=9.7445e-07 < tolerance=1e-06
# EM start iterations, llf=-3435.7
# EM iteration 50, llf=-3385.6, convergence criterion=2.366e-06
# EM converged at iteration 74, llf=-3385.5, convergence criterion=9.909e-07 < tolerance=1e-06
# EM start iterations, llf=-3437
# EM iteration 50, llf=-3386.9, convergence criterion=2.3978e-06
# EM converged at iteration 75, llf=-3386.7, convergence criterion=9.7836e-07 < tolerance=1e-06
# EM start iterations, llf=-3447
# EM iteration 50, llf=-3397, convergence criterion=2.3294e-06
# EM converged at iteration 74, llf=-3396.9, convergence criterion=9.858e-07 < tolerance=1e-06
# EM start iterations, llf=-3447
# EM iteration 50, llf=-3397, convergence criterion=2.3294e-06
# EM converged at iteration 74, llf=-3396.9, convergence criterion=9.858e-07 < tolerance=1e-06
# EM start iterations, llf=-3455.5
# EM iteration 50, llf=-3406.1, convergence criterion=2.2933e-06
# EM converged at iteration 73, llf=-3406, convergence criterion=9.9459e-07 < tolerance=1e-06
# EM start iterations, llf=-3455.5
# EM iteration 50, llf=-3406.1, convergence criterion=2.2933e-06
# EM converged at iteration 73, llf=-3406, convergence criterion=9.9459e-07 < tolerance=1e-06
# EM start iterations, llf=-3455.5
# EM iteration 50, llf=-3406.1, convergence criterion=2.2933e-06
# EM converged at iteration 73, llf=-3406, convergence criterion=9.9459e-07 < tolerance=1e-06
# EM start iterations, llf=-3470.8
# EM iteration 50, llf=-3421.1, convergence criterion=2.3248e-06
# EM converged at iteration 74, llf=-3420.9, convergence criterion=9.7241e-07 < tolerance=1e-06
# EM start iterations, llf=-3472.2
# EM iteration 50, llf=-3422.6, convergence criterion=2.2939e-06
# EM converged at iteration 73, llf=-3422.4, convergence criterion=9.9218e-07 < tolerance=1e-06
# EM start iterations, llf=-3485.7
# EM iteration 50, llf=-3435.8, convergence criterion=2.2836e-06
# EM converged at iteration 73, llf=-3435.7, convergence criterion=9.8721e-07 < tolerance=1e-06
# EM start iterations, llf=-3485.7
# EM iteration 50, llf=-3435.8, convergence criterion=2.2836e-06
# EM converged at iteration 73, llf=-3435.7, convergence criterion=9.8721e-07 < tolerance=1e-06
# EM start iterations, llf=-3497.3
# EM iteration 50, llf=-3447.4, convergence criterion=2.2795e-06
# EM converged at iteration 73, llf=-3447.2, convergence criterion=9.8588e-07 < tolerance=1e-06
# EM start iterations, llf=-3497.3
# EM iteration 50, llf=-3447.4, convergence criterion=2.2795e-06
# EM converged at iteration 73, llf=-3447.2, convergence criterion=9.8588e-07 < tolerance=1e-06
# EM start iterations, llf=-3497.3
# EM iteration 50, llf=-3447.4, convergence criterion=2.2795e-06
# EM converged at iteration 73, llf=-3447.2, convergence criterion=9.8588e-07 < tolerance=1e-06
# EM start iterations, llf=-3512
# EM iteration 50, llf=-3462.2, convergence criterion=2.2487e-06
# EM converged at iteration 73, llf=-3462.1, convergence criterion=9.8049e-07 < tolerance=1e-06
# EM start iterations, llf=-3513.7
# EM iteration 50, llf=-3463.8, convergence criterion=2.3036e-06
# ...
# EM converged at iteration 129, llf=-3472.4, convergence criterion=9.9896e-07 < tolerance=1e-06
# EM start iterations, llf=-3571.5
# EM iteration 50, llf=-3473.2, convergence criterion=8.5256e-06
# EM iteration 100, llf=-3472.5, convergence criterion=1.8546e-06
# EM converged at iteration 129, llf=-3472.4, convergence criterion=9.9896e-07 < tolerance=1e-06
# EM start iterations, llf=-3583
# EM iteration 50, llf=-3484.4, convergence criterion=7.8079e-06
# EM iteration 100, llf=-3483.7, convergence criterion=1.7636e-06
# EM converged at iteration 128, llf=-3483.6, convergence criterion=9.8286e-07 < tolerance=1e-06
# EM start iterations, llf=-3584.2
# EM iteration 50, llf=-3485.6, convergence criterion=7.8031e-06
# EM iteration 100, llf=-3484.9, convergence criterion=1.7637e-06
# EM converged at iteration 128, llf=-3484.8, convergence criterion=9.8297e-07 < tolerance=1e-06
# EM start iterations, llf=-3601.1
# EM iteration 50, llf=-3502.5, convergence criterion=7.846e-06
# EM iteration 100, llf=-3501.9, convergence criterion=1.7226e-06
# EM converged at iteration 126, llf=-3501.7, convergence criterion=9.9708e-07 < tolerance=1e-06
# EM start iterations, llf=-3601.1
# EM iteration 50, llf=-3502.5, convergence criterion=7.846e-06
# EM iteration 100, llf=-3501.9, convergence criterion=1.7226e-06
# EM converged at iteration 126, llf=-3501.7, convergence criterion=9.9708e-07 < tolerance=1e-06
# EM start iterations, llf=-3611.7
# EM iteration 50, llf=-3513.3, convergence criterion=7.8559e-06
# EM iteration 100, llf=-3512.7, convergence criterion=1.7102e-06
# EM converged at iteration 126, llf=-3512.6, convergence criterion=9.8857e-07 < tolerance=1e-06
# EM start iterations, llf=-3611.7
# EM iteration 50, llf=-3513.3, convergence criterion=7.8559e-06
# EM iteration 100, llf=-3512.7, convergence criterion=1.7102e-06
# EM converged at iteration 126, llf=-3512.6, convergence criterion=9.8857e-07 < tolerance=1e-06
# EM start iterations, llf=-3611.7
# EM iteration 50, llf=-3513.3, convergence criterion=7.8559e-06
# EM iteration 100, llf=-3512.7, convergence criterion=1.7102e-06
# EM converged at iteration 126, llf=-3512.6, convergence criterion=9.8857e-07 < tolerance=1e-06
# EM start iterations, llf=-3622
# EM iteration 50, llf=-3523.6, convergence criterion=7.8366e-06
# EM iteration 100, llf=-3522.9, convergence criterion=1.6981e-06
# EM converged at iteration 125, llf=-3522.8, convergence criterion=9.9903e-07 < tolerance=1e-06
# EM start iterations, llf=-3623.4
# EM iteration 50, llf=-3524.9, convergence criterion=7.8923e-06
# EM iteration 100, llf=-3524.2, convergence criterion=1.7088e-06
# EM converged at iteration 126, llf=-3524.1, convergence criterion=9.8692e-07 < tolerance=1e-06
# EM start iterations, llf=-3634.7
# EM iteration 50, llf=-3536.1, convergence criterion=7.8828e-06
# EM iteration 100, llf=-3535.5, convergence criterion=1.6896e-06
# EM converged at iteration 125, llf=-3535.4, convergence criterion=9.9386e-07 < tolerance=1e-06
# EM start iterations, llf=-3634.7
# EM iteration 50, llf=-3536.1, convergence criterion=7.8828e-06
# EM iteration 100, llf=-3535.5, convergence criterion=1.6896e-06
# EM converged at iteration 125, llf=-3535.4, convergence criterion=9.9386e-07 < tolerance=1e-06
# EM start iterations, llf=-3645.1
# EM iteration 50, llf=-3546.2, convergence criterion=7.9342e-06
# EM iteration 100, llf=-3545.5, convergence criterion=1.6914e-06
# EM converged at iteration 125, llf=-3545.4, convergence criterion=9.942e-07 < tolerance=1e-06
# EM start iterations, llf=-3645.1
# EM iteration 50, llf=-3546.2, convergence criterion=7.9342e-06
# EM iteration 100, llf=-3545.5, convergence criterion=1.6914e-06
# EM converged at iteration 125, llf=-3545.4, convergence criterion=9.942e-07 < tolerance=1e-06
# EM start iterations, llf=-3645.1
# EM iteration 50, llf=-3546.2, convergence criterion=7.9342e-06
# EM iteration 100, llf=-3545.5, convergence criterion=1.6914e-06
# EM converged at iteration 125, llf=-3545.4, convergence criterion=9.942e-07 < tolerance=1e-06
# EM start iterations, llf=-3656.1
# EM iteration 50, llf=-3557, convergence criterion=7.9734e-06
# EM iteration 100, llf=-3556.3, convergence criterion=1.6913e-06
# EM converged at iteration 125, llf=-3556.2, convergence criterion=9.9127e-07 < tolerance=1e-06
# EM start iterations, llf=-3657.3
# EM iteration 50, llf=-3558.1, convergence criterion=7.9954e-06
# EM iteration 100, llf=-3557.5, convergence criterion=1.6977e-06
# EM converged at iteration 125, llf=-3557.3, convergence criterion=9.9567e-07 < tolerance=1e-06
# EM start iterations, llf=-3667.3
# EM iteration 50, llf=-3567.9, convergence criterion=7.9836e-06
# EM iteration 100, llf=-3567.2, convergence criterion=1.6974e-06
# EM converged at iteration 125, llf=-3567.1, convergence criterion=9.954e-07 < tolerance=1e-06
# EM start iterations, llf=-3667.3
# EM iteration 50, llf=-3567.9, convergence criterion=7.9836e-06
# EM iteration 100, llf=-3567.2, convergence criterion=1.6974e-06
# EM converged at iteration 125, llf=-3567.1, convergence criterion=9.954e-07 < tolerance=1e-06
# EM start iterations, llf=-3678.1
# EM iteration 50, llf=-3578.5, convergence criterion=7.9877e-06
# EM iteration 100, llf=-3577.8, convergence criterion=1.6908e-06
# EM converged at iteration 125, llf=-3577.7, convergence criterion=9.8927e-07 < tolerance=1e-06
# EM start iterations, llf=-3678.1
# EM iteration 50, llf=-3578.5, convergence criterion=7.9877e-06
# EM iteration 100, llf=-3577.8, convergence criterion=1.6908e-06
# EM converged at iteration 125, llf=-3577.7, convergence criterion=9.8927e-07 < tolerance=1e-06
# EM start iterations, llf=-3678.1
# EM iteration 50, llf=-3578.5, convergence criterion=7.9877e-06
# EM iteration 100, llf=-3577.8, convergence criterion=1.6908e-06
# EM converged at iteration 125, llf=-3577.7, convergence criterion=9.8927e-07 < tolerance=1e-06
# EM start iterations, llf=-3689.8
# EM iteration 50, llf=-3590.3, convergence criterion=7.9525e-06
# EM iteration 100, llf=-3589.6, convergence criterion=1.6941e-06
# EM converged at iteration 125, llf=-3589.5, convergence criterion=9.9065e-07 < tolerance=1e-06
# EM start iterations, llf=-3690.8
# EM iteration 50, llf=-3591.3, convergence criterion=7.8476e-06
# EM iteration 100, llf=-3590.6, convergence criterion=1.6772e-06
# EM converged at iteration 125, llf=-3590.5, convergence criterion=9.8256e-07 < tolerance=1e-06
# EM start iterations, llf=-3702.9
# EM iteration 50, llf=-3603.2, convergence criterion=7.807e-06
# EM iteration 100, llf=-3602.6, convergence criterion=1.642e-06
# EM converged at iteration 123, llf=-3602.5, convergence criterion=9.9195e-07 < tolerance=1e-06
# EM start iterations, llf=-3702.9
# EM iteration 50, llf=-3603.2, convergence criterion=7.807e-06
# EM iteration 100, llf=-3602.6, convergence criterion=1.642e-06
# EM converged at iteration 123, llf=-3602.5, convergence criterion=9.9195e-07 < tolerance=1e-06
# EM start iterations, llf=-3715.8
# EM iteration 50, llf=-3615.7, convergence criterion=7.7583e-06
# EM iteration 100, llf=-3615, convergence criterion=1.618e-06
# EM converged at iteration 122, llf=-3614.9, convergence criterion=9.9786e-07 < tolerance=1e-06
# EM start iterations, llf=-3715.8
# EM iteration 50, llf=-3615.7, convergence criterion=7.7583e-06
# EM iteration 100, llf=-3615, convergence criterion=1.618e-06
# EM converged at iteration 122, llf=-3614.9, convergence criterion=9.9786e-07 < tolerance=1e-06
# EM start iterations, llf=-3715.8
# EM iteration 50, llf=-3615.7, convergence criterion=7.7583e-06
# EM iteration 100, llf=-3615, convergence criterion=1.618e-06
# EM converged at iteration 122, llf=-3614.9, convergence criterion=9.9786e-07 < tolerance=1e-06
# EM start iterations, llf=-3728
# EM iteration 50, llf=-3627.7, convergence criterion=7.6574e-06
# EM iteration 100, llf=-3627.1, convergence criterion=1.6091e-06
# EM converged at iteration 122, llf=-3627, convergence criterion=9.9154e-07 < tolerance=1e-06
# EM start iterations, llf=-3729.1
# EM iteration 50, llf=-3628.8, convergence criterion=7.6861e-06
# EM iteration 100, llf=-3628.1, convergence criterion=1.6146e-06
# EM converged at iteration 122, llf=-3628, convergence criterion=9.9484e-07 < tolerance=1e-06
# EM start iterations, llf=-3741.4
# EM iteration 50, llf=-3640.8, convergence criterion=7.8385e-06
# EM iteration 100, llf=-3640.1, convergence criterion=1.6634e-06
# EM converged at iteration 124, llf=-3640, convergence criterion=9.8833e-07 < tolerance=1e-06
# EM start iterations, llf=-3741.4
# EM iteration 50, llf=-3640.8, convergence criterion=7.8385e-06
# EM iteration 100, llf=-3640.1, convergence criterion=1.6634e-06
# EM converged at iteration 124, llf=-3640, convergence criterion=9.8833e-07 < tolerance=1e-06
# EM start iterations, llf=-3753.9
# EM iteration 50, llf=-3653.2, convergence criterion=7.896e-06
# EM iteration 100, llf=-3652.5, convergence criterion=1.6872e-06
# EM converged at iteration 125, llf=-3652.4, convergence criterion=9.8728e-07 < tolerance=1e-06
# EM start iterations, llf=-3753.9
# EM iteration 50, llf=-3653.2, convergence criterion=7.896e-06
# EM iteration 100, llf=-3652.5, convergence criterion=1.6872e-06
# EM converged at iteration 125, llf=-3652.4, convergence criterion=9.8728e-07 < tolerance=1e-06
# EM start iterations, llf=-3753.9
# EM iteration 50, llf=-3653.2, convergence criterion=7.896e-06
# EM iteration 100, llf=-3652.5, convergence criterion=1.6872e-06
# EM converged at iteration 125, llf=-3652.4, convergence criterion=9.8728e-07 < tolerance=1e-06
# EM start iterations, llf=-3766.7
# EM iteration 50, llf=-3665.8, convergence criterion=7.8183e-06
# EM iteration 100, llf=-3665.1, convergence criterion=1.6887e-06
# EM converged at iteration 125, llf=-3665, convergence criterion=9.9013e-07 < tolerance=1e-06
# EM start iterations, llf=-3767.9
# EM iteration 50, llf=-3667, convergence criterion=7.855e-06
# EM iteration 100, llf=-3666.3, convergence criterion=1.6979e-06
# EM converged at iteration 125, llf=-3666.2, convergence criterion=9.9601e-07 < tolerance=1e-06
# EM start iterations, llf=-3781
# EM iteration 50, llf=-3679.6, convergence criterion=7.8521e-06
# EM iteration 100, llf=-3678.9, convergence criterion=1.6872e-06
# EM converged at iteration 125, llf=-3678.8, convergence criterion=9.9063e-07 < tolerance=1e-06
# EM start iterations, llf=-3781
# EM iteration 50, llf=-3679.6, convergence criterion=7.8521e-06
# EM iteration 100, llf=-3678.9, convergence criterion=1.6872e-06
# EM converged at iteration 125, llf=-3678.8, convergence criterion=9.9063e-07 < tolerance=1e-06
# EM start iterations, llf=-3793.7
# EM iteration 50, llf=-3692.1, convergence criterion=7.9541e-06
# EM iteration 100, llf=-3691.4, convergence criterion=1.7162e-06
# EM converged at iteration 126, llf=-3691.3, convergence criterion=9.8952e-07 < tolerance=1e-06
# EM start iterations, llf=-3793.7
# EM iteration 50, llf=-3692.1, convergence criterion=7.9541e-06
# EM iteration 100, llf=-3691.4, convergence criterion=1.7162e-06
# EM converged at iteration 126, llf=-3691.3, convergence criterion=9.8952e-07 < tolerance=1e-06
# EM start iterations, llf=-3793.7
# EM iteration 50, llf=-3692.1, convergence criterion=7.9541e-06
# EM iteration 100, llf=-3691.4, convergence criterion=1.7162e-06
# EM converged at iteration 126, llf=-3691.3, convergence criterion=9.8952e-07 < tolerance=1e-06
# EM start iterations, llf=-3806.4
# EM iteration 50, llf=-3704.6, convergence criterion=7.8296e-06
# EM iteration 100, llf=-3703.9, convergence criterion=1.6539e-06
# EM converged at iteration 123, llf=-3703.8, convergence criterion=9.9635e-07 < tolerance=1e-06
# EM start iterations, llf=-3807.7
# EM iteration 50, llf=-3705.9, convergence criterion=7.8363e-06
# EM iteration 100, llf=-3705.2, convergence criterion=1.657e-06
# EM converged at iteration 123, llf=-3705.1, convergence criterion=9.9871e-07 < tolerance=1e-06
# EM start iterations, llf=-3819.1
# EM iteration 50, llf=-3717.3, convergence criterion=7.5028e-06
# EM iteration 100, llf=-3716.7, convergence criterion=1.6491e-06
# EM converged at iteration 124, llf=-3716.6, convergence criterion=9.8686e-07 < tolerance=1e-06
# EM start iterations, llf=-3819.1
# EM iteration 50, llf=-3717.3, convergence criterion=7.5028e-06
# EM iteration 100, llf=-3716.7, convergence criterion=1.6491e-06
# EM converged at iteration 124, llf=-3716.6, convergence criterion=9.8686e-07 < tolerance=1e-06
# EM start iterations, llf=-3831.4
# EM iteration 50, llf=-3729.8, convergence criterion=7.4343e-06
# EM iteration 100, llf=-3729.2, convergence criterion=1.58e-06
# EM converged at iteration 121, llf=-3729.1, convergence criterion=9.9569e-07 < tolerance=1e-06
# EM start iterations, llf=-3831.4
# EM iteration 50, llf=-3729.8, convergence criterion=7.4343e-06
# EM iteration 100, llf=-3729.2, convergence criterion=1.58e-06
# EM converged at iteration 121, llf=-3729.1, convergence criterion=9.9569e-07 < tolerance=1e-06
# EM start iterations, llf=-3831.4
# EM iteration 50, llf=-3729.8, convergence criterion=7.4343e-06
# EM iteration 100, llf=-3729.2, convergence criterion=1.58e-06
# EM converged at iteration 121, llf=-3729.1, convergence criterion=9.9569e-07 < tolerance=1e-06
# EM start iterations, llf=-3842.1
# EM iteration 50, llf=-3740.5, convergence criterion=7.2577e-06
# EM iteration 100, llf=-3739.9, convergence criterion=1.5453e-06
# EM converged at iteration 120, llf=-3739.8, convergence criterion=9.9818e-07 < tolerance=1e-06
# EM start iterations, llf=-3843.8
# EM iteration 50, llf=-3742.4, convergence criterion=7.2911e-06
# EM iteration 100, llf=-3741.7, convergence criterion=1.5472e-06
# EM converged at iteration 120, llf=-3741.6, convergence criterion=9.9807e-07 < tolerance=1e-06
# EM start iterations, llf=-3858.7
# EM iteration 50, llf=-3757.1, convergence criterion=7.4681e-06
# EM iteration 100, llf=-3756.5, convergence criterion=1.5933e-06
# EM converged at iteration 122, llf=-3756.4, convergence criterion=9.9324e-07 < tolerance=1e-06
# EM start iterations, llf=-3858.7
# EM iteration 50, llf=-3757.1, convergence criterion=7.4681e-06
# EM iteration 100, llf=-3756.5, convergence criterion=1.5933e-06
# EM converged at iteration 122, llf=-3756.4, convergence criterion=9.9324e-07 < tolerance=1e-06
# EM start iterations, llf=-3872.5
# EM iteration 50, llf=-3771.6, convergence criterion=6.8299e-06
# EM iteration 100, llf=-3771, convergence criterion=1.4981e-06
# EM converged at iteration 119, llf=-3770.9, convergence criterion=9.9178e-07 < tolerance=1e-06
# EM start iterations, llf=-3872.5
# EM iteration 50, llf=-3771.6, convergence criterion=6.8299e-06
# EM iteration 100, llf=-3771, convergence criterion=1.4981e-06
# EM converged at iteration 119, llf=-3770.9, convergence criterion=9.9178e-07 < tolerance=1e-06
# EM start iterations, llf=-3872.5
# EM iteration 50, llf=-3771.6, convergence criterion=6.8299e-06
# EM iteration 100, llf=-3771, convergence criterion=1.4981e-06
# EM converged at iteration 119, llf=-3770.9, convergence criterion=9.9178e-07 < tolerance=1e-06
# EM start iterations, llf=-3882.8
# EM iteration 50, llf=-3781.8, convergence criterion=6.9189e-06
# EM iteration 100, llf=-3781.2, convergence criterion=1.534e-06
# EM converged at iteration 120, llf=-3781.1, convergence criterion=9.9645e-07 < tolerance=1e-06
# EM start iterations, llf=-3884.1
# EM iteration 50, llf=-3783, convergence criterion=6.9149e-06
# EM iteration 100, llf=-3782.4, convergence criterion=1.5334e-06
# EM converged at iteration 120, llf=-3782.3, convergence criterion=9.9641e-07 < tolerance=1e-06
# EM start iterations, llf=-3897.8
# EM iteration 50, llf=-3796.4, convergence criterion=6.9462e-06
# EM iteration 100, llf=-3795.8, convergence criterion=1.537e-06
# EM converged at iteration 120, llf=-3795.7, convergence criterion=9.9987e-07 < tolerance=1e-06
# EM start iterations, llf=-3897.8
# EM iteration 50, llf=-3796.4, convergence criterion=6.9462e-06
# EM iteration 100, llf=-3795.8, convergence criterion=1.537e-06
# EM converged at iteration 120, llf=-3795.7, convergence criterion=9.9987e-07 < tolerance=1e-06
# EM start iterations, llf=-3914.4
# EM iteration 50, llf=-3813.4, convergence criterion=6.5199e-06
# EM iteration 100, llf=-3812.8, convergence criterion=1.4608e-06
# EM converged at iteration 118, llf=-3812.7, convergence criterion=9.8386e-07 < tolerance=1e-06
# Model with Global factors = 2 and order = 3 estimated in 1:58:42.288089.
# Overall time taken for running all models: 3:19:40.423141.

# %% [markdown]
# Plot MSE values for the models with 1 or 2 Global factors evaluated over the 2008–2018 period.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]
q_var = 'GDP'
text_type = "topics"
estimation_period = "2007"
num_topics = "200"
source = "all"

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Define the directory containing MSE files
mse_dir = f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"

# Create a figure with 1 row and 2 columns of subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Loop over each number of global factors (1 and 2)
for i, num_factors in enumerate(range(1, 3)):
    ax = axs[i]
    
    order = 3

    # Construct file name based on the model's parameters
    factors_str = f"Global_{num_factors}_{order}"
    mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
    mse_file_path = os.path.join(mse_dir, mse_file_name)

    # Load the MSE values from file
    mse_df = pd.read_csv(mse_file_path)
    # Construct y values based on the vintages
    y_values = [mse_df[col].iloc[0] for col in vintage_col_names]

    # Extend the y-values so the step function holds the last value
    y_extended = y_values.copy()
    y_extended.append(y_values[-1]) # Repeat the last value

    # Plot the step function for the current model
    ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
             label=f"Order: {order}")

    # Customize the subplot
    ax.set_xlabel("Month of Quarter")
    # Set ticks only at 1, 2, and 3 to mark the beginning of each month
    ax.set_xticks([1, 2, 3])
    ax.set_xlim(0.9, 4.1)
    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    if i == 0:  # Only the leftmost subplot gets the y-axis label
        ax.set_ylabel("MSE")
    ax.legend()

plt.suptitle(f"MSE for the Models with 1 or 2 Global Factors and Lag Order 3 ({q_var}, 2008-2018)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_2008-2018_{q_var}")
plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot MSE values for the models with 1 or 2 Global Factors and Lag Order 3 evaluated over the 2008–2010 and 2011-2018 periods.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics"
estimation_period = "2007"
num_topics = "200"
source = "all"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Define two periods
periods = {
    "2008-2010": lambda df: df["date_float"] < 2011,
    "2011-2018": lambda df: df["date_float"] >= 2011
}

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Loop over each period and create a separate figure
for period_label, period_filter in periods.items():
    
    # Create a figure with 1 row and 2 columns of subplots
    fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)
    
    # Loop over each number of global factors (1 and 2)
    for i, num_factors in enumerate(range(1, 3)):
        ax = axs[i]
        
        order = 3

        # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
        factors_str = f"Global_{num_factors}_{order}"
        forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
        forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

        # Load forecast data 
        forecasts = pd.read_csv(forecast_file_path, index_col=0)
        forecasts.index.name = "date"
        forecasts.reset_index(inplace=True)

        # Merge forecasts with actual growth 
        merged = pd.merge(forecasts, actual_growth, on="date", how="inner")
        merged["date_float"] = merged["date"].apply(quarter_to_float)
        merged.sort_values("date_float", inplace=True)

        # Filter merged data for the current period
        merged_period = merged[ period_filter(merged) ]

        # Calculate MSE for each vintage column over the filtered period
        mse_dict = {}
        for col in vintage_col_names:
            mse = ((merged_period[col] - merged_period["growth"]) ** 2).mean()
            mse_dict[col] = mse

        # Construct y values based on the vintages
        y_values = [mse_dict[col] for col in vintage_col_names]

        # Extend the y-values so the step function holds the last value
        y_extended = y_values.copy()
        y_extended.append(y_values[-1]) # Repeat the last value

        # Plot the step function for the current model (order)
        ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
                label=f"Order: {order}")

        # Customize the subplot
        ax.set_xlabel("Month of Quarter")
        # Set ticks only at 1, 2, and 3 to mark the beginning of each month
        ax.set_xticks([1, 2, 3])
        ax.set_xlim(0.9, 4.1)
        ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
        if i == 0:  # Only the leftmost subplot gets the y-axis label
            ax.set_ylabel("MSE")
        ax.legend()
   
    plt.suptitle(f"MSE for the Models with 1 or 2 Global Factors and Lag Order 3 ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot forecasts vs actual growth values for the models with 1 or 2 Global Factors, Lag Order 3 and different time periods (2008-2010, 2008-2018, and 2011-2018).

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Convert quarter strings like "2008-03" into a float (e.g. 2008.00 for Q1, 2008.25 for Q2, etc.)
def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics"
estimation_period = "2007"
num_topics = "200"
source = "all"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Assign 7 small offsets within each quarter, so each quarter has 7 forecast points
offsets = np.linspace(0, 0.23, 7)

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Build x,y arrays for the actual growth
x_act = actual_growth["date_float"].tolist()
y_act = actual_growth["growth"].tolist()

# Define period configurations: x-axis limits and tick positions for each period
period_configs = {
    "2008-2010": {"xlim": (2008, 2010.99), "xticks": list(range(2008, 2011))},
    "2008-2018": {"xlim": (2008, 2018.99), "xticks": list(range(2008, 2019))},
    "2011-2018": {"xlim": (2011, 2018.99), "xticks": list(range(2011, 2019))}
}

# Loop over each period configuration to create and save separate plots
for period_label, config in period_configs.items():
    
    # Extend the actual growth arrays so that the step function continues until the end of the x-axis
    if period_label in ["2008-2018", "2011-2018"]:
        x_act_extended = x_act.copy()
        x_act_extended.append(config["xlim"][1])
        y_act_extended = y_act.copy()
        y_act_extended.append(y_act[-1])
    else:
        x_act_extended = x_act
        y_act_extended = y_act

    # Create a figure with 1 row and 2 columns for the three global factor counts
    fig, axs = plt.subplots(1, 2, figsize=(18, 8), sharey=True)
    
    # Loop over each global factor count (1 and 2)
    for i, num_factors in enumerate([1, 2]):
        ax = axs[i]

        order = 3

        # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
        factors_str = f"Global_{num_factors}_{order}"
        forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
        forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

        # Load forecast data 
        forecasts = pd.read_csv(forecast_file_path, index_col=0)
        forecasts.index.name = "date"
        forecasts.reset_index(inplace=True)

        # Merge forecasts with actual growth dates
        merged = pd.merge(forecasts, actual_growth[['date']], on="date", how="inner")
        merged["date_float"] = merged["date"].apply(quarter_to_float)
        merged.sort_values("date_float", inplace=True)

        # Build forecast x and y arrays 
        x_fore = []
        y_fore = []
        for idx, row in merged.iterrows():
            base_x = row["date_float"]
            # For each of the 7 vintage columns, define an x-position and take that forecast value
            for j, col in enumerate(vintage_col_names):
                x_fore.append(base_x + offsets[j])
                y_fore.append(row[col])

        # Plot the forecast step curve for the current order
        ax.step(x_fore, y_fore, where='post', linewidth=1.2, label=f"Order: {order}")

        # Plot actual growth as a step plot in each subplot
        ax.step(x_act_extended, y_act_extended, where='post', color='black', linewidth=1.2, label="Actual growth")

        # Customize the subplot
        ax.set_xlabel("Year")
        ax.set_xlim(config["xlim"][0], config["xlim"][1])
        ax.set_xticks(config["xticks"])

        # Set y-axis limits based on the data within the period range
        x_min, x_max = config["xlim"]
        def filter_points(x_arr, y_arr, x_min, x_max):
            return [y for x, y in zip(x_arr, y_arr) if x_min <= x <= x_max]

        # Filter y-values
        y_filtered = filter_points(x_fore, y_fore, x_min, x_max)
        y_act_filtered = filter_points(x_act_extended, y_act_extended, x_min, x_max)

        # Combine all filtered y-values
        combined_y = y_filtered + y_act_filtered
        ax.set_ylim(1.05 * min(combined_y), 1.2 * max(combined_y))

        ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
        if i == 0:
            ax.set_ylabel("Annualized q-o-q Growth (%)")
        ax.legend()
        
    plt.suptitle(f"Forecast vs Actual Growth for the Models with 1 or 2 Global Factors and Lag Order 3 ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_forecast_vs_actual_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
