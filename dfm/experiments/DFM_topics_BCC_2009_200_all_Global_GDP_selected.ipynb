# %% [markdown]
# # Out-of-sample forecasting experiments
#
# I conduct out-of-sample forecasting experiments to understand what kind of text data (topics, sentiment, or uncertainty) helps improve forecasts of three quarterly variables (GDP, Investment, and Consumption) more.
#
# In this notebook, I evaluate the performance of dynamic factor models (DFM) using hard data, survey information, and 10 pre-selected sign-adjusted topics (BCC) (out of 200 topics estimated on articles published before 2010 using all sources). I forecast GDP growth and integrate text data into economic forecasting.
#
# ## Experiment Details
#
# - **Data Sources:** Hard data, surveys, 10 pre-selected sign-adjusted topics, BCC (<=2009, 200 topics, all sources).
# - **Forecast Target:** GDP growth.
# - **Model:** Dynamic Factor Models (DFM).
# - **Parameters Explored:**
#   - **Number of Global Factors:** 1 to 3
#   - **Factor Order:** 1 to 3 (for each number of factors)

# %%
import os
import time
import datetime
import pandas as pd
import DFM_function

# Define inputs common to all models
q_var = 'GDP'                      # quarterly variable being forecasted
additional_factors = None          # or "all" or e.g. ['Labor market']
start = '1991-04'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
with_text = True

# Generate list of forecast_month strings for quarters from 2008Q1 to 2018Q4
# forecast_month is set to the month corresponding to quarter-end:
# Q1: 'YYYY-03', Q2: 'YYYY-06', Q3: 'YYYY-09', Q4: 'YYYY-12'
forecast_months = []
for year in range(2008, 2019):
    forecast_months.extend([f"{year}-03", f"{year}-06", f"{year}-09", f"{year}-12"])
    
# Define the vintage column names 
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Create directories to save forecasts and MSE results
os.makedirs(f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
os.makedirs(f"../MSE/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)

# Load the actual growth data
actual_growth_file = f"../{q_var}_growth_actual.csv"
actual_growth = pd.read_csv(actual_growth_file)

# Record overall start time
overall_start = time.time()

# Loop over the number of factors and factor order values from 1 to 3
for num_factors in range(1, 4):  # Varying number of Global factors: 1, 2, 3
    for order in range(1, 4):    # Varying factor order: 1, 2, 3
        
        # Define model-specific parameters
        factor_multiplicities = {'Global': num_factors}
        factor_orders = {'Global': order}

        # Prepare lists to store each quarter's forecasts and row labels
        forecasts_all_quarters = []
        row_labels = []
        
        # Start timing for this model
        start_time = time.time()

        # Loop over each forecast month, get the forecasts, and store the results
        for fm in forecast_months:
            # Use the forecast_month string as the row label
            row_labels.append(fm)

            # Run the forecast function for this quarter
            forecasts_dict = DFM_function.get_forecasts(
                forecast_month = fm,
                q_var = q_var,
                additional_factors = additional_factors,
                factor_multiplicities = factor_multiplicities,
                factor_orders = factor_orders,
                start = start,
                text_type = text_type,
                estimation_period = estimation_period,
                num_topics = num_topics,
                source = source,
                selected = selected,
                with_text = with_text
            )

            # Obtain the correct ordering of vintages
            vintages_order = DFM_function.vintage_dates(fm)
            # Extract the forecast value for each vintage in that order
            quarter_forecasts = [forecasts_dict[vint] for vint in vintages_order]
            forecasts_all_quarters.append(quarter_forecasts)

        # Create a DataFrame with rows labeled by the forecast_month strings and columns as vintage names
        results = pd.DataFrame(forecasts_all_quarters, index=row_labels, columns=vintage_col_names)
        
        # Stop timing for this model and print elapsed time
        elapsed = time.time() - start_time
        elapsed_time = datetime.timedelta(seconds=elapsed)
        print(f"Model with Global factors = {num_factors} and order = {order} estimated in {elapsed_time}.")

        # Construct the output file name
        factors_str = "_".join([
            f"{factor.replace(' ', '_')}_{factor_multiplicities[factor]}_{factor_orders[factor]}"
            for factor in factor_multiplicities])
        file_name = f"forecasts_{q_var}_{factors_str}.csv"

        # Save the CSV file in a subfolder 
        output_path = os.path.join(f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", file_name)
        results.to_csv(output_path, index=True)
        
        # ----- MSE Calculation -----
        # Load forecasts
        forecasts = pd.read_csv(output_path, index_col=0)
        # Make sure the index is a column named "date"
        forecasts.index.name = "date"
        forecasts.reset_index(inplace=True)

        # Merge dfs by date 
        merged = pd.merge(forecasts, actual_growth, on="date", how="inner")

        # Calculate the Mean Squared Error (MSE) for each vintage column
        mse_dict = {}
        for col in vintage_col_names:
            mse = ((merged[col] - merged["growth"]) ** 2).mean()
            mse_dict[col] = mse

        # Create a df with one row (the MSE values for each forecasting horizon)
        mse_df = pd.DataFrame(mse_dict, index=[0])

        # Save MSE results to CSV
        mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
        mse_output_path = os.path.join(f"../MSE/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", mse_file_name)
        mse_df.to_csv(mse_output_path, index=False)
        
# Stop overall timing and print overall elapsed time
overall_elapsed = time.time() - overall_start
overall_elapsed_time = datetime.timedelta(seconds=overall_elapsed)
print(f"Overall time taken for running all models: {overall_elapsed_time}.")
# Out:
# EM start iterations, llf=-11835
# EM iteration 50, llf=-11673, convergence criterion=1.4425e-06
# EM converged at iteration 61, llf=-11673, convergence criterion=9.6674e-07 < tolerance=1e-06
# EM start iterations, llf=-11847
# EM iteration 50, llf=-11684, convergence criterion=1.444e-06
# EM converged at iteration 61, llf=-11684, convergence criterion=9.6781e-07 < tolerance=1e-06
# EM start iterations, llf=-11904
# EM iteration 50, llf=-11739, convergence criterion=1.4468e-06
# EM converged at iteration 61, llf=-11739, convergence criterion=9.6963e-07 < tolerance=1e-06
# EM start iterations, llf=-11912
# EM iteration 50, llf=-11747, convergence criterion=1.4402e-06
# EM converged at iteration 60, llf=-11747, convergence criterion=9.9885e-07 < tolerance=1e-06
# EM start iterations, llf=-11978
# EM iteration 50, llf=-11812, convergence criterion=1.4505e-06
# EM converged at iteration 61, llf=-11811, convergence criterion=9.7251e-07 < tolerance=1e-06
# EM start iterations, llf=-11986
# EM iteration 50, llf=-11821, convergence criterion=1.4506e-06
# EM converged at iteration 61, llf=-11821, convergence criterion=9.7249e-07 < tolerance=1e-06
# EM start iterations, llf=-12043
# EM iteration 50, llf=-11880, convergence criterion=1.4201e-06
# EM converged at iteration 60, llf=-11880, convergence criterion=9.8435e-07 < tolerance=1e-06
# EM start iterations, llf=-12043
# EM iteration 50, llf=-11880, convergence criterion=1.4201e-06
# EM converged at iteration 60, llf=-11880, convergence criterion=9.8435e-07 < tolerance=1e-06
# EM start iterations, llf=-12050
# EM iteration 50, llf=-11887, convergence criterion=1.4256e-06
# EM converged at iteration 60, llf=-11886, convergence criterion=9.8821e-07 < tolerance=1e-06
# EM start iterations, llf=-12105
# EM iteration 50, llf=-11939, convergence criterion=1.4362e-06
# EM converged at iteration 60, llf=-11939, convergence criterion=9.9553e-07 < tolerance=1e-06
# EM start iterations, llf=-12113
# EM iteration 50, llf=-11947, convergence criterion=1.2932e-06
# EM converged at iteration 57, llf=-11947, convergence criterion=9.9089e-07 < tolerance=1e-06
# EM start iterations, llf=-12155
# EM iteration 50, llf=-11985, convergence criterion=1.3029e-06
# EM converged at iteration 57, llf=-11985, convergence criterion=9.9783e-07 < tolerance=1e-06
# EM start iterations, llf=-12165
# EM iteration 50, llf=-11996, convergence criterion=1.3028e-06
# EM converged at iteration 57, llf=-11996, convergence criterion=9.9783e-07 < tolerance=1e-06
# EM start iterations, llf=-12213
# EM iteration 50, llf=-12040, convergence criterion=1.3324e-06
# EM converged at iteration 58, llf=-12040, convergence criterion=9.836e-07 < tolerance=1e-06
# EM start iterations, llf=-12213
# EM iteration 50, llf=-12040, convergence criterion=1.3324e-06
# EM converged at iteration 58, llf=-12040, convergence criterion=9.836e-07 < tolerance=1e-06
# EM start iterations, llf=-12225
# EM iteration 50, llf=-12048, convergence criterion=1.3551e-06
# EM converged at iteration 58, llf=-12047, convergence criterion=9.9968e-07 < tolerance=1e-06
# EM start iterations, llf=-12269
# EM iteration 50, llf=-12091, convergence criterion=1.3574e-06
# EM converged at iteration 59, llf=-12091, convergence criterion=9.6618e-07 < tolerance=1e-06
# EM start iterations, llf=-12284
# EM converged at iteration 43, llf=-12108, convergence criterion=9.6387e-07 < tolerance=1e-06
# EM start iterations, llf=-12328
# EM converged at iteration 43, llf=-12146, convergence criterion=9.8598e-07 < tolerance=1e-06
# EM start iterations, llf=-12336
# EM converged at iteration 43, llf=-12153, convergence criterion=9.8556e-07 < tolerance=1e-06
# EM start iterations, llf=-12403
# EM converged at iteration 42, llf=-12225, convergence criterion=9.9074e-07 < tolerance=1e-06
# EM start iterations, llf=-12403
# EM converged at iteration 42, llf=-12225, convergence criterion=9.9074e-07 < tolerance=1e-06
# EM start iterations, llf=-12403
# EM converged at iteration 43, llf=-12220, convergence criterion=9.7362e-07 < tolerance=1e-06
# EM start iterations, llf=-12463
# EM converged at iteration 40, llf=-12305, convergence criterion=9.6386e-07 < tolerance=1e-06
# EM start iterations, llf=-12472
# EM converged at iteration 43, llf=-12324, convergence criterion=9.8475e-07 < tolerance=1e-06
# EM start iterations, llf=-12443
# EM converged at iteration 42, llf=-12302, convergence criterion=9.6216e-07 < tolerance=1e-06
# EM start iterations, llf=-12445
# EM converged at iteration 42, llf=-12304, convergence criterion=9.8186e-07 < tolerance=1e-06
# EM start iterations, llf=-12434
# EM converged at iteration 42, llf=-12300, convergence criterion=9.8668e-07 < tolerance=1e-06
# EM start iterations, llf=-12434
# EM converged at iteration 42, llf=-12300, convergence criterion=9.8668e-07 < tolerance=1e-06
# EM start iterations, llf=-12428
# EM converged at iteration 42, llf=-12294, convergence criterion=9.7175e-07 < tolerance=1e-06
# EM start iterations, llf=-12473
# EM converged at iteration 42, llf=-12344, convergence criterion=9.6115e-07 < tolerance=1e-06
# EM start iterations, llf=-12468
# EM converged at iteration 37, llf=-12340, convergence criterion=9.5752e-07 < tolerance=1e-06
# EM start iterations, llf=-12474
# EM converged at iteration 36, llf=-12345, convergence criterion=9.8517e-07 < tolerance=1e-06
# EM start iterations, llf=-12479
# EM converged at iteration 36, llf=-12343, convergence criterion=9.6542e-07 < tolerance=1e-06
# EM start iterations, llf=-12487
# EM converged at iteration 37, llf=-12346, convergence criterion=9.8008e-07 < tolerance=1e-06
# EM start iterations, llf=-12487
# EM converged at iteration 37, llf=-12346, convergence criterion=9.8008e-07 < tolerance=1e-06
# EM start iterations, llf=-12497
# EM converged at iteration 37, llf=-12356, convergence criterion=9.6377e-07 < tolerance=1e-06
# EM start iterations, llf=-12547
# EM converged at iteration 36, llf=-12410, convergence criterion=9.7555e-07 < tolerance=1e-06
# EM start iterations, llf=-12554
# EM converged at iteration 36, llf=-12418, convergence criterion=9.4394e-07 < tolerance=1e-06
# EM start iterations, llf=-12599
# EM converged at iteration 36, llf=-12464, convergence criterion=9.4572e-07 < tolerance=1e-06
# EM start iterations, llf=-12606
# EM converged at iteration 36, llf=-12472, convergence criterion=9.5109e-07 < tolerance=1e-06
# EM start iterations, llf=-12656
# EM converged at iteration 36, llf=-12522, convergence criterion=9.6083e-07 < tolerance=1e-06
# EM start iterations, llf=-12656
# EM converged at iteration 36, llf=-12522, convergence criterion=9.6083e-07 < tolerance=1e-06
# EM start iterations, llf=-12668
# EM converged at iteration 36, llf=-12534, convergence criterion=9.6647e-07 < tolerance=1e-06
# EM start iterations, llf=-12720
# EM converged at iteration 36, llf=-12587, convergence criterion=9.744e-07 < tolerance=1e-06
# EM start iterations, llf=-12733
# EM converged at iteration 32, llf=-12600, convergence criterion=9.5236e-07 < tolerance=1e-06
# EM start iterations, llf=-12782
# EM converged at iteration 32, llf=-12650, convergence criterion=9.5867e-07 < tolerance=1e-06
# EM start iterations, llf=-12793
# EM converged at iteration 32, llf=-12661, convergence criterion=9.5829e-07 < tolerance=1e-06
# EM start iterations, llf=-12854
# EM converged at iteration 32, llf=-12721, convergence criterion=9.5726e-07 < tolerance=1e-06
# EM start iterations, llf=-12854
# EM converged at iteration 32, llf=-12721, convergence criterion=9.5726e-07 < tolerance=1e-06
# EM start iterations, llf=-12862
# EM converged at iteration 32, llf=-12728, convergence criterion=9.5573e-07 < tolerance=1e-06
# EM start iterations, llf=-12919
# EM converged at iteration 32, llf=-12785, convergence criterion=9.6557e-07 < tolerance=1e-06
# EM start iterations, llf=-12932
# EM converged at iteration 35, llf=-12798, convergence criterion=9.5204e-07 < tolerance=1e-06
# EM start iterations, llf=-12987
# EM converged at iteration 35, llf=-12853, convergence criterion=9.5598e-07 < tolerance=1e-06
# EM start iterations, llf=-12996
# EM converged at iteration 35, llf=-12863, convergence criterion=9.5724e-07 < tolerance=1e-06
# EM start iterations, llf=-13048
# EM converged at iteration 35, llf=-12914, convergence criterion=9.5526e-07 < tolerance=1e-06
# EM start iterations, llf=-13048
# EM converged at iteration 35, llf=-12914, convergence criterion=9.5526e-07 < tolerance=1e-06
# EM start iterations, llf=-13057
# EM converged at iteration 35, llf=-12923, convergence criterion=9.5174e-07 < tolerance=1e-06
# EM start iterations, llf=-13113
# EM converged at iteration 34, llf=-12980, convergence criterion=9.9299e-07 < tolerance=1e-06
# EM start iterations, llf=-13124
# EM converged at iteration 35, llf=-12991, convergence criterion=9.6382e-07 < tolerance=1e-06
# EM start iterations, llf=-13174
# EM converged at iteration 35, llf=-13042, convergence criterion=9.6077e-07 < tolerance=1e-06
# EM start iterations, llf=-13223
# EM converged at iteration 34, llf=-13089, convergence criterion=9.8783e-07 < tolerance=1e-06
# EM start iterations, llf=-13277
# EM converged at iteration 34, llf=-13143, convergence criterion=9.8317e-07 < tolerance=1e-06
# EM start iterations, llf=-13277
# EM converged at iteration 34, llf=-13143, convergence criterion=9.8317e-07 < tolerance=1e-06
# EM start iterations, llf=-13286
# EM converged at iteration 34, llf=-13152, convergence criterion=9.8644e-07 < tolerance=1e-06
# EM start iterations, llf=-13331
# EM converged at iteration 34, llf=-13197, convergence criterion=9.6383e-07 < tolerance=1e-06
# EM start iterations, llf=-13340
# EM converged at iteration 34, llf=-13203, convergence criterion=9.6334e-07 < tolerance=1e-06
# EM start iterations, llf=-13390
# EM converged at iteration 33, llf=-13253, convergence criterion=9.9951e-07 < tolerance=1e-06
# EM start iterations, llf=-13400
# EM converged at iteration 34, llf=-13264, convergence criterion=9.4903e-07 < tolerance=1e-06
# EM start iterations, llf=-13451
# EM converged at iteration 34, llf=-13313, convergence criterion=9.4425e-07 < tolerance=1e-06
# EM start iterations, llf=-13451
# EM converged at iteration 34, llf=-13313, convergence criterion=9.4425e-07 < tolerance=1e-06
# EM start iterations, llf=-13460
# EM converged at iteration 34, llf=-13322, convergence criterion=9.443e-07 < tolerance=1e-06
# EM start iterations, llf=-13507
# EM converged at iteration 33, llf=-13367, convergence criterion=9.8135e-07 < tolerance=1e-06
# EM start iterations, llf=-13513
# EM converged at iteration 33, llf=-13373, convergence criterion=9.7324e-07 < tolerance=1e-06
# EM start iterations, llf=-13572
# EM converged at iteration 33, llf=-13430, convergence criterion=9.6381e-07 < tolerance=1e-06
# EM start iterations, llf=-13584
# EM converged at iteration 33, llf=-13443, convergence criterion=9.6939e-07 < tolerance=1e-06
# EM start iterations, llf=-13634
# EM converged at iteration 33, llf=-13493, convergence criterion=9.6148e-07 < tolerance=1e-06
# EM start iterations, llf=-13634
# EM converged at iteration 33, llf=-13493, convergence criterion=9.6148e-07 < tolerance=1e-06
# EM start iterations, llf=-13641
# EM converged at iteration 33, llf=-13500, convergence criterion=9.5309e-07 < tolerance=1e-06
# EM start iterations, llf=-13684
# EM converged at iteration 33, llf=-13543, convergence criterion=9.443e-07 < tolerance=1e-06
# EM start iterations, llf=-13695
# EM converged at iteration 35, llf=-13554, convergence criterion=9.6832e-07 < tolerance=1e-06
# EM start iterations, llf=-13740
# EM converged at iteration 35, llf=-13599, convergence criterion=9.7192e-07 < tolerance=1e-06
# EM start iterations, llf=-13750
# EM converged at iteration 35, llf=-13607, convergence criterion=9.5386e-07 < tolerance=1e-06
# EM start iterations, llf=-13787
# EM converged at iteration 35, llf=-13645, convergence criterion=9.502e-07 < tolerance=1e-06
# EM start iterations, llf=-13787
# EM converged at iteration 35, llf=-13645, convergence criterion=9.502e-07 < tolerance=1e-06
# EM start iterations, llf=-13801
# EM converged at iteration 35, llf=-13660, convergence criterion=9.5451e-07 < tolerance=1e-06
# EM start iterations, llf=-13830
# EM converged at iteration 35, llf=-13690, convergence criterion=9.6934e-07 < tolerance=1e-06
# EM start iterations, llf=-13841
# EM converged at iteration 38, llf=-13705, convergence criterion=9.4979e-07 < tolerance=1e-06
# EM start iterations, llf=-13866
# EM converged at iteration 38, llf=-13733, convergence criterion=9.6689e-07 < tolerance=1e-06
# EM start iterations, llf=-13870
# EM converged at iteration 37, llf=-13735, convergence criterion=9.9311e-07 < tolerance=1e-06
# EM start iterations, llf=-13917
# EM converged at iteration 38, llf=-13777, convergence criterion=9.8636e-07 < tolerance=1e-06
# EM start iterations, llf=-13917
# EM converged at iteration 38, llf=-13777, convergence criterion=9.8636e-07 < tolerance=1e-06
# EM start iterations, llf=-13926
# EM converged at iteration 38, llf=-13787, convergence criterion=9.8744e-07 < tolerance=1e-06
# EM start iterations, llf=-13980
# EM converged at iteration 38, llf=-13841, convergence criterion=9.8734e-07 < tolerance=1e-06
# EM start iterations, llf=-13988
# EM converged at iteration 35, llf=-13849, convergence criterion=9.9007e-07 < tolerance=1e-06
# EM start iterations, llf=-14049
# EM converged at iteration 35, llf=-13909, convergence criterion=9.8427e-07 < tolerance=1e-06
# EM start iterations, llf=-14058
# EM converged at iteration 35, llf=-13919, convergence criterion=9.8105e-07 < tolerance=1e-06
# EM start iterations, llf=-14114
# EM converged at iteration 35, llf=-13974, convergence criterion=9.7834e-07 < tolerance=1e-06
# EM start iterations, llf=-14114
# EM converged at iteration 35, llf=-13974, convergence criterion=9.7834e-07 < tolerance=1e-06
# EM start iterations, llf=-14123
# EM converged at iteration 35, llf=-13984, convergence criterion=9.7813e-07 < tolerance=1e-06
# EM start iterations, llf=-14170
# EM converged at iteration 35, llf=-14030, convergence criterion=9.7363e-07 < tolerance=1e-06
# EM start iterations, llf=-14181
# EM converged at iteration 35, llf=-14040, convergence criterion=9.6747e-07 < tolerance=1e-06
# EM start iterations, llf=-14228
# EM converged at iteration 35, llf=-14088, convergence criterion=9.7884e-07 < tolerance=1e-06
# EM start iterations, llf=-14237
# EM converged at iteration 35, llf=-14099, convergence criterion=9.8933e-07 < tolerance=1e-06
# EM start iterations, llf=-14276
# EM converged at iteration 35, llf=-14134, convergence criterion=9.8662e-07 < tolerance=1e-06
# EM start iterations, llf=-14276
# EM converged at iteration 35, llf=-14134, convergence criterion=9.8662e-07 < tolerance=1e-06
# EM start iterations, llf=-14286
# EM converged at iteration 35, llf=-14141, convergence criterion=9.7642e-07 < tolerance=1e-06
# EM start iterations, llf=-14356
# EM converged at iteration 35, llf=-14208, convergence criterion=9.5471e-07 < tolerance=1e-06
# EM start iterations, llf=-14363
# EM converged at iteration 34, llf=-14215, convergence criterion=9.9737e-07 < tolerance=1e-06
# EM start iterations, llf=-14412
# EM converged at iteration 34, llf=-14264, convergence criterion=9.9884e-07 < tolerance=1e-06
# EM start iterations, llf=-14423
# EM converged at iteration 35, llf=-14275, convergence criterion=9.456e-07 < tolerance=1e-06
# EM start iterations, llf=-14474
# EM converged at iteration 34, llf=-14326, convergence criterion=9.9746e-07 < tolerance=1e-06
# EM start iterations, llf=-14474
# EM converged at iteration 34, llf=-14326, convergence criterion=9.9746e-07 < tolerance=1e-06
# EM start iterations, llf=-14484
# EM converged at iteration 34, llf=-14335, convergence criterion=9.9304e-07 < tolerance=1e-06
# EM start iterations, llf=-14538
# EM converged at iteration 34, llf=-14390, convergence criterion=9.9112e-07 < tolerance=1e-06
# EM start iterations, llf=-14548
# EM converged at iteration 35, llf=-14400, convergence criterion=9.4871e-07 < tolerance=1e-06
# EM start iterations, llf=-14597
# EM converged at iteration 34, llf=-14450, convergence criterion=9.9958e-07 < tolerance=1e-06
# EM start iterations, llf=-14606
# EM converged at iteration 34, llf=-14457, convergence criterion=9.9508e-07 < tolerance=1e-06
# EM start iterations, llf=-14659
# EM converged at iteration 34, llf=-14510, convergence criterion=9.9327e-07 < tolerance=1e-06
# EM start iterations, llf=-14659
# EM converged at iteration 34, llf=-14510, convergence criterion=9.9327e-07 < tolerance=1e-06
# EM start iterations, llf=-14665
# EM converged at iteration 34, llf=-14516, convergence criterion=9.9355e-07 < tolerance=1e-06
# EM start iterations, llf=-14716
# EM converged at iteration 34, llf=-14566, convergence criterion=9.9119e-07 < tolerance=1e-06
# EM start iterations, llf=-14723
# EM converged at iteration 34, llf=-14574, convergence criterion=9.8936e-07 < tolerance=1e-06
# EM start iterations, llf=-14777
# EM converged at iteration 34, llf=-14628, convergence criterion=9.8829e-07 < tolerance=1e-06
# EM start iterations, llf=-14789
# EM converged at iteration 34, llf=-14640, convergence criterion=9.8826e-07 < tolerance=1e-06
# EM start iterations, llf=-14837
# EM converged at iteration 34, llf=-14686, convergence criterion=9.8461e-07 < tolerance=1e-06
# EM start iterations, llf=-14837
# EM converged at iteration 34, llf=-14686, convergence criterion=9.8461e-07 < tolerance=1e-06
# EM start iterations, llf=-14844
# EM converged at iteration 34, llf=-14694, convergence criterion=9.9015e-07 < tolerance=1e-06
# EM start iterations, llf=-14896
# EM converged at iteration 34, llf=-14746, convergence criterion=9.8916e-07 < tolerance=1e-06
# EM start iterations, llf=-14903
# EM converged at iteration 35, llf=-14753, convergence criterion=9.46e-07 < tolerance=1e-06
# EM start iterations, llf=-14958
# EM converged at iteration 34, llf=-14807, convergence criterion=9.9835e-07 < tolerance=1e-06
# EM start iterations, llf=-14966
# EM converged at iteration 34, llf=-14815, convergence criterion=9.9994e-07 < tolerance=1e-06
# EM start iterations, llf=-15025
# EM converged at iteration 34, llf=-14874, convergence criterion=9.9804e-07 < tolerance=1e-06
# EM start iterations, llf=-15025
# EM converged at iteration 34, llf=-14874, convergence criterion=9.9804e-07 < tolerance=1e-06
# EM start iterations, llf=-15034
# EM converged at iteration 34, llf=-14884, convergence criterion=9.9612e-07 < tolerance=1e-06
# EM start iterations, llf=-15087
# EM converged at iteration 34, llf=-14937, convergence criterion=9.9559e-07 < tolerance=1e-06
# EM start iterations, llf=-15099
# EM converged at iteration 35, llf=-14949, convergence criterion=9.4446e-07 < tolerance=1e-06
# EM start iterations, llf=-15146
# EM converged at iteration 35, llf=-14996, convergence criterion=9.4479e-07 < tolerance=1e-06
# EM start iterations, llf=-15154
# EM converged at iteration 35, llf=-15004, convergence criterion=9.4692e-07 < tolerance=1e-06
# EM start iterations, llf=-15201
# EM converged at iteration 35, llf=-15051, convergence criterion=9.4722e-07 < tolerance=1e-06
# EM start iterations, llf=-15201
# EM converged at iteration 35, llf=-15051, convergence criterion=9.4722e-07 < tolerance=1e-06
# EM start iterations, llf=-15213
# EM converged at iteration 35, llf=-15062, convergence criterion=9.4416e-07 < tolerance=1e-06
# EM start iterations, llf=-15258
# EM converged at iteration 34, llf=-15107, convergence criterion=9.9768e-07 < tolerance=1e-06
# EM start iterations, llf=-15269
# EM converged at iteration 34, llf=-15118, convergence criterion=9.5056e-07 < tolerance=1e-06
# EM start iterations, llf=-15327
# EM converged at iteration 34, llf=-15174, convergence criterion=9.4481e-07 < tolerance=1e-06
# EM start iterations, llf=-15337
# EM converged at iteration 34, llf=-15185, convergence criterion=9.4436e-07 < tolerance=1e-06
# EM start iterations, llf=-15394
# EM converged at iteration 34, llf=-15240, convergence criterion=9.4229e-07 < tolerance=1e-06
# EM start iterations, llf=-15394
# EM converged at iteration 34, llf=-15240, convergence criterion=9.4229e-07 < tolerance=1e-06
# EM start iterations, llf=-15405
# EM converged at iteration 34, llf=-15252, convergence criterion=9.4262e-07 < tolerance=1e-06
# EM start iterations, llf=-15466
# EM converged at iteration 34, llf=-15312, convergence criterion=9.438e-07 < tolerance=1e-06
# EM start iterations, llf=-15477
# EM converged at iteration 34, llf=-15323, convergence criterion=9.6457e-07 < tolerance=1e-06
# EM start iterations, llf=-15533
# EM converged at iteration 34, llf=-15378, convergence criterion=9.6029e-07 < tolerance=1e-06
# EM start iterations, llf=-15539
# EM converged at iteration 34, llf=-15384, convergence criterion=9.6092e-07 < tolerance=1e-06
# EM start iterations, llf=-15600
# EM converged at iteration 34, llf=-15444, convergence criterion=9.4835e-07 < tolerance=1e-06
# EM start iterations, llf=-15600
# EM converged at iteration 34, llf=-15444, convergence criterion=9.4835e-07 < tolerance=1e-06
# EM start iterations, llf=-15609
# EM converged at iteration 34, llf=-15454, convergence criterion=9.5208e-07 < tolerance=1e-06
# EM start iterations, llf=-15662
# EM converged at iteration 34, llf=-15508, convergence criterion=9.5068e-07 < tolerance=1e-06
# EM start iterations, llf=-15667
# EM converged at iteration 31, llf=-15512, convergence criterion=9.4516e-07 < tolerance=1e-06
# EM start iterations, llf=-15725
# EM converged at iteration 31, llf=-15570, convergence criterion=9.393e-07 < tolerance=1e-06
# EM start iterations, llf=-15729
# EM converged at iteration 31, llf=-15574, convergence criterion=9.4126e-07 < tolerance=1e-06
# EM start iterations, llf=-15772
# EM converged at iteration 31, llf=-15617, convergence criterion=9.3824e-07 < tolerance=1e-06
# EM start iterations, llf=-15772
# EM converged at iteration 31, llf=-15617, convergence criterion=9.3824e-07 < tolerance=1e-06
# EM start iterations, llf=-15246
# EM converged at iteration 27, llf=-15107, convergence criterion=9.9154e-07 < tolerance=1e-06
# EM start iterations, llf=-15440
# EM converged at iteration 29, llf=-15298, convergence criterion=9.4611e-07 < tolerance=1e-06
# EM start iterations, llf=-15450
# EM converged at iteration 28, llf=-15307, convergence criterion=9.6419e-07 < tolerance=1e-06
# EM start iterations, llf=-15907
# EM converged at iteration 30, llf=-15752, convergence criterion=9.9862e-07 < tolerance=1e-06
# EM start iterations, llf=-15911
# EM converged at iteration 30, llf=-15756, convergence criterion=9.9881e-07 < tolerance=1e-06
# EM start iterations, llf=-15959
# EM converged at iteration 30, llf=-15804, convergence criterion=9.9718e-07 < tolerance=1e-06
# EM start iterations, llf=-15959
# EM converged at iteration 30, llf=-15804, convergence criterion=9.9718e-07 < tolerance=1e-06
# EM start iterations, llf=-15972
# EM converged at iteration 30, llf=-15816, convergence criterion=9.9336e-07 < tolerance=1e-06
# EM start iterations, llf=-16027
# EM converged at iteration 30, llf=-15871, convergence criterion=9.8952e-07 < tolerance=1e-06
# EM start iterations, llf=-16033
# EM converged at iteration 31, llf=-15876, convergence criterion=9.3565e-07 < tolerance=1e-06
# EM start iterations, llf=-16089
# EM converged at iteration 31, llf=-15932, convergence criterion=9.3633e-07 < tolerance=1e-06
# EM start iterations, llf=-16094
# EM converged at iteration 31, llf=-15938, convergence criterion=9.3525e-07 < tolerance=1e-06
# EM start iterations, llf=-16152
# EM converged at iteration 30, llf=-15996, convergence criterion=9.9991e-07 < tolerance=1e-06
# EM start iterations, llf=-16152
# EM converged at iteration 30, llf=-15996, convergence criterion=9.9991e-07 < tolerance=1e-06
# EM start iterations, llf=-16162
# EM converged at iteration 31, llf=-16006, convergence criterion=9.3464e-07 < tolerance=1e-06
# EM start iterations, llf=-16216
# EM converged at iteration 30, llf=-16060, convergence criterion=9.9649e-07 < tolerance=1e-06
# EM start iterations, llf=-16226
# EM converged at iteration 31, llf=-16070, convergence criterion=9.5016e-07 < tolerance=1e-06
# EM start iterations, llf=-16277
# EM converged at iteration 31, llf=-16120, convergence criterion=9.4946e-07 < tolerance=1e-06
# EM start iterations, llf=-16285
# EM converged at iteration 31, llf=-16128, convergence criterion=9.4865e-07 < tolerance=1e-06
# EM start iterations, llf=-16340
# EM converged at iteration 31, llf=-16183, convergence criterion=9.4706e-07 < tolerance=1e-06
# EM start iterations, llf=-16340
# EM converged at iteration 31, llf=-16183, convergence criterion=9.4706e-07 < tolerance=1e-06
# EM start iterations, llf=-16350
# EM converged at iteration 31, llf=-16193, convergence criterion=9.4674e-07 < tolerance=1e-06
# EM start iterations, llf=-16402
# EM converged at iteration 31, llf=-16245, convergence criterion=9.4658e-07 < tolerance=1e-06
# EM start iterations, llf=-16409
# EM converged at iteration 26, llf=-16252, convergence criterion=9.937e-07 < tolerance=1e-06
# EM start iterations, llf=-16463
# EM converged at iteration 26, llf=-16305, convergence criterion=9.9977e-07 < tolerance=1e-06
# EM start iterations, llf=-16470
# EM converged at iteration 27, llf=-16313, convergence criterion=9.2868e-07 < tolerance=1e-06
# EM start iterations, llf=-16524
# EM converged at iteration 27, llf=-16367, convergence criterion=9.2882e-07 < tolerance=1e-06
# EM start iterations, llf=-16524
# EM converged at iteration 27, llf=-16367, convergence criterion=9.2882e-07 < tolerance=1e-06
# EM start iterations, llf=-16528
# EM converged at iteration 26, llf=-16370, convergence criterion=9.946e-07 < tolerance=1e-06
# EM start iterations, llf=-16579
# EM converged at iteration 26, llf=-16420, convergence criterion=9.9331e-07 < tolerance=1e-06
# EM start iterations, llf=-16587
# EM converged at iteration 27, llf=-16427, convergence criterion=9.2984e-07 < tolerance=1e-06
# EM start iterations, llf=-16642
# EM converged at iteration 27, llf=-16481, convergence criterion=9.2739e-07 < tolerance=1e-06
# EM start iterations, llf=-16648
# EM converged at iteration 27, llf=-16488, convergence criterion=9.2824e-07 < tolerance=1e-06
# EM start iterations, llf=-16695
# EM converged at iteration 27, llf=-16535, convergence criterion=9.2675e-07 < tolerance=1e-06
# EM start iterations, llf=-16695
# EM converged at iteration 27, llf=-16535, convergence criterion=9.2675e-07 < tolerance=1e-06
# EM start iterations, llf=-16709
# EM converged at iteration 27, llf=-16548, convergence criterion=9.2739e-07 < tolerance=1e-06
# EM start iterations, llf=-16769
# EM converged at iteration 27, llf=-16608, convergence criterion=9.2748e-07 < tolerance=1e-06
# EM start iterations, llf=-16775
# EM converged at iteration 27, llf=-16614, convergence criterion=9.4339e-07 < tolerance=1e-06
# EM start iterations, llf=-16827
# EM converged at iteration 27, llf=-16666, convergence criterion=9.378e-07 < tolerance=1e-06
# EM start iterations, llf=-16835
# EM converged at iteration 27, llf=-16674, convergence criterion=9.3807e-07 < tolerance=1e-06
# EM start iterations, llf=-16890
# EM converged at iteration 27, llf=-16729, convergence criterion=9.3418e-07 < tolerance=1e-06
# EM start iterations, llf=-16890
# EM converged at iteration 27, llf=-16729, convergence criterion=9.3418e-07 < tolerance=1e-06
# EM start iterations, llf=-16898
# EM converged at iteration 27, llf=-16736, convergence criterion=9.3075e-07 < tolerance=1e-06
# EM start iterations, llf=-16950
# EM converged at iteration 26, llf=-16788, convergence criterion=9.9741e-07 < tolerance=1e-06
# EM start iterations, llf=-16960
# EM converged at iteration 27, llf=-16798, convergence criterion=9.291e-07 < tolerance=1e-06
# EM start iterations, llf=-17011
# EM converged at iteration 26, llf=-16848, convergence criterion=9.9938e-07 < tolerance=1e-06
# EM start iterations, llf=-17022
# EM converged at iteration 26, llf=-16859, convergence criterion=9.9662e-07 < tolerance=1e-06
# EM start iterations, llf=-17077
# EM converged at iteration 26, llf=-16914, convergence criterion=9.9131e-07 < tolerance=1e-06
# EM start iterations, llf=-17077
# EM converged at iteration 26, llf=-16914, convergence criterion=9.9131e-07 < tolerance=1e-06
# EM start iterations, llf=-17084
# EM converged at iteration 26, llf=-16922, convergence criterion=9.9032e-07 < tolerance=1e-06
# EM start iterations, llf=-17139
# EM converged at iteration 26, llf=-16976, convergence criterion=9.9351e-07 < tolerance=1e-06
# EM start iterations, llf=-17146
# EM converged at iteration 28, llf=-16983, convergence criterion=9.4836e-07 < tolerance=1e-06
# EM start iterations, llf=-17199
# EM converged at iteration 28, llf=-17035, convergence criterion=9.5015e-07 < tolerance=1e-06
# EM start iterations, llf=-17208
# EM converged at iteration 28, llf=-17044, convergence criterion=9.5002e-07 < tolerance=1e-06
# EM start iterations, llf=-17260
# EM converged at iteration 28, llf=-17096, convergence criterion=9.4723e-07 < tolerance=1e-06
# EM start iterations, llf=-17260
# EM converged at iteration 28, llf=-17096, convergence criterion=9.4723e-07 < tolerance=1e-06
# EM start iterations, llf=-17266
# EM converged at iteration 28, llf=-17103, convergence criterion=9.4564e-07 < tolerance=1e-06
# EM start iterations, llf=-17322
# EM converged at iteration 28, llf=-17158, convergence criterion=9.4396e-07 < tolerance=1e-06
# EM start iterations, llf=-17328
# EM converged at iteration 28, llf=-17164, convergence criterion=9.4664e-07 < tolerance=1e-06
# EM start iterations, llf=-17382
# EM converged at iteration 28, llf=-17218, convergence criterion=9.4497e-07 < tolerance=1e-06
# EM start iterations, llf=-17391
# EM converged at iteration 28, llf=-17226, convergence criterion=9.4367e-07 < tolerance=1e-06
# EM start iterations, llf=-17439
# EM converged at iteration 28, llf=-17274, convergence criterion=9.4053e-07 < tolerance=1e-06
# EM start iterations, llf=-17439
# EM converged at iteration 28, llf=-17274, convergence criterion=9.4053e-07 < tolerance=1e-06
# EM start iterations, llf=-17458
# EM converged at iteration 28, llf=-17293, convergence criterion=9.3985e-07 < tolerance=1e-06
# EM start iterations, llf=-17513
# EM converged at iteration 28, llf=-17348, convergence criterion=9.3756e-07 < tolerance=1e-06
# EM start iterations, llf=-17522
# EM converged at iteration 28, llf=-17357, convergence criterion=9.4621e-07 < tolerance=1e-06
# EM start iterations, llf=-17568
# EM converged at iteration 28, llf=-17402, convergence criterion=9.4264e-07 < tolerance=1e-06
# EM start iterations, llf=-17579
# EM converged at iteration 28, llf=-17414, convergence criterion=9.4486e-07 < tolerance=1e-06
# EM start iterations, llf=-17637
# EM converged at iteration 28, llf=-17472, convergence criterion=9.4684e-07 < tolerance=1e-06
# EM start iterations, llf=-17637
# EM converged at iteration 28, llf=-17472, convergence criterion=9.4684e-07 < tolerance=1e-06
# EM start iterations, llf=-17645
# EM converged at iteration 28, llf=-17480, convergence criterion=9.4307e-07 < tolerance=1e-06
# EM start iterations, llf=-17696
# EM converged at iteration 28, llf=-17531, convergence criterion=9.4033e-07 < tolerance=1e-06
# EM start iterations, llf=-17705
# EM converged at iteration 28, llf=-17539, convergence criterion=9.4676e-07 < tolerance=1e-06
# EM start iterations, llf=-17760
# EM converged at iteration 28, llf=-17595, convergence criterion=9.4533e-07 < tolerance=1e-06
# EM start iterations, llf=-17768
# EM converged at iteration 28, llf=-17603, convergence criterion=9.4331e-07 < tolerance=1e-06
# EM start iterations, llf=-17823
# EM converged at iteration 28, llf=-17658, convergence criterion=9.3995e-07 < tolerance=1e-06
# EM start iterations, llf=-17823
# EM converged at iteration 28, llf=-17658, convergence criterion=9.3995e-07 < tolerance=1e-06
# EM start iterations, llf=-17831
# EM converged at iteration 28, llf=-17665, convergence criterion=9.4215e-07 < tolerance=1e-06
# EM start iterations, llf=-17880
# EM converged at iteration 28, llf=-17714, convergence criterion=9.4027e-07 < tolerance=1e-06
# EM start iterations, llf=-17886
# EM converged at iteration 28, llf=-17720, convergence criterion=9.6586e-07 < tolerance=1e-06
# EM start iterations, llf=-17937
# EM converged at iteration 28, llf=-17770, convergence criterion=9.6309e-07 < tolerance=1e-06
# EM start iterations, llf=-17944
# EM converged at iteration 28, llf=-17776, convergence criterion=9.5875e-07 < tolerance=1e-06
# EM start iterations, llf=-18000
# EM converged at iteration 28, llf=-17832, convergence criterion=9.5954e-07 < tolerance=1e-06
# EM start iterations, llf=-18000
# EM converged at iteration 28, llf=-17832, convergence criterion=9.5954e-07 < tolerance=1e-06
# EM start iterations, llf=-18006
# EM converged at iteration 28, llf=-17838, convergence criterion=9.6213e-07 < tolerance=1e-06
# EM start iterations, llf=-18061
# EM converged at iteration 28, llf=-17892, convergence criterion=9.6016e-07 < tolerance=1e-06
# EM start iterations, llf=-18072
# EM converged at iteration 28, llf=-17904, convergence criterion=9.6481e-07 < tolerance=1e-06
# EM start iterations, llf=-18126
# EM converged at iteration 28, llf=-17958, convergence criterion=9.6315e-07 < tolerance=1e-06
# EM start iterations, llf=-18133
# EM converged at iteration 28, llf=-17964, convergence criterion=9.6272e-07 < tolerance=1e-06
# EM start iterations, llf=-18180
# EM converged at iteration 28, llf=-18011, convergence criterion=9.6077e-07 < tolerance=1e-06
# EM start iterations, llf=-18180
# EM converged at iteration 28, llf=-18011, convergence criterion=9.6077e-07 < tolerance=1e-06
# EM start iterations, llf=-18193
# EM converged at iteration 28, llf=-18024, convergence criterion=9.5871e-07 < tolerance=1e-06
# EM start iterations, llf=-18251
# EM converged at iteration 28, llf=-18081, convergence criterion=9.529e-07 < tolerance=1e-06
# EM start iterations, llf=-18261
# EM converged at iteration 28, llf=-18092, convergence criterion=9.6716e-07 < tolerance=1e-06
# EM start iterations, llf=-18305
# EM converged at iteration 28, llf=-18136, convergence criterion=9.6829e-07 < tolerance=1e-06
# EM start iterations, llf=-18315
# EM converged at iteration 28, llf=-18146, convergence criterion=9.6541e-07 < tolerance=1e-06
# EM start iterations, llf=-18173
# EM converged at iteration 28, llf=-18009, convergence criterion=9.8755e-07 < tolerance=1e-06
# EM start iterations, llf=-18173
# EM converged at iteration 28, llf=-18009, convergence criterion=9.8755e-07 < tolerance=1e-06
# EM start iterations, llf=-18178
# EM converged at iteration 28, llf=-18013, convergence criterion=9.8183e-07 < tolerance=1e-06
# EM start iterations, llf=-18230
# EM converged at iteration 28, llf=-18064, convergence criterion=9.7691e-07 < tolerance=1e-06
# EM start iterations, llf=-18242
# EM converged at iteration 28, llf=-18078, convergence criterion=9.8294e-07 < tolerance=1e-06
# EM start iterations, llf=-18300
# EM converged at iteration 28, llf=-18135, convergence criterion=9.8118e-07 < tolerance=1e-06
# EM start iterations, llf=-18305
# EM converged at iteration 28, llf=-18139, convergence criterion=9.7811e-07 < tolerance=1e-06
# EM start iterations, llf=-18363
# EM converged at iteration 28, llf=-18198, convergence criterion=9.7318e-07 < tolerance=1e-06
# EM start iterations, llf=-18363
# EM converged at iteration 28, llf=-18198, convergence criterion=9.7318e-07 < tolerance=1e-06
# EM start iterations, llf=-18369
# EM converged at iteration 28, llf=-18203, convergence criterion=9.7185e-07 < tolerance=1e-06
# EM start iterations, llf=-18420
# EM converged at iteration 28, llf=-18254, convergence criterion=9.701e-07 < tolerance=1e-06
# EM start iterations, llf=-18428
# EM converged at iteration 29, llf=-18262, convergence criterion=9.4155e-07 < tolerance=1e-06
# EM start iterations, llf=-18484
# EM converged at iteration 29, llf=-18317, convergence criterion=9.4105e-07 < tolerance=1e-06
# EM start iterations, llf=-18491
# EM converged at iteration 29, llf=-18324, convergence criterion=9.3921e-07 < tolerance=1e-06
# EM start iterations, llf=-18546
# EM converged at iteration 29, llf=-18379, convergence criterion=9.3808e-07 < tolerance=1e-06
# EM start iterations, llf=-18546
# EM converged at iteration 29, llf=-18379, convergence criterion=9.3808e-07 < tolerance=1e-06
# EM start iterations, llf=-18552
# EM converged at iteration 29, llf=-18385, convergence criterion=9.3965e-07 < tolerance=1e-06
# EM start iterations, llf=-18608
# EM converged at iteration 28, llf=-18441, convergence criterion=9.9983e-07 < tolerance=1e-06
# EM start iterations, llf=-18616
# EM converged at iteration 29, llf=-18449, convergence criterion=9.4548e-07 < tolerance=1e-06
# EM start iterations, llf=-18664
# EM converged at iteration 29, llf=-18498, convergence criterion=9.4468e-07 < tolerance=1e-06
# EM start iterations, llf=-18677
# EM converged at iteration 29, llf=-18510, convergence criterion=9.4553e-07 < tolerance=1e-06
# EM start iterations, llf=-18723
# EM converged at iteration 29, llf=-18556, convergence criterion=9.4458e-07 < tolerance=1e-06
# EM start iterations, llf=-18723
# EM converged at iteration 29, llf=-18556, convergence criterion=9.4458e-07 < tolerance=1e-06
# EM start iterations, llf=-18732
# EM converged at iteration 29, llf=-18565, convergence criterion=9.4028e-07 < tolerance=1e-06
# EM start iterations, llf=-18779
# EM converged at iteration 28, llf=-18611, convergence criterion=9.9005e-07 < tolerance=1e-06
# EM start iterations, llf=-18787
# EM converged at iteration 29, llf=-18619, convergence criterion=9.4291e-07 < tolerance=1e-06
# EM start iterations, llf=-18839
# EM converged at iteration 29, llf=-18671, convergence criterion=9.4325e-07 < tolerance=1e-06
# EM start iterations, llf=-18849
# EM converged at iteration 29, llf=-18679, convergence criterion=9.3997e-07 < tolerance=1e-06
# EM start iterations, llf=-18900
# EM converged at iteration 29, llf=-18729, convergence criterion=9.3931e-07 < tolerance=1e-06
# EM start iterations, llf=-18900
# EM converged at iteration 29, llf=-18729, convergence criterion=9.3931e-07 < tolerance=1e-06
# EM start iterations, llf=-18908
# EM converged at iteration 29, llf=-18737, convergence criterion=9.4184e-07 < tolerance=1e-06
# EM start iterations, llf=-18963
# EM converged at iteration 29, llf=-18792, convergence criterion=9.4082e-07 < tolerance=1e-06
# EM start iterations, llf=-18972
# EM converged at iteration 29, llf=-18801, convergence criterion=9.4303e-07 < tolerance=1e-06
# EM start iterations, llf=-19024
# EM converged at iteration 29, llf=-18852, convergence criterion=9.422e-07 < tolerance=1e-06
# EM start iterations, llf=-19033
# EM converged at iteration 29, llf=-18862, convergence criterion=9.4288e-07 < tolerance=1e-06
# EM start iterations, llf=-19087
# EM converged at iteration 29, llf=-18916, convergence criterion=9.4123e-07 < tolerance=1e-06
# EM start iterations, llf=-19087
# EM converged at iteration 29, llf=-18916, convergence criterion=9.4123e-07 < tolerance=1e-06
# EM start iterations, llf=-19091
# EM converged at iteration 29, llf=-18920, convergence criterion=9.3921e-07 < tolerance=1e-06
# EM start iterations, llf=-19151
# EM converged at iteration 29, llf=-18978, convergence criterion=9.3635e-07 < tolerance=1e-06
# EM start iterations, llf=-19161
# EM converged at iteration 28, llf=-18988, convergence criterion=9.9424e-07 < tolerance=1e-06
# EM start iterations, llf=-19214
# EM converged at iteration 28, llf=-19041, convergence criterion=9.941e-07 < tolerance=1e-06
# EM start iterations, llf=-19221
# EM converged at iteration 28, llf=-19048, convergence criterion=9.9415e-07 < tolerance=1e-06
# EM start iterations, llf=-19269
# EM converged at iteration 28, llf=-19096, convergence criterion=9.9279e-07 < tolerance=1e-06
# EM start iterations, llf=-19269
# EM converged at iteration 28, llf=-19096, convergence criterion=9.9279e-07 < tolerance=1e-06
# EM start iterations, llf=-19002
# EM converged at iteration 27, llf=-18835, convergence criterion=9.4477e-07 < tolerance=1e-06
# EM start iterations, llf=-19058
# EM converged at iteration 27, llf=-18891, convergence criterion=9.4505e-07 < tolerance=1e-06
# EM start iterations, llf=-19071
# EM converged at iteration 26, llf=-18903, convergence criterion=9.9695e-07 < tolerance=1e-06
# EM start iterations, llf=-19124
# EM converged at iteration 26, llf=-18956, convergence criterion=9.9689e-07 < tolerance=1e-06
# EM start iterations, llf=-19128
# EM converged at iteration 26, llf=-18961, convergence criterion=9.9761e-07 < tolerance=1e-06
# EM start iterations, llf=-19181
# EM converged at iteration 26, llf=-19012, convergence criterion=9.9429e-07 < tolerance=1e-06
# Model with Global factors = 1 and order = 1 estimated in 1:03:18.977822.
# EM start iterations, llf=-11835
# EM iteration 50, llf=-11670, convergence criterion=1.6942e-06
# EM converged at iteration 66, llf=-11669, convergence criterion=9.8411e-07 < tolerance=1e-06
# EM start iterations, llf=-11847
# EM iteration 50, llf=-11681, convergence criterion=1.6995e-06
# EM converged at iteration 66, llf=-11681, convergence criterion=9.8715e-07 < tolerance=1e-06
# EM start iterations, llf=-11904
# EM iteration 50, llf=-11736, convergence criterion=1.7023e-06
# EM converged at iteration 66, llf=-11736, convergence criterion=9.8927e-07 < tolerance=1e-06
# EM start iterations, llf=-11912
# EM iteration 50, llf=-11744, convergence criterion=1.696e-06
# EM converged at iteration 66, llf=-11744, convergence criterion=9.8624e-07 < tolerance=1e-06
# EM start iterations, llf=-11978
# EM iteration 50, llf=-11808, convergence criterion=1.72e-06
# EM converged at iteration 66, llf=-11808, convergence criterion=9.989e-07 < tolerance=1e-06
# EM start iterations, llf=-11987
# EM iteration 50, llf=-11817, convergence criterion=1.7194e-06
# EM converged at iteration 66, llf=-11817, convergence criterion=9.9847e-07 < tolerance=1e-06
# EM start iterations, llf=-12043
# EM iteration 50, llf=-11877, convergence criterion=1.682e-06
# EM converged at iteration 66, llf=-11876, convergence criterion=9.7668e-07 < tolerance=1e-06
# EM start iterations, llf=-12043
# EM iteration 50, llf=-11877, convergence criterion=1.682e-06
# EM converged at iteration 66, llf=-11876, convergence criterion=9.7668e-07 < tolerance=1e-06
# EM start iterations, llf=-12050
# EM iteration 50, llf=-11883, convergence criterion=1.6907e-06
# EM converged at iteration 66, llf=-11883, convergence criterion=9.8146e-07 < tolerance=1e-06
# EM start iterations, llf=-12105
# EM iteration 50, llf=-11935, convergence criterion=1.7145e-06
# EM converged at iteration 66, llf=-11935, convergence criterion=9.9346e-07 < tolerance=1e-06
# EM start iterations, llf=-12113
# EM iteration 50, llf=-11943, convergence criterion=1.5692e-06
# EM converged at iteration 63, llf=-11943, convergence criterion=9.9078e-07 < tolerance=1e-06
# EM start iterations, llf=-12155
# EM iteration 50, llf=-11981, convergence criterion=1.579e-06
# EM converged at iteration 63, llf=-11981, convergence criterion=9.9392e-07 < tolerance=1e-06
# EM start iterations, llf=-12165
# EM iteration 50, llf=-11991, convergence criterion=1.5808e-06
# EM converged at iteration 63, llf=-11991, convergence criterion=9.9531e-07 < tolerance=1e-06
# EM start iterations, llf=-12213
# EM iteration 50, llf=-12035, convergence criterion=1.6318e-06
# EM converged at iteration 64, llf=-12035, convergence criterion=9.9068e-07 < tolerance=1e-06
# EM start iterations, llf=-12213
# EM iteration 50, llf=-12035, convergence criterion=1.6318e-06
# EM converged at iteration 64, llf=-12035, convergence criterion=9.9068e-07 < tolerance=1e-06
# EM start iterations, llf=-12225
# EM iteration 50, llf=-12042, convergence criterion=1.6638e-06
# EM converged at iteration 65, llf=-12042, convergence criterion=9.7611e-07 < tolerance=1e-06
# EM start iterations, llf=-12269
# EM iteration 50, llf=-12086, convergence criterion=1.6607e-06
# EM converged at iteration 65, llf=-12085, convergence criterion=9.7356e-07 < tolerance=1e-06
# EM start iterations, llf=-12284
# EM converged at iteration 49, llf=-12102, convergence criterion=9.6467e-07 < tolerance=1e-06
# EM start iterations, llf=-12328
# EM converged at iteration 49, llf=-12139, convergence criterion=9.7826e-07 < tolerance=1e-06
# EM start iterations, llf=-12336
# EM converged at iteration 49, llf=-12146, convergence criterion=9.806e-07 < tolerance=1e-06
# EM start iterations, llf=-12403
# EM converged at iteration 48, llf=-12219, convergence criterion=9.7673e-07 < tolerance=1e-06
# EM start iterations, llf=-12403
# EM converged at iteration 48, llf=-12219, convergence criterion=9.7673e-07 < tolerance=1e-06
# EM start iterations, llf=-12403
# EM converged at iteration 48, llf=-12213, convergence criterion=9.987e-07 < tolerance=1e-06
# EM start iterations, llf=-12463
# EM converged at iteration 44, llf=-12301, convergence criterion=9.8291e-07 < tolerance=1e-06
# EM start iterations, llf=-12472
# EM converged at iteration 46, llf=-12321, convergence criterion=9.9915e-07 < tolerance=1e-06
# EM start iterations, llf=-12443
# EM converged at iteration 44, llf=-12300, convergence criterion=9.5871e-07 < tolerance=1e-06
# EM start iterations, llf=-12445
# EM converged at iteration 44, llf=-12303, convergence criterion=9.7767e-07 < tolerance=1e-06
# EM start iterations, llf=-12434
# EM converged at iteration 44, llf=-12298, convergence criterion=9.811e-07 < tolerance=1e-06
# EM start iterations, llf=-12434
# EM converged at iteration 44, llf=-12298, convergence criterion=9.811e-07 < tolerance=1e-06
# EM start iterations, llf=-12428
# EM converged at iteration 44, llf=-12293, convergence criterion=9.6617e-07 < tolerance=1e-06
# EM start iterations, llf=-12473
# EM converged at iteration 44, llf=-12343, convergence criterion=9.6423e-07 < tolerance=1e-06
# EM start iterations, llf=-12468
# EM converged at iteration 39, llf=-12339, convergence criterion=9.77e-07 < tolerance=1e-06
# EM start iterations, llf=-12474
# EM converged at iteration 38, llf=-12345, convergence criterion=9.9085e-07 < tolerance=1e-06
# EM start iterations, llf=-12479
# EM converged at iteration 38, llf=-12343, convergence criterion=9.7891e-07 < tolerance=1e-06
# EM start iterations, llf=-12487
# EM converged at iteration 40, llf=-12345, convergence criterion=9.5106e-07 < tolerance=1e-06
# EM start iterations, llf=-12487
# EM converged at iteration 40, llf=-12345, convergence criterion=9.5106e-07 < tolerance=1e-06
# EM start iterations, llf=-12497
# EM converged at iteration 39, llf=-12355, convergence criterion=9.8597e-07 < tolerance=1e-06
# EM start iterations, llf=-12547
# EM converged at iteration 39, llf=-12409, convergence criterion=9.8079e-07 < tolerance=1e-06
# EM start iterations, llf=-12554
# EM converged at iteration 39, llf=-12417, convergence criterion=9.8026e-07 < tolerance=1e-06
# EM start iterations, llf=-12599
# EM converged at iteration 40, llf=-12463, convergence criterion=9.5238e-07 < tolerance=1e-06
# EM start iterations, llf=-12606
# EM converged at iteration 40, llf=-12470, convergence criterion=9.523e-07 < tolerance=1e-06
# EM start iterations, llf=-12656
# EM converged at iteration 40, llf=-12520, convergence criterion=9.6906e-07 < tolerance=1e-06
# EM start iterations, llf=-12656
# EM converged at iteration 40, llf=-12520, convergence criterion=9.6906e-07 < tolerance=1e-06
# EM start iterations, llf=-12668
# EM converged at iteration 40, llf=-12532, convergence criterion=9.9092e-07 < tolerance=1e-06
# EM start iterations, llf=-12720
# EM converged at iteration 40, llf=-12585, convergence criterion=9.9145e-07 < tolerance=1e-06
# EM start iterations, llf=-12733
# EM converged at iteration 36, llf=-12598, convergence criterion=9.9878e-07 < tolerance=1e-06
# EM start iterations, llf=-12782
# EM converged at iteration 36, llf=-12648, convergence criterion=9.7536e-07 < tolerance=1e-06
# EM start iterations, llf=-12793
# EM converged at iteration 36, llf=-12659, convergence criterion=9.7246e-07 < tolerance=1e-06
# EM start iterations, llf=-12854
# EM converged at iteration 35, llf=-12719, convergence criterion=9.9191e-07 < tolerance=1e-06
# EM start iterations, llf=-12854
# EM converged at iteration 35, llf=-12719, convergence criterion=9.9191e-07 < tolerance=1e-06
# EM start iterations, llf=-12862
# EM converged at iteration 35, llf=-12727, convergence criterion=9.9014e-07 < tolerance=1e-06
# EM start iterations, llf=-12919
# EM converged at iteration 35, llf=-12784, convergence criterion=9.7672e-07 < tolerance=1e-06
# EM start iterations, llf=-12932
# EM converged at iteration 38, llf=-12797, convergence criterion=9.8032e-07 < tolerance=1e-06
# EM start iterations, llf=-12987
# EM converged at iteration 38, llf=-12852, convergence criterion=9.7829e-07 < tolerance=1e-06
# EM start iterations, llf=-12996
# EM converged at iteration 38, llf=-12861, convergence criterion=9.7968e-07 < tolerance=1e-06
# EM start iterations, llf=-13048
# EM converged at iteration 38, llf=-12913, convergence criterion=9.8746e-07 < tolerance=1e-06
# EM start iterations, llf=-13048
# EM converged at iteration 38, llf=-12913, convergence criterion=9.8746e-07 < tolerance=1e-06
# EM start iterations, llf=-13057
# EM converged at iteration 38, llf=-12922, convergence criterion=9.8157e-07 < tolerance=1e-06
# EM start iterations, llf=-13113
# ...
# EM iteration 50, llf=-15944, convergence criterion=1.7897e-06
# EM converged at iteration 72, llf=-15943, convergence criterion=9.8606e-07 < tolerance=1e-06
# EM start iterations, llf=-16080
# EM iteration 50, llf=-15944, convergence criterion=1.7897e-06
# EM converged at iteration 72, llf=-15943, convergence criterion=9.8606e-07 < tolerance=1e-06
# EM start iterations, llf=-16098
# EM iteration 50, llf=-15963, convergence criterion=1.7973e-06
# EM converged at iteration 72, llf=-15962, convergence criterion=9.9129e-07 < tolerance=1e-06
# EM start iterations, llf=-16148
# EM iteration 50, llf=-16013, convergence criterion=1.7824e-06
# EM converged at iteration 72, llf=-16013, convergence criterion=9.791e-07 < tolerance=1e-06
# EM start iterations, llf=-16156
# EM iteration 50, llf=-16021, convergence criterion=1.7884e-06
# EM converged at iteration 72, llf=-16021, convergence criterion=9.8362e-07 < tolerance=1e-06
# EM start iterations, llf=-16206
# EM iteration 50, llf=-16071, convergence criterion=1.7659e-06
# EM converged at iteration 71, llf=-16071, convergence criterion=9.8984e-07 < tolerance=1e-06
# EM start iterations, llf=-16217
# EM iteration 50, llf=-16082, convergence criterion=1.7977e-06
# EM converged at iteration 72, llf=-16082, convergence criterion=9.878e-07 < tolerance=1e-06
# EM start iterations, llf=-16267
# EM iteration 50, llf=-16133, convergence criterion=1.8046e-06
# EM converged at iteration 72, llf=-16132, convergence criterion=9.9886e-07 < tolerance=1e-06
# EM start iterations, llf=-16267
# EM iteration 50, llf=-16133, convergence criterion=1.8046e-06
# EM converged at iteration 72, llf=-16132, convergence criterion=9.9886e-07 < tolerance=1e-06
# EM start iterations, llf=-16277
# EM iteration 50, llf=-16142, convergence criterion=1.8052e-06
# EM converged at iteration 72, llf=-16141, convergence criterion=9.9802e-07 < tolerance=1e-06
# EM start iterations, llf=-16324
# EM iteration 50, llf=-16190, convergence criterion=1.7819e-06
# EM converged at iteration 72, llf=-16189, convergence criterion=9.8196e-07 < tolerance=1e-06
# EM start iterations, llf=-16332
# EM iteration 50, llf=-16198, convergence criterion=1.792e-06
# EM converged at iteration 72, llf=-16197, convergence criterion=9.8999e-07 < tolerance=1e-06
# EM start iterations, llf=-16385
# EM iteration 50, llf=-16250, convergence criterion=1.8189e-06
# EM converged at iteration 73, llf=-16249, convergence criterion=9.8322e-07 < tolerance=1e-06
# EM start iterations, llf=-16392
# EM iteration 50, llf=-16257, convergence criterion=1.8216e-06
# EM converged at iteration 73, llf=-16257, convergence criterion=9.8533e-07 < tolerance=1e-06
# EM start iterations, llf=-16443
# EM iteration 50, llf=-16308, convergence criterion=1.8192e-06
# EM converged at iteration 73, llf=-16307, convergence criterion=9.8054e-07 < tolerance=1e-06
# EM start iterations, llf=-16443
# EM iteration 50, llf=-16308, convergence criterion=1.8192e-06
# EM converged at iteration 73, llf=-16307, convergence criterion=9.8054e-07 < tolerance=1e-06
# EM start iterations, llf=-16451
# EM iteration 50, llf=-16315, convergence criterion=1.8102e-06
# EM converged at iteration 72, llf=-16315, convergence criterion=9.975e-07 < tolerance=1e-06
# EM start iterations, llf=-16496
# EM iteration 50, llf=-16361, convergence criterion=1.7733e-06
# EM converged at iteration 72, llf=-16361, convergence criterion=9.8085e-07 < tolerance=1e-06
# EM start iterations, llf=-16504
# EM iteration 50, llf=-16369, convergence criterion=1.7697e-06
# EM converged at iteration 71, llf=-16369, convergence criterion=9.9774e-07 < tolerance=1e-06
# EM start iterations, llf=-16553
# EM iteration 50, llf=-16418, convergence criterion=1.7584e-06
# EM converged at iteration 71, llf=-16417, convergence criterion=9.8639e-07 < tolerance=1e-06
# EM start iterations, llf=-16560
# EM iteration 50, llf=-16424, convergence criterion=1.8087e-06
# EM converged at iteration 72, llf=-16423, convergence criterion=9.9665e-07 < tolerance=1e-06
# EM start iterations, llf=-16610
# EM iteration 50, llf=-16475, convergence criterion=1.7977e-06
# EM converged at iteration 72, llf=-16474, convergence criterion=9.9316e-07 < tolerance=1e-06
# EM start iterations, llf=-16610
# EM iteration 50, llf=-16475, convergence criterion=1.7977e-06
# EM converged at iteration 72, llf=-16474, convergence criterion=9.9316e-07 < tolerance=1e-06
# EM start iterations, llf=-16619
# EM iteration 50, llf=-16483, convergence criterion=1.7751e-06
# EM converged at iteration 71, llf=-16483, convergence criterion=9.9821e-07 < tolerance=1e-06
# EM start iterations, llf=-16668
# EM iteration 50, llf=-16532, convergence criterion=1.7612e-06
# EM converged at iteration 71, llf=-16532, convergence criterion=9.8949e-07 < tolerance=1e-06
# EM start iterations, llf=-16679
# EM iteration 50, llf=-16543, convergence criterion=1.7772e-06
# EM converged at iteration 71, llf=-16543, convergence criterion=9.992e-07 < tolerance=1e-06
# EM start iterations, llf=-16731
# EM iteration 50, llf=-16595, convergence criterion=1.782e-06
# EM converged at iteration 71, llf=-16594, convergence criterion=9.9751e-07 < tolerance=1e-06
# EM start iterations, llf=-16736
# EM iteration 50, llf=-16600, convergence criterion=1.7619e-06
# EM converged at iteration 71, llf=-16600, convergence criterion=9.8439e-07 < tolerance=1e-06
# EM start iterations, llf=-16782
# EM iteration 50, llf=-16646, convergence criterion=1.7621e-06
# EM converged at iteration 71, llf=-16645, convergence criterion=9.85e-07 < tolerance=1e-06
# EM start iterations, llf=-16782
# EM iteration 50, llf=-16646, convergence criterion=1.7621e-06
# EM converged at iteration 71, llf=-16645, convergence criterion=9.85e-07 < tolerance=1e-06
# EM start iterations, llf=-16795
# EM iteration 50, llf=-16659, convergence criterion=1.7696e-06
# EM converged at iteration 71, llf=-16658, convergence criterion=9.8809e-07 < tolerance=1e-06
# EM start iterations, llf=-16852
# EM iteration 50, llf=-16715, convergence criterion=1.7528e-06
# EM converged at iteration 71, llf=-16715, convergence criterion=9.7935e-07 < tolerance=1e-06
# EM start iterations, llf=-16858
# EM iteration 50, llf=-16721, convergence criterion=1.7632e-06
# EM converged at iteration 71, llf=-16720, convergence criterion=9.9055e-07 < tolerance=1e-06
# EM start iterations, llf=-16903
# EM iteration 50, llf=-16767, convergence criterion=1.7346e-06
# EM converged at iteration 70, llf=-16766, convergence criterion=9.9602e-07 < tolerance=1e-06
# EM start iterations, llf=-16915
# EM iteration 50, llf=-16778, convergence criterion=1.7178e-06
# EM converged at iteration 70, llf=-16777, convergence criterion=9.8466e-07 < tolerance=1e-06
# EM start iterations, llf=-16752
# EM iteration 50, llf=-16621, convergence criterion=1.7406e-06
# EM converged at iteration 71, llf=-16620, convergence criterion=9.8744e-07 < tolerance=1e-06
# EM start iterations, llf=-16752
# EM iteration 50, llf=-16621, convergence criterion=1.7406e-06
# EM converged at iteration 71, llf=-16620, convergence criterion=9.8744e-07 < tolerance=1e-06
# EM start iterations, llf=-16759
# EM iteration 50, llf=-16628, convergence criterion=1.7486e-06
# EM converged at iteration 71, llf=-16627, convergence criterion=9.9238e-07 < tolerance=1e-06
# EM start iterations, llf=-16809
# EM iteration 50, llf=-16675, convergence criterion=1.7763e-06
# EM converged at iteration 72, llf=-16675, convergence criterion=9.8994e-07 < tolerance=1e-06
# EM start iterations, llf=-16819
# EM iteration 50, llf=-16685, convergence criterion=1.7718e-06
# EM converged at iteration 72, llf=-16685, convergence criterion=9.9251e-07 < tolerance=1e-06
# EM start iterations, llf=-16872
# EM iteration 50, llf=-16738, convergence criterion=1.731e-06
# EM converged at iteration 71, llf=-16737, convergence criterion=9.9362e-07 < tolerance=1e-06
# EM start iterations, llf=-16879
# EM iteration 50, llf=-16744, convergence criterion=1.7422e-06
# EM converged at iteration 71, llf=-16744, convergence criterion=9.9777e-07 < tolerance=1e-06
# EM start iterations, llf=-16935
# EM iteration 50, llf=-16801, convergence criterion=1.7212e-06
# EM converged at iteration 71, llf=-16800, convergence criterion=9.8282e-07 < tolerance=1e-06
# EM start iterations, llf=-16935
# EM iteration 50, llf=-16801, convergence criterion=1.7212e-06
# EM converged at iteration 71, llf=-16800, convergence criterion=9.8282e-07 < tolerance=1e-06
# EM start iterations, llf=-16941
# EM iteration 50, llf=-16807, convergence criterion=1.7342e-06
# EM converged at iteration 71, llf=-16806, convergence criterion=9.8927e-07 < tolerance=1e-06
# EM start iterations, llf=-16987
# EM iteration 50, llf=-16852, convergence criterion=1.6647e-06
# EM converged at iteration 69, llf=-16852, convergence criterion=9.969e-07 < tolerance=1e-06
# EM start iterations, llf=-16995
# EM iteration 50, llf=-16860, convergence criterion=1.6526e-06
# EM converged at iteration 69, llf=-16860, convergence criterion=9.8846e-07 < tolerance=1e-06
# EM start iterations, llf=-17046
# EM iteration 50, llf=-16911, convergence criterion=1.6179e-06
# EM converged at iteration 68, llf=-16911, convergence criterion=9.9127e-07 < tolerance=1e-06
# EM start iterations, llf=-17053
# EM iteration 50, llf=-16918, convergence criterion=1.6272e-06
# EM converged at iteration 68, llf=-16918, convergence criterion=9.9788e-07 < tolerance=1e-06
# EM start iterations, llf=-17104
# EM iteration 50, llf=-16969, convergence criterion=1.629e-06
# EM converged at iteration 69, llf=-16969, convergence criterion=9.7775e-07 < tolerance=1e-06
# EM start iterations, llf=-17104
# EM iteration 50, llf=-16969, convergence criterion=1.629e-06
# EM converged at iteration 69, llf=-16969, convergence criterion=9.7775e-07 < tolerance=1e-06
# EM start iterations, llf=-17111
# EM iteration 50, llf=-16976, convergence criterion=1.6184e-06
# EM converged at iteration 68, llf=-16975, convergence criterion=9.9681e-07 < tolerance=1e-06
# EM start iterations, llf=-17166
# EM iteration 50, llf=-17030, convergence criterion=1.615e-06
# EM converged at iteration 68, llf=-17030, convergence criterion=9.9375e-07 < tolerance=1e-06
# EM start iterations, llf=-17171
# EM iteration 50, llf=-17037, convergence criterion=1.6229e-06
# EM converged at iteration 69, llf=-17036, convergence criterion=9.7676e-07 < tolerance=1e-06
# EM start iterations, llf=-17217
# EM iteration 50, llf=-17082, convergence criterion=1.6131e-06
# EM converged at iteration 68, llf=-17081, convergence criterion=9.9256e-07 < tolerance=1e-06
# EM start iterations, llf=-17231
# EM iteration 50, llf=-17096, convergence criterion=1.6043e-06
# EM converged at iteration 68, llf=-17095, convergence criterion=9.8651e-07 < tolerance=1e-06
# EM start iterations, llf=-17275
# EM iteration 50, llf=-17139, convergence criterion=1.5909e-06
# EM converged at iteration 68, llf=-17139, convergence criterion=9.812e-07 < tolerance=1e-06
# EM start iterations, llf=-17275
# EM iteration 50, llf=-17139, convergence criterion=1.5909e-06
# EM converged at iteration 68, llf=-17139, convergence criterion=9.812e-07 < tolerance=1e-06
# EM start iterations, llf=-17283
# EM iteration 50, llf=-17147, convergence criterion=1.5861e-06
# EM converged at iteration 68, llf=-17147, convergence criterion=9.77e-07 < tolerance=1e-06
# EM start iterations, llf=-17330
# EM iteration 50, llf=-17195, convergence criterion=1.5945e-06
# EM converged at iteration 67, llf=-17195, convergence criterion=9.9921e-07 < tolerance=1e-06
# EM start iterations, llf=-17339
# EM iteration 50, llf=-17204, convergence criterion=1.5958e-06
# EM converged at iteration 67, llf=-17204, convergence criterion=9.9871e-07 < tolerance=1e-06
# EM start iterations, llf=-17384
# EM iteration 50, llf=-17248, convergence criterion=1.595e-06
# EM converged at iteration 68, llf=-17247, convergence criterion=9.766e-07 < tolerance=1e-06
# EM start iterations, llf=-17391
# EM iteration 50, llf=-17255, convergence criterion=1.6216e-06
# EM converged at iteration 68, llf=-17254, convergence criterion=9.9344e-07 < tolerance=1e-06
# EM start iterations, llf=-17437
# EM iteration 50, llf=-17301, convergence criterion=1.5562e-06
# EM converged at iteration 67, llf=-17301, convergence criterion=9.791e-07 < tolerance=1e-06
# EM start iterations, llf=-17437
# EM iteration 50, llf=-17301, convergence criterion=1.5562e-06
# EM converged at iteration 67, llf=-17301, convergence criterion=9.791e-07 < tolerance=1e-06
# EM start iterations, llf=-17445
# EM iteration 50, llf=-17309, convergence criterion=1.5337e-06
# EM converged at iteration 66, llf=-17309, convergence criterion=9.8821e-07 < tolerance=1e-06
# EM start iterations, llf=-17499
# EM iteration 50, llf=-17361, convergence criterion=1.5159e-06
# EM converged at iteration 66, llf=-17361, convergence criterion=9.7657e-07 < tolerance=1e-06
# EM start iterations, llf=-17507
# EM iteration 50, llf=-17369, convergence criterion=1.5288e-06
# EM converged at iteration 66, llf=-17369, convergence criterion=9.8672e-07 < tolerance=1e-06
# EM start iterations, llf=-17554
# EM iteration 50, llf=-17417, convergence criterion=1.5703e-06
# EM converged at iteration 67, llf=-17417, convergence criterion=9.8773e-07 < tolerance=1e-06
# EM start iterations, llf=-17563
# EM iteration 50, llf=-17426, convergence criterion=1.5769e-06
# EM converged at iteration 67, llf=-17425, convergence criterion=9.9232e-07 < tolerance=1e-06
# EM start iterations, llf=-17614
# EM iteration 50, llf=-17477, convergence criterion=1.6526e-06
# EM converged at iteration 69, llf=-17477, convergence criterion=9.9429e-07 < tolerance=1e-06
# EM start iterations, llf=-17614
# EM iteration 50, llf=-17477, convergence criterion=1.6526e-06
# EM converged at iteration 69, llf=-17477, convergence criterion=9.9429e-07 < tolerance=1e-06
# EM start iterations, llf=-17620
# EM iteration 50, llf=-17482, convergence criterion=1.616e-06
# EM converged at iteration 68, llf=-17482, convergence criterion=9.9615e-07 < tolerance=1e-06
# EM start iterations, llf=-17678
# EM iteration 50, llf=-17539, convergence criterion=1.5725e-06
# EM converged at iteration 67, llf=-17539, convergence criterion=9.9058e-07 < tolerance=1e-06
# EM start iterations, llf=-17688
# EM iteration 50, llf=-17549, convergence criterion=1.5852e-06
# EM converged at iteration 68, llf=-17548, convergence criterion=9.7724e-07 < tolerance=1e-06
# EM start iterations, llf=-17739
# EM iteration 50, llf=-17599, convergence criterion=1.5805e-06
# EM converged at iteration 67, llf=-17599, convergence criterion=9.972e-07 < tolerance=1e-06
# EM start iterations, llf=-17746
# EM iteration 50, llf=-17606, convergence criterion=1.5796e-06
# EM converged at iteration 67, llf=-17606, convergence criterion=9.9721e-07 < tolerance=1e-06
# EM start iterations, llf=-17790
# EM iteration 50, llf=-17650, convergence criterion=1.5806e-06
# EM converged at iteration 67, llf=-17650, convergence criterion=9.9563e-07 < tolerance=1e-06
# EM start iterations, llf=-17790
# EM iteration 50, llf=-17650, convergence criterion=1.5806e-06
# EM converged at iteration 67, llf=-17650, convergence criterion=9.9563e-07 < tolerance=1e-06
# EM start iterations, llf=-17534
# EM iteration 50, llf=-17400, convergence criterion=1.5521e-06
# EM converged at iteration 67, llf=-17399, convergence criterion=9.8792e-07 < tolerance=1e-06
# EM start iterations, llf=-17586
# EM iteration 50, llf=-17452, convergence criterion=1.5722e-06
# EM converged at iteration 68, llf=-17452, convergence criterion=9.7863e-07 < tolerance=1e-06
# EM start iterations, llf=-17599
# EM iteration 50, llf=-17466, convergence criterion=1.5633e-06
# EM converged at iteration 67, llf=-17465, convergence criterion=9.9455e-07 < tolerance=1e-06
# EM start iterations, llf=-17650
# EM iteration 50, llf=-17516, convergence criterion=1.5971e-06
# EM converged at iteration 68, llf=-17515, convergence criterion=9.9234e-07 < tolerance=1e-06
# EM start iterations, llf=-17655
# EM iteration 50, llf=-17521, convergence criterion=1.5896e-06
# EM converged at iteration 68, llf=-17520, convergence criterion=9.8707e-07 < tolerance=1e-06
# EM start iterations, llf=-17705
# EM iteration 50, llf=-17571, convergence criterion=1.5802e-06
# EM converged at iteration 68, llf=-17571, convergence criterion=9.8441e-07 < tolerance=1e-06
# Model with Global factors = 3 and order = 3 estimated in 3:26:40.986279.
# Overall time taken for running all models: 16:22:17.916065.

# %% [markdown]
# Plot MSE values for all models evaluated over the 2008–2018 period.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]
q_var = 'GDP'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Define the directory containing MSE files
mse_dir = f"../MSE/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"

# Create a figure with 1 row and 3 columns of subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Loop over each number of global factors (1, 2, and 3)
for i, num_factors in enumerate(range(1, 4)):
    ax = axs[i]
    # Within each subplot, loop over factor orders 1 to 3
    for order in range(1, 4):
        # Construct file name based on the model's parameters
        factors_str = f"Global_{num_factors}_{order}"
        mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
        mse_file_path = os.path.join(mse_dir, mse_file_name)
        
        # Load the MSE values from file
        mse_df = pd.read_csv(mse_file_path)
        # Construct y values based on the vintages
        y_values = [mse_df[col].iloc[0] for col in vintage_col_names]
        
        # Extend the y-values so the step function holds the last value
        y_extended = y_values.copy()
        y_extended.append(y_values[-1]) # Repeat the last value
        
        # Plot the step function for the current model
        ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
                 label=f"Order: {order}")
        
    # Customize the subplot
    ax.set_xlabel("Month of Quarter")
    # Set ticks only at 1, 2, and 3 to mark the beginning of each month
    ax.set_xticks([1, 2, 3])
    ax.set_xlim(0.9, 4.1)
    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    if i == 0:  # Only the leftmost subplot gets the y-axis label
        ax.set_ylabel("MSE")
    ax.legend()

plt.suptitle(f"MSE for Different Models ({q_var}, 2008-2018)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
os.makedirs(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
base_filename = os.path.join(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_2008-2018_{q_var}")
plt.savefig(f"{base_filename}.png", format="png")
plt.savefig(f"{base_filename}.eps", format="eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot MSE values for all models evaluated over the 2008–2010 and 2011-2018 periods.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
forecasts_dir = f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Define two periods
periods = {
    "2008-2010": lambda df: df["date_float"] < 2011,
    "2011-2018": lambda df: df["date_float"] >= 2011
}

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Loop over each period and create a separate figure
for period_label, period_filter in periods.items():
    
    # Create a figure with 1 row and 3 columns of subplots
    fig, axs = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
    
    # Loop over each number of global factors (1, 2, and 3)
    for i, num_factors in enumerate(range(1, 4)):
        ax = axs[i]
        # Within each subplot, loop over factor orders 1 to 3
        for order in range(1, 4):
            # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
            factors_str = f"Global_{num_factors}_{order}"
            forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
            forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)
    
            # Load forecast data 
            forecasts = pd.read_csv(forecast_file_path, index_col=0)
            forecasts.index.name = "date"
            forecasts.reset_index(inplace=True)
            
            # Merge forecasts with actual growth 
            merged = pd.merge(forecasts, actual_growth, on="date", how="inner")
            merged["date_float"] = merged["date"].apply(quarter_to_float)
            merged.sort_values("date_float", inplace=True)
            
            # Filter merged data for the current period
            merged_period = merged[ period_filter(merged) ]
            
            # Calculate MSE for each vintage column over the filtered period
            mse_dict = {}
            for col in vintage_col_names:
                mse = ((merged_period[col] - merged_period["growth"]) ** 2).mean()
                mse_dict[col] = mse
                
            # Construct y values based on the vintages
            y_values = [mse_dict[col] for col in vintage_col_names]
            
            # Extend the y-values so the step function holds the last value
            y_extended = y_values.copy()
            y_extended.append(y_values[-1]) # Repeat the last value
            
            # Plot the step function for the current model (order)
            ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
                    label=f"Order: {order}")
            
        # Customize the subplot
        ax.set_xlabel("Month of Quarter")
        # Set ticks only at 1, 2, and 3 to mark the beginning of each month
        ax.set_xticks([1, 2, 3])
        ax.set_xlim(0.9, 4.1)
        ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
        if i == 0:  # Only the leftmost subplot gets the y-axis label
            ax.set_ylabel("MSE")
        ax.legend()
   
    plt.suptitle(f"MSE for Different Models ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png")
    plt.savefig(f"{base_filename}.eps", format="eps")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot forecasts vs actual growth values for all models and different time periods (2008-2010, 2008-2018, and 2011-2018).

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Convert quarter strings like "2008-03" into a float (e.g. 2008.00 for Q1, 2008.25 for Q2, etc.)
def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
forecasts_dir = f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Assign 7 small offsets within each quarter, so each quarter has 7 forecast points
offsets = np.linspace(0, 0.23, 7)

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Build x,y arrays for the actual growth
x_act = actual_growth["date_float"].tolist()
y_act = actual_growth["growth"].tolist()

# Define period configurations: x-axis limits and tick positions for each period
period_configs = {
    "2008-2010": {"xlim": (2008, 2010.99), "xticks": list(range(2008, 2011))},
    "2008-2018": {"xlim": (2008, 2018.99), "xticks": list(range(2008, 2019))},
    "2011-2018": {"xlim": (2011, 2018.99), "xticks": list(range(2011, 2019))}
}

# Loop over each period configuration to create and save separate plots
for period_label, config in period_configs.items():
    
    # Extend the actual growth arrays so that the step function continues until the end of the x-axis
    if period_label in ["2008-2018", "2011-2018"]:
        x_act_extended = x_act.copy()
        x_act_extended.append(config["xlim"][1])
        y_act_extended = y_act.copy()
        y_act_extended.append(y_act[-1])
    else:
        x_act_extended = x_act
        y_act_extended = y_act

    # Create a figure with 1 row and 3 columns for the three global factor counts
    fig, axs = plt.subplots(1, 3, figsize=(24, 8), sharey=True)

    # Loop over each global factor count (1, 2, and 3)
    for i, num_factors in enumerate([1, 2, 3]):
        ax = axs[i]

        # For each global factor count, plot forecasts for orders 1, 2, and 3
        for order in range(1, 4):

            # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
            factors_str = f"Global_{num_factors}_{order}"
            forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
            forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

            # Load forecast data 
            forecasts = pd.read_csv(forecast_file_path, index_col=0)
            forecasts.index.name = "date"
            forecasts.reset_index(inplace=True)

            # Merge forecasts with actual growth dates
            merged = pd.merge(forecasts, actual_growth[['date']], on="date", how="inner")
            merged["date_float"] = merged["date"].apply(quarter_to_float)
            merged.sort_values("date_float", inplace=True)

            # Build forecast x and y arrays 
            x_fore = []
            y_fore = []
            for idx, row in merged.iterrows():
                base_x = row["date_float"]
                # For each of the 7 vintage columns, define an x-position and take that forecast value
                for j, col in enumerate(vintage_col_names):
                    x_fore.append(base_x + offsets[j])
                    y_fore.append(row[col])

            # Plot the forecast step curve for the current order
            ax.step(x_fore, y_fore, where='post', linewidth=1.2, label=f"Order: {order}")

        # Plot actual growth as a step plot in each subplot
        ax.step(x_act_extended, y_act_extended, where='post', color='black', linewidth=1.2, label="Actual growth")

        # Customize the subplot
        ax.set_xlabel("Year")
        ax.set_xlim(config["xlim"][0], config["xlim"][1])
        ax.set_xticks(config["xticks"])
        
        # Set y-axis limits based on the data within the period range
        x_min, x_max = config["xlim"]
        def filter_points(x_arr, y_arr, x_min, x_max):
            return [y for x, y in zip(x_arr, y_arr) if x_min <= x <= x_max]

        # Filter y-values
        y_filtered = filter_points(x_fore, y_fore, x_min, x_max)
        y_act_filtered = filter_points(x_act_extended, y_act_extended, x_min, x_max)
        
        # Combine all filtered y-values
        combined_y = y_filtered + y_act_filtered
        ax.set_ylim(1.05 * min(combined_y), 1.2 * max(combined_y))
        
        ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
        if i == 0:
            ax.set_ylabel("Annualized q-o-q Growth (%)")
        ax.legend()
        
    plt.suptitle(f"Forecast vs Actual Growth for Different Models ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_forecast_vs_actual_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png")
    plt.savefig(f"{base_filename}.eps", format="eps")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
