# %% [markdown]
# # Out-of-sample forecasting experiments
#
# I conduct out-of-sample forecasting experiments to understand what kind of text data (topics, sentiment, or uncertainty) helps improve forecasts of three quarterly variables (GDP, Investment, and Consumption) more.
#
# In this notebook, I evaluate the performance of dynamic factor models (DFM) using only 10 sentiment-adjusted topics (BPW) most highly correlated with Consumption growth (out of 200 topics estimated on articles published before 2008 using all sources). I use text data to forecast Consumption growth.
#
# ## Experiment Details
#
# - **Data Sources:** 10 sentiment-adjusted topics, BPW (<=2007, 200 topics, all sources).
# - **Forecast Target:** Consumption growth.
# - **Model:** Dynamic Factor Models (DFM).
# - **Parameters Explored:**
#   - **Number of Global Factors:** 1
#   - **Factor Order:** 3

# %%
import os
import time
import datetime
import pandas as pd
import DFM_function

# Define inputs common to all models
q_var = 'Consumption'              # quarterly variable being forecasted
additional_factors = None          # or "all" or e.g. ['Labor market']
start = '1991-04'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"
with_text = True
only_text = True

# Generate list of forecast_month strings for quarters from 2008Q1 to 2018Q4
# forecast_month is set to the month corresponding to quarter-end:
# Q1: 'YYYY-03', Q2: 'YYYY-06', Q3: 'YYYY-09', Q4: 'YYYY-12'
forecast_months = []
for year in range(2008, 2019):
    forecast_months.extend([f"{year}-03", f"{year}-06", f"{year}-09", f"{year}-12"])
    
# Define the vintage column names 
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Create directories to save forecasts and MSE results
os.makedirs(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
os.makedirs(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)

# Load the actual growth data
actual_growth_file = f"../{q_var}_growth_actual.csv"
actual_growth = pd.read_csv(actual_growth_file)

num_factors = 1
order = 3
      
# Define model-specific parameters
factor_multiplicities = {'Global': num_factors}
factor_orders = {'Global': order}

# Prepare lists to store each quarter's forecasts and row labels
forecasts_all_quarters = []
row_labels = []

# Start timing for this model
start_time = time.time()

# Loop over each forecast month, get the forecasts, and store the results
for fm in forecast_months:
    # Use the forecast_month string as the row label
    row_labels.append(fm)

    # Run the forecast function for this quarter
    forecasts_dict = DFM_function.get_forecasts(
        forecast_month = fm,
        q_var = q_var,
        additional_factors = additional_factors,
        factor_multiplicities = factor_multiplicities,
        factor_orders = factor_orders,
        start = start,
        text_type = text_type,
        estimation_period = estimation_period,
        num_topics = num_topics,
        source = source,
        with_text = with_text,
        only_text = only_text
    )

    # Obtain the correct ordering of vintages
    vintages_order = DFM_function.vintage_dates(fm)
    # Extract the forecast value for each vintage in that order
    quarter_forecasts = [forecasts_dict[vint] for vint in vintages_order]
    forecasts_all_quarters.append(quarter_forecasts)

# Create a DataFrame with rows labeled by the forecast_month strings and columns as vintage names
results = pd.DataFrame(forecasts_all_quarters, index=row_labels, columns=vintage_col_names)

# Stop timing for this model and print elapsed time
elapsed = time.time() - start_time
elapsed_time = datetime.timedelta(seconds=elapsed)
print(f"Model with Global factors = {num_factors} and order = {order} estimated in {elapsed_time}.")

# Construct the output file name
factors_str = "_".join([
    f"{factor.replace(' ', '_')}_{factor_multiplicities[factor]}_{factor_orders[factor]}"
    for factor in factor_multiplicities])
file_name = f"forecasts_{q_var}_{factors_str}.csv"

# Save the CSV file in a subfolder 
output_path = os.path.join(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", file_name)
results.to_csv(output_path, index=True)

# ----- MSE Calculation -----
# Load forecasts
forecasts = pd.read_csv(output_path, index_col=0)
# Make sure the index is a column named "date"
forecasts.index.name = "date"
forecasts.reset_index(inplace=True)

# Merge dfs by date 
merged = pd.merge(forecasts, actual_growth, on="date", how="inner")

# Calculate the Mean Squared Error (MSE) for each vintage column
mse_dict = {}
for col in vintage_col_names:
    mse = ((merged[col] - merged["growth"]) ** 2).mean()
    mse_dict[col] = mse

# Create a df with one row (the MSE values for each forecasting horizon)
mse_df = pd.DataFrame(mse_dict, index=[0])

# Save MSE results to CSV
mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
mse_output_path = os.path.join(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", mse_file_name)
mse_df.to_csv(mse_output_path, index=False)
# Out:
# EM start iterations, llf=-2735.6
# EM iteration 100, llf=-2696.1, convergence criterion=1.7208e-06
# EM converged at iteration 132, llf=-2696, convergence criterion=9.9455e-07 < tolerance=1e-06
# EM start iterations, llf=-2735.6
# EM iteration 100, llf=-2696.1, convergence criterion=1.7208e-06
# EM converged at iteration 132, llf=-2696, convergence criterion=9.9455e-07 < tolerance=1e-06
# EM start iterations, llf=-2748.1
# EM iteration 100, llf=-2708.2, convergence criterion=1.6812e-06
# EM converged at iteration 130, llf=-2708.1, convergence criterion=9.9861e-07 < tolerance=1e-06
# EM start iterations, llf=-2748.1
# EM iteration 100, llf=-2708.2, convergence criterion=1.6812e-06
# EM converged at iteration 130, llf=-2708.1, convergence criterion=9.9861e-07 < tolerance=1e-06
# EM start iterations, llf=-2762.8
# EM iteration 100, llf=-2722.7, convergence criterion=1.6917e-06
# EM converged at iteration 131, llf=-2722.6, convergence criterion=9.9069e-07 < tolerance=1e-06
# EM start iterations, llf=-2762.8
# EM iteration 100, llf=-2722.7, convergence criterion=1.6917e-06
# EM converged at iteration 131, llf=-2722.6, convergence criterion=9.9069e-07 < tolerance=1e-06
# EM start iterations, llf=-2775.8
# EM iteration 100, llf=-2735.5, convergence criterion=1.6861e-06
# EM converged at iteration 131, llf=-2735.4, convergence criterion=9.8811e-07 < tolerance=1e-06
# EM start iterations, llf=-2775.8
# EM iteration 100, llf=-2735.5, convergence criterion=1.6861e-06
# EM converged at iteration 131, llf=-2735.4, convergence criterion=9.8811e-07 < tolerance=1e-06
# EM start iterations, llf=-2775.8
# EM iteration 100, llf=-2735.5, convergence criterion=1.6861e-06
# EM converged at iteration 131, llf=-2735.4, convergence criterion=9.8811e-07 < tolerance=1e-06
# EM start iterations, llf=-2790.2
# EM iteration 100, llf=-2749.7, convergence criterion=1.6826e-06
# EM converged at iteration 131, llf=-2749.6, convergence criterion=9.8828e-07 < tolerance=1e-06
# EM start iterations, llf=-2790.2
# EM iteration 100, llf=-2749.7, convergence criterion=1.6826e-06
# EM converged at iteration 131, llf=-2749.6, convergence criterion=9.8828e-07 < tolerance=1e-06
# EM start iterations, llf=-2804.1
# EM iteration 100, llf=-2763.5, convergence criterion=1.7094e-06
# EM converged at iteration 132, llf=-2763.4, convergence criterion=9.868e-07 < tolerance=1e-06
# EM start iterations, llf=-2804.1
# EM iteration 100, llf=-2763.5, convergence criterion=1.7094e-06
# EM converged at iteration 132, llf=-2763.4, convergence criterion=9.868e-07 < tolerance=1e-06
# EM start iterations, llf=-2814.1
# EM iteration 100, llf=-2773.5, convergence criterion=1.7152e-06
# EM converged at iteration 132, llf=-2773.4, convergence criterion=9.9036e-07 < tolerance=1e-06
# EM start iterations, llf=-2814.1
# EM iteration 100, llf=-2773.5, convergence criterion=1.7152e-06
# EM converged at iteration 132, llf=-2773.4, convergence criterion=9.9036e-07 < tolerance=1e-06
# EM start iterations, llf=-2814.1
# EM iteration 100, llf=-2773.5, convergence criterion=1.7152e-06
# EM converged at iteration 132, llf=-2773.4, convergence criterion=9.9036e-07 < tolerance=1e-06
# EM start iterations, llf=-2825.6
# EM iteration 100, llf=-2785.1, convergence criterion=1.6979e-06
# EM converged at iteration 131, llf=-2785, convergence criterion=9.9612e-07 < tolerance=1e-06
# EM start iterations, llf=-2825.6
# EM iteration 100, llf=-2785.1, convergence criterion=1.6979e-06
# EM converged at iteration 131, llf=-2785, convergence criterion=9.9612e-07 < tolerance=1e-06
# EM start iterations, llf=-2842.9
# EM iteration 100, llf=-2802.5, convergence criterion=1.5762e-06
# EM converged at iteration 126, llf=-2802.5, convergence criterion=9.9244e-07 < tolerance=1e-06
# EM start iterations, llf=-2842.9
# EM iteration 100, llf=-2802.5, convergence criterion=1.5762e-06
# EM converged at iteration 126, llf=-2802.5, convergence criterion=9.9244e-07 < tolerance=1e-06
# EM start iterations, llf=-2849
# EM iteration 100, llf=-2808.9, convergence criterion=1.6426e-06
# EM converged at iteration 129, llf=-2808.8, convergence criterion=9.9874e-07 < tolerance=1e-06
# EM start iterations, llf=-2849
# EM iteration 100, llf=-2808.9, convergence criterion=1.6426e-06
# EM converged at iteration 129, llf=-2808.8, convergence criterion=9.9874e-07 < tolerance=1e-06
# EM start iterations, llf=-2849
# EM iteration 100, llf=-2808.9, convergence criterion=1.6426e-06
# EM converged at iteration 129, llf=-2808.8, convergence criterion=9.9874e-07 < tolerance=1e-06
# EM start iterations, llf=-2873.8
# EM iteration 100, llf=-2834, convergence criterion=1.5574e-06
# EM converged at iteration 126, llf=-2833.9, convergence criterion=9.8859e-07 < tolerance=1e-06
# EM start iterations, llf=-2873.8
# EM iteration 100, llf=-2834, convergence criterion=1.5574e-06
# EM converged at iteration 126, llf=-2833.9, convergence criterion=9.8859e-07 < tolerance=1e-06
# EM start iterations, llf=-2883.5
# EM iteration 100, llf=-2843.6, convergence criterion=1.5518e-06
# EM converged at iteration 125, llf=-2843.5, convergence criterion=9.9844e-07 < tolerance=1e-06
# EM start iterations, llf=-2883.5
# EM iteration 100, llf=-2843.6, convergence criterion=1.5518e-06
# EM converged at iteration 125, llf=-2843.5, convergence criterion=9.9844e-07 < tolerance=1e-06
# EM start iterations, llf=-2894.6
# EM iteration 100, llf=-2854.8, convergence criterion=1.5744e-06
# EM converged at iteration 127, llf=-2854.7, convergence criterion=9.8546e-07 < tolerance=1e-06
# EM start iterations, llf=-2894.6
# EM iteration 100, llf=-2854.8, convergence criterion=1.5744e-06
# EM converged at iteration 127, llf=-2854.7, convergence criterion=9.8546e-07 < tolerance=1e-06
# EM start iterations, llf=-2894.6
# EM iteration 100, llf=-2854.8, convergence criterion=1.5744e-06
# EM converged at iteration 127, llf=-2854.7, convergence criterion=9.8546e-07 < tolerance=1e-06
# EM start iterations, llf=-2906.9
# EM iteration 100, llf=-2867.2, convergence criterion=1.5391e-06
# EM converged at iteration 125, llf=-2867.1, convergence criterion=9.9378e-07 < tolerance=1e-06
# EM start iterations, llf=-2906.9
# EM iteration 100, llf=-2867.2, convergence criterion=1.5391e-06
# EM converged at iteration 125, llf=-2867.1, convergence criterion=9.9378e-07 < tolerance=1e-06
# EM start iterations, llf=-2918.9
# EM iteration 100, llf=-2879.2, convergence criterion=1.4348e-06
# EM converged at iteration 121, llf=-2879.1, convergence criterion=9.8422e-07 < tolerance=1e-06
# EM start iterations, llf=-2918.9
# EM iteration 100, llf=-2879.2, convergence criterion=1.4348e-06
# EM converged at iteration 121, llf=-2879.1, convergence criterion=9.8422e-07 < tolerance=1e-06
# EM start iterations, llf=-2929.1
# EM iteration 100, llf=-2889, convergence criterion=1.5022e-06
# EM converged at iteration 123, llf=-2888.9, convergence criterion=9.9766e-07 < tolerance=1e-06
# EM start iterations, llf=-2929.1
# EM iteration 100, llf=-2889, convergence criterion=1.5022e-06
# EM converged at iteration 123, llf=-2888.9, convergence criterion=9.9766e-07 < tolerance=1e-06
# EM start iterations, llf=-2929.1
# EM iteration 100, llf=-2889, convergence criterion=1.5022e-06
# EM converged at iteration 123, llf=-2888.9, convergence criterion=9.9766e-07 < tolerance=1e-06
# EM start iterations, llf=-2936
# EM iteration 100, llf=-2895.3, convergence criterion=1.5768e-06
# EM converged at iteration 127, llf=-2895.2, convergence criterion=9.8569e-07 < tolerance=1e-06
# EM start iterations, llf=-2936
# EM iteration 100, llf=-2895.3, convergence criterion=1.5768e-06
# EM converged at iteration 127, llf=-2895.2, convergence criterion=9.8569e-07 < tolerance=1e-06
# EM start iterations, llf=-2950.9
# EM iteration 100, llf=-2910, convergence criterion=1.6059e-06
# EM converged at iteration 128, llf=-2909.9, convergence criterion=9.8773e-07 < tolerance=1e-06
# EM start iterations, llf=-2950.9
# EM iteration 100, llf=-2910, convergence criterion=1.6059e-06
# EM converged at iteration 128, llf=-2909.9, convergence criterion=9.8773e-07 < tolerance=1e-06
# EM start iterations, llf=-2964.7
# EM iteration 100, llf=-2923.8, convergence criterion=1.6072e-06
# EM converged at iteration 128, llf=-2923.7, convergence criterion=9.8922e-07 < tolerance=1e-06
# EM start iterations, llf=-2964.7
# EM iteration 100, llf=-2923.8, convergence criterion=1.6072e-06
# EM converged at iteration 128, llf=-2923.7, convergence criterion=9.8922e-07 < tolerance=1e-06
# EM start iterations, llf=-2964.7
# EM iteration 100, llf=-2923.8, convergence criterion=1.6072e-06
# EM converged at iteration 128, llf=-2923.7, convergence criterion=9.8922e-07 < tolerance=1e-06
# EM start iterations, llf=-2978.6
# EM iteration 100, llf=-2937.6, convergence criterion=1.5874e-06
# EM converged at iteration 127, llf=-2937.5, convergence criterion=9.9162e-07 < tolerance=1e-06
# EM start iterations, llf=-2978.6
# EM iteration 100, llf=-2937.6, convergence criterion=1.5874e-06
# EM converged at iteration 127, llf=-2937.5, convergence criterion=9.9162e-07 < tolerance=1e-06
# EM start iterations, llf=-2994.9
# EM iteration 100, llf=-2954.5, convergence criterion=1.4018e-06
# EM converged at iteration 119, llf=-2954.4, convergence criterion=9.9172e-07 < tolerance=1e-06
# EM start iterations, llf=-2994.9
# EM iteration 100, llf=-2954.5, convergence criterion=1.4018e-06
# EM converged at iteration 119, llf=-2954.4, convergence criterion=9.9172e-07 < tolerance=1e-06
# EM start iterations, llf=-3005.8
# EM iteration 100, llf=-2965.3, convergence criterion=1.3748e-06
# EM converged at iteration 118, llf=-2965.2, convergence criterion=9.8807e-07 < tolerance=1e-06
# EM start iterations, llf=-3005.8
# EM iteration 100, llf=-2965.3, convergence criterion=1.3748e-06
# EM converged at iteration 118, llf=-2965.2, convergence criterion=9.8807e-07 < tolerance=1e-06
# EM start iterations, llf=-3005.8
# EM iteration 100, llf=-2965.3, convergence criterion=1.3748e-06
# EM converged at iteration 118, llf=-2965.2, convergence criterion=9.8807e-07 < tolerance=1e-06
# EM start iterations, llf=-3022.3
# EM iteration 100, llf=-2981.9, convergence criterion=1.3723e-06
# EM converged at iteration 118, llf=-2981.8, convergence criterion=9.8806e-07 < tolerance=1e-06
# EM start iterations, llf=-3022.3
# EM iteration 100, llf=-2981.9, convergence criterion=1.3723e-06
# EM converged at iteration 118, llf=-2981.8, convergence criterion=9.8806e-07 < tolerance=1e-06
# EM start iterations, llf=-3037.4
# EM iteration 100, llf=-2997.3, convergence criterion=1.319e-06
# EM converged at iteration 116, llf=-2997.3, convergence criterion=9.8375e-07 < tolerance=1e-06
# EM start iterations, llf=-3037.4
# EM iteration 100, llf=-2997.3, convergence criterion=1.319e-06
# EM converged at iteration 116, llf=-2997.3, convergence criterion=9.8375e-07 < tolerance=1e-06
# EM start iterations, llf=-3050.5
# EM iteration 100, llf=-3010.3, convergence criterion=1.2854e-06
# EM converged at iteration 114, llf=-3010.3, convergence criterion=9.911e-07 < tolerance=1e-06
# EM start iterations, llf=-3050.5
# EM iteration 100, llf=-3010.3, convergence criterion=1.2854e-06
# EM converged at iteration 114, llf=-3010.3, convergence criterion=9.911e-07 < tolerance=1e-06
# EM start iterations, llf=-3050.5
# EM iteration 100, llf=-3010.3, convergence criterion=1.2854e-06
# EM converged at iteration 114, llf=-3010.3, convergence criterion=9.911e-07 < tolerance=1e-06
# EM start iterations, llf=-3062.2
# EM iteration 100, llf=-3021.9, convergence criterion=1.2812e-06
# EM converged at iteration 114, llf=-3021.8, convergence criterion=9.876e-07 < tolerance=1e-06
# EM start iterations, llf=-3062.2
# EM iteration 100, llf=-3021.9, convergence criterion=1.2812e-06
# EM converged at iteration 114, llf=-3021.8, convergence criterion=9.876e-07 < tolerance=1e-06
# EM start iterations, llf=-3076.3
# EM iteration 100, llf=-3036.1, convergence criterion=1.2838e-06
# EM converged at iteration 114, llf=-3036, convergence criterion=9.8944e-07 < tolerance=1e-06
# EM start iterations, llf=-3076.3
# EM iteration 100, llf=-3036.1, convergence criterion=1.2838e-06
# EM converged at iteration 114, llf=-3036, convergence criterion=9.8944e-07 < tolerance=1e-06
# EM start iterations, llf=-3090.2
# EM iteration 100, llf=-3050.1, convergence criterion=1.3423e-06
# EM converged at iteration 117, llf=-3050.1, convergence criterion=9.8396e-07 < tolerance=1e-06
# EM start iterations, llf=-3090.2
# EM iteration 100, llf=-3050.1, convergence criterion=1.3423e-06
# EM converged at iteration 117, llf=-3050.1, convergence criterion=9.8396e-07 < tolerance=1e-06
# EM start iterations, llf=-3090.2
# EM iteration 100, llf=-3050.1, convergence criterion=1.3423e-06
# EM converged at iteration 117, llf=-3050.1, convergence criterion=9.8396e-07 < tolerance=1e-06
# EM start iterations, llf=-3100.3
# EM iteration 100, llf=-3060.2, convergence criterion=1.3495e-06
# EM converged at iteration 117, llf=-3060.1, convergence criterion=9.8925e-07 < tolerance=1e-06
# EM start iterations, llf=-3100.3
# EM iteration 100, llf=-3060.2, convergence criterion=1.3495e-06
# EM converged at iteration 117, llf=-3060.1, convergence criterion=9.8925e-07 < tolerance=1e-06
# EM start iterations, llf=-3115.1
# EM iteration 100, llf=-3074.7, convergence criterion=1.2837e-06
# EM converged at iteration 114, llf=-3074.7, convergence criterion=9.8897e-07 < tolerance=1e-06
# EM start iterations, llf=-3115.1
# EM iteration 100, llf=-3074.7, convergence criterion=1.2837e-06
# EM converged at iteration 114, llf=-3074.7, convergence criterion=9.8897e-07 < tolerance=1e-06
# EM start iterations, llf=-3127.2
# EM iteration 100, llf=-3086.8, convergence criterion=1.2928e-06
# EM converged at iteration 114, llf=-3086.8, convergence criterion=9.9649e-07 < tolerance=1e-06
# EM start iterations, llf=-3127.2
# EM iteration 100, llf=-3086.8, convergence criterion=1.2928e-06
# EM converged at iteration 114, llf=-3086.8, convergence criterion=9.9649e-07 < tolerance=1e-06
# EM start iterations, llf=-3127.2
# EM iteration 100, llf=-3086.8, convergence criterion=1.2928e-06
# EM converged at iteration 114, llf=-3086.8, convergence criterion=9.9649e-07 < tolerance=1e-06
# EM start iterations, llf=-3141.3
# EM iteration 100, llf=-3100.8, convergence criterion=1.3175e-06
# EM converged at iteration 115, llf=-3100.8, convergence criterion=9.9962e-07 < tolerance=1e-06
# EM start iterations, llf=-3141.3
# EM iteration 100, llf=-3100.8, convergence criterion=1.3175e-06
# EM converged at iteration 115, llf=-3100.8, convergence criterion=9.9962e-07 < tolerance=1e-06
# EM start iterations, llf=-3157.6
# EM iteration 100, llf=-3116.6, convergence criterion=1.3846e-06
# EM converged at iteration 118, llf=-3116.6, convergence criterion=9.9772e-07 < tolerance=1e-06
# EM start iterations, llf=-3157.6
# EM iteration 100, llf=-3116.6, convergence criterion=1.3846e-06
# EM converged at iteration 118, llf=-3116.6, convergence criterion=9.9772e-07 < tolerance=1e-06
# EM start iterations, llf=-3168.6
# EM iteration 100, llf=-3127.7, convergence criterion=1.3395e-06
# EM converged at iteration 116, llf=-3127.6, convergence criterion=9.9744e-07 < tolerance=1e-06
# EM start iterations, llf=-3168.6
# EM iteration 100, llf=-3127.7, convergence criterion=1.3395e-06
# EM converged at iteration 116, llf=-3127.6, convergence criterion=9.9744e-07 < tolerance=1e-06
# EM start iterations, llf=-3168.6
# EM iteration 100, llf=-3127.7, convergence criterion=1.3395e-06
# EM converged at iteration 116, llf=-3127.6, convergence criterion=9.9744e-07 < tolerance=1e-06
# EM start iterations, llf=-3180.8
# EM iteration 100, llf=-3139.9, convergence criterion=1.3481e-06
# EM converged at iteration 117, llf=-3139.8, convergence criterion=9.8734e-07 < tolerance=1e-06
# EM start iterations, llf=-3180.8
# EM iteration 100, llf=-3139.9, convergence criterion=1.3481e-06
# EM converged at iteration 117, llf=-3139.8, convergence criterion=9.8734e-07 < tolerance=1e-06
# EM start iterations, llf=-3196.5
# EM iteration 100, llf=-3155.4, convergence criterion=1.2902e-06
# EM converged at iteration 114, llf=-3155.3, convergence criterion=9.9379e-07 < tolerance=1e-06
# EM start iterations, llf=-3196.5
# EM iteration 100, llf=-3155.4, convergence criterion=1.2902e-06
# EM converged at iteration 114, llf=-3155.3, convergence criterion=9.9379e-07 < tolerance=1e-06
# EM start iterations, llf=-3210.4
# EM iteration 100, llf=-3169.1, convergence criterion=1.3322e-06
# EM converged at iteration 116, llf=-3169.1, convergence criterion=9.9225e-07 < tolerance=1e-06
# EM start iterations, llf=-3210.4
# EM iteration 100, llf=-3169.1, convergence criterion=1.3322e-06
# EM converged at iteration 116, llf=-3169.1, convergence criterion=9.9225e-07 < tolerance=1e-06
# EM start iterations, llf=-3210.4
# EM iteration 100, llf=-3169.1, convergence criterion=1.3322e-06
# EM converged at iteration 116, llf=-3169.1, convergence criterion=9.9225e-07 < tolerance=1e-06
# EM start iterations, llf=-3223.8
# EM iteration 100, llf=-3182.3, convergence criterion=1.3156e-06
# EM converged at iteration 115, llf=-3182.3, convergence criterion=9.9623e-07 < tolerance=1e-06
# EM start iterations, llf=-3223.8
# EM iteration 100, llf=-3182.3, convergence criterion=1.3156e-06
# EM converged at iteration 115, llf=-3182.3, convergence criterion=9.9623e-07 < tolerance=1e-06
# EM start iterations, llf=-3238.1
# EM iteration 100, llf=-3196.3, convergence criterion=1.3277e-06
# EM converged at iteration 116, llf=-3196.2, convergence criterion=9.8727e-07 < tolerance=1e-06
# EM start iterations, llf=-3238.1
# EM iteration 100, llf=-3196.3, convergence criterion=1.3277e-06
# EM converged at iteration 116, llf=-3196.2, convergence criterion=9.8727e-07 < tolerance=1e-06
# EM start iterations, llf=-3252.8
# EM iteration 100, llf=-3210.5, convergence criterion=1.3169e-06
# EM converged at iteration 115, llf=-3210.5, convergence criterion=9.9483e-07 < tolerance=1e-06
# EM start iterations, llf=-3252.8
# EM iteration 100, llf=-3210.5, convergence criterion=1.3169e-06
# EM converged at iteration 115, llf=-3210.5, convergence criterion=9.9483e-07 < tolerance=1e-06
# EM start iterations, llf=-3252.8
# EM iteration 100, llf=-3210.5, convergence criterion=1.3169e-06
# EM converged at iteration 115, llf=-3210.5, convergence criterion=9.9483e-07 < tolerance=1e-06
# EM start iterations, llf=-3265.5
# EM iteration 100, llf=-3223.1, convergence criterion=1.2948e-06
# EM converged at iteration 114, llf=-3223.1, convergence criterion=9.951e-07 < tolerance=1e-06
# EM start iterations, llf=-3265.5
# EM iteration 100, llf=-3223.1, convergence criterion=1.2948e-06
# EM converged at iteration 114, llf=-3223.1, convergence criterion=9.951e-07 < tolerance=1e-06
# EM start iterations, llf=-3279.9
# EM iteration 100, llf=-3237.5, convergence criterion=1.339e-06
# EM converged at iteration 116, llf=-3237.5, convergence criterion=9.9487e-07 < tolerance=1e-06
# EM start iterations, llf=-3279.9
# EM iteration 100, llf=-3237.5, convergence criterion=1.339e-06
# EM converged at iteration 116, llf=-3237.5, convergence criterion=9.9487e-07 < tolerance=1e-06
# EM start iterations, llf=-3294.6
# EM iteration 100, llf=-3251.7, convergence criterion=1.3167e-06
# EM converged at iteration 115, llf=-3251.7, convergence criterion=9.9364e-07 < tolerance=1e-06
# EM start iterations, llf=-3294.6
# EM iteration 100, llf=-3251.7, convergence criterion=1.3167e-06
# EM converged at iteration 115, llf=-3251.7, convergence criterion=9.9364e-07 < tolerance=1e-06
# EM start iterations, llf=-3294.6
# EM iteration 100, llf=-3251.7, convergence criterion=1.3167e-06
# EM converged at iteration 115, llf=-3251.7, convergence criterion=9.9364e-07 < tolerance=1e-06
# EM start iterations, llf=-3306.3
# EM iteration 100, llf=-3262.6, convergence criterion=1.3352e-06
# EM converged at iteration 116, llf=-3262.5, convergence criterion=9.8919e-07 < tolerance=1e-06
# EM start iterations, llf=-3306.3
# EM iteration 100, llf=-3262.6, convergence criterion=1.3352e-06
# EM converged at iteration 116, llf=-3262.5, convergence criterion=9.8919e-07 < tolerance=1e-06
# EM start iterations, llf=-3317.9
# EM iteration 100, llf=-3273.8, convergence criterion=1.3506e-06
# EM converged at iteration 117, llf=-3273.7, convergence criterion=9.8375e-07 < tolerance=1e-06
# EM start iterations, llf=-3321.1
# EM iteration 100, llf=-3278.6, convergence criterion=1.3548e-06
# EM converged at iteration 117, llf=-3278.6, convergence criterion=9.8855e-07 < tolerance=1e-06
# EM start iterations, llf=-3334.1
# EM iteration 100, llf=-3291.2, convergence criterion=1.3445e-06
# EM converged at iteration 116, llf=-3291.1, convergence criterion=9.953e-07 < tolerance=1e-06
# EM start iterations, llf=-3334.1
# EM iteration 100, llf=-3291.2, convergence criterion=1.3445e-06
# EM converged at iteration 116, llf=-3291.1, convergence criterion=9.953e-07 < tolerance=1e-06
# EM start iterations, llf=-3334.1
# EM iteration 100, llf=-3291.2, convergence criterion=1.3445e-06
# EM converged at iteration 116, llf=-3291.1, convergence criterion=9.953e-07 < tolerance=1e-06
# EM start iterations, llf=-3346.8
# EM iteration 100, llf=-3303, convergence criterion=1.2621e-06
# EM converged at iteration 112, llf=-3303, convergence criterion=9.984e-07 < tolerance=1e-06
# EM start iterations, llf=-3346.8
# EM iteration 100, llf=-3303, convergence criterion=1.2621e-06
# EM converged at iteration 112, llf=-3303, convergence criterion=9.984e-07 < tolerance=1e-06
# EM start iterations, llf=-3361.4
# EM iteration 100, llf=-3318.7, convergence criterion=1.2671e-06
# EM converged at iteration 113, llf=-3318.6, convergence criterion=9.8834e-07 < tolerance=1e-06
# EM start iterations, llf=-3361.4
# EM iteration 100, llf=-3318.7, convergence criterion=1.2671e-06
# EM converged at iteration 113, llf=-3318.6, convergence criterion=9.8834e-07 < tolerance=1e-06
# EM start iterations, llf=-3373.9
# EM iteration 100, llf=-3331, convergence criterion=1.2489e-06
# EM converged at iteration 112, llf=-3331, convergence criterion=9.9079e-07 < tolerance=1e-06
# EM start iterations, llf=-3373.9
# EM iteration 100, llf=-3331, convergence criterion=1.2489e-06
# EM converged at iteration 112, llf=-3331, convergence criterion=9.9079e-07 < tolerance=1e-06
# EM start iterations, llf=-3373.9
# EM iteration 100, llf=-3331, convergence criterion=1.2489e-06
# EM converged at iteration 112, llf=-3331, convergence criterion=9.9079e-07 < tolerance=1e-06
# EM start iterations, llf=-3387.8
# EM iteration 100, llf=-3344.8, convergence criterion=1.226e-06
# EM converged at iteration 111, llf=-3344.8, convergence criterion=9.8989e-07 < tolerance=1e-06
# EM start iterations, llf=-3387.8
# EM iteration 100, llf=-3344.8, convergence criterion=1.226e-06
# EM converged at iteration 111, llf=-3344.8, convergence criterion=9.8989e-07 < tolerance=1e-06
# EM start iterations, llf=-3402
# EM iteration 100, llf=-3358.6, convergence criterion=1.2075e-06
# EM converged at iteration 110, llf=-3358.6, convergence criterion=9.9334e-07 < tolerance=1e-06
# EM start iterations, llf=-3402
# EM iteration 100, llf=-3358.6, convergence criterion=1.2075e-06
# EM converged at iteration 110, llf=-3358.6, convergence criterion=9.9334e-07 < tolerance=1e-06
# EM start iterations, llf=-3415.5
# EM iteration 100, llf=-3372, convergence criterion=1.1729e-06
# EM converged at iteration 109, llf=-3371.9, convergence criterion=9.8484e-07 < tolerance=1e-06
# EM start iterations, llf=-3415.5
# EM iteration 100, llf=-3372, convergence criterion=1.1729e-06
# EM converged at iteration 109, llf=-3371.9, convergence criterion=9.8484e-07 < tolerance=1e-06
# EM start iterations, llf=-3415.5
# EM iteration 100, llf=-3372, convergence criterion=1.1729e-06
# EM converged at iteration 109, llf=-3371.9, convergence criterion=9.8484e-07 < tolerance=1e-06
# EM start iterations, llf=-3427.6
# EM iteration 100, llf=-3384.1, convergence criterion=1.1785e-06
# EM converged at iteration 109, llf=-3384, convergence criterion=9.8912e-07 < tolerance=1e-06
# EM start iterations, llf=-3427.6
# EM iteration 100, llf=-3384.1, convergence criterion=1.1785e-06
# EM converged at iteration 109, llf=-3384, convergence criterion=9.8912e-07 < tolerance=1e-06
# EM start iterations, llf=-3441
# EM iteration 100, llf=-3397.4, convergence criterion=1.1767e-06
# EM converged at iteration 109, llf=-3397.4, convergence criterion=9.8768e-07 < tolerance=1e-06
# EM start iterations, llf=-3441
# EM iteration 100, llf=-3397.4, convergence criterion=1.1767e-06
# EM converged at iteration 109, llf=-3397.4, convergence criterion=9.8768e-07 < tolerance=1e-06
# EM start iterations, llf=-3454.5
# EM iteration 100, llf=-3410.8, convergence criterion=1.176e-06
# EM converged at iteration 109, llf=-3410.8, convergence criterion=9.8674e-07 < tolerance=1e-06
# EM start iterations, llf=-3454.5
# EM iteration 100, llf=-3410.8, convergence criterion=1.176e-06
# EM converged at iteration 109, llf=-3410.8, convergence criterion=9.8674e-07 < tolerance=1e-06
# EM start iterations, llf=-3454.5
# EM iteration 100, llf=-3410.8, convergence criterion=1.176e-06
# EM converged at iteration 109, llf=-3410.8, convergence criterion=9.8674e-07 < tolerance=1e-06
# EM start iterations, llf=-3468.5
# EM iteration 100, llf=-3424.7, convergence criterion=1.1608e-06
# EM converged at iteration 108, llf=-3424.7, convergence criterion=9.923e-07 < tolerance=1e-06
# EM start iterations, llf=-3468.5
# EM iteration 100, llf=-3424.7, convergence criterion=1.1608e-06
# EM converged at iteration 108, llf=-3424.7, convergence criterion=9.923e-07 < tolerance=1e-06
# EM start iterations, llf=-3483.5
# EM iteration 100, llf=-3439.6, convergence criterion=1.2856e-06
# EM converged at iteration 114, llf=-3439.6, convergence criterion=9.862e-07 < tolerance=1e-06
# EM start iterations, llf=-3483.5
# EM iteration 100, llf=-3439.6, convergence criterion=1.2856e-06
# EM converged at iteration 114, llf=-3439.6, convergence criterion=9.862e-07 < tolerance=1e-06
# EM start iterations, llf=-3497.7
# EM iteration 100, llf=-3453.5, convergence criterion=1.2887e-06
# EM converged at iteration 114, llf=-3453.4, convergence criterion=9.8817e-07 < tolerance=1e-06
# EM start iterations, llf=-3497.7
# EM iteration 100, llf=-3453.5, convergence criterion=1.2887e-06
# EM converged at iteration 114, llf=-3453.4, convergence criterion=9.8817e-07 < tolerance=1e-06
# EM start iterations, llf=-3497.7
# EM iteration 100, llf=-3453.5, convergence criterion=1.2887e-06
# EM converged at iteration 114, llf=-3453.4, convergence criterion=9.8817e-07 < tolerance=1e-06
# EM start iterations, llf=-3511.6
# EM iteration 100, llf=-3467.3, convergence criterion=1.2619e-06
# EM converged at iteration 113, llf=-3467.3, convergence criterion=9.8484e-07 < tolerance=1e-06
# EM start iterations, llf=-3511.6
# EM iteration 100, llf=-3467.3, convergence criterion=1.2619e-06
# EM converged at iteration 113, llf=-3467.3, convergence criterion=9.8484e-07 < tolerance=1e-06
# EM start iterations, llf=-3526.3
# EM iteration 100, llf=-3481.9, convergence criterion=1.2675e-06
# EM converged at iteration 113, llf=-3481.9, convergence criterion=9.8942e-07 < tolerance=1e-06
# EM start iterations, llf=-3526.3
# EM iteration 100, llf=-3481.9, convergence criterion=1.2675e-06
# EM converged at iteration 113, llf=-3481.9, convergence criterion=9.8942e-07 < tolerance=1e-06
# EM start iterations, llf=-3539.9
# EM iteration 100, llf=-3495.5, convergence criterion=1.2562e-06
# EM converged at iteration 112, llf=-3495.4, convergence criterion=9.9836e-07 < tolerance=1e-06
# EM start iterations, llf=-3539.9
# EM iteration 100, llf=-3495.5, convergence criterion=1.2562e-06
# EM converged at iteration 112, llf=-3495.4, convergence criterion=9.9836e-07 < tolerance=1e-06
# EM start iterations, llf=-3539.9
# EM iteration 100, llf=-3495.5, convergence criterion=1.2562e-06
# EM converged at iteration 112, llf=-3495.4, convergence criterion=9.9836e-07 < tolerance=1e-06
# EM start iterations, llf=-3552.7
# EM iteration 100, llf=-3508.2, convergence criterion=1.2516e-06
# EM converged at iteration 112, llf=-3508.2, convergence criterion=9.9511e-07 < tolerance=1e-06
# EM start iterations, llf=-3552.7
# EM iteration 100, llf=-3508.2, convergence criterion=1.2516e-06
# EM converged at iteration 112, llf=-3508.2, convergence criterion=9.9511e-07 < tolerance=1e-06
# EM start iterations, llf=-3566.6
# EM iteration 100, llf=-3522.1, convergence criterion=1.2463e-06
# EM converged at iteration 112, llf=-3522, convergence criterion=9.9108e-07 < tolerance=1e-06
# EM start iterations, llf=-3566.6
# EM iteration 100, llf=-3522.1, convergence criterion=1.2463e-06
# EM converged at iteration 112, llf=-3522, convergence criterion=9.9108e-07 < tolerance=1e-06
# EM start iterations, llf=-3580.8
# EM iteration 100, llf=-3536, convergence criterion=1.2453e-06
# EM converged at iteration 112, llf=-3535.9, convergence criterion=9.9024e-07 < tolerance=1e-06
# EM start iterations, llf=-3580.8
# EM iteration 100, llf=-3536, convergence criterion=1.2453e-06
# EM converged at iteration 112, llf=-3535.9, convergence criterion=9.9024e-07 < tolerance=1e-06
# EM start iterations, llf=-3580.8
# EM iteration 100, llf=-3536, convergence criterion=1.2453e-06
# EM converged at iteration 112, llf=-3535.9, convergence criterion=9.9024e-07 < tolerance=1e-06
# EM start iterations, llf=-3593.9
# EM iteration 100, llf=-3549, convergence criterion=1.2426e-06
# EM converged at iteration 112, llf=-3548.9, convergence criterion=9.8807e-07 < tolerance=1e-06
# EM start iterations, llf=-3593.9
# EM iteration 100, llf=-3549, convergence criterion=1.2426e-06
# EM converged at iteration 112, llf=-3548.9, convergence criterion=9.8807e-07 < tolerance=1e-06
# EM start iterations, llf=-3611.1
# EM iteration 100, llf=-3565.8, convergence criterion=1.2435e-06
# EM converged at iteration 112, llf=-3565.8, convergence criterion=9.8746e-07 < tolerance=1e-06
# EM start iterations, llf=-3611.1
# EM iteration 100, llf=-3565.8, convergence criterion=1.2435e-06
# EM converged at iteration 112, llf=-3565.8, convergence criterion=9.8746e-07 < tolerance=1e-06
# EM start iterations, llf=-3625.8
# EM iteration 100, llf=-3580.4, convergence criterion=1.208e-06
# EM converged at iteration 110, llf=-3580.4, convergence criterion=9.9516e-07 < tolerance=1e-06
# EM start iterations, llf=-3625.8
# EM iteration 100, llf=-3580.4, convergence criterion=1.208e-06
# EM converged at iteration 110, llf=-3580.4, convergence criterion=9.9516e-07 < tolerance=1e-06
# EM start iterations, llf=-3625.8
# EM iteration 100, llf=-3580.4, convergence criterion=1.208e-06
# EM converged at iteration 110, llf=-3580.4, convergence criterion=9.9516e-07 < tolerance=1e-06
# EM start iterations, llf=-3639
# EM iteration 100, llf=-3593.5, convergence criterion=1.2064e-06
# EM converged at iteration 110, llf=-3593.5, convergence criterion=9.9375e-07 < tolerance=1e-06
# EM start iterations, llf=-3639
# EM iteration 100, llf=-3593.5, convergence criterion=1.2064e-06
# EM converged at iteration 110, llf=-3593.5, convergence criterion=9.9375e-07 < tolerance=1e-06
# EM start iterations, llf=-3653
# EM iteration 100, llf=-3607.3, convergence criterion=1.1972e-06
# EM converged at iteration 110, llf=-3607.2, convergence criterion=9.8597e-07 < tolerance=1e-06
# EM start iterations, llf=-3653
# EM iteration 100, llf=-3607.3, convergence criterion=1.1972e-06
# EM converged at iteration 110, llf=-3607.2, convergence criterion=9.8597e-07 < tolerance=1e-06
# EM start iterations, llf=-3667.3
# EM iteration 100, llf=-3621.7, convergence criterion=1.2002e-06
# EM converged at iteration 110, llf=-3621.6, convergence criterion=9.8869e-07 < tolerance=1e-06
# EM start iterations, llf=-3667.3
# EM iteration 100, llf=-3621.7, convergence criterion=1.2002e-06
# EM converged at iteration 110, llf=-3621.6, convergence criterion=9.8869e-07 < tolerance=1e-06
# EM start iterations, llf=-3667.3
# EM iteration 100, llf=-3621.7, convergence criterion=1.2002e-06
# EM converged at iteration 110, llf=-3621.6, convergence criterion=9.8869e-07 < tolerance=1e-06
# EM start iterations, llf=-3681.4
# EM iteration 100, llf=-3635.9, convergence criterion=1.1977e-06
# EM converged at iteration 110, llf=-3635.9, convergence criterion=9.8605e-07 < tolerance=1e-06
# EM start iterations, llf=-3681.4
# EM iteration 100, llf=-3635.9, convergence criterion=1.1977e-06
# EM converged at iteration 110, llf=-3635.9, convergence criterion=9.8605e-07 < tolerance=1e-06
# EM start iterations, llf=-3695.8
# EM iteration 100, llf=-3650.1, convergence criterion=1.2228e-06
# EM converged at iteration 111, llf=-3650.1, convergence criterion=9.889e-07 < tolerance=1e-06
# EM start iterations, llf=-3695.8
# EM iteration 100, llf=-3650.1, convergence criterion=1.2228e-06
# EM converged at iteration 111, llf=-3650.1, convergence criterion=9.889e-07 < tolerance=1e-06
# EM start iterations, llf=-3708.9
# EM iteration 100, llf=-3663.2, convergence criterion=1.2105e-06
# EM converged at iteration 110, llf=-3663.2, convergence criterion=9.9772e-07 < tolerance=1e-06
# EM start iterations, llf=-3708.9
# EM iteration 100, llf=-3663.2, convergence criterion=1.2105e-06
# EM converged at iteration 110, llf=-3663.2, convergence criterion=9.9772e-07 < tolerance=1e-06
# EM start iterations, llf=-3708.9
# EM iteration 100, llf=-3663.2, convergence criterion=1.2105e-06
# EM converged at iteration 110, llf=-3663.2, convergence criterion=9.9772e-07 < tolerance=1e-06
# EM start iterations, llf=-3722.7
# EM iteration 100, llf=-3677, convergence criterion=1.2162e-06
# EM converged at iteration 111, llf=-3677, convergence criterion=9.8422e-07 < tolerance=1e-06
# EM start iterations, llf=-3722.7
# EM iteration 100, llf=-3677, convergence criterion=1.2162e-06
# EM converged at iteration 111, llf=-3677, convergence criterion=9.8422e-07 < tolerance=1e-06
# EM start iterations, llf=-3737.6
# EM iteration 100, llf=-3691.7, convergence criterion=1.2254e-06
# EM converged at iteration 111, llf=-3691.7, convergence criterion=9.9155e-07 < tolerance=1e-06
# EM start iterations, llf=-3737.6
# EM iteration 100, llf=-3691.7, convergence criterion=1.2254e-06
# EM converged at iteration 111, llf=-3691.7, convergence criterion=9.9155e-07 < tolerance=1e-06
# EM start iterations, llf=-3753.7
# EM iteration 100, llf=-3707.7, convergence criterion=1.1713e-06
# EM converged at iteration 109, llf=-3707.6, convergence criterion=9.8342e-07 < tolerance=1e-06
# EM start iterations, llf=-3753.7
# EM iteration 100, llf=-3707.7, convergence criterion=1.1713e-06
# EM converged at iteration 109, llf=-3707.6, convergence criterion=9.8342e-07 < tolerance=1e-06
# EM start iterations, llf=-3753.7
# EM iteration 100, llf=-3707.7, convergence criterion=1.1713e-06
# EM converged at iteration 109, llf=-3707.6, convergence criterion=9.8342e-07 < tolerance=1e-06
# EM start iterations, llf=-3762.9
# EM iteration 100, llf=-3716.8, convergence criterion=1.127e-06
# EM converged at iteration 107, llf=-3716.8, convergence criterion=9.8265e-07 < tolerance=1e-06
# EM start iterations, llf=-3762.9
# EM iteration 100, llf=-3716.8, convergence criterion=1.127e-06
# EM converged at iteration 107, llf=-3716.8, convergence criterion=9.8265e-07 < tolerance=1e-06
# EM start iterations, llf=-3775.2
# EM iteration 100, llf=-3728.6, convergence criterion=1.1036e-06
# EM converged at iteration 105, llf=-3728.6, convergence criterion=9.9972e-07 < tolerance=1e-06
# EM start iterations, llf=-3775.2
# EM iteration 100, llf=-3728.6, convergence criterion=1.1036e-06
# EM converged at iteration 105, llf=-3728.6, convergence criterion=9.9972e-07 < tolerance=1e-06
# EM start iterations, llf=-3787
# EM iteration 100, llf=-3740.1, convergence criterion=1.0859e-06
# EM converged at iteration 105, llf=-3740.1, convergence criterion=9.8387e-07 < tolerance=1e-06
# EM start iterations, llf=-3787
# EM iteration 100, llf=-3740.1, convergence criterion=1.0859e-06
# EM converged at iteration 105, llf=-3740.1, convergence criterion=9.8387e-07 < tolerance=1e-06
# EM start iterations, llf=-3787
# EM iteration 100, llf=-3740.1, convergence criterion=1.0859e-06
# EM converged at iteration 105, llf=-3740.1, convergence criterion=9.8387e-07 < tolerance=1e-06
# EM start iterations, llf=-3801.3
# EM iteration 100, llf=-3754.4, convergence criterion=1.1034e-06
# EM converged at iteration 105, llf=-3754.4, convergence criterion=9.9984e-07 < tolerance=1e-06
# EM start iterations, llf=-3801.3
# EM iteration 100, llf=-3754.4, convergence criterion=1.1034e-06
# EM converged at iteration 105, llf=-3754.4, convergence criterion=9.9984e-07 < tolerance=1e-06
# EM start iterations, llf=-3815.6
# EM iteration 100, llf=-3768.5, convergence criterion=1.0878e-06
# EM converged at iteration 105, llf=-3768.5, convergence criterion=9.8551e-07 < tolerance=1e-06
# EM start iterations, llf=-3817.1
# EM iteration 100, llf=-3767.7, convergence criterion=1.679e-06
# EM converged at iteration 131, llf=-3767.6, convergence criterion=9.9328e-07 < tolerance=1e-06
# EM start iterations, llf=-3827.8
# EM iteration 100, llf=-3778.2, convergence criterion=1.6778e-06
# EM converged at iteration 131, llf=-3778, convergence criterion=9.9226e-07 < tolerance=1e-06
# EM start iterations, llf=-3827.8
# EM iteration 100, llf=-3778.2, convergence criterion=1.6778e-06
# EM converged at iteration 131, llf=-3778, convergence criterion=9.9226e-07 < tolerance=1e-06
# EM start iterations, llf=-3827.8
# EM iteration 100, llf=-3778.2, convergence criterion=1.6778e-06
# EM converged at iteration 131, llf=-3778, convergence criterion=9.9226e-07 < tolerance=1e-06
# EM start iterations, llf=-3839.8
# EM iteration 100, llf=-3790.1, convergence criterion=1.6758e-06
# EM converged at iteration 131, llf=-3790, convergence criterion=9.9115e-07 < tolerance=1e-06
# EM start iterations, llf=-3839.8
# EM iteration 100, llf=-3790.1, convergence criterion=1.6758e-06
# EM converged at iteration 131, llf=-3790, convergence criterion=9.9115e-07 < tolerance=1e-06
# EM start iterations, llf=-3854.4
# EM iteration 100, llf=-3804.7, convergence criterion=1.6674e-06
# EM converged at iteration 131, llf=-3804.6, convergence criterion=9.9085e-07 < tolerance=1e-06
# EM start iterations, llf=-3854.4
# EM iteration 100, llf=-3804.7, convergence criterion=1.6674e-06
# EM converged at iteration 131, llf=-3804.6, convergence criterion=9.9085e-07 < tolerance=1e-06
# EM start iterations, llf=-3868.2
# EM iteration 100, llf=-3818.6, convergence criterion=1.6512e-06
# EM converged at iteration 130, llf=-3818.4, convergence criterion=9.9571e-07 < tolerance=1e-06
# EM start iterations, llf=-3868.2
# EM iteration 100, llf=-3818.6, convergence criterion=1.6512e-06
# EM converged at iteration 130, llf=-3818.4, convergence criterion=9.9571e-07 < tolerance=1e-06
# EM start iterations, llf=-3868.2
# EM iteration 100, llf=-3818.6, convergence criterion=1.6512e-06
# EM converged at iteration 130, llf=-3818.4, convergence criterion=9.9571e-07 < tolerance=1e-06
# EM start iterations, llf=-3881.7
# EM iteration 100, llf=-3832.1, convergence criterion=1.6501e-06
# EM converged at iteration 130, llf=-3831.9, convergence criterion=9.9527e-07 < tolerance=1e-06
# EM start iterations, llf=-3881.7
# EM iteration 100, llf=-3832.1, convergence criterion=1.6501e-06
# EM converged at iteration 130, llf=-3831.9, convergence criterion=9.9527e-07 < tolerance=1e-06
# EM start iterations, llf=-3897.4
# EM iteration 100, llf=-3847.6, convergence criterion=1.6692e-06
# EM converged at iteration 131, llf=-3847.4, convergence criterion=9.9277e-07 < tolerance=1e-06
# EM start iterations, llf=-3897.4
# EM iteration 100, llf=-3847.6, convergence criterion=1.6692e-06
# EM converged at iteration 131, llf=-3847.4, convergence criterion=9.9277e-07 < tolerance=1e-06
# EM start iterations, llf=-3909
# EM iteration 100, llf=-3859.2, convergence criterion=1.6545e-06
# EM converged at iteration 130, llf=-3859, convergence criterion=9.9945e-07 < tolerance=1e-06
# EM start iterations, llf=-3909
# EM iteration 100, llf=-3859.2, convergence criterion=1.6545e-06
# EM converged at iteration 130, llf=-3859, convergence criterion=9.9945e-07 < tolerance=1e-06
# EM start iterations, llf=-3909
# EM iteration 100, llf=-3859.2, convergence criterion=1.6545e-06
# EM converged at iteration 130, llf=-3859, convergence criterion=9.9945e-07 < tolerance=1e-06
# EM start iterations, llf=-3923.5
# EM iteration 100, llf=-3873.7, convergence criterion=1.6458e-06
# EM converged at iteration 130, llf=-3873.5, convergence criterion=9.9412e-07 < tolerance=1e-06
# EM start iterations, llf=-3923.5
# EM iteration 100, llf=-3873.7, convergence criterion=1.6458e-06
# EM converged at iteration 130, llf=-3873.5, convergence criterion=9.9412e-07 < tolerance=1e-06
# EM start iterations, llf=-3938.3
# EM iteration 100, llf=-3888.3, convergence criterion=1.6707e-06
# EM converged at iteration 131, llf=-3888.1, convergence criterion=9.9435e-07 < tolerance=1e-06
# EM start iterations, llf=-3938.3
# EM iteration 100, llf=-3888.3, convergence criterion=1.6707e-06
# EM converged at iteration 131, llf=-3888.1, convergence criterion=9.9435e-07 < tolerance=1e-06
# EM start iterations, llf=-3953.5
# EM iteration 100, llf=-3903.6, convergence criterion=1.6944e-06
# EM converged at iteration 132, llf=-3903.5, convergence criterion=9.9314e-07 < tolerance=1e-06
# EM start iterations, llf=-3953.5
# EM iteration 100, llf=-3903.6, convergence criterion=1.6944e-06
# EM converged at iteration 132, llf=-3903.5, convergence criterion=9.9314e-07 < tolerance=1e-06
# EM start iterations, llf=-3953.5
# EM iteration 100, llf=-3903.6, convergence criterion=1.6944e-06
# EM converged at iteration 132, llf=-3903.5, convergence criterion=9.9314e-07 < tolerance=1e-06
# EM start iterations, llf=-3968.3
# EM iteration 100, llf=-3917.4, convergence criterion=1.6811e-06
# EM converged at iteration 131, llf=-3917.2, convergence criterion=9.9866e-07 < tolerance=1e-06
# EM start iterations, llf=-3968.3
# EM iteration 100, llf=-3917.4, convergence criterion=1.6811e-06
# EM converged at iteration 131, llf=-3917.2, convergence criterion=9.9866e-07 < tolerance=1e-06
# EM start iterations, llf=-3981.1
# EM iteration 100, llf=-3929.8, convergence criterion=1.6953e-06
# EM converged at iteration 132, llf=-3929.6, convergence criterion=9.9488e-07 < tolerance=1e-06
# EM start iterations, llf=-3981.1
# EM iteration 100, llf=-3929.8, convergence criterion=1.6953e-06
# EM converged at iteration 132, llf=-3929.6, convergence criterion=9.9488e-07 < tolerance=1e-06
# EM start iterations, llf=-3995.5
# EM iteration 100, llf=-3944.1, convergence criterion=1.6815e-06
# EM converged at iteration 132, llf=-3943.9, convergence criterion=9.8732e-07 < tolerance=1e-06
# EM start iterations, llf=-3995.5
# EM iteration 100, llf=-3944.1, convergence criterion=1.6815e-06
# EM converged at iteration 132, llf=-3943.9, convergence criterion=9.8732e-07 < tolerance=1e-06
# EM start iterations, llf=-3995.5
# EM iteration 100, llf=-3944.1, convergence criterion=1.6815e-06
# EM converged at iteration 132, llf=-3943.9, convergence criterion=9.8732e-07 < tolerance=1e-06
# EM start iterations, llf=-4008.2
# EM iteration 100, llf=-3957, convergence criterion=1.6555e-06
# EM converged at iteration 131, llf=-3956.9, convergence criterion=9.8624e-07 < tolerance=1e-06
# EM start iterations, llf=-4008.2
# EM iteration 100, llf=-3957, convergence criterion=1.6555e-06
# EM converged at iteration 131, llf=-3956.9, convergence criterion=9.8624e-07 < tolerance=1e-06
# EM start iterations, llf=-4019.5
# EM iteration 100, llf=-3968.3, convergence criterion=1.6598e-06
# EM converged at iteration 131, llf=-3968.2, convergence criterion=9.8899e-07 < tolerance=1e-06
# EM start iterations, llf=-4019.5
# EM iteration 100, llf=-3968.3, convergence criterion=1.6598e-06
# EM converged at iteration 131, llf=-3968.2, convergence criterion=9.8899e-07 < tolerance=1e-06
# EM start iterations, llf=-4033.5
# EM iteration 100, llf=-3982.1, convergence criterion=1.654e-06
# EM converged at iteration 130, llf=-3981.9, convergence criterion=9.9982e-07 < tolerance=1e-06
# EM start iterations, llf=-4033.5
# EM iteration 100, llf=-3982.1, convergence criterion=1.654e-06
# EM converged at iteration 130, llf=-3981.9, convergence criterion=9.9982e-07 < tolerance=1e-06
# EM start iterations, llf=-4033.5
# EM iteration 100, llf=-3982.1, convergence criterion=1.654e-06
# EM converged at iteration 130, llf=-3981.9, convergence criterion=9.9982e-07 < tolerance=1e-06
# EM start iterations, llf=-4047
# EM iteration 100, llf=-3995.5, convergence criterion=1.6412e-06
# EM converged at iteration 130, llf=-3995.3, convergence criterion=9.9172e-07 < tolerance=1e-06
# EM start iterations, llf=-4047
# EM iteration 100, llf=-3995.5, convergence criterion=1.6412e-06
# EM converged at iteration 130, llf=-3995.3, convergence criterion=9.9172e-07 < tolerance=1e-06
# EM start iterations, llf=-4060.9
# EM iteration 100, llf=-4009.1, convergence criterion=1.64e-06
# EM converged at iteration 130, llf=-4008.9, convergence criterion=9.904e-07 < tolerance=1e-06
# EM start iterations, llf=-4060.9
# EM iteration 100, llf=-4009.1, convergence criterion=1.64e-06
# EM converged at iteration 130, llf=-4008.9, convergence criterion=9.904e-07 < tolerance=1e-06
# EM start iterations, llf=-4076.1
# EM iteration 100, llf=-4023.7, convergence criterion=1.6264e-06
# EM converged at iteration 129, llf=-4023.5, convergence criterion=9.9691e-07 < tolerance=1e-06
# EM start iterations, llf=-4076.1
# EM iteration 100, llf=-4023.7, convergence criterion=1.6264e-06
# EM converged at iteration 129, llf=-4023.5, convergence criterion=9.9691e-07 < tolerance=1e-06
# EM start iterations, llf=-4076.1
# EM iteration 100, llf=-4023.7, convergence criterion=1.6264e-06
# EM converged at iteration 129, llf=-4023.5, convergence criterion=9.9691e-07 < tolerance=1e-06
# EM start iterations, llf=-4089.6
# EM iteration 100, llf=-4037.1, convergence criterion=1.6248e-06
# EM converged at iteration 129, llf=-4037, convergence criterion=9.9614e-07 < tolerance=1e-06
# EM start iterations, llf=-4089.6
# EM iteration 100, llf=-4037.1, convergence criterion=1.6248e-06
# EM converged at iteration 129, llf=-4037, convergence criterion=9.9614e-07 < tolerance=1e-06
# EM start iterations, llf=-4104.1
# EM iteration 100, llf=-4051.5, convergence criterion=1.6252e-06
# EM converged at iteration 129, llf=-4051.4, convergence criterion=9.9633e-07 < tolerance=1e-06
# EM start iterations, llf=-4104.1
# EM iteration 100, llf=-4051.5, convergence criterion=1.6252e-06
# EM converged at iteration 129, llf=-4051.4, convergence criterion=9.9633e-07 < tolerance=1e-06
# EM start iterations, llf=-4117.8
# EM iteration 100, llf=-4064.9, convergence criterion=1.6181e-06
# EM converged at iteration 129, llf=-4064.8, convergence criterion=9.9203e-07 < tolerance=1e-06
# EM start iterations, llf=-4117.8
# EM iteration 100, llf=-4064.9, convergence criterion=1.6181e-06
# EM converged at iteration 129, llf=-4064.8, convergence criterion=9.9203e-07 < tolerance=1e-06
# EM start iterations, llf=-4117.8
# EM iteration 100, llf=-4064.9, convergence criterion=1.6181e-06
# EM converged at iteration 129, llf=-4064.8, convergence criterion=9.9203e-07 < tolerance=1e-06
# EM start iterations, llf=-4130.7
# EM iteration 100, llf=-4078.6, convergence criterion=1.6254e-06
# EM converged at iteration 129, llf=-4078.4, convergence criterion=9.9605e-07 < tolerance=1e-06
# EM start iterations, llf=-4130.7
# EM iteration 100, llf=-4078.6, convergence criterion=1.6254e-06
# EM converged at iteration 129, llf=-4078.4, convergence criterion=9.9605e-07 < tolerance=1e-06
# EM start iterations, llf=-4151.1
# EM iteration 100, llf=-4097.8, convergence criterion=1.6631e-06
# EM converged at iteration 131, llf=-4097.6, convergence criterion=9.8992e-07 < tolerance=1e-06
# EM start iterations, llf=-4151.1
# EM iteration 100, llf=-4097.8, convergence criterion=1.6631e-06
# EM converged at iteration 131, llf=-4097.6, convergence criterion=9.8992e-07 < tolerance=1e-06
# EM start iterations, llf=-4165.5
# EM iteration 100, llf=-4112.1, convergence criterion=1.6645e-06
# EM converged at iteration 131, llf=-4111.9, convergence criterion=9.897e-07 < tolerance=1e-06
# EM start iterations, llf=-4165.5
# EM iteration 100, llf=-4112.1, convergence criterion=1.6645e-06
# EM converged at iteration 131, llf=-4111.9, convergence criterion=9.897e-07 < tolerance=1e-06
# EM start iterations, llf=-4165.5
# EM iteration 100, llf=-4112.1, convergence criterion=1.6645e-06
# EM converged at iteration 131, llf=-4111.9, convergence criterion=9.897e-07 < tolerance=1e-06
# EM start iterations, llf=-4178.9
# EM iteration 100, llf=-4125.3, convergence criterion=1.6626e-06
# EM converged at iteration 131, llf=-4125.2, convergence criterion=9.8868e-07 < tolerance=1e-06
# EM start iterations, llf=-4178.9
# EM iteration 100, llf=-4125.3, convergence criterion=1.6626e-06
# EM converged at iteration 131, llf=-4125.2, convergence criterion=9.8868e-07 < tolerance=1e-06
# EM start iterations, llf=-4193.8
# EM iteration 100, llf=-4140.1, convergence criterion=1.6659e-06
# EM converged at iteration 131, llf=-4139.9, convergence criterion=9.9073e-07 < tolerance=1e-06
# EM start iterations, llf=-4193.8
# EM iteration 100, llf=-4140.1, convergence criterion=1.6659e-06
# EM converged at iteration 131, llf=-4139.9, convergence criterion=9.9073e-07 < tolerance=1e-06
# EM start iterations, llf=-4208
# EM iteration 100, llf=-4154.4, convergence criterion=1.6634e-06
# EM converged at iteration 131, llf=-4154.2, convergence criterion=9.8877e-07 < tolerance=1e-06
# EM start iterations, llf=-4208
# EM iteration 100, llf=-4154.4, convergence criterion=1.6634e-06
# EM converged at iteration 131, llf=-4154.2, convergence criterion=9.8877e-07 < tolerance=1e-06
# EM start iterations, llf=-4208
# EM iteration 100, llf=-4154.4, convergence criterion=1.6634e-06
# EM converged at iteration 131, llf=-4154.2, convergence criterion=9.8877e-07 < tolerance=1e-06
# EM start iterations, llf=-4218.9
# EM iteration 100, llf=-4165.1, convergence criterion=1.6515e-06
# EM converged at iteration 130, llf=-4164.9, convergence criterion=9.9539e-07 < tolerance=1e-06
# EM start iterations, llf=-4218.9
# EM iteration 100, llf=-4165.1, convergence criterion=1.6515e-06
# EM converged at iteration 130, llf=-4164.9, convergence criterion=9.9539e-07 < tolerance=1e-06
# EM start iterations, llf=-4235.9
# EM iteration 100, llf=-4181.9, convergence criterion=1.6676e-06
# EM converged at iteration 131, llf=-4181.8, convergence criterion=9.907e-07 < tolerance=1e-06
# EM start iterations, llf=-4235.9
# EM iteration 100, llf=-4181.9, convergence criterion=1.6676e-06
# EM converged at iteration 131, llf=-4181.8, convergence criterion=9.907e-07 < tolerance=1e-06
# EM start iterations, llf=-4248.1
# EM iteration 100, llf=-4193.9, convergence criterion=1.6776e-06
# EM converged at iteration 131, llf=-4193.7, convergence criterion=9.974e-07 < tolerance=1e-06
# EM start iterations, llf=-4248.1
# EM iteration 100, llf=-4193.9, convergence criterion=1.6776e-06
# EM converged at iteration 131, llf=-4193.7, convergence criterion=9.974e-07 < tolerance=1e-06
# EM start iterations, llf=-4248.1
# EM iteration 100, llf=-4193.9, convergence criterion=1.6776e-06
# EM converged at iteration 131, llf=-4193.7, convergence criterion=9.974e-07 < tolerance=1e-06
# EM start iterations, llf=-4262.1
# EM iteration 100, llf=-4207.8, convergence criterion=1.6694e-06
# EM converged at iteration 131, llf=-4207.6, convergence criterion=9.9206e-07 < tolerance=1e-06
# EM start iterations, llf=-4262.1
# EM iteration 100, llf=-4207.8, convergence criterion=1.6694e-06
# EM converged at iteration 131, llf=-4207.6, convergence criterion=9.9206e-07 < tolerance=1e-06
# EM start iterations, llf=-4276.4
# EM iteration 100, llf=-4221.8, convergence criterion=1.6776e-06
# EM converged at iteration 131, llf=-4221.6, convergence criterion=9.9836e-07 < tolerance=1e-06
# EM start iterations, llf=-4276.4
# EM iteration 100, llf=-4221.8, convergence criterion=1.6776e-06
# EM converged at iteration 131, llf=-4221.6, convergence criterion=9.9836e-07 < tolerance=1e-06
# EM start iterations, llf=-4291.5
# EM iteration 100, llf=-4236.8, convergence criterion=1.656e-06
# EM converged at iteration 130, llf=-4236.6, convergence criterion=9.9905e-07 < tolerance=1e-06
# EM start iterations, llf=-4291.5
# EM iteration 100, llf=-4236.8, convergence criterion=1.656e-06
# EM converged at iteration 130, llf=-4236.6, convergence criterion=9.9905e-07 < tolerance=1e-06
# EM start iterations, llf=-4291.5
# EM iteration 100, llf=-4236.8, convergence criterion=1.656e-06
# EM converged at iteration 130, llf=-4236.6, convergence criterion=9.9905e-07 < tolerance=1e-06
# EM start iterations, llf=-4304.2
# EM iteration 100, llf=-4249.3, convergence criterion=1.654e-06
# EM converged at iteration 130, llf=-4249.1, convergence criterion=9.9773e-07 < tolerance=1e-06
# EM start iterations, llf=-4304.2
# EM iteration 100, llf=-4249.3, convergence criterion=1.654e-06
# EM converged at iteration 130, llf=-4249.1, convergence criterion=9.9773e-07 < tolerance=1e-06
# EM start iterations, llf=-4321.5
# EM iteration 100, llf=-4266.2, convergence criterion=1.6334e-06
# EM converged at iteration 129, llf=-4266, convergence criterion=9.992e-07 < tolerance=1e-06
# EM start iterations, llf=-4321.5
# EM iteration 100, llf=-4266.2, convergence criterion=1.6334e-06
# EM converged at iteration 129, llf=-4266, convergence criterion=9.992e-07 < tolerance=1e-06
# EM start iterations, llf=-4332.8
# EM iteration 100, llf=-4277.1, convergence criterion=1.6211e-06
# EM converged at iteration 129, llf=-4277, convergence criterion=9.9092e-07 < tolerance=1e-06
# EM start iterations, llf=-4332.8
# EM iteration 100, llf=-4277.1, convergence criterion=1.6211e-06
# EM converged at iteration 129, llf=-4277, convergence criterion=9.9092e-07 < tolerance=1e-06
# EM start iterations, llf=-4332.8
# EM iteration 100, llf=-4277.1, convergence criterion=1.6211e-06
# EM converged at iteration 129, llf=-4277, convergence criterion=9.9092e-07 < tolerance=1e-06
# EM start iterations, llf=-4347.9
# EM iteration 100, llf=-4292.3, convergence criterion=1.608e-06
# EM converged at iteration 128, llf=-4292.1, convergence criterion=9.9769e-07 < tolerance=1e-06
# EM start iterations, llf=-4347.9
# EM iteration 100, llf=-4292.3, convergence criterion=1.608e-06
# EM converged at iteration 128, llf=-4292.1, convergence criterion=9.9769e-07 < tolerance=1e-06
# EM start iterations, llf=-4361.7
# EM iteration 100, llf=-4306.2, convergence criterion=1.6131e-06
# EM converged at iteration 129, llf=-4306, convergence criterion=9.8681e-07 < tolerance=1e-06
# EM start iterations, llf=-4361.7
# EM iteration 100, llf=-4306.2, convergence criterion=1.6131e-06
# EM converged at iteration 129, llf=-4306, convergence criterion=9.8681e-07 < tolerance=1e-06
# EM start iterations, llf=-4373.8
# EM iteration 100, llf=-4318.3, convergence criterion=1.6096e-06
# EM converged at iteration 128, llf=-4318.1, convergence criterion=9.9997e-07 < tolerance=1e-06
# EM start iterations, llf=-4373.8
# EM iteration 100, llf=-4318.3, convergence criterion=1.6096e-06
# EM converged at iteration 128, llf=-4318.1, convergence criterion=9.9997e-07 < tolerance=1e-06
# EM start iterations, llf=-4373.8
# EM iteration 100, llf=-4318.3, convergence criterion=1.6096e-06
# EM converged at iteration 128, llf=-4318.1, convergence criterion=9.9997e-07 < tolerance=1e-06
# EM start iterations, llf=-4385.4
# EM iteration 100, llf=-4329.9, convergence criterion=1.5993e-06
# EM converged at iteration 128, llf=-4329.8, convergence criterion=9.9496e-07 < tolerance=1e-06
# EM start iterations, llf=-4385.4
# EM iteration 100, llf=-4329.9, convergence criterion=1.5993e-06
# EM converged at iteration 128, llf=-4329.8, convergence criterion=9.9496e-07 < tolerance=1e-06
# EM start iterations, llf=-4400.3
# EM iteration 100, llf=-4344.5, convergence criterion=1.6134e-06
# EM converged at iteration 129, llf=-4344.3, convergence criterion=9.8839e-07 < tolerance=1e-06
# EM start iterations, llf=-4400.3
# EM iteration 100, llf=-4344.5, convergence criterion=1.6134e-06
# EM converged at iteration 129, llf=-4344.3, convergence criterion=9.8839e-07 < tolerance=1e-06
# EM start iterations, llf=-4415.4
# EM iteration 100, llf=-4359.4, convergence criterion=1.6036e-06
# EM converged at iteration 128, llf=-4359.3, convergence criterion=9.967e-07 < tolerance=1e-06
# EM start iterations, llf=-4415.4
# EM iteration 100, llf=-4359.4, convergence criterion=1.6036e-06
# EM converged at iteration 128, llf=-4359.3, convergence criterion=9.967e-07 < tolerance=1e-06
# EM start iterations, llf=-4415.4
# EM iteration 100, llf=-4359.4, convergence criterion=1.6036e-06
# EM converged at iteration 128, llf=-4359.3, convergence criterion=9.967e-07 < tolerance=1e-06
# EM start iterations, llf=-4428.6
# EM iteration 100, llf=-4372.9, convergence criterion=1.5967e-06
# EM converged at iteration 128, llf=-4372.7, convergence criterion=9.9241e-07 < tolerance=1e-06
# EM start iterations, llf=-4428.6
# EM iteration 100, llf=-4372.9, convergence criterion=1.5967e-06
# EM converged at iteration 128, llf=-4372.7, convergence criterion=9.9241e-07 < tolerance=1e-06
# EM start iterations, llf=-4444.4
# EM iteration 100, llf=-4388.7, convergence criterion=1.5639e-06
# EM converged at iteration 127, llf=-4388.5, convergence criterion=9.8551e-07 < tolerance=1e-06
# EM start iterations, llf=-4444.4
# EM iteration 100, llf=-4388.7, convergence criterion=1.5639e-06
# EM converged at iteration 127, llf=-4388.5, convergence criterion=9.8551e-07 < tolerance=1e-06
# EM start iterations, llf=-4457.5
# EM iteration 100, llf=-4401.9, convergence criterion=1.5885e-06
# EM converged at iteration 128, llf=-4401.8, convergence criterion=9.8719e-07 < tolerance=1e-06
# EM start iterations, llf=-4457.5
# EM iteration 100, llf=-4401.9, convergence criterion=1.5885e-06
# EM converged at iteration 128, llf=-4401.8, convergence criterion=9.8719e-07 < tolerance=1e-06
# EM start iterations, llf=-4457.5
# EM iteration 100, llf=-4401.9, convergence criterion=1.5885e-06
# EM converged at iteration 128, llf=-4401.8, convergence criterion=9.8719e-07 < tolerance=1e-06
# EM start iterations, llf=-4468.5
# EM iteration 100, llf=-4413, convergence criterion=1.5655e-06
# EM converged at iteration 127, llf=-4412.9, convergence criterion=9.8654e-07 < tolerance=1e-06
# EM start iterations, llf=-4468.5
# EM iteration 100, llf=-4413, convergence criterion=1.5655e-06
# EM converged at iteration 127, llf=-4412.9, convergence criterion=9.8654e-07 < tolerance=1e-06
# EM start iterations, llf=-4487.9
# EM iteration 100, llf=-4431.8, convergence criterion=1.5958e-06
# EM converged at iteration 128, llf=-4431.6, convergence criterion=9.9013e-07 < tolerance=1e-06
# EM start iterations, llf=-4487.9
# EM iteration 100, llf=-4431.8, convergence criterion=1.5958e-06
# EM converged at iteration 128, llf=-4431.6, convergence criterion=9.9013e-07 < tolerance=1e-06
# EM start iterations, llf=-4500.8
# EM iteration 100, llf=-4444.7, convergence criterion=1.5887e-06
# EM converged at iteration 128, llf=-4444.5, convergence criterion=9.8619e-07 < tolerance=1e-06
# EM start iterations, llf=-4500.8
# EM iteration 100, llf=-4444.7, convergence criterion=1.5887e-06
# EM converged at iteration 128, llf=-4444.5, convergence criterion=9.8619e-07 < tolerance=1e-06
# EM start iterations, llf=-4500.8
# EM iteration 100, llf=-4444.7, convergence criterion=1.5887e-06
# EM converged at iteration 128, llf=-4444.5, convergence criterion=9.8619e-07 < tolerance=1e-06
# EM start iterations, llf=-4512.8
# EM iteration 100, llf=-4457, convergence criterion=1.5593e-06
# EM converged at iteration 126, llf=-4456.8, convergence criterion=9.9838e-07 < tolerance=1e-06
# EM start iterations, llf=-4512.8
# EM iteration 100, llf=-4457, convergence criterion=1.5593e-06
# EM converged at iteration 126, llf=-4456.8, convergence criterion=9.9838e-07 < tolerance=1e-06
# EM start iterations, llf=-4527.9
# EM iteration 100, llf=-4472, convergence criterion=1.5823e-06
# EM converged at iteration 127, llf=-4471.9, convergence criterion=9.9768e-07 < tolerance=1e-06
# EM start iterations, llf=-4527.9
# EM iteration 100, llf=-4472, convergence criterion=1.5823e-06
# EM converged at iteration 127, llf=-4471.9, convergence criterion=9.9768e-07 < tolerance=1e-06
# EM start iterations, llf=-4543.3
# EM iteration 100, llf=-4486.8, convergence criterion=1.5467e-06
# EM converged at iteration 126, llf=-4486.7, convergence criterion=9.907e-07 < tolerance=1e-06
# Model with Global factors = 1 and order = 3 estimated in 1:56:26.275995.

# %% [markdown]
# Plot MSE values for the model with 1 Global Factor and Lag Order 3 evaluated over the 2008–2018 period.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]
q_var = 'Consumption'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Define the directory containing MSE files
mse_dir = f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"

# Create a single‐plot figure for 1 global factor, order 3
fig, ax = plt.subplots(figsize=(6, 6), sharey=True)

num_factors = 1
order = 3
    
# Construct file name based on the model's parameters
factors_str = f"Global_{num_factors}_{order}"
mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
mse_file_path = os.path.join(mse_dir, mse_file_name)

# Load the MSE values from file
mse_df = pd.read_csv(mse_file_path)
# Construct y values based on the vintages
y_values = [mse_df[col].iloc[0] for col in vintage_col_names]

# Extend the y-values so the step function holds the last value
y_extended = y_values.copy()
y_extended.append(y_values[-1]) # Repeat the last value

# Plot the step function for the current model
ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
         label=f"Order: {order}")
        
# Customize the subplot
ax.set_xlabel("Month of Quarter")
# Set ticks only at 1, 2, and 3 to mark the beginning of each month
ax.set_xticks([1, 2, 3])
ax.set_xlim(0.9, 4.1)
ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
ax.set_ylabel("MSE")
ax.legend()

plt.suptitle(f"MSE for the Model with 1 Global Factor and Lag Order 3 ({q_var}, 2008-2018)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_2008-2018_{q_var}")
plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot MSE values for the model with 1 Global Factor and Lag Order 3 evaluated over the 2008–2010 and 2011-2018 periods.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'Consumption'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Define two periods
periods = {
    "2008-2010": lambda df: df["date_float"] < 2011,
    "2011-2018": lambda df: df["date_float"] >= 2011
}

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Loop over each period and create a separate figure
for period_label, period_filter in periods.items():
    
    # Create a single‐plot figure for 1 global factor, order 3
    fig, ax = plt.subplots(figsize=(6, 6), sharey=True)
    
    num_factors = 1
    order = 3
         
    # Construct forecast file name, e.g., "forecasts_Consumption_Global_1_1.csv"
    factors_str = f"Global_{num_factors}_{order}"
    forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
    forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

    # Load forecast data 
    forecasts = pd.read_csv(forecast_file_path, index_col=0)
    forecasts.index.name = "date"
    forecasts.reset_index(inplace=True)

    # Merge forecasts with actual growth 
    merged = pd.merge(forecasts, actual_growth, on="date", how="inner")
    merged["date_float"] = merged["date"].apply(quarter_to_float)
    merged.sort_values("date_float", inplace=True)

    # Filter merged data for the current period
    merged_period = merged[ period_filter(merged) ]

    # Calculate MSE for each vintage column over the filtered period
    mse_dict = {}
    for col in vintage_col_names:
        mse = ((merged_period[col] - merged_period["growth"]) ** 2).mean()
        mse_dict[col] = mse

    # Construct y values based on the vintages
    y_values = [mse_dict[col] for col in vintage_col_names]

    # Extend the y-values so the step function holds the last value
    y_extended = y_values.copy()
    y_extended.append(y_values[-1]) # Repeat the last value

    # Plot the step function for the current model (order)
    ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
            label=f"Order: {order}")
            
    # Customize the subplot
    ax.set_xlabel("Month of Quarter")
    # Set ticks only at 1, 2, and 3 to mark the beginning of each month
    ax.set_xticks([1, 2, 3])
    ax.set_xlim(0.9, 4.1)
    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    ax.set_ylabel("MSE")
    ax.legend()
   
    plt.suptitle(f"MSE for the Model with 1 Global Factor and Lag Order 3 ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot forecasts vs actual growth values for the model with 1 Global Factor, Lag Order 3 and different time periods (2008-2010, 2008-2018, and 2011-2018).

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Convert quarter strings like "2008-03" into a float (e.g. 2008.00 for Q1, 2008.25 for Q2, etc.)
def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'Consumption'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Assign 7 small offsets within each quarter, so each quarter has 7 forecast points
offsets = np.linspace(0, 0.23, 7)

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Build x,y arrays for the actual growth
x_act = actual_growth["date_float"].tolist()
y_act = actual_growth["growth"].tolist()

# Define period configurations: x-axis limits and tick positions for each period
period_configs = {
    "2008-2010": {"xlim": (2008, 2010.99), "xticks": list(range(2008, 2011))},
    "2008-2018": {"xlim": (2008, 2018.99), "xticks": list(range(2008, 2019))},
    "2011-2018": {"xlim": (2011, 2018.99), "xticks": list(range(2011, 2019))}
}

# Loop over each period configuration to create and save separate plots
for period_label, config in period_configs.items():
    
    # Extend the actual growth arrays so that the step function continues until the end of the x-axis
    if period_label in ["2008-2018", "2011-2018"]:
        x_act_extended = x_act.copy()
        x_act_extended.append(config["xlim"][1])
        y_act_extended = y_act.copy()
        y_act_extended.append(y_act[-1])
    else:
        x_act_extended = x_act
        y_act_extended = y_act

    # Create a single‐plot figure for 1 global factor, order 3
    fig, ax = plt.subplots(figsize=(6, 6), sharey=True)

    num_factors = 1
    order = 3
    
    # Construct forecast file name, e.g., "forecasts_Consumption_Global_1_1.csv"
    factors_str = f"Global_{num_factors}_{order}"
    forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
    forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

    # Load forecast data 
    forecasts = pd.read_csv(forecast_file_path, index_col=0)
    forecasts.index.name = "date"
    forecasts.reset_index(inplace=True)

    # Merge forecasts with actual growth dates
    merged = pd.merge(forecasts, actual_growth[['date']], on="date", how="inner")
    merged["date_float"] = merged["date"].apply(quarter_to_float)
    merged.sort_values("date_float", inplace=True)

    # Build forecast x and y arrays 
    x_fore = []
    y_fore = []
    for idx, row in merged.iterrows():
        base_x = row["date_float"]
        # For each of the 7 vintage columns, define an x-position and take that forecast value
        for j, col in enumerate(vintage_col_names):
            x_fore.append(base_x + offsets[j])
            y_fore.append(row[col])

    # Plot the forecast step curve for the current order
    ax.step(x_fore, y_fore, where='post', linewidth=1.2, label=f"Order: {order}")

    # Plot actual growth as a step plot in each subplot
    ax.step(x_act_extended, y_act_extended, where='post', color='black', linewidth=1.2, label="Actual growth")

    # Customize the subplot
    ax.set_xlabel("Year")
    ax.set_xlim(config["xlim"][0], config["xlim"][1])
    ax.set_xticks(config["xticks"])

    # Set y-axis limits based on the data within the period range
    x_min, x_max = config["xlim"]
    def filter_points(x_arr, y_arr, x_min, x_max):
        return [y for x, y in zip(x_arr, y_arr) if x_min <= x <= x_max]

    # Filter y-values
    y_filtered = filter_points(x_fore, y_fore, x_min, x_max)
    y_act_filtered = filter_points(x_act_extended, y_act_extended, x_min, x_max)

    # Combine all filtered y-values
    combined_y = y_filtered + y_act_filtered
    ax.set_ylim(1.05 * min(combined_y), 1.2 * max(combined_y))

    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    ax.set_ylabel("Annualized q-o-q Growth (%)")
    ax.legend()
        
    plt.suptitle(f"Forecast vs Actual Growth for Different Models ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_forecast_vs_actual_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
