# %% [markdown]
# # Out-of-sample forecasting experiments
#
# I conduct out-of-sample forecasting experiments to understand what kind of text data (topics, sentiment, or uncertainty) helps improve forecasts of three quarterly variables (GDP, Investment, and Consumption) more.
#
# In this notebook, I evaluate the performance of dynamic factor models (DFM) using only 10 sentiment-adjusted topics (BPW) most highly correlated with GDP growth (out of 200 topics estimated on articles published before 2008 using all sources). I use text data to forecast GDP growth.
#
# ## Experiment Details
#
# - **Data Sources:** 10 sentiment-adjusted topics, BPW (<=2007, 200 topics, all sources).
# - **Forecast Target:** GDP growth.
# - **Model:** Dynamic Factor Models (DFM).
# - **Parameters Explored:**
#   - **Number of Global Factors:** 1
#   - **Factor Order:** 3

# %%
import os
import time
import datetime
import pandas as pd
import DFM_function

# Define inputs common to all models
q_var = 'GDP'                      # quarterly variable being forecasted
additional_factors = None          # or "all" or e.g. ['Labor market']
start = '1991-04'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"
with_text = True
only_text = True

# Generate list of forecast_month strings for quarters from 2008Q1 to 2018Q4
# forecast_month is set to the month corresponding to quarter-end:
# Q1: 'YYYY-03', Q2: 'YYYY-06', Q3: 'YYYY-09', Q4: 'YYYY-12'
forecast_months = []
for year in range(2008, 2019):
    forecast_months.extend([f"{year}-03", f"{year}-06", f"{year}-09", f"{year}-12"])
    
# Define the vintage column names 
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Create directories to save forecasts and MSE results
os.makedirs(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
os.makedirs(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)

# Load the actual growth data
actual_growth_file = f"../{q_var}_growth_actual.csv"
actual_growth = pd.read_csv(actual_growth_file)

# Record overall start time
overall_start = time.time()

num_factors = 1
order = 3
      
# Define model-specific parameters
factor_multiplicities = {'Global': num_factors}
factor_orders = {'Global': order}

# Prepare lists to store each quarter's forecasts and row labels
forecasts_all_quarters = []
row_labels = []

# Start timing for this model
start_time = time.time()

# Loop over each forecast month, get the forecasts, and store the results
for fm in forecast_months:
    # Use the forecast_month string as the row label
    row_labels.append(fm)

    # Run the forecast function for this quarter
    forecasts_dict = DFM_function.get_forecasts(
        forecast_month = fm,
        q_var = q_var,
        additional_factors = additional_factors,
        factor_multiplicities = factor_multiplicities,
        factor_orders = factor_orders,
        start = start,
        text_type = text_type,
        estimation_period = estimation_period,
        num_topics = num_topics,
        source = source,
        with_text = with_text,
        only_text = only_text
    )

    # Obtain the correct ordering of vintages
    vintages_order = DFM_function.vintage_dates(fm)
    # Extract the forecast value for each vintage in that order
    quarter_forecasts = [forecasts_dict[vint] for vint in vintages_order]
    forecasts_all_quarters.append(quarter_forecasts)

# Create a DataFrame with rows labeled by the forecast_month strings and columns as vintage names
results = pd.DataFrame(forecasts_all_quarters, index=row_labels, columns=vintage_col_names)

# Stop timing for this model and print elapsed time
elapsed = time.time() - start_time
elapsed_time = datetime.timedelta(seconds=elapsed)
print(f"Model with Global factors = {num_factors} and order = {order} estimated in {elapsed_time}.")

# Construct the output file name
factors_str = "_".join([
    f"{factor.replace(' ', '_')}_{factor_multiplicities[factor]}_{factor_orders[factor]}"
    for factor in factor_multiplicities])
file_name = f"forecasts_{q_var}_{factors_str}.csv"

# Save the CSV file in a subfolder 
output_path = os.path.join(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", file_name)
results.to_csv(output_path, index=True)

# ----- MSE Calculation -----
# Load forecasts
forecasts = pd.read_csv(output_path, index_col=0)
# Make sure the index is a column named "date"
forecasts.index.name = "date"
forecasts.reset_index(inplace=True)

# Merge dfs by date 
merged = pd.merge(forecasts, actual_growth, on="date", how="inner")

# Calculate the Mean Squared Error (MSE) for each vintage column
mse_dict = {}
for col in vintage_col_names:
    mse = ((merged[col] - merged["growth"]) ** 2).mean()
    mse_dict[col] = mse

# Create a df with one row (the MSE values for each forecasting horizon)
mse_df = pd.DataFrame(mse_dict, index=[0])

# Save MSE results to CSV
mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
mse_output_path = os.path.join(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", mse_file_name)
mse_df.to_csv(mse_output_path, index=False)
# Out:
# EM start iterations, llf=-2204.3
# EM iteration 100, llf=-2165.1, convergence criterion=2.3904e-06
# EM converged at iteration 150, llf=-2164.9, convergence criterion=9.884e-07 < tolerance=1e-06
# EM start iterations, llf=-2204.3
# EM iteration 100, llf=-2165.1, convergence criterion=2.3904e-06
# EM converged at iteration 150, llf=-2164.9, convergence criterion=9.884e-07 < tolerance=1e-06
# EM start iterations, llf=-2215.2
# EM iteration 100, llf=-2175.8, convergence criterion=2.377e-06
# EM converged at iteration 149, llf=-2175.6, convergence criterion=9.9734e-07 < tolerance=1e-06
# EM start iterations, llf=-2216.7
# EM iteration 100, llf=-2177.3, convergence criterion=2.3601e-06
# EM converged at iteration 149, llf=-2177.1, convergence criterion=9.9012e-07 < tolerance=1e-06
# EM start iterations, llf=-2240.9
# EM iteration 100, llf=-2200.2, convergence criterion=2.3458e-06
# EM converged at iteration 149, llf=-2200, convergence criterion=9.8551e-07 < tolerance=1e-06
# EM start iterations, llf=-2240.9
# EM iteration 100, llf=-2200.2, convergence criterion=2.3458e-06
# EM converged at iteration 149, llf=-2200, convergence criterion=9.8551e-07 < tolerance=1e-06
# EM start iterations, llf=-2256.7
# EM iteration 100, llf=-2217.7, convergence criterion=2.3774e-06
# EM converged at iteration 150, llf=-2217.5, convergence criterion=9.9686e-07 < tolerance=1e-06
# EM start iterations, llf=-2256.7
# EM iteration 100, llf=-2217.7, convergence criterion=2.3774e-06
# EM converged at iteration 150, llf=-2217.5, convergence criterion=9.9686e-07 < tolerance=1e-06
# EM start iterations, llf=-2256.7
# EM iteration 100, llf=-2217.7, convergence criterion=2.3774e-06
# EM converged at iteration 150, llf=-2217.5, convergence criterion=9.9686e-07 < tolerance=1e-06
# EM start iterations, llf=-2272.6
# EM iteration 100, llf=-2234.4, convergence criterion=2.2896e-06
# EM converged at iteration 148, llf=-2234.2, convergence criterion=9.8705e-07 < tolerance=1e-06
# EM start iterations, llf=-2274.1
# EM iteration 100, llf=-2235.9, convergence criterion=1.9672e-06
# EM converged at iteration 138, llf=-2235.8, convergence criterion=9.8656e-07 < tolerance=1e-06
# EM start iterations, llf=-2288.3
# EM iteration 100, llf=-2250.4, convergence criterion=1.9432e-06
# EM converged at iteration 137, llf=-2250.3, convergence criterion=9.8958e-07 < tolerance=1e-06
# EM start iterations, llf=-2288.3
# EM iteration 100, llf=-2250.4, convergence criterion=1.9432e-06
# EM converged at iteration 137, llf=-2250.3, convergence criterion=9.8958e-07 < tolerance=1e-06
# EM start iterations, llf=-2304.8
# EM iteration 100, llf=-2265.8, convergence criterion=1.9378e-06
# EM converged at iteration 137, llf=-2265.7, convergence criterion=9.8625e-07 < tolerance=1e-06
# EM start iterations, llf=-2304.8
# EM iteration 100, llf=-2265.8, convergence criterion=1.9378e-06
# EM converged at iteration 137, llf=-2265.7, convergence criterion=9.8625e-07 < tolerance=1e-06
# EM start iterations, llf=-2304.8
# EM iteration 100, llf=-2265.8, convergence criterion=1.9378e-06
# EM converged at iteration 137, llf=-2265.7, convergence criterion=9.8625e-07 < tolerance=1e-06
# EM start iterations, llf=-2318.8
# EM iteration 100, llf=-2279.5, convergence criterion=1.9263e-06
# EM converged at iteration 136, llf=-2279.4, convergence criterion=9.959e-07 < tolerance=1e-06
# EM start iterations, llf=-2320
# EM converged at iteration 95, llf=-2281, convergence criterion=9.9014e-07 < tolerance=1e-06
# EM start iterations, llf=-2335.4
# EM converged at iteration 97, llf=-2296.2, convergence criterion=9.8243e-07 < tolerance=1e-06
# EM start iterations, llf=-2335.4
# EM converged at iteration 97, llf=-2296.2, convergence criterion=9.8243e-07 < tolerance=1e-06
# EM start iterations, llf=-2354
# EM converged at iteration 96, llf=-2314.8, convergence criterion=9.8629e-07 < tolerance=1e-06
# EM start iterations, llf=-2354
# EM converged at iteration 96, llf=-2314.8, convergence criterion=9.8629e-07 < tolerance=1e-06
# EM start iterations, llf=-2354
# EM converged at iteration 96, llf=-2314.8, convergence criterion=9.8629e-07 < tolerance=1e-06
# EM start iterations, llf=-2419.2
# EM converged at iteration 91, llf=-2365.7, convergence criterion=9.9046e-07 < tolerance=1e-06
# EM start iterations, llf=-2420.4
# EM iteration 100, llf=-2367, convergence criterion=1.0236e-06
# EM converged at iteration 102, llf=-2367, convergence criterion=9.8097e-07 < tolerance=1e-06
# EM start iterations, llf=-2355.5
# EM iteration 100, llf=-2305.8, convergence criterion=1.0692e-06
# EM converged at iteration 104, llf=-2305.8, convergence criterion=9.8321e-07 < tolerance=1e-06
# EM start iterations, llf=-2355.5
# EM iteration 100, llf=-2305.8, convergence criterion=1.0692e-06
# EM converged at iteration 104, llf=-2305.8, convergence criterion=9.8321e-07 < tolerance=1e-06
# EM start iterations, llf=-2319.8
# EM iteration 100, llf=-2270.6, convergence criterion=1.096e-06
# EM converged at iteration 105, llf=-2270.6, convergence criterion=9.8733e-07 < tolerance=1e-06
# EM start iterations, llf=-2319.8
# EM iteration 100, llf=-2270.6, convergence criterion=1.096e-06
# EM converged at iteration 105, llf=-2270.6, convergence criterion=9.8733e-07 < tolerance=1e-06
# EM start iterations, llf=-2319.8
# EM iteration 100, llf=-2270.6, convergence criterion=1.096e-06
# EM converged at iteration 105, llf=-2270.6, convergence criterion=9.8733e-07 < tolerance=1e-06
# EM start iterations, llf=-2292.3
# EM iteration 100, llf=-2245.5, convergence criterion=1.1146e-06
# EM converged at iteration 106, llf=-2245.5, convergence criterion=9.8398e-07 < tolerance=1e-06
# EM start iterations, llf=-2289
# EM iteration 100, llf=-2242.5, convergence criterion=1.0465e-06
# EM converged at iteration 103, llf=-2242.5, convergence criterion=9.8299e-07 < tolerance=1e-06
# EM start iterations, llf=-2251.9
# EM iteration 100, llf=-2206.1, convergence criterion=1.0405e-06
# EM converged at iteration 102, llf=-2206.1, convergence criterion=9.9752e-07 < tolerance=1e-06
# EM start iterations, llf=-2251.9
# EM iteration 100, llf=-2206.1, convergence criterion=1.0405e-06
# EM converged at iteration 102, llf=-2206.1, convergence criterion=9.9752e-07 < tolerance=1e-06
# EM start iterations, llf=-2221.2
# EM iteration 100, llf=-2177.3, convergence criterion=1.0522e-06
# EM converged at iteration 103, llf=-2177.3, convergence criterion=9.8767e-07 < tolerance=1e-06
# EM start iterations, llf=-2221.2
# EM iteration 100, llf=-2177.3, convergence criterion=1.0522e-06
# EM converged at iteration 103, llf=-2177.3, convergence criterion=9.8767e-07 < tolerance=1e-06
# EM start iterations, llf=-2221.2
# EM iteration 100, llf=-2177.3, convergence criterion=1.0522e-06
# EM converged at iteration 103, llf=-2177.3, convergence criterion=9.8767e-07 < tolerance=1e-06
# EM start iterations, llf=-2218.5
# EM iteration 100, llf=-2173.9, convergence criterion=1.0114e-06
# EM converged at iteration 101, llf=-2173.9, convergence criterion=9.9025e-07 < tolerance=1e-06
# EM start iterations, llf=-2209.5
# EM iteration 100, llf=-2165.5, convergence criterion=1.5955e-06
# EM converged at iteration 126, llf=-2165.4, convergence criterion=9.923e-07 < tolerance=1e-06
# EM start iterations, llf=-2203.3
# EM iteration 100, llf=-2159.7, convergence criterion=1.6059e-06
# EM converged at iteration 126, llf=-2159.6, convergence criterion=9.9683e-07 < tolerance=1e-06
# EM start iterations, llf=-2203.3
# EM iteration 100, llf=-2159.7, convergence criterion=1.6059e-06
# EM converged at iteration 126, llf=-2159.6, convergence criterion=9.9683e-07 < tolerance=1e-06
# EM start iterations, llf=-2225.1
# EM iteration 100, llf=-2179.9, convergence criterion=1.6078e-06
# EM converged at iteration 127, llf=-2179.8, convergence criterion=9.8753e-07 < tolerance=1e-06
# EM start iterations, llf=-2225.1
# EM iteration 100, llf=-2179.9, convergence criterion=1.6078e-06
# EM converged at iteration 127, llf=-2179.8, convergence criterion=9.8753e-07 < tolerance=1e-06
# EM start iterations, llf=-2225.1
# EM iteration 100, llf=-2179.9, convergence criterion=1.6078e-06
# EM converged at iteration 127, llf=-2179.8, convergence criterion=9.8753e-07 < tolerance=1e-06
# EM start iterations, llf=-2231.8
# EM iteration 100, llf=-2186.9, convergence criterion=1.601e-06
# EM converged at iteration 126, llf=-2186.8, convergence criterion=9.9689e-07 < tolerance=1e-06
# EM start iterations, llf=-2237.1
# EM converged at iteration 90, llf=-2192.3, convergence criterion=9.7742e-07 < tolerance=1e-06
# EM start iterations, llf=-2254.2
# EM converged at iteration 89, llf=-2210.2, convergence criterion=9.8465e-07 < tolerance=1e-06
# EM start iterations, llf=-2254.2
# EM converged at iteration 89, llf=-2210.2, convergence criterion=9.8465e-07 < tolerance=1e-06
# EM start iterations, llf=-2266.5
# EM converged at iteration 89, llf=-2221.1, convergence criterion=9.8513e-07 < tolerance=1e-06
# EM start iterations, llf=-2266.5
# EM converged at iteration 89, llf=-2221.1, convergence criterion=9.8513e-07 < tolerance=1e-06
# EM start iterations, llf=-2266.5
# EM converged at iteration 89, llf=-2221.1, convergence criterion=9.8513e-07 < tolerance=1e-06
# EM start iterations, llf=-2278
# EM converged at iteration 89, llf=-2232.3, convergence criterion=9.828e-07 < tolerance=1e-06
# EM start iterations, llf=-2280.7
# EM iteration 100, llf=-2235.4, convergence criterion=1.4495e-06
# EM converged at iteration 121, llf=-2235.4, convergence criterion=9.8429e-07 < tolerance=1e-06
# EM start iterations, llf=-2294.1
# EM iteration 100, llf=-2248.4, convergence criterion=1.4423e-06
# EM converged at iteration 120, llf=-2248.3, convergence criterion=9.9566e-07 < tolerance=1e-06
# EM start iterations, llf=-2294.1
# EM iteration 100, llf=-2248.4, convergence criterion=1.4423e-06
# EM converged at iteration 120, llf=-2248.3, convergence criterion=9.9566e-07 < tolerance=1e-06
# EM start iterations, llf=-2306.8
# EM iteration 100, llf=-2260.7, convergence criterion=1.4281e-06
# EM converged at iteration 120, llf=-2260.6, convergence criterion=9.8641e-07 < tolerance=1e-06
# EM start iterations, llf=-2306.8
# EM iteration 100, llf=-2260.7, convergence criterion=1.4281e-06
# EM converged at iteration 120, llf=-2260.6, convergence criterion=9.8641e-07 < tolerance=1e-06
# EM start iterations, llf=-2306.8
# EM iteration 100, llf=-2260.7, convergence criterion=1.4281e-06
# EM converged at iteration 120, llf=-2260.6, convergence criterion=9.8641e-07 < tolerance=1e-06
# EM start iterations, llf=-2319.1
# EM iteration 100, llf=-2272.9, convergence criterion=1.4252e-06
# EM converged at iteration 120, llf=-2272.8, convergence criterion=9.8444e-07 < tolerance=1e-06
# EM start iterations, llf=-2320.3
# EM iteration 100, llf=-2274.1, convergence criterion=1.4204e-06
# EM converged at iteration 119, llf=-2274, convergence criterion=9.9857e-07 < tolerance=1e-06
# EM start iterations, llf=-2330.9
# EM iteration 100, llf=-2284.5, convergence criterion=1.4147e-06
# EM converged at iteration 119, llf=-2284.4, convergence criterion=9.9421e-07 < tolerance=1e-06
# EM start iterations, llf=-2330.9
# EM iteration 100, llf=-2284.5, convergence criterion=1.4147e-06
# EM converged at iteration 119, llf=-2284.4, convergence criterion=9.9421e-07 < tolerance=1e-06
# EM start iterations, llf=-2343.7
# EM iteration 100, llf=-2297.3, convergence criterion=1.4193e-06
# EM converged at iteration 119, llf=-2297.3, convergence criterion=9.9751e-07 < tolerance=1e-06
# EM start iterations, llf=-2343.7
# EM iteration 100, llf=-2297.3, convergence criterion=1.4193e-06
# EM converged at iteration 119, llf=-2297.3, convergence criterion=9.9751e-07 < tolerance=1e-06
# EM start iterations, llf=-2343.7
# EM iteration 100, llf=-2297.3, convergence criterion=1.4193e-06
# EM converged at iteration 119, llf=-2297.3, convergence criterion=9.9751e-07 < tolerance=1e-06
# EM start iterations, llf=-2354.1
# EM iteration 100, llf=-2307.8, convergence criterion=1.4103e-06
# EM converged at iteration 119, llf=-2307.7, convergence criterion=9.9107e-07 < tolerance=1e-06
# EM start iterations, llf=-2355.5
# EM iteration 100, llf=-2309.1, convergence criterion=1.6756e-06
# EM converged at iteration 130, llf=-2309, convergence criterion=9.8641e-07 < tolerance=1e-06
# EM start iterations, llf=-2373.4
# EM iteration 100, llf=-2326.5, convergence criterion=1.6786e-06
# EM converged at iteration 130, llf=-2326.4, convergence criterion=9.8846e-07 < tolerance=1e-06
# EM start iterations, llf=-2373.4
# EM iteration 100, llf=-2326.5, convergence criterion=1.6786e-06
# EM converged at iteration 130, llf=-2326.4, convergence criterion=9.8846e-07 < tolerance=1e-06
# EM start iterations, llf=-2386
# EM iteration 100, llf=-2338.6, convergence criterion=1.669e-06
# EM converged at iteration 129, llf=-2338.5, convergence criterion=9.9818e-07 < tolerance=1e-06
# EM start iterations, llf=-2386
# EM iteration 100, llf=-2338.6, convergence criterion=1.669e-06
# EM converged at iteration 129, llf=-2338.5, convergence criterion=9.9818e-07 < tolerance=1e-06
# EM start iterations, llf=-2386
# EM iteration 100, llf=-2338.6, convergence criterion=1.669e-06
# EM converged at iteration 129, llf=-2338.5, convergence criterion=9.9818e-07 < tolerance=1e-06
# EM start iterations, llf=-2398.8
# EM iteration 100, llf=-2351.2, convergence criterion=1.6446e-06
# EM converged at iteration 128, llf=-2351.1, convergence criterion=9.9808e-07 < tolerance=1e-06
# EM start iterations, llf=-2401
# EM iteration 100, llf=-2353.2, convergence criterion=1.4954e-06
# EM converged at iteration 122, llf=-2353.1, convergence criterion=9.9867e-07 < tolerance=1e-06
# EM start iterations, llf=-2409
# EM iteration 100, llf=-2361.4, convergence criterion=1.5695e-06
# EM converged at iteration 125, llf=-2361.3, convergence criterion=9.9828e-07 < tolerance=1e-06
# EM start iterations, llf=-2409
# EM iteration 100, llf=-2361.4, convergence criterion=1.5695e-06
# EM converged at iteration 125, llf=-2361.3, convergence criterion=9.9828e-07 < tolerance=1e-06
# EM start iterations, llf=-2415.3
# EM iteration 100, llf=-2367.9, convergence criterion=1.5994e-06
# EM converged at iteration 127, llf=-2367.8, convergence criterion=9.8639e-07 < tolerance=1e-06
# EM start iterations, llf=-2415.3
# EM iteration 100, llf=-2367.9, convergence criterion=1.5994e-06
# EM converged at iteration 127, llf=-2367.8, convergence criterion=9.8639e-07 < tolerance=1e-06
# EM start iterations, llf=-2415.3
# EM iteration 100, llf=-2367.9, convergence criterion=1.5994e-06
# EM converged at iteration 127, llf=-2367.8, convergence criterion=9.8639e-07 < tolerance=1e-06
# EM start iterations, llf=-2418.3
# EM iteration 100, llf=-2371.1, convergence criterion=1.6392e-06
# EM converged at iteration 128, llf=-2371, convergence criterion=9.9606e-07 < tolerance=1e-06
# EM start iterations, llf=-2419.6
# EM iteration 100, llf=-2372.2, convergence criterion=1.7037e-06
# EM converged at iteration 130, llf=-2372.1, convergence criterion=9.9746e-07 < tolerance=1e-06
# EM start iterations, llf=-2429.8
# EM iteration 100, llf=-2382.4, convergence criterion=1.6981e-06
# EM converged at iteration 130, llf=-2382.3, convergence criterion=9.9473e-07 < tolerance=1e-06
# EM start iterations, llf=-2429.8
# EM iteration 100, llf=-2382.4, convergence criterion=1.6981e-06
# EM converged at iteration 130, llf=-2382.3, convergence criterion=9.9473e-07 < tolerance=1e-06
# EM start iterations, llf=-2435.8
# EM iteration 100, llf=-2388.6, convergence criterion=1.6915e-06
# EM converged at iteration 130, llf=-2388.5, convergence criterion=9.9083e-07 < tolerance=1e-06
# EM start iterations, llf=-2435.8
# EM iteration 100, llf=-2388.6, convergence criterion=1.6915e-06
# EM converged at iteration 130, llf=-2388.5, convergence criterion=9.9083e-07 < tolerance=1e-06
# EM start iterations, llf=-2435.8
# EM iteration 100, llf=-2388.6, convergence criterion=1.6915e-06
# EM converged at iteration 130, llf=-2388.5, convergence criterion=9.9083e-07 < tolerance=1e-06
# EM start iterations, llf=-2436.8
# EM iteration 100, llf=-2389.7, convergence criterion=1.6451e-06
# EM converged at iteration 128, llf=-2389.7, convergence criterion=9.9401e-07 < tolerance=1e-06
# EM start iterations, llf=-2438.4
# EM iteration 100, llf=-2391.4, convergence criterion=2.045e-06
# EM converged at iteration 144, llf=-2391.3, convergence criterion=9.9947e-07 < tolerance=1e-06
# EM start iterations, llf=-2439.9
# EM iteration 100, llf=-2393, convergence criterion=2.0396e-06
# EM converged at iteration 144, llf=-2392.8, convergence criterion=9.971e-07 < tolerance=1e-06
# EM start iterations, llf=-2439.9
# EM iteration 100, llf=-2393, convergence criterion=2.0396e-06
# EM converged at iteration 144, llf=-2392.8, convergence criterion=9.971e-07 < tolerance=1e-06
# EM start iterations, llf=-2443.5
# EM iteration 100, llf=-2396.6, convergence criterion=2.0386e-06
# EM converged at iteration 144, llf=-2396.4, convergence criterion=9.9709e-07 < tolerance=1e-06
# EM start iterations, llf=-2443.5
# EM iteration 100, llf=-2396.6, convergence criterion=2.0386e-06
# EM converged at iteration 144, llf=-2396.4, convergence criterion=9.9709e-07 < tolerance=1e-06
# EM start iterations, llf=-2443.5
# EM iteration 100, llf=-2396.6, convergence criterion=2.0386e-06
# EM converged at iteration 144, llf=-2396.4, convergence criterion=9.9709e-07 < tolerance=1e-06
# EM start iterations, llf=-2450.3
# EM iteration 100, llf=-2403.3, convergence criterion=2.0333e-06
# EM converged at iteration 144, llf=-2403.2, convergence criterion=9.9504e-07 < tolerance=1e-06
# EM start iterations, llf=-2450.8
# EM iteration 100, llf=-2403.8, convergence criterion=1.5851e-06
# EM converged at iteration 127, llf=-2403.7, convergence criterion=9.8529e-07 < tolerance=1e-06
# EM start iterations, llf=-2457.8
# EM iteration 100, llf=-2410.9, convergence criterion=1.5916e-06
# EM converged at iteration 127, llf=-2410.8, convergence criterion=9.8947e-07 < tolerance=1e-06
# EM start iterations, llf=-2457.8
# EM iteration 100, llf=-2410.9, convergence criterion=1.5916e-06
# EM converged at iteration 127, llf=-2410.8, convergence criterion=9.8947e-07 < tolerance=1e-06
# EM start iterations, llf=-2465
# EM iteration 100, llf=-2418, convergence criterion=1.6044e-06
# EM converged at iteration 127, llf=-2417.9, convergence criterion=9.9846e-07 < tolerance=1e-06
# EM start iterations, llf=-2465
# EM iteration 100, llf=-2418, convergence criterion=1.6044e-06
# EM converged at iteration 127, llf=-2417.9, convergence criterion=9.9846e-07 < tolerance=1e-06
# EM start iterations, llf=-2465
# EM iteration 100, llf=-2418, convergence criterion=1.6044e-06
# EM converged at iteration 127, llf=-2417.9, convergence criterion=9.9846e-07 < tolerance=1e-06
# EM start iterations, llf=-2473.8
# EM iteration 100, llf=-2426.7, convergence criterion=1.6175e-06
# EM converged at iteration 128, llf=-2426.6, convergence criterion=9.9161e-07 < tolerance=1e-06
# EM start iterations, llf=-2473.8
# EM iteration 100, llf=-2426.7, convergence criterion=1.6175e-06
# EM converged at iteration 128, llf=-2426.6, convergence criterion=9.9161e-07 < tolerance=1e-06
# EM start iterations, llf=-2497.7
# EM iteration 100, llf=-2451.7, convergence criterion=1.5004e-06
# EM converged at iteration 123, llf=-2451.6, convergence criterion=9.9072e-07 < tolerance=1e-06
# EM start iterations, llf=-2497.7
# EM iteration 100, llf=-2451.7, convergence criterion=1.5004e-06
# EM converged at iteration 123, llf=-2451.6, convergence criterion=9.9072e-07 < tolerance=1e-06
# EM start iterations, llf=-2511.3
# EM iteration 100, llf=-2464.7, convergence criterion=1.5032e-06
# EM converged at iteration 123, llf=-2464.6, convergence criterion=9.9388e-07 < tolerance=1e-06
# EM start iterations, llf=-2511.3
# EM iteration 100, llf=-2464.7, convergence criterion=1.5032e-06
# EM converged at iteration 123, llf=-2464.6, convergence criterion=9.9388e-07 < tolerance=1e-06
# EM start iterations, llf=-2511.3
# EM iteration 100, llf=-2464.7, convergence criterion=1.5032e-06
# EM converged at iteration 123, llf=-2464.6, convergence criterion=9.9388e-07 < tolerance=1e-06
# EM start iterations, llf=-2520.7
# EM iteration 100, llf=-2474.9, convergence criterion=1.4806e-06
# EM converged at iteration 122, llf=-2474.8, convergence criterion=9.9359e-07 < tolerance=1e-06
# EM start iterations, llf=-2521.6
# EM iteration 100, llf=-2475.8, convergence criterion=1.5268e-06
# EM converged at iteration 124, llf=-2475.8, convergence criterion=9.9306e-07 < tolerance=1e-06
# EM start iterations, llf=-2528
# EM iteration 100, llf=-2482.2, convergence criterion=1.5202e-06
# EM converged at iteration 124, llf=-2482.1, convergence criterion=9.8865e-07 < tolerance=1e-06
# EM start iterations, llf=-2528
# EM iteration 100, llf=-2482.2, convergence criterion=1.5202e-06
# EM converged at iteration 124, llf=-2482.1, convergence criterion=9.8865e-07 < tolerance=1e-06
# EM start iterations, llf=-2536.5
# EM iteration 100, llf=-2490.7, convergence criterion=1.5165e-06
# EM converged at iteration 124, llf=-2490.6, convergence criterion=9.8609e-07 < tolerance=1e-06
# EM start iterations, llf=-2536.5
# EM iteration 100, llf=-2490.7, convergence criterion=1.5165e-06
# EM converged at iteration 124, llf=-2490.6, convergence criterion=9.8609e-07 < tolerance=1e-06
# EM start iterations, llf=-2536.5
# EM iteration 100, llf=-2490.7, convergence criterion=1.5165e-06
# EM converged at iteration 124, llf=-2490.6, convergence criterion=9.8609e-07 < tolerance=1e-06
# EM start iterations, llf=-2547.4
# EM iteration 100, llf=-2501.1, convergence criterion=1.5139e-06
# EM converged at iteration 124, llf=-2501, convergence criterion=9.8473e-07 < tolerance=1e-06
# EM start iterations, llf=-2548.4
# EM iteration 100, llf=-2502.1, convergence criterion=1.4842e-06
# EM converged at iteration 122, llf=-2502, convergence criterion=9.9687e-07 < tolerance=1e-06
# EM start iterations, llf=-2561.3
# EM iteration 100, llf=-2514.8, convergence criterion=1.4772e-06
# EM converged at iteration 122, llf=-2514.7, convergence criterion=9.9165e-07 < tolerance=1e-06
# EM start iterations, llf=-2561.3
# EM iteration 100, llf=-2514.8, convergence criterion=1.4772e-06
# EM converged at iteration 122, llf=-2514.7, convergence criterion=9.9165e-07 < tolerance=1e-06
# EM start iterations, llf=-2576.7
# EM iteration 100, llf=-2529.3, convergence criterion=1.4656e-06
# EM converged at iteration 122, llf=-2529.2, convergence criterion=9.8459e-07 < tolerance=1e-06
# EM start iterations, llf=-2576.7
# EM iteration 100, llf=-2529.3, convergence criterion=1.4656e-06
# EM converged at iteration 122, llf=-2529.2, convergence criterion=9.8459e-07 < tolerance=1e-06
# EM start iterations, llf=-2576.7
# EM iteration 100, llf=-2529.3, convergence criterion=1.4656e-06
# EM converged at iteration 122, llf=-2529.2, convergence criterion=9.8459e-07 < tolerance=1e-06
# EM start iterations, llf=-2587.4
# EM iteration 100, llf=-2539.9, convergence criterion=1.4619e-06
# EM converged at iteration 121, llf=-2539.8, convergence criterion=9.988e-07 < tolerance=1e-06
# EM start iterations, llf=-2588.7
# EM iteration 100, llf=-2541.2, convergence criterion=1.4602e-06
# EM converged at iteration 121, llf=-2541.1, convergence criterion=9.9671e-07 < tolerance=1e-06
# EM start iterations, llf=-2600.9
# EM iteration 100, llf=-2553.9, convergence criterion=1.4472e-06
# EM converged at iteration 121, llf=-2553.9, convergence criterion=9.8649e-07 < tolerance=1e-06
# EM start iterations, llf=-2600.9
# EM iteration 100, llf=-2553.9, convergence criterion=1.4472e-06
# EM converged at iteration 121, llf=-2553.9, convergence criterion=9.8649e-07 < tolerance=1e-06
# EM start iterations, llf=-2613.3
# EM iteration 100, llf=-2566, convergence criterion=1.4408e-06
# EM converged at iteration 120, llf=-2565.9, convergence criterion=9.9881e-07 < tolerance=1e-06
# EM start iterations, llf=-2613.3
# EM iteration 100, llf=-2566, convergence criterion=1.4408e-06
# EM converged at iteration 120, llf=-2565.9, convergence criterion=9.9881e-07 < tolerance=1e-06
# EM start iterations, llf=-2613.3
# EM iteration 100, llf=-2566, convergence criterion=1.4408e-06
# EM converged at iteration 120, llf=-2565.9, convergence criterion=9.9881e-07 < tolerance=1e-06
# EM start iterations, llf=-2631.5
# EM iteration 100, llf=-2583.3, convergence criterion=1.4444e-06
# EM converged at iteration 121, llf=-2583.3, convergence criterion=9.8555e-07 < tolerance=1e-06
# EM start iterations, llf=-2632.9
# EM iteration 100, llf=-2584.7, convergence criterion=1.6712e-06
# EM converged at iteration 130, llf=-2584.6, convergence criterion=9.8878e-07 < tolerance=1e-06
# EM start iterations, llf=-2634.8
# EM iteration 100, llf=-2587.3, convergence criterion=1.6816e-06
# EM converged at iteration 130, llf=-2587.2, convergence criterion=9.9833e-07 < tolerance=1e-06
# EM start iterations, llf=-2634.8
# EM iteration 100, llf=-2587.3, convergence criterion=1.6816e-06
# EM converged at iteration 130, llf=-2587.2, convergence criterion=9.9833e-07 < tolerance=1e-06
# EM start iterations, llf=-2649.8
# EM iteration 100, llf=-2601.3, convergence criterion=1.672e-06
# EM converged at iteration 130, llf=-2601.2, convergence criterion=9.9116e-07 < tolerance=1e-06
# EM start iterations, llf=-2649.8
# EM iteration 100, llf=-2601.3, convergence criterion=1.672e-06
# EM converged at iteration 130, llf=-2601.2, convergence criterion=9.9116e-07 < tolerance=1e-06
# EM start iterations, llf=-2649.8
# EM iteration 100, llf=-2601.3, convergence criterion=1.672e-06
# EM converged at iteration 130, llf=-2601.2, convergence criterion=9.9116e-07 < tolerance=1e-06
# EM start iterations, llf=-2660.6
# EM iteration 100, llf=-2611.9, convergence criterion=1.6723e-06
# EM converged at iteration 130, llf=-2611.8, convergence criterion=9.9197e-07 < tolerance=1e-06
# EM start iterations, llf=-2662
# EM iteration 100, llf=-2613.2, convergence criterion=1.6381e-06
# EM converged at iteration 129, llf=-2613.1, convergence criterion=9.8464e-07 < tolerance=1e-06
# EM start iterations, llf=-2672.7
# EM iteration 100, llf=-2623.8, convergence criterion=1.6343e-06
# EM converged at iteration 128, llf=-2623.7, convergence criterion=9.9775e-07 < tolerance=1e-06
# EM start iterations, llf=-2672.7
# EM iteration 100, llf=-2623.8, convergence criterion=1.6343e-06
# EM converged at iteration 128, llf=-2623.7, convergence criterion=9.9775e-07 < tolerance=1e-06
# EM start iterations, llf=-2685.2
# EM iteration 100, llf=-2636.1, convergence criterion=1.6385e-06
# EM converged at iteration 129, llf=-2636, convergence criterion=9.8506e-07 < tolerance=1e-06
# EM start iterations, llf=-2685.2
# EM iteration 100, llf=-2636.1, convergence criterion=1.6385e-06
# EM converged at iteration 129, llf=-2636, convergence criterion=9.8506e-07 < tolerance=1e-06
# EM start iterations, llf=-2685.2
# EM iteration 100, llf=-2636.1, convergence criterion=1.6385e-06
# EM converged at iteration 129, llf=-2636, convergence criterion=9.8506e-07 < tolerance=1e-06
# EM start iterations, llf=-2696.6
# EM iteration 100, llf=-2647.1, convergence criterion=1.6349e-06
# EM converged at iteration 128, llf=-2647, convergence criterion=9.9878e-07 < tolerance=1e-06
# EM start iterations, llf=-2697.6
# EM iteration 100, llf=-2648.1, convergence criterion=1.5121e-06
# EM converged at iteration 123, llf=-2648, convergence criterion=9.9707e-07 < tolerance=1e-06
# EM start iterations, llf=-2711.7
# EM iteration 100, llf=-2662.3, convergence criterion=1.5082e-06
# EM converged at iteration 123, llf=-2662.3, convergence criterion=9.9502e-07 < tolerance=1e-06
# EM start iterations, llf=-2711.7
# EM iteration 100, llf=-2662.3, convergence criterion=1.5082e-06
# EM converged at iteration 123, llf=-2662.3, convergence criterion=9.9502e-07 < tolerance=1e-06
# EM start iterations, llf=-2721.6
# EM iteration 100, llf=-2672.2, convergence criterion=1.5073e-06
# EM converged at iteration 123, llf=-2672.1, convergence criterion=9.9481e-07 < tolerance=1e-06
# EM start iterations, llf=-2721.6
# EM iteration 100, llf=-2672.2, convergence criterion=1.5073e-06
# EM converged at iteration 123, llf=-2672.1, convergence criterion=9.9481e-07 < tolerance=1e-06
# EM start iterations, llf=-2721.6
# EM iteration 100, llf=-2672.2, convergence criterion=1.5073e-06
# EM converged at iteration 123, llf=-2672.1, convergence criterion=9.9481e-07 < tolerance=1e-06
# EM start iterations, llf=-2732.5
# EM iteration 100, llf=-2683, convergence criterion=1.5099e-06
# EM converged at iteration 123, llf=-2683, convergence criterion=9.9712e-07 < tolerance=1e-06
# EM start iterations, llf=-2733.8
# EM iteration 100, llf=-2684.3, convergence criterion=1.4777e-06
# EM converged at iteration 122, llf=-2684.2, convergence criterion=9.9122e-07 < tolerance=1e-06
# EM start iterations, llf=-2749.3
# EM iteration 100, llf=-2699.4, convergence criterion=1.4652e-06
# EM converged at iteration 121, llf=-2699.4, convergence criterion=9.9856e-07 < tolerance=1e-06
# EM start iterations, llf=-2749.3
# EM iteration 100, llf=-2699.4, convergence criterion=1.4652e-06
# EM converged at iteration 121, llf=-2699.4, convergence criterion=9.9856e-07 < tolerance=1e-06
# EM start iterations, llf=-2760.4
# EM iteration 100, llf=-2710.7, convergence criterion=1.4582e-06
# EM converged at iteration 121, llf=-2710.6, convergence criterion=9.9366e-07 < tolerance=1e-06
# EM start iterations, llf=-2760.4
# EM iteration 100, llf=-2710.7, convergence criterion=1.4582e-06
# EM converged at iteration 121, llf=-2710.6, convergence criterion=9.9366e-07 < tolerance=1e-06
# EM start iterations, llf=-2760.4
# EM iteration 100, llf=-2710.7, convergence criterion=1.4582e-06
# EM converged at iteration 121, llf=-2710.6, convergence criterion=9.9366e-07 < tolerance=1e-06
# EM start iterations, llf=-2772.2
# EM iteration 100, llf=-2722, convergence criterion=1.4522e-06
# EM converged at iteration 121, llf=-2721.9, convergence criterion=9.8918e-07 < tolerance=1e-06
# EM start iterations, llf=-2773.5
# EM iteration 100, llf=-2723.3, convergence criterion=1.1231e-06
# EM converged at iteration 106, llf=-2723.3, convergence criterion=9.98e-07 < tolerance=1e-06
# EM start iterations, llf=-2785.9
# EM iteration 100, llf=-2735.6, convergence criterion=1.1218e-06
# EM converged at iteration 106, llf=-2735.6, convergence criterion=9.9707e-07 < tolerance=1e-06
# EM start iterations, llf=-2785.9
# EM iteration 100, llf=-2735.6, convergence criterion=1.1218e-06
# EM converged at iteration 106, llf=-2735.6, convergence criterion=9.9707e-07 < tolerance=1e-06
# EM start iterations, llf=-2797.4
# EM iteration 100, llf=-2747, convergence criterion=1.1177e-06
# EM converged at iteration 106, llf=-2747, convergence criterion=9.9352e-07 < tolerance=1e-06
# EM start iterations, llf=-2797.4
# EM iteration 100, llf=-2747, convergence criterion=1.1177e-06
# EM converged at iteration 106, llf=-2747, convergence criterion=9.9352e-07 < tolerance=1e-06
# EM start iterations, llf=-2797.4
# EM iteration 100, llf=-2747, convergence criterion=1.1177e-06
# EM converged at iteration 106, llf=-2747, convergence criterion=9.9352e-07 < tolerance=1e-06
# EM start iterations, llf=-2806.5
# EM iteration 100, llf=-2755.9, convergence criterion=1.1145e-06
# EM converged at iteration 106, llf=-2755.8, convergence criterion=9.9075e-07 < tolerance=1e-06
# EM start iterations, llf=-2807.7
# EM iteration 100, llf=-2757.1, convergence criterion=1.1261e-06
# EM converged at iteration 107, llf=-2757.1, convergence criterion=9.8227e-07 < tolerance=1e-06
# EM start iterations, llf=-2821.5
# EM iteration 100, llf=-2770.6, convergence criterion=1.1183e-06
# EM converged at iteration 106, llf=-2770.5, convergence criterion=9.941e-07 < tolerance=1e-06
# EM start iterations, llf=-2821.5
# EM iteration 100, llf=-2770.6, convergence criterion=1.1183e-06
# EM converged at iteration 106, llf=-2770.5, convergence criterion=9.941e-07 < tolerance=1e-06
# EM start iterations, llf=-2831.3
# EM iteration 100, llf=-2780.1, convergence criterion=1.1194e-06
# EM converged at iteration 106, llf=-2780.1, convergence criterion=9.9534e-07 < tolerance=1e-06
# EM start iterations, llf=-2831.3
# EM iteration 100, llf=-2780.1, convergence criterion=1.1194e-06
# EM converged at iteration 106, llf=-2780.1, convergence criterion=9.9534e-07 < tolerance=1e-06
# EM start iterations, llf=-2831.3
# EM iteration 100, llf=-2780.1, convergence criterion=1.1194e-06
# EM converged at iteration 106, llf=-2780.1, convergence criterion=9.9534e-07 < tolerance=1e-06
# EM start iterations, llf=-2840.6
# EM iteration 100, llf=-2789.2, convergence criterion=1.1154e-06
# EM converged at iteration 106, llf=-2789.2, convergence criterion=9.9176e-07 < tolerance=1e-06
# EM start iterations, llf=-2841.8
# EM iteration 100, llf=-2790.5, convergence criterion=1.1362e-06
# EM converged at iteration 107, llf=-2790.4, convergence criterion=9.9149e-07 < tolerance=1e-06
# EM start iterations, llf=-2853.6
# EM iteration 100, llf=-2801.9, convergence criterion=1.1366e-06
# EM converged at iteration 107, llf=-2801.8, convergence criterion=9.9191e-07 < tolerance=1e-06
# EM start iterations, llf=-2853.6
# EM iteration 100, llf=-2801.9, convergence criterion=1.1366e-06
# EM converged at iteration 107, llf=-2801.8, convergence criterion=9.9191e-07 < tolerance=1e-06
# EM start iterations, llf=-2865.3
# EM iteration 100, llf=-2813.2, convergence criterion=1.1358e-06
# EM converged at iteration 107, llf=-2813.1, convergence criterion=9.9122e-07 < tolerance=1e-06
# EM start iterations, llf=-2865.3
# EM iteration 100, llf=-2813.2, convergence criterion=1.1358e-06
# EM converged at iteration 107, llf=-2813.1, convergence criterion=9.9122e-07 < tolerance=1e-06
# EM start iterations, llf=-2865.3
# EM iteration 100, llf=-2813.2, convergence criterion=1.1358e-06
# EM converged at iteration 107, llf=-2813.1, convergence criterion=9.9122e-07 < tolerance=1e-06
# EM start iterations, llf=-2875.9
# EM iteration 100, llf=-2823.5, convergence criterion=1.1371e-06
# EM converged at iteration 107, llf=-2823.5, convergence criterion=9.9256e-07 < tolerance=1e-06
# EM start iterations, llf=-2877
# EM iteration 100, llf=-2824.6, convergence criterion=1.1181e-06
# EM converged at iteration 106, llf=-2824.6, convergence criterion=9.9477e-07 < tolerance=1e-06
# EM start iterations, llf=-2887.8
# EM iteration 100, llf=-2835.1, convergence criterion=1.1137e-06
# EM converged at iteration 106, llf=-2835.1, convergence criterion=9.9102e-07 < tolerance=1e-06
# EM start iterations, llf=-2887.8
# EM iteration 100, llf=-2835.1, convergence criterion=1.1137e-06
# EM converged at iteration 106, llf=-2835.1, convergence criterion=9.9102e-07 < tolerance=1e-06
# EM start iterations, llf=-2898.3
# EM iteration 100, llf=-2845.3, convergence criterion=1.1094e-06
# EM converged at iteration 106, llf=-2845.3, convergence criterion=9.8708e-07 < tolerance=1e-06
# EM start iterations, llf=-2898.3
# EM iteration 100, llf=-2845.3, convergence criterion=1.1094e-06
# EM converged at iteration 106, llf=-2845.3, convergence criterion=9.8708e-07 < tolerance=1e-06
# EM start iterations, llf=-2898.3
# EM iteration 100, llf=-2845.3, convergence criterion=1.1094e-06
# EM converged at iteration 106, llf=-2845.3, convergence criterion=9.8708e-07 < tolerance=1e-06
# EM start iterations, llf=-2908.3
# EM iteration 100, llf=-2855.1, convergence criterion=1.1071e-06
# EM converged at iteration 106, llf=-2855.1, convergence criterion=9.8501e-07 < tolerance=1e-06
# EM start iterations, llf=-2907.8
# EM converged at iteration 88, llf=-2854.9, convergence criterion=9.8907e-07 < tolerance=1e-06
# EM start iterations, llf=-2923.8
# EM converged at iteration 88, llf=-2870.7, convergence criterion=9.8047e-07 < tolerance=1e-06
# EM start iterations, llf=-2923.8
# EM converged at iteration 88, llf=-2870.7, convergence criterion=9.8047e-07 < tolerance=1e-06
# EM start iterations, llf=-2940.1
# EM converged at iteration 87, llf=-2885.5, convergence criterion=9.9616e-07 < tolerance=1e-06
# EM start iterations, llf=-2940.1
# EM converged at iteration 87, llf=-2885.5, convergence criterion=9.9616e-07 < tolerance=1e-06
# EM start iterations, llf=-2940.1
# EM converged at iteration 87, llf=-2885.5, convergence criterion=9.9616e-07 < tolerance=1e-06
# EM start iterations, llf=-2951
# EM converged at iteration 87, llf=-2896.2, convergence criterion=9.9796e-07 < tolerance=1e-06
# EM start iterations, llf=-2952.2
# EM converged at iteration 89, llf=-2897.4, convergence criterion=9.7949e-07 < tolerance=1e-06
# EM start iterations, llf=-2962.2
# EM converged at iteration 89, llf=-2907.1, convergence criterion=9.8259e-07 < tolerance=1e-06
# EM start iterations, llf=-2962.2
# EM converged at iteration 89, llf=-2907.1, convergence criterion=9.8259e-07 < tolerance=1e-06
# EM start iterations, llf=-2975.6
# EM converged at iteration 88, llf=-2921.2, convergence criterion=9.867e-07 < tolerance=1e-06
# EM start iterations, llf=-2975.6
# EM converged at iteration 88, llf=-2921.2, convergence criterion=9.867e-07 < tolerance=1e-06
# EM start iterations, llf=-2975.6
# EM converged at iteration 88, llf=-2921.2, convergence criterion=9.867e-07 < tolerance=1e-06
# EM start iterations, llf=-2986.2
# EM converged at iteration 88, llf=-2931.6, convergence criterion=9.8435e-07 < tolerance=1e-06
# EM start iterations, llf=-2987.6
# EM converged at iteration 88, llf=-2933.1, convergence criterion=9.9899e-07 < tolerance=1e-06
# EM start iterations, llf=-2999.5
# EM converged at iteration 88, llf=-2944.8, convergence criterion=9.9408e-07 < tolerance=1e-06
# EM start iterations, llf=-2999.5
# EM converged at iteration 88, llf=-2944.8, convergence criterion=9.9408e-07 < tolerance=1e-06
# EM start iterations, llf=-3010.5
# EM converged at iteration 88, llf=-2955.5, convergence criterion=9.926e-07 < tolerance=1e-06
# EM start iterations, llf=-3010.5
# EM converged at iteration 88, llf=-2955.5, convergence criterion=9.926e-07 < tolerance=1e-06
# EM start iterations, llf=-3010.5
# EM converged at iteration 88, llf=-2955.5, convergence criterion=9.926e-07 < tolerance=1e-06
# EM start iterations, llf=-3019.8
# EM converged at iteration 88, llf=-2964.7, convergence criterion=9.8753e-07 < tolerance=1e-06
# EM start iterations, llf=-3021
# EM converged at iteration 88, llf=-2965.9, convergence criterion=9.8538e-07 < tolerance=1e-06
# EM start iterations, llf=-3032
# EM converged at iteration 88, llf=-2976.7, convergence criterion=9.8494e-07 < tolerance=1e-06
# EM start iterations, llf=-3032
# EM converged at iteration 88, llf=-2976.7, convergence criterion=9.8494e-07 < tolerance=1e-06
# EM start iterations, llf=-3044.5
# EM converged at iteration 88, llf=-2989.4, convergence criterion=9.8577e-07 < tolerance=1e-06
# EM start iterations, llf=-3044.5
# EM converged at iteration 88, llf=-2989.4, convergence criterion=9.8577e-07 < tolerance=1e-06
# EM start iterations, llf=-3044.5
# EM converged at iteration 88, llf=-2989.4, convergence criterion=9.8577e-07 < tolerance=1e-06
# EM start iterations, llf=-3055.8
# EM converged at iteration 88, llf=-3000.9, convergence criterion=9.9027e-07 < tolerance=1e-06
# EM start iterations, llf=-3056.8
# EM converged at iteration 94, llf=-3001.8, convergence criterion=9.8474e-07 < tolerance=1e-06
# EM start iterations, llf=-3069.4
# EM converged at iteration 93, llf=-3014.4, convergence criterion=9.9786e-07 < tolerance=1e-06
# EM start iterations, llf=-3069.4
# EM converged at iteration 93, llf=-3014.4, convergence criterion=9.9786e-07 < tolerance=1e-06
# EM start iterations, llf=-3082.1
# EM converged at iteration 93, llf=-3026.8, convergence criterion=9.9567e-07 < tolerance=1e-06
# EM start iterations, llf=-3082.1
# EM converged at iteration 93, llf=-3026.8, convergence criterion=9.9567e-07 < tolerance=1e-06
# EM start iterations, llf=-3082.1
# EM converged at iteration 93, llf=-3026.8, convergence criterion=9.9567e-07 < tolerance=1e-06
# EM start iterations, llf=-3092.9
# EM converged at iteration 93, llf=-3037.8, convergence criterion=9.8936e-07 < tolerance=1e-06
# EM start iterations, llf=-3094.1
# EM converged at iteration 93, llf=-3039, convergence criterion=9.9725e-07 < tolerance=1e-06
# EM start iterations, llf=-3103.8
# EM converged at iteration 93, llf=-3048.5, convergence criterion=9.9112e-07 < tolerance=1e-06
# EM start iterations, llf=-3103.8
# EM converged at iteration 93, llf=-3048.5, convergence criterion=9.9112e-07 < tolerance=1e-06
# EM start iterations, llf=-3114.3
# EM converged at iteration 93, llf=-3058.7, convergence criterion=9.8648e-07 < tolerance=1e-06
# EM start iterations, llf=-3114.3
# EM converged at iteration 93, llf=-3058.7, convergence criterion=9.8648e-07 < tolerance=1e-06
# EM start iterations, llf=-3114.3
# EM converged at iteration 93, llf=-3058.7, convergence criterion=9.8648e-07 < tolerance=1e-06
# EM start iterations, llf=-3125.8
# EM converged at iteration 93, llf=-3070.3, convergence criterion=9.8222e-07 < tolerance=1e-06
# EM start iterations, llf=-3127.1
# EM converged at iteration 93, llf=-3071.5, convergence criterion=9.9463e-07 < tolerance=1e-06
# EM start iterations, llf=-3138.9
# EM converged at iteration 93, llf=-3083.3, convergence criterion=9.9478e-07 < tolerance=1e-06
# EM start iterations, llf=-3138.9
# EM converged at iteration 93, llf=-3083.3, convergence criterion=9.9478e-07 < tolerance=1e-06
# EM start iterations, llf=-3148.7
# EM converged at iteration 93, llf=-3093.2, convergence criterion=9.9034e-07 < tolerance=1e-06
# EM start iterations, llf=-3148.7
# EM converged at iteration 93, llf=-3093.2, convergence criterion=9.9034e-07 < tolerance=1e-06
# EM start iterations, llf=-3148.7
# EM converged at iteration 93, llf=-3093.2, convergence criterion=9.9034e-07 < tolerance=1e-06
# EM start iterations, llf=-3161
# EM converged at iteration 93, llf=-3105.5, convergence criterion=9.8753e-07 < tolerance=1e-06
# EM start iterations, llf=-3162.4
# EM converged at iteration 94, llf=-3106.9, convergence criterion=9.8139e-07 < tolerance=1e-06
# EM start iterations, llf=-3173
# EM converged at iteration 94, llf=-3117.6, convergence criterion=9.8124e-07 < tolerance=1e-06
# EM start iterations, llf=-3173
# EM converged at iteration 94, llf=-3117.6, convergence criterion=9.8124e-07 < tolerance=1e-06
# EM start iterations, llf=-3183.5
# EM converged at iteration 93, llf=-3127.7, convergence criterion=9.9935e-07 < tolerance=1e-06
# EM start iterations, llf=-3183.5
# EM converged at iteration 93, llf=-3127.7, convergence criterion=9.9935e-07 < tolerance=1e-06
# EM start iterations, llf=-3183.5
# EM converged at iteration 93, llf=-3127.7, convergence criterion=9.9935e-07 < tolerance=1e-06
# EM start iterations, llf=-3195.9
# EM converged at iteration 93, llf=-3140.1, convergence criterion=9.9728e-07 < tolerance=1e-06
# EM start iterations, llf=-3197.5
# EM converged at iteration 93, llf=-3141.7, convergence criterion=9.8853e-07 < tolerance=1e-06
# EM start iterations, llf=-3207.3
# EM converged at iteration 93, llf=-3151.4, convergence criterion=9.8883e-07 < tolerance=1e-06
# EM start iterations, llf=-3207.3
# EM converged at iteration 93, llf=-3151.4, convergence criterion=9.8883e-07 < tolerance=1e-06
# EM start iterations, llf=-3219.4
# EM converged at iteration 93, llf=-3163.6, convergence criterion=9.8607e-07 < tolerance=1e-06
# EM start iterations, llf=-3219.4
# EM converged at iteration 93, llf=-3163.6, convergence criterion=9.8607e-07 < tolerance=1e-06
# EM start iterations, llf=-3219.4
# EM converged at iteration 93, llf=-3163.6, convergence criterion=9.8607e-07 < tolerance=1e-06
# EM start iterations, llf=-3232.9
# EM converged at iteration 93, llf=-3177, convergence criterion=9.8612e-07 < tolerance=1e-06
# EM start iterations, llf=-3234.2
# EM converged at iteration 93, llf=-3178.2, convergence criterion=9.9239e-07 < tolerance=1e-06
# EM start iterations, llf=-3244.4
# EM converged at iteration 93, llf=-3188.2, convergence criterion=9.8812e-07 < tolerance=1e-06
# EM start iterations, llf=-3244.4
# EM converged at iteration 93, llf=-3188.2, convergence criterion=9.8812e-07 < tolerance=1e-06
# EM start iterations, llf=-3255.5
# EM converged at iteration 93, llf=-3199.2, convergence criterion=9.8681e-07 < tolerance=1e-06
# EM start iterations, llf=-3255.5
# EM converged at iteration 93, llf=-3199.2, convergence criterion=9.8681e-07 < tolerance=1e-06
# EM start iterations, llf=-3255.5
# EM converged at iteration 93, llf=-3199.2, convergence criterion=9.8681e-07 < tolerance=1e-06
# EM start iterations, llf=-3266
# EM converged at iteration 93, llf=-3209.5, convergence criterion=9.8444e-07 < tolerance=1e-06
# EM start iterations, llf=-3267.3
# EM converged at iteration 93, llf=-3210.8, convergence criterion=9.9607e-07 < tolerance=1e-06
# EM start iterations, llf=-3277.5
# EM converged at iteration 93, llf=-3220.8, convergence criterion=9.922e-07 < tolerance=1e-06
# EM start iterations, llf=-3277.5
# EM converged at iteration 93, llf=-3220.8, convergence criterion=9.922e-07 < tolerance=1e-06
# EM start iterations, llf=-3288.2
# EM converged at iteration 93, llf=-3231.5, convergence criterion=9.9017e-07 < tolerance=1e-06
# EM start iterations, llf=-3288.2
# EM converged at iteration 93, llf=-3231.5, convergence criterion=9.9017e-07 < tolerance=1e-06
# EM start iterations, llf=-3288.2
# EM converged at iteration 93, llf=-3231.5, convergence criterion=9.9017e-07 < tolerance=1e-06
# EM start iterations, llf=-3297.7
# EM converged at iteration 93, llf=-3240.8, convergence criterion=9.874e-07 < tolerance=1e-06
# EM start iterations, llf=-3298.9
# EM converged at iteration 94, llf=-3241.9, convergence criterion=9.8424e-07 < tolerance=1e-06
# EM start iterations, llf=-3308.3
# EM converged at iteration 94, llf=-3251.1, convergence criterion=9.8226e-07 < tolerance=1e-06
# EM start iterations, llf=-3308.3
# EM converged at iteration 94, llf=-3251.1, convergence criterion=9.8226e-07 < tolerance=1e-06
# EM start iterations, llf=-3319.5
# EM converged at iteration 94, llf=-3262.2, convergence criterion=9.8254e-07 < tolerance=1e-06
# EM start iterations, llf=-3319.5
# EM converged at iteration 94, llf=-3262.2, convergence criterion=9.8254e-07 < tolerance=1e-06
# EM start iterations, llf=-3319.5
# EM converged at iteration 94, llf=-3262.2, convergence criterion=9.8254e-07 < tolerance=1e-06
# EM start iterations, llf=-3330.4
# EM converged at iteration 93, llf=-3273.1, convergence criterion=9.9957e-07 < tolerance=1e-06
# EM start iterations, llf=-3331.5
# EM converged at iteration 95, llf=-3274.2, convergence criterion=9.9827e-07 < tolerance=1e-06
# EM start iterations, llf=-3342.5
# EM converged at iteration 95, llf=-3285, convergence criterion=9.9565e-07 < tolerance=1e-06
# EM start iterations, llf=-3342.5
# EM converged at iteration 95, llf=-3285, convergence criterion=9.9565e-07 < tolerance=1e-06
# EM start iterations, llf=-3354.9
# EM converged at iteration 95, llf=-3297.4, convergence criterion=9.9488e-07 < tolerance=1e-06
# EM start iterations, llf=-3354.9
# EM converged at iteration 95, llf=-3297.4, convergence criterion=9.9488e-07 < tolerance=1e-06
# EM start iterations, llf=-3354.9
# EM converged at iteration 95, llf=-3297.4, convergence criterion=9.9488e-07 < tolerance=1e-06
# EM start iterations, llf=-3364.7
# EM converged at iteration 95, llf=-3307.1, convergence criterion=9.9528e-07 < tolerance=1e-06
# EM start iterations, llf=-3365.9
# EM converged at iteration 95, llf=-3308.3, convergence criterion=9.9907e-07 < tolerance=1e-06
# EM start iterations, llf=-3376
# EM converged at iteration 95, llf=-3318.3, convergence criterion=9.9848e-07 < tolerance=1e-06
# EM start iterations, llf=-3376
# EM converged at iteration 95, llf=-3318.3, convergence criterion=9.9848e-07 < tolerance=1e-06
# EM start iterations, llf=-3386.4
# EM converged at iteration 95, llf=-3328.7, convergence criterion=9.9752e-07 < tolerance=1e-06
# EM start iterations, llf=-3386.4
# EM converged at iteration 95, llf=-3328.7, convergence criterion=9.9752e-07 < tolerance=1e-06
# EM start iterations, llf=-3386.4
# EM converged at iteration 95, llf=-3328.7, convergence criterion=9.9752e-07 < tolerance=1e-06
# EM start iterations, llf=-3397.9
# EM converged at iteration 95, llf=-3340.1, convergence criterion=9.981e-07 < tolerance=1e-06
# EM start iterations, llf=-3399.1
# EM converged at iteration 96, llf=-3341.3, convergence criterion=9.9616e-07 < tolerance=1e-06
# EM start iterations, llf=-3409
# EM converged at iteration 96, llf=-3351.1, convergence criterion=9.907e-07 < tolerance=1e-06
# EM start iterations, llf=-3409
# EM converged at iteration 96, llf=-3351.1, convergence criterion=9.907e-07 < tolerance=1e-06
# EM start iterations, llf=-3419.9
# EM converged at iteration 96, llf=-3361.9, convergence criterion=9.8659e-07 < tolerance=1e-06
# EM start iterations, llf=-3419.9
# EM converged at iteration 96, llf=-3361.9, convergence criterion=9.8659e-07 < tolerance=1e-06
# EM start iterations, llf=-3419.9
# EM converged at iteration 96, llf=-3361.9, convergence criterion=9.8659e-07 < tolerance=1e-06
# EM start iterations, llf=-3433.6
# EM converged at iteration 95, llf=-3375.2, convergence criterion=9.9929e-07 < tolerance=1e-06
# EM start iterations, llf=-3434.9
# EM converged at iteration 96, llf=-3376.5, convergence criterion=9.8621e-07 < tolerance=1e-06
# EM start iterations, llf=-3446.4
# EM converged at iteration 96, llf=-3387.9, convergence criterion=9.8852e-07 < tolerance=1e-06
# EM start iterations, llf=-3446.4
# EM converged at iteration 96, llf=-3387.9, convergence criterion=9.8852e-07 < tolerance=1e-06
# EM start iterations, llf=-3457.6
# EM converged at iteration 96, llf=-3399, convergence criterion=9.8509e-07 < tolerance=1e-06
# EM start iterations, llf=-3457.6
# EM converged at iteration 96, llf=-3399, convergence criterion=9.8509e-07 < tolerance=1e-06
# EM start iterations, llf=-3457.6
# EM converged at iteration 96, llf=-3399, convergence criterion=9.8509e-07 < tolerance=1e-06
# EM start iterations, llf=-3468.5
# EM converged at iteration 96, llf=-3409.7, convergence criterion=9.8265e-07 < tolerance=1e-06
# EM start iterations, llf=-3470
# EM converged at iteration 93, llf=-3411.3, convergence criterion=9.9256e-07 < tolerance=1e-06
# EM start iterations, llf=-3481.6
# EM converged at iteration 93, llf=-3422.6, convergence criterion=9.9151e-07 < tolerance=1e-06
# EM start iterations, llf=-3481.6
# EM converged at iteration 93, llf=-3422.6, convergence criterion=9.9151e-07 < tolerance=1e-06
# EM start iterations, llf=-3492.8
# EM converged at iteration 93, llf=-3433.7, convergence criterion=9.8865e-07 < tolerance=1e-06
# EM start iterations, llf=-3492.8
# EM converged at iteration 93, llf=-3433.7, convergence criterion=9.8865e-07 < tolerance=1e-06
# EM start iterations, llf=-3492.8
# EM converged at iteration 93, llf=-3433.7, convergence criterion=9.8865e-07 < tolerance=1e-06
# EM start iterations, llf=-3503.3
# EM converged at iteration 93, llf=-3444.1, convergence criterion=9.8487e-07 < tolerance=1e-06
# EM start iterations, llf=-3504.6
# EM converged at iteration 93, llf=-3445.4, convergence criterion=9.8149e-07 < tolerance=1e-06
# EM start iterations, llf=-3515.4
# EM converged at iteration 93, llf=-3456.1, convergence criterion=9.8051e-07 < tolerance=1e-06
# EM start iterations, llf=-3515.4
# EM converged at iteration 93, llf=-3456.1, convergence criterion=9.8051e-07 < tolerance=1e-06
# EM start iterations, llf=-3526.6
# EM converged at iteration 93, llf=-3467, convergence criterion=9.8115e-07 < tolerance=1e-06
# Model with Global factors = 1 and order = 3 estimated in 1:39:02.354155.

# %% [markdown]
# Plot MSE values for the model with 1 Global Factor and Lag Order 3 evaluated over the 2008–2018 period.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]
q_var = 'GDP'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Define the directory containing MSE files
mse_dir = f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"

# Create a single‐plot figure for 1 global factor, order 3
fig, ax = plt.subplots(figsize=(6, 6), sharey=True)

num_factors = 1
order = 3
    
# Construct file name based on the model's parameters
factors_str = f"Global_{num_factors}_{order}"
mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
mse_file_path = os.path.join(mse_dir, mse_file_name)

# Load the MSE values from file
mse_df = pd.read_csv(mse_file_path)
# Construct y values based on the vintages
y_values = [mse_df[col].iloc[0] for col in vintage_col_names]

# Extend the y-values so the step function holds the last value
y_extended = y_values.copy()
y_extended.append(y_values[-1]) # Repeat the last value

# Plot the step function for the current model
ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
         label=f"Order: {order}")
        
# Customize the subplot
ax.set_xlabel("Month of Quarter")
# Set ticks only at 1, 2, and 3 to mark the beginning of each month
ax.set_xticks([1, 2, 3])
ax.set_xlim(0.9, 4.1)
ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
ax.set_ylabel("MSE")
ax.legend()

plt.suptitle(f"MSE for the Model with 1 Global Factor and Lag Order 3 ({q_var}, 2008-2018)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_2008-2018_{q_var}")
plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot MSE values for the model with 1 Global Factor and Lag Order 3 evaluated over the 2008–2010 and 2011-2018 periods.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Define two periods
periods = {
    "2008-2010": lambda df: df["date_float"] < 2011,
    "2011-2018": lambda df: df["date_float"] >= 2011
}

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Loop over each period and create a separate figure
for period_label, period_filter in periods.items():
    
    # Create a single‐plot figure for 1 global factor, order 3
    fig, ax = plt.subplots(figsize=(6, 6), sharey=True)
    
    num_factors = 1
    order = 3
         
    # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
    factors_str = f"Global_{num_factors}_{order}"
    forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
    forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

    # Load forecast data 
    forecasts = pd.read_csv(forecast_file_path, index_col=0)
    forecasts.index.name = "date"
    forecasts.reset_index(inplace=True)

    # Merge forecasts with actual growth 
    merged = pd.merge(forecasts, actual_growth, on="date", how="inner")
    merged["date_float"] = merged["date"].apply(quarter_to_float)
    merged.sort_values("date_float", inplace=True)

    # Filter merged data for the current period
    merged_period = merged[ period_filter(merged) ]

    # Calculate MSE for each vintage column over the filtered period
    mse_dict = {}
    for col in vintage_col_names:
        mse = ((merged_period[col] - merged_period["growth"]) ** 2).mean()
        mse_dict[col] = mse

    # Construct y values based on the vintages
    y_values = [mse_dict[col] for col in vintage_col_names]

    # Extend the y-values so the step function holds the last value
    y_extended = y_values.copy()
    y_extended.append(y_values[-1]) # Repeat the last value

    # Plot the step function for the current model (order)
    ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
            label=f"Order: {order}")
            
    # Customize the subplot
    ax.set_xlabel("Month of Quarter")
    # Set ticks only at 1, 2, and 3 to mark the beginning of each month
    ax.set_xticks([1, 2, 3])
    ax.set_xlim(0.9, 4.1)
    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    ax.set_ylabel("MSE")
    ax.legend()
   
    plt.suptitle(f"MSE for the Model with 1 Global Factor and Lag Order 3 ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot forecasts vs actual growth values for the model with 1 Global Factor, Lag Order 3 and different time periods (2008-2010, 2008-2018, and 2011-2018).

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Convert quarter strings like "2008-03" into a float (e.g. 2008.00 for Q1, 2008.25 for Q2, etc.)
def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics_BPW"
estimation_period = "2007"
num_topics = "200"
source = "all"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Assign 7 small offsets within each quarter, so each quarter has 7 forecast points
offsets = np.linspace(0, 0.23, 7)

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Build x,y arrays for the actual growth
x_act = actual_growth["date_float"].tolist()
y_act = actual_growth["growth"].tolist()

# Define period configurations: x-axis limits and tick positions for each period
period_configs = {
    "2008-2010": {"xlim": (2008, 2010.99), "xticks": list(range(2008, 2011))},
    "2008-2018": {"xlim": (2008, 2018.99), "xticks": list(range(2008, 2019))},
    "2011-2018": {"xlim": (2011, 2018.99), "xticks": list(range(2011, 2019))}
}

# Loop over each period configuration to create and save separate plots
for period_label, config in period_configs.items():
    
    # Extend the actual growth arrays so that the step function continues until the end of the x-axis
    if period_label in ["2008-2018", "2011-2018"]:
        x_act_extended = x_act.copy()
        x_act_extended.append(config["xlim"][1])
        y_act_extended = y_act.copy()
        y_act_extended.append(y_act[-1])
    else:
        x_act_extended = x_act
        y_act_extended = y_act

    # Create a single‐plot figure for 1 global factor, order 3
    fig, ax = plt.subplots(figsize=(6, 6), sharey=True)

    num_factors = 1
    order = 3
    
    # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
    factors_str = f"Global_{num_factors}_{order}"
    forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
    forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

    # Load forecast data 
    forecasts = pd.read_csv(forecast_file_path, index_col=0)
    forecasts.index.name = "date"
    forecasts.reset_index(inplace=True)

    # Merge forecasts with actual growth dates
    merged = pd.merge(forecasts, actual_growth[['date']], on="date", how="inner")
    merged["date_float"] = merged["date"].apply(quarter_to_float)
    merged.sort_values("date_float", inplace=True)

    # Build forecast x and y arrays 
    x_fore = []
    y_fore = []
    for idx, row in merged.iterrows():
        base_x = row["date_float"]
        # For each of the 7 vintage columns, define an x-position and take that forecast value
        for j, col in enumerate(vintage_col_names):
            x_fore.append(base_x + offsets[j])
            y_fore.append(row[col])

    # Plot the forecast step curve for the current order
    ax.step(x_fore, y_fore, where='post', linewidth=1.2, label=f"Order: {order}")

    # Plot actual growth as a step plot in each subplot
    ax.step(x_act_extended, y_act_extended, where='post', color='black', linewidth=1.2, label="Actual growth")

    # Customize the subplot
    ax.set_xlabel("Year")
    ax.set_xlim(config["xlim"][0], config["xlim"][1])
    ax.set_xticks(config["xticks"])

    # Set y-axis limits based on the data within the period range
    x_min, x_max = config["xlim"]
    def filter_points(x_arr, y_arr, x_min, x_max):
        return [y for x, y in zip(x_arr, y_arr) if x_min <= x <= x_max]

    # Filter y-values
    y_filtered = filter_points(x_fore, y_fore, x_min, x_max)
    y_act_filtered = filter_points(x_act_extended, y_act_extended, x_min, x_max)

    # Combine all filtered y-values
    combined_y = y_filtered + y_act_filtered
    ax.set_ylim(1.05 * min(combined_y), 1.2 * max(combined_y))

    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    ax.set_ylabel("Annualized q-o-q Growth (%)")
    ax.legend()
        
    plt.suptitle(f"Forecast vs Actual Growth for Different Models ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}_global_factors_forecast_vs_actual_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
