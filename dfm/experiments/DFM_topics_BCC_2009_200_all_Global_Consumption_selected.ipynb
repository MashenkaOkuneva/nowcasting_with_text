# %% [markdown]
# # Out-of-sample forecasting experiments
#
# I conduct out-of-sample forecasting experiments to understand what kind of text data (topics, sentiment, or uncertainty) helps improve forecasts of three quarterly variables (GDP, Investment, and Consumption) more.
#
# In this notebook, I evaluate the performance of dynamic factor models (DFM) using hard data, survey information, and 10 pre-selected sign-adjusted topics (BCC) (out of 200 topics estimated on articles published before 2010 using all sources). I forecast Consumption growth and integrate text data into economic forecasting.
#
# ## Experiment Details
#
# - **Data Sources:** Hard data, surveys, 10 pre-selected sign-adjusted topics, BCC (<=2009, 200 topics, all sources).
# - **Forecast Target:** Consumption growth.
# - **Model:** Dynamic Factor Models (DFM).
# - **Parameters Explored:**
#   - **Number of Global Factors:** 1 to 3
#   - **Factor Order:** 1 to 3 (for each number of factors)

# %%
import os
import time
import datetime
import pandas as pd
import DFM_function

# Define inputs common to all models
q_var = 'Consumption'              # quarterly variable being forecasted
additional_factors = None          # or "all" or e.g. ['Labor market']
start = '1991-04'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
with_text = True

# Generate list of forecast_month strings for quarters from 2008Q1 to 2018Q4
# forecast_month is set to the month corresponding to quarter-end:
# Q1: 'YYYY-03', Q2: 'YYYY-06', Q3: 'YYYY-09', Q4: 'YYYY-12'
forecast_months = []
for year in range(2008, 2019):
    forecast_months.extend([f"{year}-03", f"{year}-06", f"{year}-09", f"{year}-12"])
    
# Define the vintage column names 
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Create directories to save forecasts and MSE results
os.makedirs(f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
os.makedirs(f"../MSE/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)

# Load the actual growth data
actual_growth_file = f"../{q_var}_growth_actual.csv"
actual_growth = pd.read_csv(actual_growth_file)

# Record overall start time
overall_start = time.time()

# Loop over the number of factors and factor order values from 1 to 3
for num_factors in range(1, 4):  # Varying number of Global factors: 1, 2, 3
    for order in range(1, 4):    # Varying factor order: 1, 2, 3
        
        # Define model-specific parameters
        factor_multiplicities = {'Global': num_factors}
        factor_orders = {'Global': order}

        # Prepare lists to store each quarter's forecasts and row labels
        forecasts_all_quarters = []
        row_labels = []
        
        # Start timing for this model
        start_time = time.time()

        # Loop over each forecast month, get the forecasts, and store the results
        for fm in forecast_months:
            # Use the forecast_month string as the row label
            row_labels.append(fm)

            # Run the forecast function for this quarter
            forecasts_dict = DFM_function.get_forecasts(
                forecast_month = fm,
                q_var = q_var,
                additional_factors = additional_factors,
                factor_multiplicities = factor_multiplicities,
                factor_orders = factor_orders,
                start = start,
                text_type = text_type,
                estimation_period = estimation_period,
                num_topics = num_topics,
                source = source,
                selected = selected,
                with_text = with_text
            )

            # Obtain the correct ordering of vintages
            vintages_order = DFM_function.vintage_dates(fm)
            # Extract the forecast value for each vintage in that order
            quarter_forecasts = [forecasts_dict[vint] for vint in vintages_order]
            forecasts_all_quarters.append(quarter_forecasts)

        # Create a DataFrame with rows labeled by the forecast_month strings and columns as vintage names
        results = pd.DataFrame(forecasts_all_quarters, index=row_labels, columns=vintage_col_names)
        
        # Stop timing for this model and print elapsed time
        elapsed = time.time() - start_time
        elapsed_time = datetime.timedelta(seconds=elapsed)
        print(f"Model with Global factors = {num_factors} and order = {order} estimated in {elapsed_time}.")

        # Construct the output file name
        factors_str = "_".join([
            f"{factor.replace(' ', '_')}_{factor_multiplicities[factor]}_{factor_orders[factor]}"
            for factor in factor_multiplicities])
        file_name = f"forecasts_{q_var}_{factors_str}.csv"

        # Save the CSV file in a subfolder 
        output_path = os.path.join(f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", file_name)
        results.to_csv(output_path, index=True)
        
        # ----- MSE Calculation -----
        # Load forecasts
        forecasts = pd.read_csv(output_path, index_col=0)
        # Make sure the index is a column named "date"
        forecasts.index.name = "date"
        forecasts.reset_index(inplace=True)

        # Merge dfs by date 
        merged = pd.merge(forecasts, actual_growth, on="date", how="inner")

        # Calculate the Mean Squared Error (MSE) for each vintage column
        mse_dict = {}
        for col in vintage_col_names:
            mse = ((merged[col] - merged["growth"]) ** 2).mean()
            mse_dict[col] = mse

        # Create a df with one row (the MSE values for each forecasting horizon)
        mse_df = pd.DataFrame(mse_dict, index=[0])

        # Save MSE results to CSV
        mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
        mse_output_path = os.path.join(f"../MSE/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", mse_file_name)
        mse_df.to_csv(mse_output_path, index=False)
        
# Stop overall timing and print overall elapsed time
overall_elapsed = time.time() - overall_start
overall_elapsed_time = datetime.timedelta(seconds=overall_elapsed)
print(f"Overall time taken for running all models: {overall_elapsed_time}.")
# Out:
# EM start iterations, llf=-11838
# EM iteration 50, llf=-11670, convergence criterion=1.1907e-06
# EM converged at iteration 55, llf=-11670, convergence criterion=9.903e-07 < tolerance=1e-06
# EM start iterations, llf=-11850
# EM iteration 50, llf=-11681, convergence criterion=1.1898e-06
# EM converged at iteration 55, llf=-11681, convergence criterion=9.8944e-07 < tolerance=1e-06
# EM start iterations, llf=-11907
# EM iteration 50, llf=-11736, convergence criterion=1.1846e-06
# EM converged at iteration 55, llf=-11735, convergence criterion=9.8499e-07 < tolerance=1e-06
# EM start iterations, llf=-11914
# EM iteration 50, llf=-11743, convergence criterion=1.1838e-06
# EM converged at iteration 55, llf=-11743, convergence criterion=9.8439e-07 < tolerance=1e-06
# EM start iterations, llf=-11981
# EM iteration 50, llf=-11808, convergence criterion=1.2133e-06
# EM converged at iteration 56, llf=-11808, convergence criterion=9.7388e-07 < tolerance=1e-06
# EM start iterations, llf=-11990
# EM iteration 50, llf=-11818, convergence criterion=1.2124e-06
# EM converged at iteration 56, llf=-11817, convergence criterion=9.7316e-07 < tolerance=1e-06
# EM start iterations, llf=-12047
# EM iteration 50, llf=-11877, convergence criterion=1.2026e-06
# EM converged at iteration 56, llf=-11877, convergence criterion=9.659e-07 < tolerance=1e-06
# EM start iterations, llf=-12047
# EM iteration 50, llf=-11877, convergence criterion=1.2026e-06
# EM converged at iteration 56, llf=-11877, convergence criterion=9.659e-07 < tolerance=1e-06
# EM start iterations, llf=-12053
# EM iteration 50, llf=-11883, convergence criterion=1.2032e-06
# EM converged at iteration 56, llf=-11883, convergence criterion=9.6616e-07 < tolerance=1e-06
# EM start iterations, llf=-12108
# EM iteration 50, llf=-11936, convergence criterion=1.2022e-06
# EM converged at iteration 55, llf=-11936, convergence criterion=9.9923e-07 < tolerance=1e-06
# EM start iterations, llf=-12115
# EM iteration 50, llf=-11942, convergence criterion=1.203e-06
# EM converged at iteration 55, llf=-11942, convergence criterion=9.9961e-07 < tolerance=1e-06
# EM start iterations, llf=-12158
# EM iteration 50, llf=-11981, convergence criterion=1.2198e-06
# EM converged at iteration 56, llf=-11981, convergence criterion=9.7818e-07 < tolerance=1e-06
# EM start iterations, llf=-12168
# EM iteration 50, llf=-11991, convergence criterion=1.2184e-06
# EM converged at iteration 56, llf=-11991, convergence criterion=9.771e-07 < tolerance=1e-06
# EM start iterations, llf=-12216
# EM iteration 50, llf=-12036, convergence criterion=1.2219e-06
# EM converged at iteration 56, llf=-12035, convergence criterion=9.7872e-07 < tolerance=1e-06
# EM start iterations, llf=-12216
# EM iteration 50, llf=-12036, convergence criterion=1.2219e-06
# EM converged at iteration 56, llf=-12035, convergence criterion=9.7872e-07 < tolerance=1e-06
# EM start iterations, llf=-12228
# EM iteration 50, llf=-12043, convergence criterion=1.2264e-06
# EM converged at iteration 56, llf=-12043, convergence criterion=9.8143e-07 < tolerance=1e-06
# EM start iterations, llf=-12272
# EM iteration 50, llf=-12087, convergence criterion=1.223e-06
# EM converged at iteration 56, llf=-12087, convergence criterion=9.7848e-07 < tolerance=1e-06
# EM start iterations, llf=-12285
# EM iteration 50, llf=-12101, convergence criterion=1.2205e-06
# EM converged at iteration 56, llf=-12101, convergence criterion=9.7674e-07 < tolerance=1e-06
# EM start iterations, llf=-12329
# EM iteration 50, llf=-12139, convergence criterion=1.0707e-06
# EM converged at iteration 52, llf=-12139, convergence criterion=9.8946e-07 < tolerance=1e-06
# EM start iterations, llf=-12337
# EM iteration 50, llf=-12146, convergence criterion=1.0697e-06
# EM converged at iteration 52, llf=-12146, convergence criterion=9.8848e-07 < tolerance=1e-06
# EM start iterations, llf=-12404
# EM iteration 50, llf=-12219, convergence criterion=1.048e-06
# EM converged at iteration 52, llf=-12219, convergence criterion=9.6896e-07 < tolerance=1e-06
# EM start iterations, llf=-12404
# EM iteration 50, llf=-12219, convergence criterion=1.048e-06
# EM converged at iteration 52, llf=-12219, convergence criterion=9.6896e-07 < tolerance=1e-06
# EM start iterations, llf=-12404
# EM iteration 50, llf=-12213, convergence criterion=1.0631e-06
# EM converged at iteration 52, llf=-12213, convergence criterion=9.8279e-07 < tolerance=1e-06
# EM start iterations, llf=-12464
# EM iteration 50, llf=-12299, convergence criterion=1.0156e-06
# EM converged at iteration 51, llf=-12299, convergence criterion=9.7696e-07 < tolerance=1e-06
# EM start iterations, llf=-12472
# EM iteration 50, llf=-12318, convergence criterion=1.0157e-06
# EM converged at iteration 51, llf=-12318, convergence criterion=9.771e-07 < tolerance=1e-06
# EM start iterations, llf=-12446
# EM iteration 50, llf=-12299, convergence criterion=1.0891e-06
# EM converged at iteration 53, llf=-12299, convergence criterion=9.712e-07 < tolerance=1e-06
# EM start iterations, llf=-12447
# EM iteration 50, llf=-12302, convergence criterion=1.0789e-06
# EM converged at iteration 52, llf=-12302, convergence criterion=9.9894e-07 < tolerance=1e-06
# EM start iterations, llf=-12437
# EM iteration 50, llf=-12297, convergence criterion=1.0898e-06
# EM converged at iteration 53, llf=-12297, convergence criterion=9.7193e-07 < tolerance=1e-06
# EM start iterations, llf=-12437
# EM iteration 50, llf=-12297, convergence criterion=1.0898e-06
# EM converged at iteration 53, llf=-12297, convergence criterion=9.7193e-07 < tolerance=1e-06
# EM start iterations, llf=-12430
# EM iteration 50, llf=-12293, convergence criterion=1.1013e-06
# EM converged at iteration 53, llf=-12292, convergence criterion=9.8211e-07 < tolerance=1e-06
# EM start iterations, llf=-12476
# EM iteration 50, llf=-12343, convergence criterion=1.1114e-06
# EM converged at iteration 53, llf=-12343, convergence criterion=9.9101e-07 < tolerance=1e-06
# EM start iterations, llf=-12475
# EM iteration 50, llf=-12343, convergence criterion=1.1101e-06
# EM converged at iteration 53, llf=-12343, convergence criterion=9.8994e-07 < tolerance=1e-06
# EM start iterations, llf=-12483
# EM iteration 50, llf=-12351, convergence criterion=1.091e-06
# EM converged at iteration 53, llf=-12351, convergence criterion=9.7198e-07 < tolerance=1e-06
# EM start iterations, llf=-12488
# EM iteration 50, llf=-12349, convergence criterion=1.0924e-06
# EM converged at iteration 53, llf=-12348, convergence criterion=9.7315e-07 < tolerance=1e-06
# EM start iterations, llf=-12497
# EM iteration 50, llf=-12352, convergence criterion=1.0968e-06
# EM converged at iteration 53, llf=-12352, convergence criterion=9.7692e-07 < tolerance=1e-06
# EM start iterations, llf=-12497
# EM iteration 50, llf=-12352, convergence criterion=1.0968e-06
# EM converged at iteration 53, llf=-12352, convergence criterion=9.7692e-07 < tolerance=1e-06
# EM start iterations, llf=-12506
# EM iteration 50, llf=-12362, convergence criterion=1.0938e-06
# EM converged at iteration 53, llf=-12361, convergence criterion=9.7432e-07 < tolerance=1e-06
# EM start iterations, llf=-12556
# EM iteration 50, llf=-12415, convergence criterion=1.0933e-06
# EM converged at iteration 53, llf=-12415, convergence criterion=9.7374e-07 < tolerance=1e-06
# EM start iterations, llf=-12572
# EM iteration 50, llf=-12432, convergence criterion=1.0931e-06
# EM converged at iteration 53, llf=-12432, convergence criterion=9.7347e-07 < tolerance=1e-06
# EM start iterations, llf=-12619
# EM iteration 50, llf=-12479, convergence criterion=1.1116e-06
# EM converged at iteration 53, llf=-12479, convergence criterion=9.8987e-07 < tolerance=1e-06
# EM start iterations, llf=-12625
# EM iteration 50, llf=-12487, convergence criterion=1.1096e-06
# EM converged at iteration 53, llf=-12487, convergence criterion=9.8819e-07 < tolerance=1e-06
# EM start iterations, llf=-12675
# EM iteration 50, llf=-12537, convergence criterion=1.1048e-06
# EM converged at iteration 53, llf=-12537, convergence criterion=9.8383e-07 < tolerance=1e-06
# EM start iterations, llf=-12675
# EM iteration 50, llf=-12537, convergence criterion=1.1048e-06
# EM converged at iteration 53, llf=-12537, convergence criterion=9.8383e-07 < tolerance=1e-06
# EM start iterations, llf=-12687
# EM iteration 50, llf=-12549, convergence criterion=1.1083e-06
# EM converged at iteration 53, llf=-12549, convergence criterion=9.8686e-07 < tolerance=1e-06
# EM start iterations, llf=-12738
# EM iteration 50, llf=-12601, convergence criterion=1.1004e-06
# EM converged at iteration 53, llf=-12601, convergence criterion=9.7987e-07 < tolerance=1e-06
# EM start iterations, llf=-12750
# EM iteration 50, llf=-12612, convergence criterion=1.0991e-06
# EM converged at iteration 53, llf=-12611, convergence criterion=9.7871e-07 < tolerance=1e-06
# EM start iterations, llf=-12799
# EM converged at iteration 49, llf=-12664, convergence criterion=9.8855e-07 < tolerance=1e-06
# EM start iterations, llf=-12810
# EM converged at iteration 49, llf=-12675, convergence criterion=9.8693e-07 < tolerance=1e-06
# EM start iterations, llf=-12870
# EM converged at iteration 49, llf=-12734, convergence criterion=9.8266e-07 < tolerance=1e-06
# EM start iterations, llf=-12870
# EM converged at iteration 49, llf=-12734, convergence criterion=9.8266e-07 < tolerance=1e-06
# EM start iterations, llf=-12879
# EM converged at iteration 49, llf=-12741, convergence criterion=9.8447e-07 < tolerance=1e-06
# EM start iterations, llf=-12936
# EM converged at iteration 49, llf=-12798, convergence criterion=9.8279e-07 < tolerance=1e-06
# EM start iterations, llf=-12947
# EM converged at iteration 49, llf=-12809, convergence criterion=9.8242e-07 < tolerance=1e-06
# EM start iterations, llf=-13004
# EM converged at iteration 49, llf=-12865, convergence criterion=9.5969e-07 < tolerance=1e-06
# EM start iterations, llf=-13012
# EM converged at iteration 48, llf=-12875, convergence criterion=9.9871e-07 < tolerance=1e-06
# EM start iterations, llf=-13064
# EM converged at iteration 48, llf=-12927, convergence criterion=9.9417e-07 < tolerance=1e-06
# EM start iterations, llf=-13064
# EM converged at iteration 48, llf=-12927, convergence criterion=9.9417e-07 < tolerance=1e-06
# EM start iterations, llf=-13073
# EM converged at iteration 48, llf=-12935, convergence criterion=9.9395e-07 < tolerance=1e-06
# EM start iterations, llf=-13130
# EM converged at iteration 48, llf=-12992, convergence criterion=9.8722e-07 < tolerance=1e-06
# EM start iterations, llf=-13138
# EM converged at iteration 48, llf=-13001, convergence criterion=9.8433e-07 < tolerance=1e-06
# EM start iterations, llf=-13191
# EM converged at iteration 49, llf=-13055, convergence criterion=9.894e-07 < tolerance=1e-06
# EM start iterations, llf=-13240
# EM converged at iteration 49, llf=-13102, convergence criterion=9.7546e-07 < tolerance=1e-06
# EM start iterations, llf=-13293
# EM converged at iteration 49, llf=-13155, convergence criterion=9.7259e-07 < tolerance=1e-06
# EM start iterations, llf=-13293
# EM converged at iteration 49, llf=-13155, convergence criterion=9.7259e-07 < tolerance=1e-06
# EM start iterations, llf=-13302
# EM converged at iteration 49, llf=-13165, convergence criterion=9.7177e-07 < tolerance=1e-06
# EM start iterations, llf=-13348
# EM converged at iteration 49, llf=-13210, convergence criterion=9.6574e-07 < tolerance=1e-06
# EM start iterations, llf=-13356
# EM converged at iteration 49, llf=-13215, convergence criterion=9.6933e-07 < tolerance=1e-06
# EM start iterations, llf=-13407
# EM converged at iteration 47, llf=-13267, convergence criterion=9.8793e-07 < tolerance=1e-06
# EM start iterations, llf=-13417
# EM converged at iteration 47, llf=-13277, convergence criterion=9.8919e-07 < tolerance=1e-06
# EM start iterations, llf=-13468
# EM converged at iteration 47, llf=-13326, convergence criterion=9.8487e-07 < tolerance=1e-06
# EM start iterations, llf=-13468
# EM converged at iteration 47, llf=-13326, convergence criterion=9.8487e-07 < tolerance=1e-06
# EM start iterations, llf=-13477
# EM converged at iteration 47, llf=-13335, convergence criterion=9.8803e-07 < tolerance=1e-06
# EM start iterations, llf=-13524
# EM converged at iteration 47, llf=-13381, convergence criterion=9.8606e-07 < tolerance=1e-06
# EM start iterations, llf=-13530
# EM converged at iteration 47, llf=-13386, convergence criterion=9.8536e-07 < tolerance=1e-06
# EM start iterations, llf=-13590
# EM converged at iteration 49, llf=-13445, convergence criterion=9.6333e-07 < tolerance=1e-06
# EM start iterations, llf=-13603
# EM converged at iteration 49, llf=-13458, convergence criterion=9.6336e-07 < tolerance=1e-06
# EM start iterations, llf=-13653
# EM converged at iteration 49, llf=-13508, convergence criterion=9.5957e-07 < tolerance=1e-06
# EM start iterations, llf=-13653
# EM converged at iteration 49, llf=-13508, convergence criterion=9.5957e-07 < tolerance=1e-06
# EM start iterations, llf=-13659
# EM converged at iteration 48, llf=-13515, convergence criterion=9.9982e-07 < tolerance=1e-06
# EM start iterations, llf=-13702
# EM converged at iteration 48, llf=-13558, convergence criterion=9.9539e-07 < tolerance=1e-06
# EM start iterations, llf=-13712
# EM converged at iteration 48, llf=-13568, convergence criterion=9.9461e-07 < tolerance=1e-06
# EM start iterations, llf=-13758
# EM converged at iteration 47, llf=-13614, convergence criterion=9.9861e-07 < tolerance=1e-06
# EM start iterations, llf=-13768
# EM converged at iteration 47, llf=-13622, convergence criterion=9.9725e-07 < tolerance=1e-06
# EM start iterations, llf=-13806
# EM converged at iteration 47, llf=-13660, convergence criterion=9.9318e-07 < tolerance=1e-06
# EM start iterations, llf=-13806
# EM converged at iteration 47, llf=-13660, convergence criterion=9.9318e-07 < tolerance=1e-06
# EM start iterations, llf=-13820
# EM converged at iteration 47, llf=-13675, convergence criterion=9.9286e-07 < tolerance=1e-06
# EM start iterations, llf=-13848
# EM converged at iteration 47, llf=-13705, convergence criterion=9.8301e-07 < tolerance=1e-06
# EM start iterations, llf=-13857
# EM converged at iteration 47, llf=-13717, convergence criterion=9.7818e-07 < tolerance=1e-06
# EM start iterations, llf=-13883
# EM converged at iteration 47, llf=-13746, convergence criterion=9.9213e-07 < tolerance=1e-06
# EM start iterations, llf=-13887
# EM converged at iteration 47, llf=-13748, convergence criterion=9.9342e-07 < tolerance=1e-06
# EM start iterations, llf=-13935
# EM converged at iteration 47, llf=-13791, convergence criterion=9.9096e-07 < tolerance=1e-06
# EM start iterations, llf=-13935
# EM converged at iteration 47, llf=-13791, convergence criterion=9.9096e-07 < tolerance=1e-06
# EM start iterations, llf=-13944
# EM converged at iteration 47, llf=-13801, convergence criterion=9.8981e-07 < tolerance=1e-06
# EM start iterations, llf=-13998
# EM converged at iteration 47, llf=-13855, convergence criterion=9.8576e-07 < tolerance=1e-06
# EM start iterations, llf=-14006
# EM converged at iteration 47, llf=-13863, convergence criterion=9.852e-07 < tolerance=1e-06
# EM start iterations, llf=-14068
# EM converged at iteration 48, llf=-13925, convergence criterion=9.6303e-07 < tolerance=1e-06
# EM start iterations, llf=-14078
# EM converged at iteration 48, llf=-13934, convergence criterion=9.6305e-07 < tolerance=1e-06
# EM start iterations, llf=-14133
# EM converged at iteration 48, llf=-13989, convergence criterion=9.5915e-07 < tolerance=1e-06
# EM start iterations, llf=-14133
# EM converged at iteration 48, llf=-13989, convergence criterion=9.5915e-07 < tolerance=1e-06
# EM start iterations, llf=-14143
# EM converged at iteration 47, llf=-13999, convergence criterion=9.9973e-07 < tolerance=1e-06
# EM start iterations, llf=-14189
# EM converged at iteration 47, llf=-14045, convergence criterion=9.969e-07 < tolerance=1e-06
# EM start iterations, llf=-14201
# EM converged at iteration 47, llf=-14056, convergence criterion=9.9589e-07 < tolerance=1e-06
# EM start iterations, llf=-14249
# EM converged at iteration 47, llf=-14104, convergence criterion=9.9852e-07 < tolerance=1e-06
# EM start iterations, llf=-14261
# EM converged at iteration 47, llf=-14120, convergence criterion=9.9991e-07 < tolerance=1e-06
# EM start iterations, llf=-14300
# EM converged at iteration 47, llf=-14156, convergence criterion=9.9901e-07 < tolerance=1e-06
# EM start iterations, llf=-14300
# EM converged at iteration 47, llf=-14156, convergence criterion=9.9901e-07 < tolerance=1e-06
# EM start iterations, llf=-14310
# EM converged at iteration 47, llf=-14163, convergence criterion=9.9783e-07 < tolerance=1e-06
# EM start iterations, llf=-14381
# EM converged at iteration 47, llf=-14230, convergence criterion=9.9107e-07 < tolerance=1e-06
# EM start iterations, llf=-14387
# EM converged at iteration 47, llf=-14236, convergence criterion=9.8934e-07 < tolerance=1e-06
# EM start iterations, llf=-14437
# EM converged at iteration 47, llf=-14286, convergence criterion=9.7505e-07 < tolerance=1e-06
# EM start iterations, llf=-14448
# EM converged at iteration 47, llf=-14297, convergence criterion=9.7534e-07 < tolerance=1e-06
# EM start iterations, llf=-14499
# EM converged at iteration 47, llf=-14349, convergence criterion=9.7183e-07 < tolerance=1e-06
# EM start iterations, llf=-14499
# EM converged at iteration 47, llf=-14349, convergence criterion=9.7183e-07 < tolerance=1e-06
# EM start iterations, llf=-14508
# EM converged at iteration 47, llf=-14358, convergence criterion=9.7062e-07 < tolerance=1e-06
# EM start iterations, llf=-14563
# EM converged at iteration 47, llf=-14412, convergence criterion=9.6646e-07 < tolerance=1e-06
# EM start iterations, llf=-14572
# EM converged at iteration 47, llf=-14422, convergence criterion=9.6456e-07 < tolerance=1e-06
# EM start iterations, llf=-14622
# EM converged at iteration 46, llf=-14472, convergence criterion=9.766e-07 < tolerance=1e-06
# EM start iterations, llf=-14631
# EM converged at iteration 46, llf=-14480, convergence criterion=9.7839e-07 < tolerance=1e-06
# EM start iterations, llf=-14684
# EM converged at iteration 46, llf=-14532, convergence criterion=9.754e-07 < tolerance=1e-06
# EM start iterations, llf=-14684
# EM converged at iteration 46, llf=-14532, convergence criterion=9.754e-07 < tolerance=1e-06
# EM start iterations, llf=-14690
# EM converged at iteration 46, llf=-14538, convergence criterion=9.7482e-07 < tolerance=1e-06
# EM start iterations, llf=-14741
# EM converged at iteration 46, llf=-14589, convergence criterion=9.7086e-07 < tolerance=1e-06
# EM start iterations, llf=-14747
# EM converged at iteration 46, llf=-14595, convergence criterion=9.7119e-07 < tolerance=1e-06
# EM start iterations, llf=-14802
# EM converged at iteration 46, llf=-14650, convergence criterion=9.8279e-07 < tolerance=1e-06
# EM start iterations, llf=-14814
# EM converged at iteration 46, llf=-14663, convergence criterion=9.828e-07 < tolerance=1e-06
# EM start iterations, llf=-14863
# EM converged at iteration 46, llf=-14709, convergence criterion=9.8269e-07 < tolerance=1e-06
# EM start iterations, llf=-14863
# EM converged at iteration 46, llf=-14709, convergence criterion=9.8269e-07 < tolerance=1e-06
# EM start iterations, llf=-14869
# EM converged at iteration 46, llf=-14716, convergence criterion=9.8205e-07 < tolerance=1e-06
# EM start iterations, llf=-14921
# EM converged at iteration 46, llf=-14768, convergence criterion=9.809e-07 < tolerance=1e-06
# EM start iterations, llf=-14928
# EM converged at iteration 46, llf=-14775, convergence criterion=9.7785e-07 < tolerance=1e-06
# EM start iterations, llf=-14984
# EM converged at iteration 48, llf=-14831, convergence criterion=9.9428e-07 < tolerance=1e-06
# EM start iterations, llf=-14992
# EM converged at iteration 48, llf=-14839, convergence criterion=9.9427e-07 < tolerance=1e-06
# EM start iterations, llf=-15051
# EM converged at iteration 48, llf=-14898, convergence criterion=9.8894e-07 < tolerance=1e-06
# EM start iterations, llf=-15051
# EM converged at iteration 48, llf=-14898, convergence criterion=9.8894e-07 < tolerance=1e-06
# EM start iterations, llf=-15060
# EM converged at iteration 48, llf=-14907, convergence criterion=9.8808e-07 < tolerance=1e-06
# EM start iterations, llf=-15113
# EM converged at iteration 48, llf=-14960, convergence criterion=9.8532e-07 < tolerance=1e-06
# EM start iterations, llf=-15124
# EM converged at iteration 48, llf=-14971, convergence criterion=9.8381e-07 < tolerance=1e-06
# EM start iterations, llf=-15172
# EM converged at iteration 48, llf=-15019, convergence criterion=9.9173e-07 < tolerance=1e-06
# EM start iterations, llf=-15180
# EM converged at iteration 48, llf=-15027, convergence criterion=9.9092e-07 < tolerance=1e-06
# EM start iterations, llf=-15228
# EM converged at iteration 48, llf=-15074, convergence criterion=9.8798e-07 < tolerance=1e-06
# EM start iterations, llf=-15228
# EM converged at iteration 48, llf=-15074, convergence criterion=9.8798e-07 < tolerance=1e-06
# EM start iterations, llf=-15239
# EM converged at iteration 48, llf=-15086, convergence criterion=9.8739e-07 < tolerance=1e-06
# EM start iterations, llf=-15285
# EM converged at iteration 48, llf=-15131, convergence criterion=9.857e-07 < tolerance=1e-06
# EM start iterations, llf=-15294
# EM converged at iteration 48, llf=-15140, convergence criterion=9.8474e-07 < tolerance=1e-06
# EM start iterations, llf=-15353
# EM converged at iteration 48, llf=-15198, convergence criterion=9.8153e-07 < tolerance=1e-06
# EM start iterations, llf=-15364
# EM converged at iteration 48, llf=-15208, convergence criterion=9.8146e-07 < tolerance=1e-06
# EM start iterations, llf=-15420
# EM converged at iteration 48, llf=-15264, convergence criterion=9.7849e-07 < tolerance=1e-06
# EM start iterations, llf=-15420
# EM converged at iteration 48, llf=-15264, convergence criterion=9.7849e-07 < tolerance=1e-06
# EM start iterations, llf=-15431
# EM converged at iteration 48, llf=-15275, convergence criterion=9.7652e-07 < tolerance=1e-06
# EM start iterations, llf=-15492
# EM converged at iteration 48, llf=-15336, convergence criterion=9.7283e-07 < tolerance=1e-06
# EM start iterations, llf=-15502
# EM converged at iteration 48, llf=-15346, convergence criterion=9.7166e-07 < tolerance=1e-06
# EM start iterations, llf=-15560
# EM converged at iteration 47, llf=-15402, convergence criterion=9.8936e-07 < tolerance=1e-06
# EM start iterations, llf=-15566
# EM converged at iteration 47, llf=-15408, convergence criterion=9.8873e-07 < tolerance=1e-06
# EM start iterations, llf=-15627
# EM converged at iteration 47, llf=-15468, convergence criterion=9.8474e-07 < tolerance=1e-06
# EM start iterations, llf=-15627
# EM converged at iteration 47, llf=-15468, convergence criterion=9.8474e-07 < tolerance=1e-06
# EM start iterations, llf=-15636
# EM converged at iteration 47, llf=-15478, convergence criterion=9.8523e-07 < tolerance=1e-06
# EM start iterations, llf=-15689
# EM converged at iteration 47, llf=-15532, convergence criterion=9.808e-07 < tolerance=1e-06
# EM start iterations, llf=-15693
# EM converged at iteration 47, llf=-15535, convergence criterion=9.8193e-07 < tolerance=1e-06
# EM start iterations, llf=-15752
# EM converged at iteration 47, llf=-15594, convergence criterion=9.6865e-07 < tolerance=1e-06
# EM start iterations, llf=-15756
# EM converged at iteration 47, llf=-15598, convergence criterion=9.684e-07 < tolerance=1e-06
# EM start iterations, llf=-15799
# EM converged at iteration 47, llf=-15641, convergence criterion=9.6624e-07 < tolerance=1e-06
# EM start iterations, llf=-15799
# EM converged at iteration 47, llf=-15641, convergence criterion=9.6624e-07 < tolerance=1e-06
# EM start iterations, llf=-15276
# EM converged at iteration 47, llf=-15133, convergence criterion=9.7006e-07 < tolerance=1e-06
# EM start iterations, llf=-15469
# EM converged at iteration 47, llf=-15323, convergence criterion=9.611e-07 < tolerance=1e-06
# EM start iterations, llf=-15477
# EM converged at iteration 47, llf=-15331, convergence criterion=9.6071e-07 < tolerance=1e-06
# EM start iterations, llf=-15934
# EM converged at iteration 47, llf=-15776, convergence criterion=9.6588e-07 < tolerance=1e-06
# EM start iterations, llf=-15938
# EM converged at iteration 47, llf=-15780, convergence criterion=9.6572e-07 < tolerance=1e-06
# EM start iterations, llf=-15987
# EM converged at iteration 47, llf=-15829, convergence criterion=9.6287e-07 < tolerance=1e-06
# EM start iterations, llf=-15987
# EM converged at iteration 47, llf=-15829, convergence criterion=9.6287e-07 < tolerance=1e-06
# EM start iterations, llf=-15999
# EM converged at iteration 47, llf=-15841, convergence criterion=9.6271e-07 < tolerance=1e-06
# EM start iterations, llf=-16054
# EM converged at iteration 47, llf=-15895, convergence criterion=9.6009e-07 < tolerance=1e-06
# EM start iterations, llf=-16059
# EM converged at iteration 47, llf=-15900, convergence criterion=9.5976e-07 < tolerance=1e-06
# EM start iterations, llf=-16116
# EM converged at iteration 47, llf=-15957, convergence criterion=9.7162e-07 < tolerance=1e-06
# EM start iterations, llf=-16122
# EM converged at iteration 47, llf=-15963, convergence criterion=9.7187e-07 < tolerance=1e-06
# EM start iterations, llf=-16180
# EM converged at iteration 47, llf=-16021, convergence criterion=9.6847e-07 < tolerance=1e-06
# EM start iterations, llf=-16180
# EM converged at iteration 47, llf=-16021, convergence criterion=9.6847e-07 < tolerance=1e-06
# EM start iterations, llf=-16190
# EM converged at iteration 47, llf=-16031, convergence criterion=9.6782e-07 < tolerance=1e-06
# EM start iterations, llf=-16244
# EM converged at iteration 47, llf=-16085, convergence criterion=9.6412e-07 < tolerance=1e-06
# EM start iterations, llf=-16253
# EM converged at iteration 47, llf=-16094, convergence criterion=9.632e-07 < tolerance=1e-06
# EM start iterations, llf=-16304
# EM converged at iteration 47, llf=-16145, convergence criterion=9.6143e-07 < tolerance=1e-06
# EM start iterations, llf=-16313
# EM converged at iteration 47, llf=-16153, convergence criterion=9.6101e-07 < tolerance=1e-06
# EM start iterations, llf=-16368
# EM converged at iteration 46, llf=-16208, convergence criterion=9.9838e-07 < tolerance=1e-06
# EM start iterations, llf=-16368
# EM converged at iteration 46, llf=-16208, convergence criterion=9.9838e-07 < tolerance=1e-06
# EM start iterations, llf=-16378
# EM converged at iteration 46, llf=-16218, convergence criterion=9.9824e-07 < tolerance=1e-06
# EM start iterations, llf=-16430
# EM converged at iteration 46, llf=-16269, convergence criterion=9.9503e-07 < tolerance=1e-06
# EM start iterations, llf=-16437
# EM converged at iteration 46, llf=-16277, convergence criterion=9.9394e-07 < tolerance=1e-06
# EM start iterations, llf=-16491
# EM converged at iteration 46, llf=-16330, convergence criterion=9.9155e-07 < tolerance=1e-06
# EM start iterations, llf=-16500
# EM iteration 50, llf=-16337, convergence criterion=1.3542e-06
# EM converged at iteration 59, llf=-16337, convergence criterion=9.8824e-07 < tolerance=1e-06
# EM start iterations, llf=-16554
# EM iteration 50, llf=-16391, convergence criterion=1.3493e-06
# EM converged at iteration 59, llf=-16391, convergence criterion=9.8469e-07 < tolerance=1e-06
# EM start iterations, llf=-16554
# EM iteration 50, llf=-16391, convergence criterion=1.3493e-06
# EM converged at iteration 59, llf=-16391, convergence criterion=9.8469e-07 < tolerance=1e-06
# EM start iterations, llf=-16558
# EM iteration 50, llf=-16394, convergence criterion=1.3488e-06
# EM converged at iteration 59, llf=-16394, convergence criterion=9.8432e-07 < tolerance=1e-06
# EM start iterations, llf=-16609
# EM iteration 50, llf=-16445, convergence criterion=1.3441e-06
# EM converged at iteration 59, llf=-16445, convergence criterion=9.8092e-07 < tolerance=1e-06
# EM start iterations, llf=-16616
# EM iteration 50, llf=-16451, convergence criterion=1.3437e-06
# EM converged at iteration 59, llf=-16451, convergence criterion=9.8065e-07 < tolerance=1e-06
# EM start iterations, llf=-16672
# EM iteration 50, llf=-16506, convergence criterion=1.2952e-06
# EM converged at iteration 58, llf=-16506, convergence criterion=9.7978e-07 < tolerance=1e-06
# EM start iterations, llf=-16678
# EM iteration 50, llf=-16513, convergence criterion=1.2947e-06
# EM converged at iteration 58, llf=-16512, convergence criterion=9.7939e-07 < tolerance=1e-06
# EM start iterations, llf=-16725
# EM iteration 50, llf=-16559, convergence criterion=1.2906e-06
# EM converged at iteration 58, llf=-16559, convergence criterion=9.7634e-07 < tolerance=1e-06
# EM start iterations, llf=-16725
# EM iteration 50, llf=-16559, convergence criterion=1.2906e-06
# EM converged at iteration 58, llf=-16559, convergence criterion=9.7634e-07 < tolerance=1e-06
# EM start iterations, llf=-16739
# EM iteration 50, llf=-16573, convergence criterion=1.2897e-06
# EM converged at iteration 58, llf=-16573, convergence criterion=9.756e-07 < tolerance=1e-06
# EM start iterations, llf=-16799
# EM iteration 50, llf=-16633, convergence criterion=1.2851e-06
# EM converged at iteration 58, llf=-16633, convergence criterion=9.7215e-07 < tolerance=1e-06
# EM start iterations, llf=-16804
# EM iteration 50, llf=-16638, convergence criterion=1.2851e-06
# EM converged at iteration 58, llf=-16637, convergence criterion=9.7214e-07 < tolerance=1e-06
# EM start iterations, llf=-16857
# EM iteration 50, llf=-16691, convergence criterion=1.2996e-06
# EM converged at iteration 58, llf=-16690, convergence criterion=9.8294e-07 < tolerance=1e-06
# EM start iterations, llf=-16865
# EM iteration 50, llf=-16699, convergence criterion=1.299e-06
# EM converged at iteration 58, llf=-16698, convergence criterion=9.825e-07 < tolerance=1e-06
# EM start iterations, llf=-16920
# EM iteration 50, llf=-16754, convergence criterion=1.2951e-06
# EM converged at iteration 58, llf=-16754, convergence criterion=9.7952e-07 < tolerance=1e-06
# EM start iterations, llf=-16920
# EM iteration 50, llf=-16754, convergence criterion=1.2951e-06
# EM converged at iteration 58, llf=-16754, convergence criterion=9.7952e-07 < tolerance=1e-06
# EM start iterations, llf=-16928
# EM iteration 50, llf=-16760, convergence criterion=1.2942e-06
# EM converged at iteration 58, llf=-16760, convergence criterion=9.7888e-07 < tolerance=1e-06
# EM start iterations, llf=-16981
# EM iteration 50, llf=-16813, convergence criterion=1.2896e-06
# EM converged at iteration 58, llf=-16812, convergence criterion=9.7543e-07 < tolerance=1e-06
# EM start iterations, llf=-16990
# EM iteration 50, llf=-16821, convergence criterion=1.2888e-06
# EM converged at iteration 58, llf=-16821, convergence criterion=9.7483e-07 < tolerance=1e-06
# EM start iterations, llf=-17041
# EM iteration 50, llf=-16873, convergence criterion=1.3085e-06
# EM converged at iteration 58, llf=-16873, convergence criterion=9.8931e-07 < tolerance=1e-06
# EM start iterations, llf=-17053
# EM iteration 50, llf=-16885, convergence criterion=1.3081e-06
# EM converged at iteration 58, llf=-16884, convergence criterion=9.8891e-07 < tolerance=1e-06
# EM start iterations, llf=-17107
# EM iteration 50, llf=-16939, convergence criterion=1.3037e-06
# EM converged at iteration 58, llf=-16939, convergence criterion=9.8561e-07 < tolerance=1e-06
# EM start iterations, llf=-17107
# EM iteration 50, llf=-16939, convergence criterion=1.3037e-06
# EM converged at iteration 58, llf=-16939, convergence criterion=9.8561e-07 < tolerance=1e-06
# EM start iterations, llf=-17115
# EM iteration 50, llf=-16947, convergence criterion=1.3035e-06
# EM converged at iteration 58, llf=-16947, convergence criterion=9.8543e-07 < tolerance=1e-06
# EM start iterations, llf=-17170
# EM iteration 50, llf=-17001, convergence criterion=1.3002e-06
# EM converged at iteration 58, llf=-17001, convergence criterion=9.8287e-07 < tolerance=1e-06
# EM start iterations, llf=-17176
# EM iteration 50, llf=-17007, convergence criterion=1.2997e-06
# EM converged at iteration 58, llf=-17007, convergence criterion=9.8248e-07 < tolerance=1e-06
# EM start iterations, llf=-17230
# EM iteration 50, llf=-17060, convergence criterion=1.3542e-06
# EM converged at iteration 59, llf=-17060, convergence criterion=9.9338e-07 < tolerance=1e-06
# EM start iterations, llf=-17239
# EM iteration 50, llf=-17069, convergence criterion=1.3537e-06
# EM converged at iteration 59, llf=-17069, convergence criterion=9.93e-07 < tolerance=1e-06
# EM start iterations, llf=-17291
# EM iteration 50, llf=-17121, convergence criterion=1.3491e-06
# EM converged at iteration 59, llf=-17121, convergence criterion=9.8964e-07 < tolerance=1e-06
# EM start iterations, llf=-17291
# EM iteration 50, llf=-17121, convergence criterion=1.3491e-06
# EM converged at iteration 59, llf=-17121, convergence criterion=9.8964e-07 < tolerance=1e-06
# EM start iterations, llf=-17297
# EM iteration 50, llf=-17128, convergence criterion=1.3481e-06
# EM converged at iteration 59, llf=-17127, convergence criterion=9.889e-07 < tolerance=1e-06
# EM start iterations, llf=-17353
# EM iteration 50, llf=-17182, convergence criterion=1.3433e-06
# EM converged at iteration 59, llf=-17182, convergence criterion=9.8538e-07 < tolerance=1e-06
# EM start iterations, llf=-17358
# EM iteration 50, llf=-17188, convergence criterion=1.3426e-06
# EM converged at iteration 59, llf=-17188, convergence criterion=9.8489e-07 < tolerance=1e-06
# EM start iterations, llf=-17413
# EM iteration 50, llf=-17242, convergence criterion=1.3517e-06
# EM converged at iteration 59, llf=-17242, convergence criterion=9.9158e-07 < tolerance=1e-06
# EM start iterations, llf=-17422
# EM iteration 50, llf=-17251, convergence criterion=1.3512e-06
# EM converged at iteration 59, llf=-17251, convergence criterion=9.9125e-07 < tolerance=1e-06
# EM start iterations, llf=-17470
# EM iteration 50, llf=-17299, convergence criterion=1.3472e-06
# EM converged at iteration 59, llf=-17299, convergence criterion=9.883e-07 < tolerance=1e-06
# EM start iterations, llf=-17470
# EM iteration 50, llf=-17299, convergence criterion=1.3472e-06
# EM converged at iteration 59, llf=-17299, convergence criterion=9.883e-07 < tolerance=1e-06
# EM start iterations, llf=-17489
# EM iteration 50, llf=-17318, convergence criterion=1.3457e-06
# EM converged at iteration 59, llf=-17318, convergence criterion=9.8718e-07 < tolerance=1e-06
# EM start iterations, llf=-17544
# EM iteration 50, llf=-17373, convergence criterion=1.341e-06
# EM converged at iteration 59, llf=-17372, convergence criterion=9.8379e-07 < tolerance=1e-06
# EM start iterations, llf=-17552
# EM iteration 50, llf=-17381, convergence criterion=1.34e-06
# EM converged at iteration 59, llf=-17381, convergence criterion=9.8303e-07 < tolerance=1e-06
# EM start iterations, llf=-17599
# EM iteration 50, llf=-17427, convergence criterion=1.3479e-06
# EM converged at iteration 59, llf=-17427, convergence criterion=9.8895e-07 < tolerance=1e-06
# EM start iterations, llf=-17610
# EM iteration 50, llf=-17439, convergence criterion=1.3467e-06
# EM converged at iteration 59, llf=-17439, convergence criterion=9.8811e-07 < tolerance=1e-06
# EM start iterations, llf=-17668
# EM iteration 50, llf=-17497, convergence criterion=1.3418e-06
# EM converged at iteration 59, llf=-17497, convergence criterion=9.845e-07 < tolerance=1e-06
# EM start iterations, llf=-17668
# EM iteration 50, llf=-17497, convergence criterion=1.3418e-06
# EM converged at iteration 59, llf=-17497, convergence criterion=9.845e-07 < tolerance=1e-06
# EM start iterations, llf=-17676
# EM iteration 50, llf=-17505, convergence criterion=1.3415e-06
# EM converged at iteration 59, llf=-17505, convergence criterion=9.8428e-07 < tolerance=1e-06
# EM start iterations, llf=-17727
# EM iteration 50, llf=-17556, convergence criterion=1.3377e-06
# EM converged at iteration 59, llf=-17556, convergence criterion=9.8147e-07 < tolerance=1e-06
# EM start iterations, llf=-17734
# EM iteration 50, llf=-17563, convergence criterion=1.337e-06
# EM converged at iteration 59, llf=-17563, convergence criterion=9.8094e-07 < tolerance=1e-06
# EM start iterations, llf=-17791
# EM iteration 50, llf=-17620, convergence criterion=1.3485e-06
# EM converged at iteration 59, llf=-17619, convergence criterion=9.8949e-07 < tolerance=1e-06
# EM start iterations, llf=-17799
# EM iteration 50, llf=-17627, convergence criterion=1.3482e-06
# EM converged at iteration 59, llf=-17627, convergence criterion=9.8925e-07 < tolerance=1e-06
# EM start iterations, llf=-17854
# EM iteration 50, llf=-17682, convergence criterion=1.3444e-06
# EM converged at iteration 59, llf=-17682, convergence criterion=9.864e-07 < tolerance=1e-06
# EM start iterations, llf=-17854
# EM iteration 50, llf=-17682, convergence criterion=1.3444e-06
# EM converged at iteration 59, llf=-17682, convergence criterion=9.864e-07 < tolerance=1e-06
# EM start iterations, llf=-17862
# EM iteration 50, llf=-17690, convergence criterion=1.3434e-06
# EM converged at iteration 59, llf=-17690, convergence criterion=9.857e-07 < tolerance=1e-06
# EM start iterations, llf=-17911
# EM iteration 50, llf=-17738, convergence criterion=1.3392e-06
# EM converged at iteration 59, llf=-17738, convergence criterion=9.8264e-07 < tolerance=1e-06
# EM start iterations, llf=-17916
# EM iteration 50, llf=-17743, convergence criterion=1.3395e-06
# EM converged at iteration 59, llf=-17743, convergence criterion=9.8283e-07 < tolerance=1e-06
# EM start iterations, llf=-17968
# EM iteration 50, llf=-17794, convergence criterion=1.3588e-06
# EM converged at iteration 59, llf=-17794, convergence criterion=9.9741e-07 < tolerance=1e-06
# EM start iterations, llf=-17975
# EM iteration 50, llf=-17801, convergence criterion=1.358e-06
# EM converged at iteration 59, llf=-17801, convergence criterion=9.9682e-07 < tolerance=1e-06
# EM start iterations, llf=-18031
# EM iteration 50, llf=-17856, convergence criterion=1.3545e-06
# EM converged at iteration 59, llf=-17856, convergence criterion=9.942e-07 < tolerance=1e-06
# EM start iterations, llf=-18031
# EM iteration 50, llf=-17856, convergence criterion=1.3545e-06
# EM converged at iteration 59, llf=-17856, convergence criterion=9.942e-07 < tolerance=1e-06
# EM start iterations, llf=-18037
# EM iteration 50, llf=-17863, convergence criterion=1.3547e-06
# EM converged at iteration 59, llf=-17862, convergence criterion=9.9426e-07 < tolerance=1e-06
# EM start iterations, llf=-18092
# EM iteration 50, llf=-17917, convergence criterion=1.3509e-06
# EM converged at iteration 59, llf=-17916, convergence criterion=9.9143e-07 < tolerance=1e-06
# EM start iterations, llf=-18102
# EM iteration 50, llf=-17928, convergence criterion=1.3499e-06
# EM converged at iteration 59, llf=-17927, convergence criterion=9.9074e-07 < tolerance=1e-06
# EM start iterations, llf=-18157
# EM iteration 50, llf=-17982, convergence criterion=1.3561e-06
# EM converged at iteration 59, llf=-17982, convergence criterion=9.952e-07 < tolerance=1e-06
# EM start iterations, llf=-18164
# EM iteration 50, llf=-17989, convergence criterion=1.3563e-06
# EM converged at iteration 59, llf=-17989, convergence criterion=9.9534e-07 < tolerance=1e-06
# EM start iterations, llf=-18211
# EM iteration 50, llf=-18036, convergence criterion=1.3522e-06
# EM converged at iteration 59, llf=-18036, convergence criterion=9.9231e-07 < tolerance=1e-06
# EM start iterations, llf=-18211
# EM iteration 50, llf=-18036, convergence criterion=1.3522e-06
# EM converged at iteration 59, llf=-18036, convergence criterion=9.9231e-07 < tolerance=1e-06
# EM start iterations, llf=-18224
# EM iteration 50, llf=-18048, convergence criterion=1.3514e-06
# EM converged at iteration 59, llf=-18048, convergence criterion=9.9172e-07 < tolerance=1e-06
# EM start iterations, llf=-18282
# EM iteration 50, llf=-18105, convergence criterion=1.3459e-06
# EM converged at iteration 59, llf=-18105, convergence criterion=9.8776e-07 < tolerance=1e-06
# EM start iterations, llf=-18291
# EM iteration 50, llf=-18115, convergence criterion=1.3443e-06
# EM converged at iteration 59, llf=-18114, convergence criterion=9.8666e-07 < tolerance=1e-06
# EM start iterations, llf=-18336
# EM iteration 50, llf=-18160, convergence criterion=1.3554e-06
# EM converged at iteration 59, llf=-18160, convergence criterion=9.9486e-07 < tolerance=1e-06
# EM start iterations, llf=-18346
# EM iteration 50, llf=-18170, convergence criterion=1.3555e-06
# EM converged at iteration 59, llf=-18170, convergence criterion=9.9488e-07 < tolerance=1e-06
# EM start iterations, llf=-18204
# EM iteration 50, llf=-18032, convergence criterion=1.3654e-06
# EM converged at iteration 60, llf=-18032, convergence criterion=9.7115e-07 < tolerance=1e-06
# EM start iterations, llf=-18204
# EM iteration 50, llf=-18032, convergence criterion=1.3654e-06
# EM converged at iteration 60, llf=-18032, convergence criterion=9.7115e-07 < tolerance=1e-06
# EM start iterations, llf=-18209
# EM iteration 50, llf=-18037, convergence criterion=1.3654e-06
# EM converged at iteration 60, llf=-18037, convergence criterion=9.7108e-07 < tolerance=1e-06
# EM start iterations, llf=-18261
# EM iteration 50, llf=-18088, convergence criterion=1.361e-06
# EM converged at iteration 59, llf=-18088, convergence criterion=9.9895e-07 < tolerance=1e-06
# EM start iterations, llf=-18272
# EM iteration 50, llf=-18101, convergence criterion=1.3596e-06
# EM converged at iteration 59, llf=-18100, convergence criterion=9.9796e-07 < tolerance=1e-06
# EM start iterations, llf=-18331
# EM iteration 50, llf=-18159, convergence criterion=1.3668e-06
# EM converged at iteration 60, llf=-18159, convergence criterion=9.7219e-07 < tolerance=1e-06
# EM start iterations, llf=-18336
# EM iteration 50, llf=-18164, convergence criterion=1.3667e-06
# EM converged at iteration 60, llf=-18163, convergence criterion=9.721e-07 < tolerance=1e-06
# EM start iterations, llf=-18395
# EM iteration 50, llf=-18222, convergence criterion=1.3609e-06
# EM converged at iteration 59, llf=-18222, convergence criterion=9.9901e-07 < tolerance=1e-06
# EM start iterations, llf=-18395
# EM iteration 50, llf=-18222, convergence criterion=1.3609e-06
# EM converged at iteration 59, llf=-18222, convergence criterion=9.9901e-07 < tolerance=1e-06
# EM start iterations, llf=-18400
# EM iteration 50, llf=-18228, convergence criterion=1.3606e-06
# EM converged at iteration 59, llf=-18227, convergence criterion=9.9881e-07 < tolerance=1e-06
# EM start iterations, llf=-18451
# EM iteration 50, llf=-18278, convergence criterion=1.3575e-06
# EM converged at iteration 59, llf=-18278, convergence criterion=9.9643e-07 < tolerance=1e-06
# EM start iterations, llf=-18458
# EM iteration 50, llf=-18285, convergence criterion=1.357e-06
# EM converged at iteration 59, llf=-18285, convergence criterion=9.9605e-07 < tolerance=1e-06
# EM start iterations, llf=-18515
# EM iteration 50, llf=-18341, convergence criterion=1.356e-06
# EM converged at iteration 59, llf=-18341, convergence criterion=9.9539e-07 < tolerance=1e-06
# EM start iterations, llf=-18522
# EM iteration 50, llf=-18348, convergence criterion=1.3555e-06
# EM converged at iteration 59, llf=-18348, convergence criterion=9.9507e-07 < tolerance=1e-06
# EM start iterations, llf=-18578
# EM iteration 50, llf=-18403, convergence criterion=1.3515e-06
# EM converged at iteration 59, llf=-18403, convergence criterion=9.9207e-07 < tolerance=1e-06
# EM start iterations, llf=-18578
# EM iteration 50, llf=-18403, convergence criterion=1.3515e-06
# EM converged at iteration 59, llf=-18403, convergence criterion=9.9207e-07 < tolerance=1e-06
# EM start iterations, llf=-18584
# EM iteration 50, llf=-18409, convergence criterion=1.3509e-06
# EM converged at iteration 59, llf=-18409, convergence criterion=9.9167e-07 < tolerance=1e-06
# EM start iterations, llf=-18640
# EM iteration 50, llf=-18465, convergence criterion=1.3469e-06
# EM converged at iteration 59, llf=-18465, convergence criterion=9.8873e-07 < tolerance=1e-06
# EM start iterations, llf=-18646
# EM iteration 50, llf=-18472, convergence criterion=1.3458e-06
# EM converged at iteration 59, llf=-18472, convergence criterion=9.8794e-07 < tolerance=1e-06
# EM start iterations, llf=-18696
# EM iteration 50, llf=-18522, convergence criterion=1.3542e-06
# EM converged at iteration 59, llf=-18522, convergence criterion=9.9429e-07 < tolerance=1e-06
# EM start iterations, llf=-18708
# EM iteration 50, llf=-18534, convergence criterion=1.3526e-06
# EM converged at iteration 59, llf=-18534, convergence criterion=9.9313e-07 < tolerance=1e-06
# EM start iterations, llf=-18755
# EM iteration 50, llf=-18580, convergence criterion=1.3487e-06
# EM converged at iteration 59, llf=-18580, convergence criterion=9.9034e-07 < tolerance=1e-06
# EM start iterations, llf=-18755
# EM iteration 50, llf=-18580, convergence criterion=1.3487e-06
# EM converged at iteration 59, llf=-18580, convergence criterion=9.9034e-07 < tolerance=1e-06
# EM start iterations, llf=-18764
# EM iteration 50, llf=-18589, convergence criterion=1.3489e-06
# EM converged at iteration 59, llf=-18589, convergence criterion=9.9044e-07 < tolerance=1e-06
# EM start iterations, llf=-18811
# EM iteration 50, llf=-18636, convergence criterion=1.3456e-06
# EM converged at iteration 59, llf=-18635, convergence criterion=9.8802e-07 < tolerance=1e-06
# EM start iterations, llf=-18818
# EM iteration 50, llf=-18642, convergence criterion=1.3452e-06
# EM converged at iteration 59, llf=-18642, convergence criterion=9.8768e-07 < tolerance=1e-06
# EM start iterations, llf=-18871
# EM iteration 50, llf=-18696, convergence criterion=1.3606e-06
# EM converged at iteration 59, llf=-18695, convergence criterion=9.9895e-07 < tolerance=1e-06
# EM start iterations, llf=-18881
# EM iteration 50, llf=-18704, convergence criterion=1.3615e-06
# EM converged at iteration 59, llf=-18704, convergence criterion=9.9949e-07 < tolerance=1e-06
# EM start iterations, llf=-18932
# EM iteration 50, llf=-18754, convergence criterion=1.3584e-06
# EM converged at iteration 59, llf=-18754, convergence criterion=9.9715e-07 < tolerance=1e-06
# EM start iterations, llf=-18932
# EM iteration 50, llf=-18754, convergence criterion=1.3584e-06
# EM converged at iteration 59, llf=-18754, convergence criterion=9.9715e-07 < tolerance=1e-06
# EM start iterations, llf=-18940
# EM iteration 50, llf=-18762, convergence criterion=1.3576e-06
# EM converged at iteration 59, llf=-18762, convergence criterion=9.9656e-07 < tolerance=1e-06
# EM start iterations, llf=-18994
# EM iteration 50, llf=-18816, convergence criterion=1.3534e-06
# EM converged at iteration 59, llf=-18816, convergence criterion=9.9349e-07 < tolerance=1e-06
# EM start iterations, llf=-19003
# EM iteration 50, llf=-18825, convergence criterion=1.353e-06
# EM converged at iteration 59, llf=-18824, convergence criterion=9.9321e-07 < tolerance=1e-06
# EM start iterations, llf=-19055
# EM iteration 50, llf=-18877, convergence criterion=1.3349e-06
# EM converged at iteration 59, llf=-18877, convergence criterion=9.793e-07 < tolerance=1e-06
# EM start iterations, llf=-19064
# EM iteration 50, llf=-18886, convergence criterion=1.3343e-06
# EM converged at iteration 59, llf=-18886, convergence criterion=9.7881e-07 < tolerance=1e-06
# EM start iterations, llf=-19119
# EM iteration 50, llf=-18941, convergence criterion=1.3301e-06
# EM converged at iteration 59, llf=-18940, convergence criterion=9.7578e-07 < tolerance=1e-06
# EM start iterations, llf=-19119
# EM iteration 50, llf=-18941, convergence criterion=1.3301e-06
# EM converged at iteration 59, llf=-18940, convergence criterion=9.7578e-07 < tolerance=1e-06
# EM start iterations, llf=-19123
# EM iteration 50, llf=-18945, convergence criterion=1.3308e-06
# EM converged at iteration 59, llf=-18945, convergence criterion=9.762e-07 < tolerance=1e-06
# EM start iterations, llf=-19183
# EM iteration 50, llf=-19003, convergence criterion=1.3266e-06
# EM converged at iteration 59, llf=-19003, convergence criterion=9.7315e-07 < tolerance=1e-06
# EM start iterations, llf=-19191
# EM iteration 50, llf=-19011, convergence criterion=1.3257e-06
# EM converged at iteration 59, llf=-19010, convergence criterion=9.7252e-07 < tolerance=1e-06
# EM start iterations, llf=-19246
# EM iteration 50, llf=-19065, convergence criterion=1.3777e-06
# EM converged at iteration 60, llf=-19065, convergence criterion=9.7946e-07 < tolerance=1e-06
# EM start iterations, llf=-19253
# EM iteration 50, llf=-19072, convergence criterion=1.3766e-06
# EM converged at iteration 60, llf=-19072, convergence criterion=9.7871e-07 < tolerance=1e-06
# EM start iterations, llf=-19301
# EM iteration 50, llf=-19120, convergence criterion=1.3731e-06
# EM converged at iteration 60, llf=-19120, convergence criterion=9.762e-07 < tolerance=1e-06
# EM start iterations, llf=-19301
# EM iteration 50, llf=-19120, convergence criterion=1.3731e-06
# EM converged at iteration 60, llf=-19120, convergence criterion=9.762e-07 < tolerance=1e-06
# EM start iterations, llf=-19035
# EM iteration 50, llf=-18859, convergence criterion=1.3808e-06
# EM converged at iteration 60, llf=-18859, convergence criterion=9.8276e-07 < tolerance=1e-06
# EM start iterations, llf=-19091
# EM iteration 50, llf=-18915, convergence criterion=1.3768e-06
# ...
# EM start iterations, llf=-16118
# EM iteration 50, llf=-15973, convergence criterion=2.8592e-06
# EM converged at iteration 91, llf=-15972, convergence criterion=9.9315e-07 < tolerance=1e-06
# EM start iterations, llf=-16118
# EM iteration 50, llf=-15973, convergence criterion=2.8592e-06
# EM converged at iteration 91, llf=-15972, convergence criterion=9.9315e-07 < tolerance=1e-06
# EM start iterations, llf=-16136
# EM iteration 50, llf=-15991, convergence criterion=2.8609e-06
# EM converged at iteration 91, llf=-15990, convergence criterion=9.952e-07 < tolerance=1e-06
# EM start iterations, llf=-16186
# EM iteration 50, llf=-16042, convergence criterion=2.8413e-06
# EM converged at iteration 91, llf=-16041, convergence criterion=9.8476e-07 < tolerance=1e-06
# EM start iterations, llf=-16193
# EM iteration 50, llf=-16049, convergence criterion=2.8422e-06
# EM converged at iteration 91, llf=-16048, convergence criterion=9.8663e-07 < tolerance=1e-06
# EM start iterations, llf=-16244
# EM iteration 50, llf=-16100, convergence criterion=2.8217e-06
# EM converged at iteration 90, llf=-16099, convergence criterion=9.9484e-07 < tolerance=1e-06
# EM start iterations, llf=-16255
# EM iteration 50, llf=-16111, convergence criterion=2.8536e-06
# EM converged at iteration 91, llf=-16110, convergence criterion=9.8984e-07 < tolerance=1e-06
# EM start iterations, llf=-16304
# EM iteration 50, llf=-16161, convergence criterion=2.8457e-06
# EM converged at iteration 91, llf=-16160, convergence criterion=9.9531e-07 < tolerance=1e-06
# EM start iterations, llf=-16304
# EM iteration 50, llf=-16161, convergence criterion=2.8457e-06
# EM converged at iteration 91, llf=-16160, convergence criterion=9.9531e-07 < tolerance=1e-06
# EM start iterations, llf=-16315
# EM iteration 50, llf=-16171, convergence criterion=2.8419e-06
# EM converged at iteration 91, llf=-16170, convergence criterion=9.9312e-07 < tolerance=1e-06
# EM start iterations, llf=-16362
# EM iteration 50, llf=-16219, convergence criterion=2.8202e-06
# EM converged at iteration 91, llf=-16217, convergence criterion=9.8152e-07 < tolerance=1e-06
# EM start iterations, llf=-16369
# EM iteration 50, llf=-16225, convergence criterion=2.8205e-06
# EM converged at iteration 91, llf=-16224, convergence criterion=9.8529e-07 < tolerance=1e-06
# EM start iterations, llf=-16423
# EM iteration 50, llf=-16278, convergence criterion=2.857e-06
# EM converged at iteration 92, llf=-16277, convergence criterion=9.8116e-07 < tolerance=1e-06
# EM start iterations, llf=-16430
# EM iteration 50, llf=-16286, convergence criterion=2.8622e-06
# EM converged at iteration 92, llf=-16285, convergence criterion=9.8329e-07 < tolerance=1e-06
# EM start iterations, llf=-16481
# EM iteration 50, llf=-16336, convergence criterion=2.8581e-06
# EM converged at iteration 91, llf=-16335, convergence criterion=9.9843e-07 < tolerance=1e-06
# EM start iterations, llf=-16481
# EM iteration 50, llf=-16336, convergence criterion=2.8581e-06
# EM converged at iteration 91, llf=-16335, convergence criterion=9.9843e-07 < tolerance=1e-06
# EM start iterations, llf=-16489
# EM iteration 50, llf=-16344, convergence criterion=2.8549e-06
# EM converged at iteration 91, llf=-16343, convergence criterion=9.949e-07 < tolerance=1e-06
# EM start iterations, llf=-16534
# EM iteration 50, llf=-16390, convergence criterion=2.8027e-06
# EM converged at iteration 91, llf=-16389, convergence criterion=9.8128e-07 < tolerance=1e-06
# EM start iterations, llf=-16540
# EM iteration 50, llf=-16397, convergence criterion=2.7889e-06
# EM converged at iteration 90, llf=-16396, convergence criterion=9.9253e-07 < tolerance=1e-06
# EM start iterations, llf=-16590
# EM iteration 50, llf=-16445, convergence criterion=2.7431e-06
# EM converged at iteration 89, llf=-16444, convergence criterion=9.9502e-07 < tolerance=1e-06
# EM start iterations, llf=-16597
# EM iteration 50, llf=-16452, convergence criterion=2.7874e-06
# EM converged at iteration 90, llf=-16450, convergence criterion=9.9863e-07 < tolerance=1e-06
# EM start iterations, llf=-16648
# EM iteration 50, llf=-16502, convergence criterion=2.7584e-06
# EM converged at iteration 90, llf=-16501, convergence criterion=9.9221e-07 < tolerance=1e-06
# EM start iterations, llf=-16648
# EM iteration 50, llf=-16502, convergence criterion=2.7584e-06
# EM converged at iteration 90, llf=-16501, convergence criterion=9.9221e-07 < tolerance=1e-06
# EM start iterations, llf=-16656
# EM iteration 50, llf=-16511, convergence criterion=2.735e-06
# EM converged at iteration 89, llf=-16510, convergence criterion=9.96e-07 < tolerance=1e-06
# EM start iterations, llf=-16705
# EM iteration 50, llf=-16560, convergence criterion=2.7266e-06
# EM converged at iteration 89, llf=-16559, convergence criterion=9.9101e-07 < tolerance=1e-06
# EM start iterations, llf=-16715
# EM iteration 50, llf=-16570, convergence criterion=2.732e-06
# EM converged at iteration 89, llf=-16569, convergence criterion=9.9568e-07 < tolerance=1e-06
# EM start iterations, llf=-16768
# EM iteration 50, llf=-16623, convergence criterion=2.7433e-06
# EM converged at iteration 89, llf=-16622, convergence criterion=9.9599e-07 < tolerance=1e-06
# EM start iterations, llf=-16774
# EM iteration 50, llf=-16628, convergence criterion=2.7198e-06
# EM converged at iteration 89, llf=-16627, convergence criterion=9.8496e-07 < tolerance=1e-06
# EM start iterations, llf=-16819
# EM iteration 50, llf=-16673, convergence criterion=2.7115e-06
# EM converged at iteration 89, llf=-16672, convergence criterion=9.818e-07 < tolerance=1e-06
# EM start iterations, llf=-16819
# EM iteration 50, llf=-16673, convergence criterion=2.7115e-06
# EM converged at iteration 89, llf=-16672, convergence criterion=9.818e-07 < tolerance=1e-06
# EM start iterations, llf=-16833
# EM iteration 50, llf=-16686, convergence criterion=2.7234e-06
# EM converged at iteration 89, llf=-16685, convergence criterion=9.8465e-07 < tolerance=1e-06
# EM start iterations, llf=-16890
# EM iteration 50, llf=-16743, convergence criterion=2.7047e-06
# EM converged at iteration 88, llf=-16742, convergence criterion=9.9903e-07 < tolerance=1e-06
# EM start iterations, llf=-16894
# EM iteration 50, llf=-16747, convergence criterion=2.697e-06
# EM converged at iteration 89, llf=-16746, convergence criterion=9.8359e-07 < tolerance=1e-06
# EM start iterations, llf=-16941
# EM iteration 50, llf=-16795, convergence criterion=2.6786e-06
# EM converged at iteration 88, llf=-16794, convergence criterion=9.9361e-07 < tolerance=1e-06
# EM start iterations, llf=-16953
# EM iteration 50, llf=-16806, convergence criterion=2.6624e-06
# EM converged at iteration 88, llf=-16805, convergence criterion=9.8462e-07 < tolerance=1e-06
# EM start iterations, llf=-16788
# EM iteration 50, llf=-16648, convergence criterion=2.6705e-06
# EM converged at iteration 89, llf=-16647, convergence criterion=9.8858e-07 < tolerance=1e-06
# EM start iterations, llf=-16788
# EM iteration 50, llf=-16648, convergence criterion=2.6705e-06
# EM converged at iteration 89, llf=-16647, convergence criterion=9.8858e-07 < tolerance=1e-06
# EM start iterations, llf=-16796
# EM iteration 50, llf=-16655, convergence criterion=2.6805e-06
# EM converged at iteration 89, llf=-16654, convergence criterion=9.9173e-07 < tolerance=1e-06
# EM start iterations, llf=-16846
# EM iteration 50, llf=-16702, convergence criterion=2.7136e-06
# EM converged at iteration 90, llf=-16701, convergence criterion=9.8829e-07 < tolerance=1e-06
# EM start iterations, llf=-16855
# EM iteration 50, llf=-16712, convergence criterion=2.6926e-06
# EM converged at iteration 90, llf=-16711, convergence criterion=9.8865e-07 < tolerance=1e-06
# EM start iterations, llf=-16909
# EM iteration 50, llf=-16765, convergence criterion=2.6566e-06
# EM converged at iteration 89, llf=-16764, convergence criterion=9.9749e-07 < tolerance=1e-06
# EM start iterations, llf=-16916
# EM iteration 50, llf=-16772, convergence criterion=2.672e-06
# EM converged at iteration 90, llf=-16771, convergence criterion=9.8105e-07 < tolerance=1e-06
# EM start iterations, llf=-16973
# EM iteration 50, llf=-16828, convergence criterion=2.6616e-06
# EM converged at iteration 89, llf=-16827, convergence criterion=9.9114e-07 < tolerance=1e-06
# EM start iterations, llf=-16973
# EM iteration 50, llf=-16828, convergence criterion=2.6616e-06
# EM converged at iteration 89, llf=-16827, convergence criterion=9.9114e-07 < tolerance=1e-06
# EM start iterations, llf=-16978
# EM iteration 50, llf=-16834, convergence criterion=2.6787e-06
# EM converged at iteration 89, llf=-16833, convergence criterion=9.9596e-07 < tolerance=1e-06
# EM start iterations, llf=-17024
# EM iteration 50, llf=-16880, convergence criterion=2.6134e-06
# EM converged at iteration 88, llf=-16879, convergence criterion=9.922e-07 < tolerance=1e-06
# EM start iterations, llf=-17031
# EM iteration 50, llf=-16886, convergence criterion=2.5785e-06
# EM converged at iteration 88, llf=-16885, convergence criterion=9.8018e-07 < tolerance=1e-06
# EM start iterations, llf=-17083
# EM iteration 50, llf=-16939, convergence criterion=2.5453e-06
# EM converged at iteration 87, llf=-16938, convergence criterion=9.8593e-07 < tolerance=1e-06
# EM start iterations, llf=-17090
# EM iteration 50, llf=-16946, convergence criterion=2.5528e-06
# EM converged at iteration 87, llf=-16945, convergence criterion=9.9009e-07 < tolerance=1e-06
# EM start iterations, llf=-17142
# EM iteration 50, llf=-16997, convergence criterion=2.555e-06
# EM converged at iteration 87, llf=-16996, convergence criterion=9.9493e-07 < tolerance=1e-06
# EM start iterations, llf=-17142
# EM iteration 50, llf=-16997, convergence criterion=2.555e-06
# EM converged at iteration 87, llf=-16996, convergence criterion=9.9493e-07 < tolerance=1e-06
# EM start iterations, llf=-17148
# EM iteration 50, llf=-17003, convergence criterion=2.5363e-06
# EM converged at iteration 87, llf=-17002, convergence criterion=9.9076e-07 < tolerance=1e-06
# EM start iterations, llf=-17203
# EM iteration 50, llf=-17058, convergence criterion=2.5344e-06
# EM converged at iteration 87, llf=-17057, convergence criterion=9.879e-07 < tolerance=1e-06
# EM start iterations, llf=-17208
# EM iteration 50, llf=-17063, convergence criterion=2.5418e-06
# EM converged at iteration 87, llf=-17062, convergence criterion=9.9431e-07 < tolerance=1e-06
# EM start iterations, llf=-17254
# EM iteration 50, llf=-17110, convergence criterion=2.5616e-06
# EM converged at iteration 87, llf=-17109, convergence criterion=9.988e-07 < tolerance=1e-06
# EM start iterations, llf=-17269
# EM iteration 50, llf=-17124, convergence criterion=2.551e-06
# EM converged at iteration 87, llf=-17123, convergence criterion=9.9435e-07 < tolerance=1e-06
# EM start iterations, llf=-17313
# EM iteration 50, llf=-17167, convergence criterion=2.529e-06
# EM converged at iteration 87, llf=-17166, convergence criterion=9.8967e-07 < tolerance=1e-06
# EM start iterations, llf=-17313
# EM iteration 50, llf=-17167, convergence criterion=2.529e-06
# EM converged at iteration 87, llf=-17166, convergence criterion=9.8967e-07 < tolerance=1e-06
# EM start iterations, llf=-17320
# EM iteration 50, llf=-17175, convergence criterion=2.5273e-06
# EM converged at iteration 87, llf=-17174, convergence criterion=9.869e-07 < tolerance=1e-06
# EM start iterations, llf=-17368
# EM iteration 50, llf=-17223, convergence criterion=2.5541e-06
# EM converged at iteration 87, llf=-17222, convergence criterion=9.8554e-07 < tolerance=1e-06
# EM start iterations, llf=-17376
# EM iteration 50, llf=-17231, convergence criterion=2.5524e-06
# EM converged at iteration 87, llf=-17230, convergence criterion=9.8346e-07 < tolerance=1e-06
# EM start iterations, llf=-17422
# EM iteration 50, llf=-17276, convergence criterion=2.562e-06
# EM converged at iteration 87, llf=-17275, convergence criterion=9.8907e-07 < tolerance=1e-06
# EM start iterations, llf=-17429
# EM iteration 50, llf=-17283, convergence criterion=2.591e-06
# EM converged at iteration 88, llf=-17282, convergence criterion=9.8279e-07 < tolerance=1e-06
# EM start iterations, llf=-17475
# EM iteration 50, llf=-17329, convergence criterion=2.5147e-06
# EM converged at iteration 86, llf=-17329, convergence criterion=9.9687e-07 < tolerance=1e-06
# EM start iterations, llf=-17475
# EM iteration 50, llf=-17329, convergence criterion=2.5147e-06
# EM converged at iteration 86, llf=-17329, convergence criterion=9.9687e-07 < tolerance=1e-06
# EM start iterations, llf=-17483
# EM iteration 50, llf=-17337, convergence criterion=2.495e-06
# EM converged at iteration 86, llf=-17336, convergence criterion=9.8706e-07 < tolerance=1e-06
# EM start iterations, llf=-17537
# EM iteration 50, llf=-17390, convergence criterion=2.4756e-06
# EM converged at iteration 85, llf=-17389, convergence criterion=9.9856e-07 < tolerance=1e-06
# EM start iterations, llf=-17544
# EM iteration 50, llf=-17397, convergence criterion=2.4815e-06
# EM converged at iteration 86, llf=-17396, convergence criterion=9.8373e-07 < tolerance=1e-06
# EM start iterations, llf=-17593
# EM iteration 50, llf=-17446, convergence criterion=2.5031e-06
# EM converged at iteration 86, llf=-17445, convergence criterion=9.901e-07 < tolerance=1e-06
# EM start iterations, llf=-17601
# EM iteration 50, llf=-17455, convergence criterion=2.5095e-06
# EM converged at iteration 86, llf=-17454, convergence criterion=9.9326e-07 < tolerance=1e-06
# EM start iterations, llf=-17652
# EM iteration 50, llf=-17506, convergence criterion=2.5873e-06
# EM converged at iteration 88, llf=-17505, convergence criterion=9.8577e-07 < tolerance=1e-06
# EM start iterations, llf=-17652
# EM iteration 50, llf=-17506, convergence criterion=2.5873e-06
# EM converged at iteration 88, llf=-17505, convergence criterion=9.8577e-07 < tolerance=1e-06
# EM start iterations, llf=-17658
# EM iteration 50, llf=-17511, convergence criterion=2.55e-06
# EM converged at iteration 87, llf=-17510, convergence criterion=9.9228e-07 < tolerance=1e-06
# EM start iterations, llf=-17717
# EM iteration 50, llf=-17568, convergence criterion=2.5024e-06
# EM converged at iteration 86, llf=-17567, convergence criterion=9.9074e-07 < tolerance=1e-06
# EM start iterations, llf=-17724
# EM iteration 50, llf=-17575, convergence criterion=2.5119e-06
# EM converged at iteration 86, llf=-17574, convergence criterion=9.9629e-07 < tolerance=1e-06
# EM start iterations, llf=-17777
# EM iteration 50, llf=-17627, convergence criterion=2.5778e-06
# EM converged at iteration 87, llf=-17626, convergence criterion=9.9767e-07 < tolerance=1e-06
# EM start iterations, llf=-17784
# EM iteration 50, llf=-17634, convergence criterion=2.576e-06
# EM converged at iteration 87, llf=-17633, convergence criterion=9.9782e-07 < tolerance=1e-06
# EM start iterations, llf=-17828
# EM iteration 50, llf=-17678, convergence criterion=2.5788e-06
# EM converged at iteration 87, llf=-17677, convergence criterion=9.9607e-07 < tolerance=1e-06
# EM start iterations, llf=-17828
# EM iteration 50, llf=-17678, convergence criterion=2.5788e-06
# EM converged at iteration 87, llf=-17677, convergence criterion=9.9607e-07 < tolerance=1e-06
# EM start iterations, llf=-17573
# EM iteration 50, llf=-17429, convergence criterion=2.53e-06
# EM converged at iteration 87, llf=-17428, convergence criterion=9.8523e-07 < tolerance=1e-06
# EM start iterations, llf=-17625
# EM iteration 50, llf=-17481, convergence criterion=2.5451e-06
# EM converged at iteration 87, llf=-17480, convergence criterion=9.9475e-07 < tolerance=1e-06
# EM start iterations, llf=-17637
# EM iteration 50, llf=-17493, convergence criterion=2.5397e-06
# EM converged at iteration 87, llf=-17492, convergence criterion=9.9006e-07 < tolerance=1e-06
# EM start iterations, llf=-17689
# EM iteration 50, llf=-17545, convergence criterion=2.5711e-06
# EM converged at iteration 88, llf=-17544, convergence criterion=9.8404e-07 < tolerance=1e-06
# EM start iterations, llf=-17694
# EM iteration 50, llf=-17550, convergence criterion=2.5651e-06
# EM converged at iteration 88, llf=-17549, convergence criterion=9.8066e-07 < tolerance=1e-06
# EM start iterations, llf=-17745
# EM iteration 50, llf=-17600, convergence criterion=2.5543e-06
# EM converged at iteration 88, llf=-17599, convergence criterion=9.8098e-07 < tolerance=1e-06
# Model with Global factors = 3 and order = 3 estimated in 3:37:06.841909.
# Overall time taken for running all models: 20:34:06.916842.

# %% [markdown]
# Plot MSE values for all models evaluated over the 2008–2018 period.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]
q_var = 'Consumption'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Define the directory containing MSE files
mse_dir = f"../MSE/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"

# Create a figure with 1 row and 3 columns of subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Loop over each number of global factors (1, 2, and 3)
for i, num_factors in enumerate(range(1, 4)):
    ax = axs[i]
    # Within each subplot, loop over factor orders 1 to 3
    for order in range(1, 4):
        # Construct file name based on the model's parameters
        factors_str = f"Global_{num_factors}_{order}"
        mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
        mse_file_path = os.path.join(mse_dir, mse_file_name)
        
        # Load the MSE values from file
        mse_df = pd.read_csv(mse_file_path)
        # Construct y values based on the vintages
        y_values = [mse_df[col].iloc[0] for col in vintage_col_names]
        
        # Extend the y-values so the step function holds the last value
        y_extended = y_values.copy()
        y_extended.append(y_values[-1]) # Repeat the last value
        
        # Plot the step function for the current model
        ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
                 label=f"Order: {order}")
        
    # Customize the subplot
    ax.set_xlabel("Month of Quarter")
    # Set ticks only at 1, 2, and 3 to mark the beginning of each month
    ax.set_xticks([1, 2, 3])
    ax.set_xlim(0.9, 4.1)
    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    if i == 0:  # Only the leftmost subplot gets the y-axis label
        ax.set_ylabel("MSE")
    ax.legend()

plt.suptitle(f"MSE for Different Models ({q_var}, 2008-2018)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
os.makedirs(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
base_filename = os.path.join(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_2008-2018_{q_var}")
plt.savefig(f"{base_filename}.png", format="png")
plt.savefig(f"{base_filename}.eps", format="eps")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot MSE values for all models evaluated over the 2008–2010 and 2011-2018 periods.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'Consumption'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
forecasts_dir = f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Define two periods
periods = {
    "2008-2010": lambda df: df["date_float"] < 2011,
    "2011-2018": lambda df: df["date_float"] >= 2011
}

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Loop over each period and create a separate figure
for period_label, period_filter in periods.items():
    
    # Create a figure with 1 row and 3 columns of subplots
    fig, axs = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
    
    # Loop over each number of global factors (1, 2, and 3)
    for i, num_factors in enumerate(range(1, 4)):
        ax = axs[i]
        # Within each subplot, loop over factor orders 1 to 3
        for order in range(1, 4):
            # Construct forecast file name, e.g., "forecasts_Consumption_Global_1_1.csv"
            factors_str = f"Global_{num_factors}_{order}"
            forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
            forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)
    
            # Load forecast data 
            forecasts = pd.read_csv(forecast_file_path, index_col=0)
            forecasts.index.name = "date"
            forecasts.reset_index(inplace=True)
            
            # Merge forecasts with actual growth 
            merged = pd.merge(forecasts, actual_growth, on="date", how="inner")
            merged["date_float"] = merged["date"].apply(quarter_to_float)
            merged.sort_values("date_float", inplace=True)
            
            # Filter merged data for the current period
            merged_period = merged[ period_filter(merged) ]
            
            # Calculate MSE for each vintage column over the filtered period
            mse_dict = {}
            for col in vintage_col_names:
                mse = ((merged_period[col] - merged_period["growth"]) ** 2).mean()
                mse_dict[col] = mse
                
            # Construct y values based on the vintages
            y_values = [mse_dict[col] for col in vintage_col_names]
            
            # Extend the y-values so the step function holds the last value
            y_extended = y_values.copy()
            y_extended.append(y_values[-1]) # Repeat the last value
            
            # Plot the step function for the current model (order)
            ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
                    label=f"Order: {order}")
            
        # Customize the subplot
        ax.set_xlabel("Month of Quarter")
        # Set ticks only at 1, 2, and 3 to mark the beginning of each month
        ax.set_xticks([1, 2, 3])
        ax.set_xlim(0.9, 4.1)
        ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
        if i == 0:  # Only the leftmost subplot gets the y-axis label
            ax.set_ylabel("MSE")
        ax.legend()
   
    plt.suptitle(f"MSE for Different Models ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png")
    plt.savefig(f"{base_filename}.eps", format="eps")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot forecasts vs actual growth values for all models and different time periods (2008-2010, 2008-2018, and 2011-2018).

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Convert quarter strings like "2008-03" into a float (e.g. 2008.00 for Q1, 2008.25 for Q2, etc.)
def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'Consumption'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
forecasts_dir = f"../forecasts/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Assign 7 small offsets within each quarter, so each quarter has 7 forecast points
offsets = np.linspace(0, 0.23, 7)

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Build x,y arrays for the actual growth
x_act = actual_growth["date_float"].tolist()
y_act = actual_growth["growth"].tolist()

# Define period configurations: x-axis limits and tick positions for each period
period_configs = {
    "2008-2010": {"xlim": (2008, 2010.99), "xticks": list(range(2008, 2011))},
    "2008-2018": {"xlim": (2008, 2018.99), "xticks": list(range(2008, 2019))},
    "2011-2018": {"xlim": (2011, 2018.99), "xticks": list(range(2011, 2019))}
}

# Loop over each period configuration to create and save separate plots
for period_label, config in period_configs.items():
    
    # Extend the actual growth arrays so that the step function continues until the end of the x-axis
    if period_label in ["2008-2018", "2011-2018"]:
        x_act_extended = x_act.copy()
        x_act_extended.append(config["xlim"][1])
        y_act_extended = y_act.copy()
        y_act_extended.append(y_act[-1])
    else:
        x_act_extended = x_act
        y_act_extended = y_act

    # Create a figure with 1 row and 3 columns for the three global factor counts
    fig, axs = plt.subplots(1, 3, figsize=(24, 8), sharey=True)

    # Loop over each global factor count (1, 2, and 3)
    for i, num_factors in enumerate([1, 2, 3]):
        ax = axs[i]

        # For each global factor count, plot forecasts for orders 1, 2, and 3
        for order in range(1, 4):

            # Construct forecast file name, e.g., "forecasts_Consumption_Global_1_1.csv"
            factors_str = f"Global_{num_factors}_{order}"
            forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
            forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

            # Load forecast data 
            forecasts = pd.read_csv(forecast_file_path, index_col=0)
            forecasts.index.name = "date"
            forecasts.reset_index(inplace=True)

            # Merge forecasts with actual growth dates
            merged = pd.merge(forecasts, actual_growth[['date']], on="date", how="inner")
            merged["date_float"] = merged["date"].apply(quarter_to_float)
            merged.sort_values("date_float", inplace=True)

            # Build forecast x and y arrays 
            x_fore = []
            y_fore = []
            for idx, row in merged.iterrows():
                base_x = row["date_float"]
                # For each of the 7 vintage columns, define an x-position and take that forecast value
                for j, col in enumerate(vintage_col_names):
                    x_fore.append(base_x + offsets[j])
                    y_fore.append(row[col])

            # Plot the forecast step curve for the current order
            ax.step(x_fore, y_fore, where='post', linewidth=1.2, label=f"Order: {order}")

        # Plot actual growth as a step plot in each subplot
        ax.step(x_act_extended, y_act_extended, where='post', color='black', linewidth=1.2, label="Actual growth")

        # Customize the subplot
        ax.set_xlabel("Year")
        ax.set_xlim(config["xlim"][0], config["xlim"][1])
        ax.set_xticks(config["xticks"])
        
        # Set y-axis limits based on the data within the period range
        x_min, x_max = config["xlim"]
        def filter_points(x_arr, y_arr, x_min, x_max):
            return [y for x, y in zip(x_arr, y_arr) if x_min <= x <= x_max]

        # Filter y-values
        y_filtered = filter_points(x_fore, y_fore, x_min, x_max)
        y_act_filtered = filter_points(x_act_extended, y_act_extended, x_min, x_max)
        
        # Combine all filtered y-values
        combined_y = y_filtered + y_act_filtered
        ax.set_ylim(1.05 * min(combined_y), 1.2 * max(combined_y))
        
        ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
        if i == 0:
            ax.set_ylabel("Annualized q-o-q Growth (%)")
        ax.legend()
        
    plt.suptitle(f"Forecast vs Actual Growth for Different Models ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_forecast_vs_actual_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png")
    plt.savefig(f"{base_filename}.eps", format="eps")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
