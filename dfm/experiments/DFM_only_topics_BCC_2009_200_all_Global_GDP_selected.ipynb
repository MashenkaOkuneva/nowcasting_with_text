# %% [markdown]
# # Out-of-sample forecasting experiments
#
# I conduct out-of-sample forecasting experiments to understand what kind of text data (topics, sentiment, or uncertainty) helps improve forecasts of three quarterly variables (GDP, Investment, and Consumption) more.
#
# In this notebook, I evaluate the performance of dynamic factor models (DFM) using only 10 pre-selected sign-adjusted topics (BCC) (out of 200 topics estimated on articles published before 2010 using all sources). I use text data to forecast GDP growth.
#
# ## Experiment Details
#
# - **Data Sources:** 10 pre-selected sign-adjusted topics, BCC (<=2009, 200 topics, all sources).
# - **Forecast Target:** GDP growth.
# - **Model:** Dynamic Factor Models (DFM).
# - **Parameters Explored:**
#   - **Number of Global Factors:** 1
#   - **Factor Order:** 3

# %%
import os
import time
import datetime
import pandas as pd
import DFM_function

# Define inputs common to all models
q_var = 'GDP'                      # quarterly variable being forecasted
additional_factors = None          # or "all" or e.g. ['Labor market']
start = '1991-04'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
with_text = True
only_text = True

# Generate list of forecast_month strings for quarters from 2008Q1 to 2018Q4
# forecast_month is set to the month corresponding to quarter-end:
# Q1: 'YYYY-03', Q2: 'YYYY-06', Q3: 'YYYY-09', Q4: 'YYYY-12'
forecast_months = []
for year in range(2008, 2019):
    forecast_months.extend([f"{year}-03", f"{year}-06", f"{year}-09", f"{year}-12"])
    
# Define the vintage column names 
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Create directories to save forecasts and MSE results
os.makedirs(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
os.makedirs(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)

# Load the actual growth data
actual_growth_file = f"../{q_var}_growth_actual.csv"
actual_growth = pd.read_csv(actual_growth_file)

num_factors = 1
order = 3
        
# Define model-specific parameters
factor_multiplicities = {'Global': num_factors}
factor_orders = {'Global': order}

# Prepare lists to store each quarter's forecasts and row labels
forecasts_all_quarters = []
row_labels = []

# Start timing for this model
start_time = time.time()

# Loop over each forecast month, get the forecasts, and store the results
for fm in forecast_months:
    # Use the forecast_month string as the row label
    row_labels.append(fm)

    # Run the forecast function for this quarter
    forecasts_dict = DFM_function.get_forecasts(
        forecast_month = fm,
        q_var = q_var,
        additional_factors = additional_factors,
        factor_multiplicities = factor_multiplicities,
        factor_orders = factor_orders,
        start = start,
        text_type = text_type,
        estimation_period = estimation_period,
        num_topics = num_topics,
        source = source,
        selected = selected,
        with_text = with_text,
        only_text = only_text
    )

    # Obtain the correct ordering of vintages
    vintages_order = DFM_function.vintage_dates(fm)
    # Extract the forecast value for each vintage in that order
    quarter_forecasts = [forecasts_dict[vint] for vint in vintages_order]
    forecasts_all_quarters.append(quarter_forecasts)

# Create a DataFrame with rows labeled by the forecast_month strings and columns as vintage names
results = pd.DataFrame(forecasts_all_quarters, index=row_labels, columns=vintage_col_names)

# Stop timing for this model and print elapsed time
elapsed = time.time() - start_time
elapsed_time = datetime.timedelta(seconds=elapsed)
print(f"Model with Global factors = {num_factors} and order = {order} estimated in {elapsed_time}.")

# Construct the output file name
factors_str = "_".join([
    f"{factor.replace(' ', '_')}_{factor_multiplicities[factor]}_{factor_orders[factor]}"
    for factor in factor_multiplicities])
file_name = f"forecasts_{q_var}_{factors_str}.csv"

# Save the CSV file in a subfolder 
output_path = os.path.join(f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", file_name)
results.to_csv(output_path, index=True)

# ----- MSE Calculation -----
# Load forecasts
forecasts = pd.read_csv(output_path, index_col=0)
# Make sure the index is a column named "date"
forecasts.index.name = "date"
forecasts.reset_index(inplace=True)

# Merge dfs by date 
merged = pd.merge(forecasts, actual_growth, on="date", how="inner")

# Calculate the Mean Squared Error (MSE) for each vintage column
mse_dict = {}
for col in vintage_col_names:
    mse = ((merged[col] - merged["growth"]) ** 2).mean()
    mse_dict[col] = mse

# Create a df with one row (the MSE values for each forecasting horizon)
mse_df = pd.DataFrame(mse_dict, index=[0])

# Save MSE results to CSV
mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
mse_output_path = os.path.join(f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", mse_file_name)
mse_df.to_csv(mse_output_path, index=False)
# Out:
# EM start iterations, llf=-2585
# EM iteration 100, llf=-2536.9, convergence criterion=2.0657e-06
# EM converged at iteration 140, llf=-2536.8, convergence criterion=9.8683e-07 < tolerance=1e-06
# EM start iterations, llf=-2585
# EM iteration 100, llf=-2536.9, convergence criterion=2.0657e-06
# EM converged at iteration 140, llf=-2536.8, convergence criterion=9.8683e-07 < tolerance=1e-06
# EM start iterations, llf=-2598.8
# EM iteration 100, llf=-2550.7, convergence criterion=2.0636e-06
# EM converged at iteration 140, llf=-2550.6, convergence criterion=9.8667e-07 < tolerance=1e-06
# EM start iterations, llf=-2600.3
# EM iteration 100, llf=-2552.2, convergence criterion=2.1199e-06
# EM converged at iteration 141, llf=-2552.1, convergence criterion=9.9713e-07 < tolerance=1e-06
# EM start iterations, llf=-2622
# EM iteration 100, llf=-2574, convergence criterion=2.0976e-06
# EM converged at iteration 141, llf=-2573.8, convergence criterion=9.8715e-07 < tolerance=1e-06
# EM start iterations, llf=-2622
# EM iteration 100, llf=-2574, convergence criterion=2.0976e-06
# EM converged at iteration 141, llf=-2573.8, convergence criterion=9.8715e-07 < tolerance=1e-06
# EM start iterations, llf=-2635.4
# EM iteration 100, llf=-2587.1, convergence criterion=2.0532e-06
# EM converged at iteration 139, llf=-2587, convergence criterion=9.9392e-07 < tolerance=1e-06
# EM start iterations, llf=-2635.4
# EM iteration 100, llf=-2587.1, convergence criterion=2.0532e-06
# EM converged at iteration 139, llf=-2587, convergence criterion=9.9392e-07 < tolerance=1e-06
# EM start iterations, llf=-2635.4
# EM iteration 100, llf=-2587.1, convergence criterion=2.0532e-06
# EM converged at iteration 139, llf=-2587, convergence criterion=9.9392e-07 < tolerance=1e-06
# EM start iterations, llf=-2649.6
# EM iteration 100, llf=-2601.1, convergence criterion=2.0385e-06
# EM converged at iteration 139, llf=-2600.9, convergence criterion=9.8698e-07 < tolerance=1e-06
# EM start iterations, llf=-2651.1
# EM iteration 100, llf=-2602.5, convergence criterion=1.7437e-06
# EM converged at iteration 129, llf=-2602.4, convergence criterion=9.9457e-07 < tolerance=1e-06
# EM start iterations, llf=-2661.7
# EM iteration 100, llf=-2611.2, convergence criterion=1.7544e-06
# EM converged at iteration 130, llf=-2611.1, convergence criterion=9.8655e-07 < tolerance=1e-06
# EM start iterations, llf=-2661.7
# EM iteration 100, llf=-2611.2, convergence criterion=1.7544e-06
# EM converged at iteration 130, llf=-2611.1, convergence criterion=9.8655e-07 < tolerance=1e-06
# EM start iterations, llf=-2674.4
# EM iteration 100, llf=-2623.7, convergence criterion=1.7338e-06
# EM converged at iteration 129, llf=-2623.6, convergence criterion=9.9141e-07 < tolerance=1e-06
# EM start iterations, llf=-2674.4
# EM iteration 100, llf=-2623.7, convergence criterion=1.7338e-06
# EM converged at iteration 129, llf=-2623.6, convergence criterion=9.9141e-07 < tolerance=1e-06
# EM start iterations, llf=-2674.4
# EM iteration 100, llf=-2623.7, convergence criterion=1.7338e-06
# EM converged at iteration 129, llf=-2623.6, convergence criterion=9.9141e-07 < tolerance=1e-06
# EM start iterations, llf=-2687.5
# EM iteration 100, llf=-2636.8, convergence criterion=1.7211e-06
# EM converged at iteration 129, llf=-2636.7, convergence criterion=9.8296e-07 < tolerance=1e-06
# EM start iterations, llf=-2689.1
# EM converged at iteration 91, llf=-2638.7, convergence criterion=9.7835e-07 < tolerance=1e-06
# EM start iterations, llf=-2703.4
# EM converged at iteration 90, llf=-2652.8, convergence criterion=9.988e-07 < tolerance=1e-06
# EM start iterations, llf=-2703.4
# EM converged at iteration 90, llf=-2652.8, convergence criterion=9.988e-07 < tolerance=1e-06
# EM start iterations, llf=-2718.5
# EM converged at iteration 90, llf=-2667.7, convergence criterion=9.8723e-07 < tolerance=1e-06
# EM start iterations, llf=-2718.5
# EM converged at iteration 90, llf=-2667.7, convergence criterion=9.8723e-07 < tolerance=1e-06
# EM start iterations, llf=-2718.5
# EM converged at iteration 90, llf=-2667.7, convergence criterion=9.8723e-07 < tolerance=1e-06
# EM start iterations, llf=-2707.1
# EM converged at iteration 89, llf=-2646.7, convergence criterion=9.9457e-07 < tolerance=1e-06
# EM start iterations, llf=-2708.7
# EM iteration 100, llf=-2648.4, convergence criterion=1.0518e-06
# EM converged at iteration 103, llf=-2648.4, convergence criterion=9.8621e-07 < tolerance=1e-06
# EM start iterations, llf=-2674.7
# EM iteration 100, llf=-2615.5, convergence criterion=1.0983e-06
# EM converged at iteration 105, llf=-2615.5, convergence criterion=9.8994e-07 < tolerance=1e-06
# EM start iterations, llf=-2674.7
# EM iteration 100, llf=-2615.5, convergence criterion=1.0983e-06
# EM converged at iteration 105, llf=-2615.5, convergence criterion=9.8994e-07 < tolerance=1e-06
# EM start iterations, llf=-2664.9
# EM iteration 100, llf=-2609.4, convergence criterion=1.0606e-06
# EM converged at iteration 103, llf=-2609.3, convergence criterion=9.9574e-07 < tolerance=1e-06
# EM start iterations, llf=-2664.9
# EM iteration 100, llf=-2609.4, convergence criterion=1.0606e-06
# EM converged at iteration 103, llf=-2609.3, convergence criterion=9.9574e-07 < tolerance=1e-06
# EM start iterations, llf=-2664.9
# EM iteration 100, llf=-2609.4, convergence criterion=1.0606e-06
# EM converged at iteration 103, llf=-2609.3, convergence criterion=9.9574e-07 < tolerance=1e-06
# EM start iterations, llf=-2640.8
# EM iteration 100, llf=-2589.9, convergence criterion=1.0682e-06
# EM converged at iteration 104, llf=-2589.9, convergence criterion=9.8106e-07 < tolerance=1e-06
# EM start iterations, llf=-2637.3
# EM iteration 100, llf=-2586.7, convergence criterion=1.0312e-06
# EM converged at iteration 102, llf=-2586.7, convergence criterion=9.8784e-07 < tolerance=1e-06
# EM start iterations, llf=-2594
# EM iteration 100, llf=-2545.1, convergence criterion=1.0685e-06
# EM converged at iteration 104, llf=-2545.1, convergence criterion=9.8173e-07 < tolerance=1e-06
# EM start iterations, llf=-2594
# EM iteration 100, llf=-2545.1, convergence criterion=1.0685e-06
# EM converged at iteration 104, llf=-2545.1, convergence criterion=9.8173e-07 < tolerance=1e-06
# EM start iterations, llf=-2551.1
# EM iteration 100, llf=-2503.3, convergence criterion=1.1059e-06
# EM converged at iteration 105, llf=-2503.3, convergence criterion=9.9548e-07 < tolerance=1e-06
# EM start iterations, llf=-2551.1
# EM iteration 100, llf=-2503.3, convergence criterion=1.1059e-06
# EM converged at iteration 105, llf=-2503.3, convergence criterion=9.9548e-07 < tolerance=1e-06
# EM start iterations, llf=-2551.1
# EM iteration 100, llf=-2503.3, convergence criterion=1.1059e-06
# EM converged at iteration 105, llf=-2503.3, convergence criterion=9.9548e-07 < tolerance=1e-06
# EM start iterations, llf=-2548
# EM iteration 100, llf=-2500.1, convergence criterion=1.1324e-06
# EM converged at iteration 106, llf=-2500.1, convergence criterion=9.9914e-07 < tolerance=1e-06
# EM start iterations, llf=-2537.6
# EM iteration 100, llf=-2490.3, convergence criterion=1.4551e-06
# EM converged at iteration 120, llf=-2490.3, convergence criterion=9.9361e-07 < tolerance=1e-06
# EM start iterations, llf=-2545.7
# EM iteration 100, llf=-2500.1, convergence criterion=1.4109e-06
# EM converged at iteration 119, llf=-2500, convergence criterion=9.9187e-07 < tolerance=1e-06
# EM start iterations, llf=-2545.7
# EM iteration 100, llf=-2500.1, convergence criterion=1.4109e-06
# EM converged at iteration 119, llf=-2500, convergence criterion=9.9187e-07 < tolerance=1e-06
# EM start iterations, llf=-2551.8
# EM iteration 100, llf=-2506.7, convergence criterion=1.4105e-06
# EM converged at iteration 119, llf=-2506.6, convergence criterion=9.8982e-07 < tolerance=1e-06
# EM start iterations, llf=-2551.8
# EM iteration 100, llf=-2506.7, convergence criterion=1.4105e-06
# EM converged at iteration 119, llf=-2506.6, convergence criterion=9.8982e-07 < tolerance=1e-06
# EM start iterations, llf=-2551.8
# EM iteration 100, llf=-2506.7, convergence criterion=1.4105e-06
# EM converged at iteration 119, llf=-2506.6, convergence criterion=9.8982e-07 < tolerance=1e-06
# EM start iterations, llf=-2567.5
# EM iteration 100, llf=-2521.9, convergence criterion=1.3381e-06
# EM converged at iteration 115, llf=-2521.9, convergence criterion=9.9607e-07 < tolerance=1e-06
# EM start iterations, llf=-2573.7
# EM converged at iteration 84, llf=-2528.3, convergence criterion=9.9633e-07 < tolerance=1e-06
# EM start iterations, llf=-2583.9
# EM converged at iteration 85, llf=-2538.5, convergence criterion=9.7597e-07 < tolerance=1e-06
# EM start iterations, llf=-2583.9
# EM converged at iteration 85, llf=-2538.5, convergence criterion=9.7597e-07 < tolerance=1e-06
# EM start iterations, llf=-2601.6
# EM converged at iteration 86, llf=-2556.5, convergence criterion=9.9076e-07 < tolerance=1e-06
# EM start iterations, llf=-2601.6
# EM converged at iteration 86, llf=-2556.5, convergence criterion=9.9076e-07 < tolerance=1e-06
# EM start iterations, llf=-2601.6
# EM converged at iteration 86, llf=-2556.5, convergence criterion=9.9076e-07 < tolerance=1e-06
# EM start iterations, llf=-2618.2
# EM converged at iteration 86, llf=-2573.4, convergence criterion=9.9286e-07 < tolerance=1e-06
# EM start iterations, llf=-2620.8
# EM iteration 100, llf=-2576.3, convergence criterion=1.4681e-06
# EM converged at iteration 121, llf=-2576.3, convergence criterion=9.9952e-07 < tolerance=1e-06
# EM start iterations, llf=-2634.3
# EM iteration 100, llf=-2590, convergence criterion=1.4661e-06
# EM converged at iteration 121, llf=-2590, convergence criterion=9.9744e-07 < tolerance=1e-06
# EM start iterations, llf=-2634.3
# EM iteration 100, llf=-2590, convergence criterion=1.4661e-06
# EM converged at iteration 121, llf=-2590, convergence criterion=9.9744e-07 < tolerance=1e-06
# EM start iterations, llf=-2651
# EM iteration 100, llf=-2606.4, convergence criterion=1.4545e-06
# EM converged at iteration 121, llf=-2606.3, convergence criterion=9.8462e-07 < tolerance=1e-06
# EM start iterations, llf=-2651
# EM iteration 100, llf=-2606.4, convergence criterion=1.4545e-06
# EM converged at iteration 121, llf=-2606.3, convergence criterion=9.8462e-07 < tolerance=1e-06
# EM start iterations, llf=-2651
# EM iteration 100, llf=-2606.4, convergence criterion=1.4545e-06
# EM converged at iteration 121, llf=-2606.3, convergence criterion=9.8462e-07 < tolerance=1e-06
# EM start iterations, llf=-2672.7
# EM iteration 100, llf=-2628.1, convergence criterion=1.4379e-06
# EM converged at iteration 120, llf=-2628, convergence criterion=9.8999e-07 < tolerance=1e-06
# EM start iterations, llf=-2674
# EM iteration 100, llf=-2629.3, convergence criterion=1.4797e-06
# EM converged at iteration 122, llf=-2629.2, convergence criterion=9.8693e-07 < tolerance=1e-06
# EM start iterations, llf=-2690.1
# EM iteration 100, llf=-2645.5, convergence criterion=1.4644e-06
# EM converged at iteration 121, llf=-2645.5, convergence criterion=9.9253e-07 < tolerance=1e-06
# EM start iterations, llf=-2690.1
# EM iteration 100, llf=-2645.5, convergence criterion=1.4644e-06
# EM converged at iteration 121, llf=-2645.5, convergence criterion=9.9253e-07 < tolerance=1e-06
# EM start iterations, llf=-2705.9
# EM iteration 100, llf=-2661.4, convergence criterion=1.4637e-06
# EM converged at iteration 121, llf=-2661.3, convergence criterion=9.9124e-07 < tolerance=1e-06
# EM start iterations, llf=-2705.9
# EM iteration 100, llf=-2661.4, convergence criterion=1.4637e-06
# EM converged at iteration 121, llf=-2661.3, convergence criterion=9.9124e-07 < tolerance=1e-06
# EM start iterations, llf=-2705.9
# EM iteration 100, llf=-2661.4, convergence criterion=1.4637e-06
# EM converged at iteration 121, llf=-2661.3, convergence criterion=9.9124e-07 < tolerance=1e-06
# EM start iterations, llf=-2714.5
# EM iteration 100, llf=-2670, convergence criterion=1.4719e-06
# EM converged at iteration 121, llf=-2669.9, convergence criterion=9.9729e-07 < tolerance=1e-06
# EM start iterations, llf=-2715.8
# EM iteration 100, llf=-2671.3, convergence criterion=1.256e-06
# EM converged at iteration 112, llf=-2671.3, convergence criterion=9.9327e-07 < tolerance=1e-06
# EM start iterations, llf=-2729.7
# EM iteration 100, llf=-2685.1, convergence criterion=1.2483e-06
# EM converged at iteration 112, llf=-2685, convergence criterion=9.8713e-07 < tolerance=1e-06
# EM start iterations, llf=-2729.7
# EM iteration 100, llf=-2685.1, convergence criterion=1.2483e-06
# EM converged at iteration 112, llf=-2685, convergence criterion=9.8713e-07 < tolerance=1e-06
# EM start iterations, llf=-2742
# EM iteration 100, llf=-2697.2, convergence criterion=1.2379e-06
# EM converged at iteration 111, llf=-2697.2, convergence criterion=9.974e-07 < tolerance=1e-06
# EM start iterations, llf=-2742
# EM iteration 100, llf=-2697.2, convergence criterion=1.2379e-06
# EM converged at iteration 111, llf=-2697.2, convergence criterion=9.974e-07 < tolerance=1e-06
# EM start iterations, llf=-2742
# EM iteration 100, llf=-2697.2, convergence criterion=1.2379e-06
# EM converged at iteration 111, llf=-2697.2, convergence criterion=9.974e-07 < tolerance=1e-06
# EM start iterations, llf=-2754.4
# EM iteration 100, llf=-2709.4, convergence criterion=1.2172e-06
# EM converged at iteration 111, llf=-2709.4, convergence criterion=9.8179e-07 < tolerance=1e-06
# EM start iterations, llf=-2755.9
# EM iteration 100, llf=-2710.8, convergence criterion=1.1396e-06
# EM converged at iteration 107, llf=-2710.7, convergence criterion=9.9114e-07 < tolerance=1e-06
# EM start iterations, llf=-2761.1
# EM iteration 100, llf=-2715.8, convergence criterion=1.1763e-06
# EM converged at iteration 109, llf=-2715.8, convergence criterion=9.8481e-07 < tolerance=1e-06
# EM start iterations, llf=-2761.1
# EM iteration 100, llf=-2715.8, convergence criterion=1.1763e-06
# EM converged at iteration 109, llf=-2715.8, convergence criterion=9.8481e-07 < tolerance=1e-06
# EM start iterations, llf=-2773.2
# EM iteration 100, llf=-2728, convergence criterion=1.1953e-06
# EM converged at iteration 110, llf=-2728, convergence criterion=9.8256e-07 < tolerance=1e-06
# EM start iterations, llf=-2773.2
# EM iteration 100, llf=-2728, convergence criterion=1.1953e-06
# EM converged at iteration 110, llf=-2728, convergence criterion=9.8256e-07 < tolerance=1e-06
# EM start iterations, llf=-2773.2
# EM iteration 100, llf=-2728, convergence criterion=1.1953e-06
# EM converged at iteration 110, llf=-2728, convergence criterion=9.8256e-07 < tolerance=1e-06
# EM start iterations, llf=-2782.9
# EM iteration 100, llf=-2738, convergence criterion=1.2408e-06
# EM converged at iteration 112, llf=-2737.9, convergence criterion=9.8248e-07 < tolerance=1e-06
# EM start iterations, llf=-2784.2
# EM iteration 100, llf=-2739.1, convergence criterion=1.313e-06
# EM converged at iteration 114, llf=-2739, convergence criterion=9.9856e-07 < tolerance=1e-06
# EM start iterations, llf=-2792.4
# EM iteration 100, llf=-2747.5, convergence criterion=1.2759e-06
# EM converged at iteration 113, llf=-2747.4, convergence criterion=9.8913e-07 < tolerance=1e-06
# EM start iterations, llf=-2792.4
# EM iteration 100, llf=-2747.5, convergence criterion=1.2759e-06
# EM converged at iteration 113, llf=-2747.4, convergence criterion=9.8913e-07 < tolerance=1e-06
# EM start iterations, llf=-2799.3
# EM iteration 100, llf=-2754.4, convergence criterion=1.171e-06
# EM converged at iteration 108, llf=-2754.4, convergence criterion=9.9858e-07 < tolerance=1e-06
# EM start iterations, llf=-2799.3
# EM iteration 100, llf=-2754.4, convergence criterion=1.171e-06
# EM converged at iteration 108, llf=-2754.4, convergence criterion=9.9858e-07 < tolerance=1e-06
# EM start iterations, llf=-2799.3
# EM iteration 100, llf=-2754.4, convergence criterion=1.171e-06
# EM converged at iteration 108, llf=-2754.4, convergence criterion=9.9858e-07 < tolerance=1e-06
# EM start iterations, llf=-2794.9
# EM iteration 100, llf=-2749.8, convergence criterion=1.2308e-06
# EM converged at iteration 111, llf=-2749.8, convergence criterion=9.9124e-07 < tolerance=1e-06
# EM start iterations, llf=-2796.5
# EM iteration 100, llf=-2751.6, convergence criterion=1.6409e-06
# EM converged at iteration 129, llf=-2751.5, convergence criterion=9.8428e-07 < tolerance=1e-06
# EM start iterations, llf=-2796.3
# EM iteration 100, llf=-2752.2, convergence criterion=1.6465e-06
# EM converged at iteration 129, llf=-2752.1, convergence criterion=9.8932e-07 < tolerance=1e-06
# EM start iterations, llf=-2796.3
# EM iteration 100, llf=-2752.2, convergence criterion=1.6465e-06
# EM converged at iteration 129, llf=-2752.1, convergence criterion=9.8932e-07 < tolerance=1e-06
# EM start iterations, llf=-2810.4
# EM iteration 100, llf=-2765.6, convergence criterion=1.6424e-06
# EM converged at iteration 129, llf=-2765.5, convergence criterion=9.883e-07 < tolerance=1e-06
# EM start iterations, llf=-2810.4
# EM iteration 100, llf=-2765.6, convergence criterion=1.6424e-06
# EM converged at iteration 129, llf=-2765.5, convergence criterion=9.883e-07 < tolerance=1e-06
# EM start iterations, llf=-2810.4
# EM iteration 100, llf=-2765.6, convergence criterion=1.6424e-06
# EM converged at iteration 129, llf=-2765.5, convergence criterion=9.883e-07 < tolerance=1e-06
# EM start iterations, llf=-2825.7
# EM iteration 100, llf=-2779.7, convergence criterion=1.6096e-06
# EM converged at iteration 127, llf=-2779.6, convergence criterion=9.9916e-07 < tolerance=1e-06
# EM start iterations, llf=-2825.9
# EM iteration 100, llf=-2780, convergence criterion=1.2627e-06
# EM converged at iteration 113, llf=-2779.9, convergence criterion=9.8783e-07 < tolerance=1e-06
# EM start iterations, llf=-2839
# EM iteration 100, llf=-2792.6, convergence criterion=1.2757e-06
# EM converged at iteration 113, llf=-2792.6, convergence criterion=9.9896e-07 < tolerance=1e-06
# EM start iterations, llf=-2839
# EM iteration 100, llf=-2792.6, convergence criterion=1.2757e-06
# EM converged at iteration 113, llf=-2792.6, convergence criterion=9.9896e-07 < tolerance=1e-06
# EM start iterations, llf=-2852.6
# EM iteration 100, llf=-2806.2, convergence criterion=1.2613e-06
# EM converged at iteration 113, llf=-2806.2, convergence criterion=9.8769e-07 < tolerance=1e-06
# EM start iterations, llf=-2852.6
# EM iteration 100, llf=-2806.2, convergence criterion=1.2613e-06
# EM converged at iteration 113, llf=-2806.2, convergence criterion=9.8769e-07 < tolerance=1e-06
# EM start iterations, llf=-2852.6
# EM iteration 100, llf=-2806.2, convergence criterion=1.2613e-06
# EM converged at iteration 113, llf=-2806.2, convergence criterion=9.8769e-07 < tolerance=1e-06
# EM start iterations, llf=-2864.2
# EM iteration 100, llf=-2817.7, convergence criterion=1.2569e-06
# EM converged at iteration 113, llf=-2817.7, convergence criterion=9.8422e-07 < tolerance=1e-06
# EM start iterations, llf=-2864.2
# EM iteration 100, llf=-2817.7, convergence criterion=1.2569e-06
# EM converged at iteration 113, llf=-2817.7, convergence criterion=9.8422e-07 < tolerance=1e-06
# EM start iterations, llf=-2882
# EM iteration 100, llf=-2835.1, convergence criterion=1.2327e-06
# EM converged at iteration 111, llf=-2835, convergence criterion=9.9875e-07 < tolerance=1e-06
# EM start iterations, llf=-2882
# EM iteration 100, llf=-2835.1, convergence criterion=1.2327e-06
# EM converged at iteration 111, llf=-2835, convergence criterion=9.9875e-07 < tolerance=1e-06
# EM start iterations, llf=-2890.7
# EM iteration 100, llf=-2843.8, convergence criterion=1.2169e-06
# EM converged at iteration 111, llf=-2843.8, convergence criterion=9.8654e-07 < tolerance=1e-06
# EM start iterations, llf=-2890.7
# EM iteration 100, llf=-2843.8, convergence criterion=1.2169e-06
# EM converged at iteration 111, llf=-2843.8, convergence criterion=9.8654e-07 < tolerance=1e-06
# EM start iterations, llf=-2890.7
# EM iteration 100, llf=-2843.8, convergence criterion=1.2169e-06
# EM converged at iteration 111, llf=-2843.8, convergence criterion=9.8654e-07 < tolerance=1e-06
# EM start iterations, llf=-2897.2
# EM iteration 100, llf=-2850.6, convergence criterion=1.2091e-06
# EM converged at iteration 110, llf=-2850.5, convergence criterion=9.9722e-07 < tolerance=1e-06
# EM start iterations, llf=-2898.4
# EM iteration 100, llf=-2851.7, convergence criterion=1.1969e-06
# EM converged at iteration 110, llf=-2851.7, convergence criterion=9.8669e-07 < tolerance=1e-06
# EM start iterations, llf=-2906.2
# EM iteration 100, llf=-2859.8, convergence criterion=1.1964e-06
# EM converged at iteration 110, llf=-2859.8, convergence criterion=9.8552e-07 < tolerance=1e-06
# EM start iterations, llf=-2906.2
# EM iteration 100, llf=-2859.8, convergence criterion=1.1964e-06
# EM converged at iteration 110, llf=-2859.8, convergence criterion=9.8552e-07 < tolerance=1e-06
# EM start iterations, llf=-2916
# EM iteration 100, llf=-2869.8, convergence criterion=1.194e-06
# EM converged at iteration 110, llf=-2869.8, convergence criterion=9.8356e-07 < tolerance=1e-06
# EM start iterations, llf=-2916
# EM iteration 100, llf=-2869.8, convergence criterion=1.194e-06
# EM converged at iteration 110, llf=-2869.8, convergence criterion=9.8356e-07 < tolerance=1e-06
# EM start iterations, llf=-2916
# EM iteration 100, llf=-2869.8, convergence criterion=1.194e-06
# EM converged at iteration 110, llf=-2869.8, convergence criterion=9.8356e-07 < tolerance=1e-06
# EM start iterations, llf=-2927.8
# EM iteration 100, llf=-2881.4, convergence criterion=1.1867e-06
# EM converged at iteration 109, llf=-2881.3, convergence criterion=9.957e-07 < tolerance=1e-06
# EM start iterations, llf=-2929
# EM iteration 100, llf=-2882.5, convergence criterion=1.2312e-06
# EM converged at iteration 111, llf=-2882.5, convergence criterion=9.9635e-07 < tolerance=1e-06
# EM start iterations, llf=-2940.6
# EM iteration 100, llf=-2894.1, convergence criterion=1.2293e-06
# EM converged at iteration 111, llf=-2894.1, convergence criterion=9.9478e-07 < tolerance=1e-06
# EM start iterations, llf=-2940.6
# EM iteration 100, llf=-2894.1, convergence criterion=1.2293e-06
# EM converged at iteration 111, llf=-2894.1, convergence criterion=9.9478e-07 < tolerance=1e-06
# EM start iterations, llf=-2955.6
# EM iteration 100, llf=-2908.9, convergence criterion=1.2193e-06
# EM converged at iteration 111, llf=-2908.8, convergence criterion=9.8624e-07 < tolerance=1e-06
# EM start iterations, llf=-2955.6
# EM iteration 100, llf=-2908.9, convergence criterion=1.2193e-06
# EM converged at iteration 111, llf=-2908.8, convergence criterion=9.8624e-07 < tolerance=1e-06
# EM start iterations, llf=-2955.6
# EM iteration 100, llf=-2908.9, convergence criterion=1.2193e-06
# EM converged at iteration 111, llf=-2908.8, convergence criterion=9.8624e-07 < tolerance=1e-06
# EM start iterations, llf=-2969.3
# EM iteration 100, llf=-2922.2, convergence criterion=1.2096e-06
# EM converged at iteration 110, llf=-2922.2, convergence criterion=9.9623e-07 < tolerance=1e-06
# EM start iterations, llf=-2970.8
# EM iteration 100, llf=-2923.7, convergence criterion=1.2454e-06
# EM converged at iteration 112, llf=-2923.7, convergence criterion=9.8829e-07 < tolerance=1e-06
# EM start iterations, llf=-2984.3
# EM iteration 100, llf=-2937.1, convergence criterion=1.2421e-06
# EM converged at iteration 112, llf=-2937, convergence criterion=9.8592e-07 < tolerance=1e-06
# EM start iterations, llf=-2984.3
# EM iteration 100, llf=-2937.1, convergence criterion=1.2421e-06
# EM converged at iteration 112, llf=-2937, convergence criterion=9.8592e-07 < tolerance=1e-06
# EM start iterations, llf=-2998.1
# EM iteration 100, llf=-2950.5, convergence criterion=1.2416e-06
# EM converged at iteration 112, llf=-2950.4, convergence criterion=9.8635e-07 < tolerance=1e-06
# EM start iterations, llf=-2998.1
# EM iteration 100, llf=-2950.5, convergence criterion=1.2416e-06
# EM converged at iteration 112, llf=-2950.4, convergence criterion=9.8635e-07 < tolerance=1e-06
# EM start iterations, llf=-2998.1
# EM iteration 100, llf=-2950.5, convergence criterion=1.2416e-06
# EM converged at iteration 112, llf=-2950.4, convergence criterion=9.8635e-07 < tolerance=1e-06
# EM start iterations, llf=-3011.8
# EM iteration 100, llf=-2964.3, convergence criterion=1.2411e-06
# EM converged at iteration 112, llf=-2964.3, convergence criterion=9.8542e-07 < tolerance=1e-06
# EM start iterations, llf=-3013.1
# EM iteration 100, llf=-2965.6, convergence criterion=1.2005e-06
# EM converged at iteration 110, llf=-2965.5, convergence criterion=9.8692e-07 < tolerance=1e-06
# EM start iterations, llf=-3023
# EM iteration 100, llf=-2975, convergence criterion=1.2021e-06
# EM converged at iteration 110, llf=-2975, convergence criterion=9.8676e-07 < tolerance=1e-06
# EM start iterations, llf=-3023
# EM iteration 100, llf=-2975, convergence criterion=1.2021e-06
# EM converged at iteration 110, llf=-2975, convergence criterion=9.8676e-07 < tolerance=1e-06
# EM start iterations, llf=-3041.8
# EM iteration 100, llf=-2992.6, convergence criterion=1.2069e-06
# EM converged at iteration 110, llf=-2992.6, convergence criterion=9.9138e-07 < tolerance=1e-06
# EM start iterations, llf=-3041.8
# EM iteration 100, llf=-2992.6, convergence criterion=1.2069e-06
# EM converged at iteration 110, llf=-2992.6, convergence criterion=9.9138e-07 < tolerance=1e-06
# EM start iterations, llf=-3041.8
# EM iteration 100, llf=-2992.6, convergence criterion=1.2069e-06
# EM converged at iteration 110, llf=-2992.6, convergence criterion=9.9138e-07 < tolerance=1e-06
# EM start iterations, llf=-3054.2
# EM iteration 100, llf=-3005, convergence criterion=1.209e-06
# EM converged at iteration 110, llf=-3005, convergence criterion=9.9257e-07 < tolerance=1e-06
# EM start iterations, llf=-3055.6
# EM iteration 100, llf=-3006.3, convergence criterion=1.081e-06
# EM converged at iteration 104, llf=-3006.3, convergence criterion=9.9709e-07 < tolerance=1e-06
# EM start iterations, llf=-3067.5
# EM iteration 100, llf=-3018.1, convergence criterion=1.0607e-06
# EM converged at iteration 103, llf=-3018.1, convergence criterion=9.9801e-07 < tolerance=1e-06
# EM start iterations, llf=-3067.5
# EM iteration 100, llf=-3018.1, convergence criterion=1.0607e-06
# EM converged at iteration 103, llf=-3018.1, convergence criterion=9.9801e-07 < tolerance=1e-06
# EM start iterations, llf=-3080
# EM iteration 100, llf=-3030.5, convergence criterion=1.0548e-06
# EM converged at iteration 103, llf=-3030.5, convergence criterion=9.9244e-07 < tolerance=1e-06
# EM start iterations, llf=-3080
# EM iteration 100, llf=-3030.5, convergence criterion=1.0548e-06
# EM converged at iteration 103, llf=-3030.5, convergence criterion=9.9244e-07 < tolerance=1e-06
# EM start iterations, llf=-3080
# EM iteration 100, llf=-3030.5, convergence criterion=1.0548e-06
# EM converged at iteration 103, llf=-3030.5, convergence criterion=9.9244e-07 < tolerance=1e-06
# EM start iterations, llf=-3094.1
# EM iteration 100, llf=-3044.5, convergence criterion=1.0444e-06
# EM converged at iteration 103, llf=-3044.5, convergence criterion=9.8255e-07 < tolerance=1e-06
# EM start iterations, llf=-3095.4
# EM iteration 100, llf=-3045.8, convergence criterion=1.0832e-06
# EM converged at iteration 104, llf=-3045.8, convergence criterion=9.9813e-07 < tolerance=1e-06
# EM start iterations, llf=-3106.3
# EM iteration 100, llf=-3056.6, convergence criterion=1.0756e-06
# EM converged at iteration 104, llf=-3056.6, convergence criterion=9.9092e-07 < tolerance=1e-06
# EM start iterations, llf=-3106.3
# EM iteration 100, llf=-3056.6, convergence criterion=1.0756e-06
# EM converged at iteration 104, llf=-3056.6, convergence criterion=9.9092e-07 < tolerance=1e-06
# EM start iterations, llf=-3120.2
# EM iteration 100, llf=-3070, convergence criterion=1.0816e-06
# EM converged at iteration 104, llf=-3070, convergence criterion=9.9692e-07 < tolerance=1e-06
# EM start iterations, llf=-3120.2
# EM iteration 100, llf=-3070, convergence criterion=1.0816e-06
# EM converged at iteration 104, llf=-3070, convergence criterion=9.9692e-07 < tolerance=1e-06
# EM start iterations, llf=-3120.2
# EM iteration 100, llf=-3070, convergence criterion=1.0816e-06
# EM converged at iteration 104, llf=-3070, convergence criterion=9.9692e-07 < tolerance=1e-06
# EM start iterations, llf=-3141.3
# EM iteration 100, llf=-3091.4, convergence criterion=1.0709e-06
# EM converged at iteration 104, llf=-3091.4, convergence criterion=9.8671e-07 < tolerance=1e-06
# EM start iterations, llf=-3142.7
# EM iteration 100, llf=-3092.8, convergence criterion=1.2104e-06
# EM converged at iteration 110, llf=-3092.8, convergence criterion=9.9242e-07 < tolerance=1e-06
# EM start iterations, llf=-3158.2
# EM iteration 100, llf=-3107.9, convergence criterion=1.2034e-06
# EM converged at iteration 110, llf=-3107.9, convergence criterion=9.8732e-07 < tolerance=1e-06
# EM start iterations, llf=-3158.2
# EM iteration 100, llf=-3107.9, convergence criterion=1.2034e-06
# EM converged at iteration 110, llf=-3107.9, convergence criterion=9.8732e-07 < tolerance=1e-06
# EM start iterations, llf=-3173.6
# EM iteration 100, llf=-3123.1, convergence criterion=1.206e-06
# EM converged at iteration 110, llf=-3123.1, convergence criterion=9.9036e-07 < tolerance=1e-06
# EM start iterations, llf=-3173.6
# EM iteration 100, llf=-3123.1, convergence criterion=1.206e-06
# EM converged at iteration 110, llf=-3123.1, convergence criterion=9.9036e-07 < tolerance=1e-06
# EM start iterations, llf=-3173.6
# EM iteration 100, llf=-3123.1, convergence criterion=1.206e-06
# EM converged at iteration 110, llf=-3123.1, convergence criterion=9.9036e-07 < tolerance=1e-06
# EM start iterations, llf=-3188.3
# EM iteration 100, llf=-3137.7, convergence criterion=1.2023e-06
# EM converged at iteration 110, llf=-3137.7, convergence criterion=9.8679e-07 < tolerance=1e-06
# EM start iterations, llf=-3189.2
# EM converged at iteration 93, llf=-3138.8, convergence criterion=9.9709e-07 < tolerance=1e-06
# EM start iterations, llf=-3202
# EM converged at iteration 93, llf=-3151.4, convergence criterion=9.9461e-07 < tolerance=1e-06
# EM start iterations, llf=-3202
# EM converged at iteration 93, llf=-3151.4, convergence criterion=9.9461e-07 < tolerance=1e-06
# EM start iterations, llf=-3213.5
# EM converged at iteration 93, llf=-3162.7, convergence criterion=9.9025e-07 < tolerance=1e-06
# EM start iterations, llf=-3213.5
# EM converged at iteration 93, llf=-3162.7, convergence criterion=9.9025e-07 < tolerance=1e-06
# EM start iterations, llf=-3213.5
# EM converged at iteration 93, llf=-3162.7, convergence criterion=9.9025e-07 < tolerance=1e-06
# EM start iterations, llf=-3226.4
# EM converged at iteration 93, llf=-3175.4, convergence criterion=9.8694e-07 < tolerance=1e-06
# EM start iterations, llf=-3227.6
# EM converged at iteration 92, llf=-3176.6, convergence criterion=9.9793e-07 < tolerance=1e-06
# EM start iterations, llf=-3240.9
# EM converged at iteration 92, llf=-3189.8, convergence criterion=9.9277e-07 < tolerance=1e-06
# EM start iterations, llf=-3240.9
# EM converged at iteration 92, llf=-3189.8, convergence criterion=9.9277e-07 < tolerance=1e-06
# EM start iterations, llf=-3253.5
# EM converged at iteration 92, llf=-3202.3, convergence criterion=9.8851e-07 < tolerance=1e-06
# EM start iterations, llf=-3253.5
# EM converged at iteration 92, llf=-3202.3, convergence criterion=9.8851e-07 < tolerance=1e-06
# EM start iterations, llf=-3253.5
# EM converged at iteration 92, llf=-3202.3, convergence criterion=9.8851e-07 < tolerance=1e-06
# EM start iterations, llf=-3265.8
# EM converged at iteration 92, llf=-3214.5, convergence criterion=9.8663e-07 < tolerance=1e-06
# EM start iterations, llf=-3267
# EM converged at iteration 92, llf=-3215.7, convergence criterion=9.9374e-07 < tolerance=1e-06
# EM start iterations, llf=-3280.1
# EM converged at iteration 92, llf=-3228.5, convergence criterion=9.9237e-07 < tolerance=1e-06
# EM start iterations, llf=-3280.1
# EM converged at iteration 92, llf=-3228.5, convergence criterion=9.9237e-07 < tolerance=1e-06
# EM start iterations, llf=-3293.5
# EM converged at iteration 92, llf=-3241.7, convergence criterion=9.8903e-07 < tolerance=1e-06
# EM start iterations, llf=-3293.5
# EM converged at iteration 92, llf=-3241.7, convergence criterion=9.8903e-07 < tolerance=1e-06
# EM start iterations, llf=-3293.5
# EM converged at iteration 92, llf=-3241.7, convergence criterion=9.8903e-07 < tolerance=1e-06
# EM start iterations, llf=-3307
# EM converged at iteration 92, llf=-3255.1, convergence criterion=9.8813e-07 < tolerance=1e-06
# EM start iterations, llf=-3308.4
# EM converged at iteration 93, llf=-3256.4, convergence criterion=9.8442e-07 < tolerance=1e-06
# EM start iterations, llf=-3321.5
# EM converged at iteration 92, llf=-3269.5, convergence criterion=9.9813e-07 < tolerance=1e-06
# EM start iterations, llf=-3321.5
# EM converged at iteration 92, llf=-3269.5, convergence criterion=9.9813e-07 < tolerance=1e-06
# EM start iterations, llf=-3335.1
# EM converged at iteration 92, llf=-3283, convergence criterion=9.9127e-07 < tolerance=1e-06
# EM start iterations, llf=-3335.1
# EM converged at iteration 92, llf=-3283, convergence criterion=9.9127e-07 < tolerance=1e-06
# EM start iterations, llf=-3335.1
# EM converged at iteration 92, llf=-3283, convergence criterion=9.9127e-07 < tolerance=1e-06
# EM start iterations, llf=-3348
# EM converged at iteration 92, llf=-3295.8, convergence criterion=9.8417e-07 < tolerance=1e-06
# EM start iterations, llf=-3346.8
# EM converged at iteration 77, llf=-3294.8, convergence criterion=9.9867e-07 < tolerance=1e-06
# EM start iterations, llf=-3362.9
# EM converged at iteration 77, llf=-3310.6, convergence criterion=9.958e-07 < tolerance=1e-06
# EM start iterations, llf=-3362.9
# EM converged at iteration 77, llf=-3310.6, convergence criterion=9.958e-07 < tolerance=1e-06
# EM start iterations, llf=-3378.4
# EM converged at iteration 77, llf=-3326.3, convergence criterion=9.9333e-07 < tolerance=1e-06
# EM start iterations, llf=-3378.4
# EM converged at iteration 77, llf=-3326.3, convergence criterion=9.9333e-07 < tolerance=1e-06
# EM start iterations, llf=-3378.4
# EM converged at iteration 77, llf=-3326.3, convergence criterion=9.9333e-07 < tolerance=1e-06
# EM start iterations, llf=-3390.4
# EM converged at iteration 77, llf=-3338, convergence criterion=9.8809e-07 < tolerance=1e-06
# EM start iterations, llf=-3391.7
# EM converged at iteration 79, llf=-3339.4, convergence criterion=9.9096e-07 < tolerance=1e-06
# EM start iterations, llf=-3403.2
# EM converged at iteration 79, llf=-3350.7, convergence criterion=9.8703e-07 < tolerance=1e-06
# EM start iterations, llf=-3403.2
# EM converged at iteration 79, llf=-3350.7, convergence criterion=9.8703e-07 < tolerance=1e-06
# EM start iterations, llf=-3416
# EM converged at iteration 79, llf=-3363.5, convergence criterion=9.8309e-07 < tolerance=1e-06
# EM start iterations, llf=-3416
# EM converged at iteration 79, llf=-3363.5, convergence criterion=9.8309e-07 < tolerance=1e-06
# EM start iterations, llf=-3416
# EM converged at iteration 79, llf=-3363.5, convergence criterion=9.8309e-07 < tolerance=1e-06
# EM start iterations, llf=-3428.7
# EM converged at iteration 79, llf=-3376.1, convergence criterion=9.7896e-07 < tolerance=1e-06
# EM start iterations, llf=-3430
# EM converged at iteration 79, llf=-3377.4, convergence criterion=9.8429e-07 < tolerance=1e-06
# EM start iterations, llf=-3442.5
# EM converged at iteration 79, llf=-3389.7, convergence criterion=9.8201e-07 < tolerance=1e-06
# EM start iterations, llf=-3442.5
# EM converged at iteration 79, llf=-3389.7, convergence criterion=9.8201e-07 < tolerance=1e-06
# EM start iterations, llf=-3454.7
# EM converged at iteration 79, llf=-3401.8, convergence criterion=9.7907e-07 < tolerance=1e-06
# EM start iterations, llf=-3454.7
# EM converged at iteration 79, llf=-3401.8, convergence criterion=9.7907e-07 < tolerance=1e-06
# EM start iterations, llf=-3454.7
# EM converged at iteration 79, llf=-3401.8, convergence criterion=9.7907e-07 < tolerance=1e-06
# EM start iterations, llf=-3467.6
# EM converged at iteration 78, llf=-3414.4, convergence criterion=9.9716e-07 < tolerance=1e-06
# EM start iterations, llf=-3468.8
# EM converged at iteration 79, llf=-3415.6, convergence criterion=9.7986e-07 < tolerance=1e-06
# EM start iterations, llf=-3480.5
# EM converged at iteration 78, llf=-3427.2, convergence criterion=9.9591e-07 < tolerance=1e-06
# EM start iterations, llf=-3480.5
# EM converged at iteration 78, llf=-3427.2, convergence criterion=9.9591e-07 < tolerance=1e-06
# EM start iterations, llf=-3493.5
# EM converged at iteration 78, llf=-3440.1, convergence criterion=9.9204e-07 < tolerance=1e-06
# EM start iterations, llf=-3493.5
# EM converged at iteration 78, llf=-3440.1, convergence criterion=9.9204e-07 < tolerance=1e-06
# EM start iterations, llf=-3493.5
# EM converged at iteration 78, llf=-3440.1, convergence criterion=9.9204e-07 < tolerance=1e-06
# EM start iterations, llf=-3507.1
# EM converged at iteration 78, llf=-3452.8, convergence criterion=9.927e-07 < tolerance=1e-06
# EM start iterations, llf=-3508
# EM converged at iteration 82, llf=-3453.6, convergence criterion=9.9263e-07 < tolerance=1e-06
# EM start iterations, llf=-3520.7
# EM converged at iteration 82, llf=-3466.1, convergence criterion=9.9453e-07 < tolerance=1e-06
# EM start iterations, llf=-3520.7
# EM converged at iteration 82, llf=-3466.1, convergence criterion=9.9453e-07 < tolerance=1e-06
# EM start iterations, llf=-3532.9
# EM converged at iteration 82, llf=-3478.2, convergence criterion=9.9444e-07 < tolerance=1e-06
# EM start iterations, llf=-3532.9
# EM converged at iteration 82, llf=-3478.2, convergence criterion=9.9444e-07 < tolerance=1e-06
# EM start iterations, llf=-3532.9
# EM converged at iteration 82, llf=-3478.2, convergence criterion=9.9444e-07 < tolerance=1e-06
# EM start iterations, llf=-3550.3
# EM converged at iteration 82, llf=-3495.7, convergence criterion=9.8795e-07 < tolerance=1e-06
# EM start iterations, llf=-3551.5
# EM converged at iteration 82, llf=-3496.9, convergence criterion=9.9692e-07 < tolerance=1e-06
# EM start iterations, llf=-3563.4
# EM converged at iteration 82, llf=-3508.5, convergence criterion=9.8808e-07 < tolerance=1e-06
# EM start iterations, llf=-3563.4
# EM converged at iteration 82, llf=-3508.5, convergence criterion=9.8808e-07 < tolerance=1e-06
# EM start iterations, llf=-3575.9
# EM converged at iteration 82, llf=-3520.8, convergence criterion=9.8378e-07 < tolerance=1e-06
# EM start iterations, llf=-3575.9
# EM converged at iteration 82, llf=-3520.8, convergence criterion=9.8378e-07 < tolerance=1e-06
# EM start iterations, llf=-3575.9
# EM converged at iteration 82, llf=-3520.8, convergence criterion=9.8378e-07 < tolerance=1e-06
# EM start iterations, llf=-3588.9
# EM converged at iteration 81, llf=-3533.7, convergence criterion=9.9984e-07 < tolerance=1e-06
# EM start iterations, llf=-3590.1
# EM converged at iteration 82, llf=-3534.9, convergence criterion=9.8295e-07 < tolerance=1e-06
# EM start iterations, llf=-3603.5
# EM converged at iteration 82, llf=-3547.7, convergence criterion=9.8249e-07 < tolerance=1e-06
# EM start iterations, llf=-3603.5
# EM converged at iteration 82, llf=-3547.7, convergence criterion=9.8249e-07 < tolerance=1e-06
# EM start iterations, llf=-3617.8
# EM converged at iteration 82, llf=-3562, convergence criterion=9.778e-07 < tolerance=1e-06
# EM start iterations, llf=-3617.8
# EM converged at iteration 82, llf=-3562, convergence criterion=9.778e-07 < tolerance=1e-06
# EM start iterations, llf=-3617.8
# EM converged at iteration 82, llf=-3562, convergence criterion=9.778e-07 < tolerance=1e-06
# EM start iterations, llf=-3632.3
# EM converged at iteration 82, llf=-3575.9, convergence criterion=9.8302e-07 < tolerance=1e-06
# EM start iterations, llf=-3633.5
# EM converged at iteration 82, llf=-3577, convergence criterion=9.8684e-07 < tolerance=1e-06
# EM start iterations, llf=-3646
# EM converged at iteration 82, llf=-3589.5, convergence criterion=9.8162e-07 < tolerance=1e-06
# EM start iterations, llf=-3646
# EM converged at iteration 82, llf=-3589.5, convergence criterion=9.8162e-07 < tolerance=1e-06
# EM start iterations, llf=-3660.4
# EM converged at iteration 81, llf=-3604, convergence criterion=9.9849e-07 < tolerance=1e-06
# EM start iterations, llf=-3660.4
# EM converged at iteration 81, llf=-3604, convergence criterion=9.9849e-07 < tolerance=1e-06
# EM start iterations, llf=-3660.4
# EM converged at iteration 81, llf=-3604, convergence criterion=9.9849e-07 < tolerance=1e-06
# EM start iterations, llf=-3674.9
# EM converged at iteration 81, llf=-3617.3, convergence criterion=9.948e-07 < tolerance=1e-06
# EM start iterations, llf=-3676.3
# EM converged at iteration 81, llf=-3618.7, convergence criterion=9.9327e-07 < tolerance=1e-06
# EM start iterations, llf=-3685.4
# EM converged at iteration 81, llf=-3628, convergence criterion=9.904e-07 < tolerance=1e-06
# EM start iterations, llf=-3685.4
# EM converged at iteration 81, llf=-3628, convergence criterion=9.904e-07 < tolerance=1e-06
# EM start iterations, llf=-3700.4
# EM converged at iteration 82, llf=-3642.6, convergence criterion=9.7749e-07 < tolerance=1e-06
# EM start iterations, llf=-3700.4
# EM converged at iteration 82, llf=-3642.6, convergence criterion=9.7749e-07 < tolerance=1e-06
# EM start iterations, llf=-3700.4
# EM converged at iteration 82, llf=-3642.6, convergence criterion=9.7749e-07 < tolerance=1e-06
# EM start iterations, llf=-3713.6
# EM converged at iteration 82, llf=-3655.7, convergence criterion=9.7819e-07 < tolerance=1e-06
# EM start iterations, llf=-3714.9
# EM converged at iteration 82, llf=-3657, convergence criterion=9.8396e-07 < tolerance=1e-06
# EM start iterations, llf=-3728.2
# EM converged at iteration 82, llf=-3670.1, convergence criterion=9.8333e-07 < tolerance=1e-06
# EM start iterations, llf=-3728.2
# EM converged at iteration 82, llf=-3670.1, convergence criterion=9.8333e-07 < tolerance=1e-06
# EM start iterations, llf=-3741.5
# EM converged at iteration 82, llf=-3683.2, convergence criterion=9.8084e-07 < tolerance=1e-06
# EM start iterations, llf=-3741.5
# EM converged at iteration 82, llf=-3683.2, convergence criterion=9.8084e-07 < tolerance=1e-06
# EM start iterations, llf=-3741.5
# EM converged at iteration 82, llf=-3683.2, convergence criterion=9.8084e-07 < tolerance=1e-06
# EM start iterations, llf=-3754.6
# EM converged at iteration 82, llf=-3696.1, convergence criterion=9.7724e-07 < tolerance=1e-06
# EM start iterations, llf=-3755.9
# EM converged at iteration 83, llf=-3697.4, convergence criterion=9.7794e-07 < tolerance=1e-06
# EM start iterations, llf=-3768.9
# EM converged at iteration 82, llf=-3710.4, convergence criterion=9.9841e-07 < tolerance=1e-06
# EM start iterations, llf=-3768.9
# EM converged at iteration 82, llf=-3710.4, convergence criterion=9.9841e-07 < tolerance=1e-06
# EM start iterations, llf=-3782.2
# EM converged at iteration 82, llf=-3723.3, convergence criterion=9.8968e-07 < tolerance=1e-06
# EM start iterations, llf=-3782.2
# EM converged at iteration 82, llf=-3723.3, convergence criterion=9.8968e-07 < tolerance=1e-06
# EM start iterations, llf=-3782.2
# EM converged at iteration 82, llf=-3723.3, convergence criterion=9.8968e-07 < tolerance=1e-06
# EM start iterations, llf=-3794.2
# EM converged at iteration 82, llf=-3735.2, convergence criterion=9.8585e-07 < tolerance=1e-06
# EM start iterations, llf=-3795.5
# EM converged at iteration 83, llf=-3736.5, convergence criterion=9.9405e-07 < tolerance=1e-06
# EM start iterations, llf=-3806.6
# EM converged at iteration 83, llf=-3747.3, convergence criterion=9.8504e-07 < tolerance=1e-06
# EM start iterations, llf=-3806.6
# EM converged at iteration 83, llf=-3747.3, convergence criterion=9.8504e-07 < tolerance=1e-06
# EM start iterations, llf=-3818.1
# EM converged at iteration 83, llf=-3758.9, convergence criterion=9.7866e-07 < tolerance=1e-06
# EM start iterations, llf=-3818.1
# EM converged at iteration 83, llf=-3758.9, convergence criterion=9.7866e-07 < tolerance=1e-06
# EM start iterations, llf=-3818.1
# EM converged at iteration 83, llf=-3758.9, convergence criterion=9.7866e-07 < tolerance=1e-06
# EM start iterations, llf=-3829
# EM converged at iteration 82, llf=-3769.7, convergence criterion=9.9774e-07 < tolerance=1e-06
# EM start iterations, llf=-3830.6
# EM converged at iteration 85, llf=-3771.2, convergence criterion=9.8324e-07 < tolerance=1e-06
# EM start iterations, llf=-3844.4
# EM converged at iteration 85, llf=-3784.5, convergence criterion=9.7918e-07 < tolerance=1e-06
# EM start iterations, llf=-3844.4
# EM converged at iteration 85, llf=-3784.5, convergence criterion=9.7918e-07 < tolerance=1e-06
# EM start iterations, llf=-3857.1
# EM converged at iteration 85, llf=-3796.9, convergence criterion=9.7894e-07 < tolerance=1e-06
# EM start iterations, llf=-3857.1
# EM converged at iteration 85, llf=-3796.9, convergence criterion=9.7894e-07 < tolerance=1e-06
# EM start iterations, llf=-3857.1
# EM converged at iteration 85, llf=-3796.9, convergence criterion=9.7894e-07 < tolerance=1e-06
# EM start iterations, llf=-3870.2
# EM converged at iteration 84, llf=-3809.9, convergence criterion=9.9948e-07 < tolerance=1e-06
# EM start iterations, llf=-3871.4
# EM converged at iteration 85, llf=-3811.1, convergence criterion=9.8454e-07 < tolerance=1e-06
# EM start iterations, llf=-3882.5
# EM converged at iteration 85, llf=-3822.1, convergence criterion=9.8136e-07 < tolerance=1e-06
# EM start iterations, llf=-3882.5
# EM converged at iteration 85, llf=-3822.1, convergence criterion=9.8136e-07 < tolerance=1e-06
# EM start iterations, llf=-3893.3
# EM converged at iteration 84, llf=-3832.9, convergence criterion=9.9908e-07 < tolerance=1e-06
# EM start iterations, llf=-3893.3
# EM converged at iteration 84, llf=-3832.9, convergence criterion=9.9908e-07 < tolerance=1e-06
# EM start iterations, llf=-3893.3
# EM converged at iteration 84, llf=-3832.9, convergence criterion=9.9908e-07 < tolerance=1e-06
# EM start iterations, llf=-3905.3
# EM converged at iteration 84, llf=-3845, convergence criterion=9.9331e-07 < tolerance=1e-06
# EM start iterations, llf=-3906.5
# EM converged at iteration 85, llf=-3846.2, convergence criterion=9.8269e-07 < tolerance=1e-06
# EM start iterations, llf=-3917.5
# EM converged at iteration 85, llf=-3857.1, convergence criterion=9.8014e-07 < tolerance=1e-06
# EM start iterations, llf=-3917.5
# EM converged at iteration 85, llf=-3857.1, convergence criterion=9.8014e-07 < tolerance=1e-06
# EM start iterations, llf=-3930.6
# EM converged at iteration 84, llf=-3870.1, convergence criterion=9.9737e-07 < tolerance=1e-06
# EM start iterations, llf=-3930.6
# EM converged at iteration 84, llf=-3870.1, convergence criterion=9.9737e-07 < tolerance=1e-06
# EM start iterations, llf=-3930.6
# EM converged at iteration 84, llf=-3870.1, convergence criterion=9.9737e-07 < tolerance=1e-06
# EM start iterations, llf=-3942.3
# EM converged at iteration 84, llf=-3881.7, convergence criterion=9.9349e-07 < tolerance=1e-06
# EM start iterations, llf=-3943.7
# EM converged at iteration 85, llf=-3883.2, convergence criterion=9.9274e-07 < tolerance=1e-06
# EM start iterations, llf=-3955.7
# EM converged at iteration 85, llf=-3895, convergence criterion=9.9045e-07 < tolerance=1e-06
# EM start iterations, llf=-3955.7
# EM converged at iteration 85, llf=-3895, convergence criterion=9.9045e-07 < tolerance=1e-06
# EM start iterations, llf=-3969.5
# EM converged at iteration 85, llf=-3908.2, convergence criterion=9.863e-07 < tolerance=1e-06
# EM start iterations, llf=-3969.5
# EM converged at iteration 85, llf=-3908.2, convergence criterion=9.863e-07 < tolerance=1e-06
# EM start iterations, llf=-3969.5
# EM converged at iteration 85, llf=-3908.2, convergence criterion=9.863e-07 < tolerance=1e-06
# EM start iterations, llf=-3984.3
# EM converged at iteration 85, llf=-3923, convergence criterion=9.8504e-07 < tolerance=1e-06
# EM start iterations, llf=-3985.8
# EM converged at iteration 83, llf=-3924.6, convergence criterion=9.9626e-07 < tolerance=1e-06
# EM start iterations, llf=-3999
# EM converged at iteration 83, llf=-3937.7, convergence criterion=9.8846e-07 < tolerance=1e-06
# EM start iterations, llf=-3999
# EM converged at iteration 83, llf=-3937.7, convergence criterion=9.8846e-07 < tolerance=1e-06
# EM start iterations, llf=-4012.8
# EM converged at iteration 83, llf=-3951, convergence criterion=9.8552e-07 < tolerance=1e-06
# EM start iterations, llf=-4012.8
# EM converged at iteration 83, llf=-3951, convergence criterion=9.8552e-07 < tolerance=1e-06
# EM start iterations, llf=-4012.8
# EM converged at iteration 83, llf=-3951, convergence criterion=9.8552e-07 < tolerance=1e-06
# EM start iterations, llf=-4025.8
# EM converged at iteration 83, llf=-3963.7, convergence criterion=9.8242e-07 < tolerance=1e-06
# EM start iterations, llf=-4027
# EM converged at iteration 83, llf=-3964.9, convergence criterion=9.7785e-07 < tolerance=1e-06
# EM start iterations, llf=-4038.9
# EM converged at iteration 82, llf=-3976.7, convergence criterion=9.9664e-07 < tolerance=1e-06
# EM start iterations, llf=-4038.9
# EM converged at iteration 82, llf=-3976.7, convergence criterion=9.9664e-07 < tolerance=1e-06
# EM start iterations, llf=-4050.6
# EM converged at iteration 82, llf=-3987.1, convergence criterion=9.9675e-07 < tolerance=1e-06
# Model with Global factors = 1 and order = 3 estimated in 1:27:02.443030.

# %% [markdown]
# Plot MSE values for the model with 1 Global Factor and Lag Order 3 evaluated over the 2008–2018 period.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]
q_var = 'GDP'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Define the directory containing MSE files
mse_dir = f"../MSE/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"

# Create a single‐plot figure for 1 global factor, order 3
fig, ax = plt.subplots(figsize=(6, 6), sharey=True)

num_factors = 1
order = 3
    
# Construct file name based on the model's parameters
factors_str = f"Global_{num_factors}_{order}"
mse_file_name = f"MSE_{q_var}_{factors_str}.csv"
mse_file_path = os.path.join(mse_dir, mse_file_name)

# Load the MSE values from file
mse_df = pd.read_csv(mse_file_path)
# Construct y values based on the vintages
y_values = [mse_df[col].iloc[0] for col in vintage_col_names]

# Extend the y-values so the step function holds the last value
y_extended = y_values.copy()
y_extended.append(y_values[-1]) # Repeat the last value

# Plot the step function for the current model
ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
         label=f"Order: {order}")

# Customize the subplot
ax.set_xlabel("Month of Quarter")
# Set ticks only at 1, 2, and 3 to mark the beginning of each month
ax.set_xticks([1, 2, 3])
ax.set_xlim(0.9, 4.1)
ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
ax.set_ylabel("MSE")
ax.legend()

plt.suptitle(f"MSE for the Model with 1 Global Factor and Lag Order 3 ({q_var}, 2008-2018)", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_2008-2018_{q_var}")
plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot MSE values for the model with 1 Global Factor and Lag Order 3 evaluated over the 2008–2010 and 2011-2018 periods.

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Define two periods
periods = {
    "2008-2010": lambda df: df["date_float"] < 2011,
    "2011-2018": lambda df: df["date_float"] >= 2011
}

# Define a mapping for each vintage to a numeric x-value
x_mapping = {
    "M1-01": 1.0,
    "M1-16": 1.5,
    "M2-01": 2.0,
    "M2-16": 2.5,
    "M3-01": 3.0,
    "M3-16": 3.5,
    "M4-01": 4.0
}

# Construct x values based on the vintages
x_values = [x_mapping[col] for col in vintage_col_names]
# Extend the x array so that the last step extends to the end of the x-axis
x_extended = x_values.copy()
x_extended.append(4.1)  # extend x-axis to 4.1

# Loop over each period and create a separate figure
for period_label, period_filter in periods.items():
    
    # Create a single‐plot figure for 1 global factor, order 3
    fig, ax = plt.subplots(figsize=(6, 6), sharey=True)
    
    num_factors = 1
    order = 3
    
    # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
    factors_str = f"Global_{num_factors}_{order}"
    forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
    forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

    # Load forecast data 
    forecasts = pd.read_csv(forecast_file_path, index_col=0)
    forecasts.index.name = "date"
    forecasts.reset_index(inplace=True)

    # Merge forecasts with actual growth 
    merged = pd.merge(forecasts, actual_growth, on="date", how="inner")
    merged["date_float"] = merged["date"].apply(quarter_to_float)
    merged.sort_values("date_float", inplace=True)

    # Filter merged data for the current period
    merged_period = merged[ period_filter(merged) ]

    # Calculate MSE for each vintage column over the filtered period
    mse_dict = {}
    for col in vintage_col_names:
        mse = ((merged_period[col] - merged_period["growth"]) ** 2).mean()
        mse_dict[col] = mse

    # Construct y values based on the vintages
    y_values = [mse_dict[col] for col in vintage_col_names]

    # Extend the y-values so the step function holds the last value
    y_extended = y_values.copy()
    y_extended.append(y_values[-1]) # Repeat the last value

    # Plot the step function for the current model (order)
    ax.step(x_extended, y_extended, where='post', linewidth=1.2, 
            label=f"Order: {order}")
            
    # Customize the subplot
    ax.set_xlabel("Month of Quarter")
    # Set ticks only at 1, 2, and 3 to mark the beginning of each month
    ax.set_xticks([1, 2, 3])
    ax.set_xlim(0.9, 4.1)
    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    ax.set_ylabel("MSE")
    ax.legend()
   
    plt.suptitle(f"MSE for the Model with 1 Global Factor and Lag Order 3 ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Plot forecasts vs actual growth values for the model with 1 Global Factor, Lag Order 3 and different time periods (2008-2010, 2008-2018, and 2011-2018).

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Convert quarter strings like "2008-03" into a float (e.g. 2008.00 for Q1, 2008.25 for Q2, etc.)
def quarter_to_float(q_str):
    """
    Convert a string like 'YYYY-MM'
    into a float: e.g. 2008-03 -> 2008.00, 2008-06 -> 2008.25, etc.
    """
    year = int(q_str[:4])
    month = int(q_str[5:])
    # Map month to fraction of the year
    if month == 3:
        fraction = 0.00
    elif month == 6:
        fraction = 0.25
    elif month == 9:
        fraction = 0.50
    elif month == 12:
        fraction = 0.75
    return year + fraction

# Forecast variable and directories
q_var = 'GDP'
text_type = "topics_BCC"
estimation_period = "2009"
num_topics = "200"
source = "all"
selected = "_selected"
forecasts_dir = f"../forecasts/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}"
actual_growth_file = f"../{q_var}_growth_actual.csv"

# Vintage columns
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Assign 7 small offsets within each quarter, so each quarter has 7 forecast points
offsets = np.linspace(0, 0.23, 7)

# Load actual growth data and convert 'date' to float
actual_growth = pd.read_csv(actual_growth_file)
actual_growth["date_float"] = actual_growth["date"].apply(quarter_to_float)
actual_growth.sort_values("date_float", inplace=True)

# Build x,y arrays for the actual growth
x_act = actual_growth["date_float"].tolist()
y_act = actual_growth["growth"].tolist()

# Define period configurations: x-axis limits and tick positions for each period
period_configs = {
    "2008-2010": {"xlim": (2008, 2010.99), "xticks": list(range(2008, 2011))},
    "2008-2018": {"xlim": (2008, 2018.99), "xticks": list(range(2008, 2019))},
    "2011-2018": {"xlim": (2011, 2018.99), "xticks": list(range(2011, 2019))}
}

# Loop over each period configuration to create and save separate plots
for period_label, config in period_configs.items():
    
    # Extend the actual growth arrays so that the step function continues until the end of the x-axis
    if period_label in ["2008-2018", "2011-2018"]:
        x_act_extended = x_act.copy()
        x_act_extended.append(config["xlim"][1])
        y_act_extended = y_act.copy()
        y_act_extended.append(y_act[-1])
    else:
        x_act_extended = x_act
        y_act_extended = y_act

    # Create a single‐plot figure for 1 global factor, order 3
    fig, ax = plt.subplots(figsize=(6, 6), sharey=True)

    num_factors = 1
    order = 3

    # Construct forecast file name, e.g., "forecasts_GDP_Global_1_1.csv"
    factors_str = f"Global_{num_factors}_{order}"
    forecast_file_name = f"forecasts_{q_var}_{factors_str}.csv"
    forecast_file_path = os.path.join(forecasts_dir, forecast_file_name)

    # Load forecast data 
    forecasts = pd.read_csv(forecast_file_path, index_col=0)
    forecasts.index.name = "date"
    forecasts.reset_index(inplace=True)

    # Merge forecasts with actual growth dates
    merged = pd.merge(forecasts, actual_growth[['date']], on="date", how="inner")
    merged["date_float"] = merged["date"].apply(quarter_to_float)
    merged.sort_values("date_float", inplace=True)

    # Build forecast x and y arrays 
    x_fore = []
    y_fore = []
    for idx, row in merged.iterrows():
        base_x = row["date_float"]
        # For each of the 7 vintage columns, define an x-position and take that forecast value
        for j, col in enumerate(vintage_col_names):
            x_fore.append(base_x + offsets[j])
            y_fore.append(row[col])

    # Plot the forecast step curve for the current order
    ax.step(x_fore, y_fore, where='post', linewidth=1.2, label=f"Order: {order}")

    # Plot actual growth as a step plot in each subplot
    ax.step(x_act_extended, y_act_extended, where='post', color='black', linewidth=1.2, label="Actual growth")

    # Customize the subplot
    ax.set_xlabel("Year")
    ax.set_xlim(config["xlim"][0], config["xlim"][1])
    ax.set_xticks(config["xticks"])

    # Set y-axis limits based on the data within the period range
    x_min, x_max = config["xlim"]
    def filter_points(x_arr, y_arr, x_min, x_max):
        return [y for x, y in zip(x_arr, y_arr) if x_min <= x <= x_max]

    # Filter y-values
    y_filtered = filter_points(x_fore, y_fore, x_min, x_max)
    y_act_filtered = filter_points(x_act_extended, y_act_extended, x_min, x_max)

    # Combine all filtered y-values
    combined_y = y_filtered + y_act_filtered
    ax.set_ylim(1.05 * min(combined_y), 1.2 * max(combined_y))

    ax.set_title(f"{num_factors} Global Factor{'s' if num_factors > 1 else ''}")
    ax.set_ylabel("Annualized q-o-q Growth (%)")
    ax.legend()
        
    plt.suptitle(f"Forecast vs Actual Growth for Different Models ({q_var}, {period_label})", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    
    # Create the "plots" directory if it doesn't exist and save the figure as PNG and EPS
    os.makedirs(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", exist_ok=True)
    base_filename = os.path.join(f"../plots/DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_{q_var}", f"DFM_only_{text_type}_{estimation_period}_{num_topics}_{source}{selected}_global_factors_forecast_vs_actual_{period_label}_{q_var}")
    plt.savefig(f"{base_filename}.png", format="png", bbox_inches="tight")
    plt.savefig(f"{base_filename}.eps", format="eps", bbox_inches="tight")

    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
