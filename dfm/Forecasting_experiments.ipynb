# %%
import os
import pandas as pd
import DFM_function

# Define inputs
q_var = 'GDP'                      # quarterly variable being forecasted
additional_factors = None          # or "all" or e.g. ['Labor market']
factor_multiplicities = {'Global': 1}
factor_orders = {'Global': 3}
start = '1991-02'

# Generate list of forecast_month strings for quarters from 2008Q1 to 2018Q4.
# forecast_month is set to the month corresponding to quarter-end:
# Q1: 'YYYY-03', Q2: 'YYYY-06', Q3: 'YYYY-09', Q4: 'YYYY-12'
forecast_months = []
for year in range(2008, 2019):
    forecast_months.extend([f"{year}-03", f"{year}-06", f"{year}-09", f"{year}-12"])
    
# Define the vintage column names 
vintage_col_names = ["M1-01", "M1-16", "M2-01", "M2-16", "M3-01", "M3-16", "M4-01"]

# Prepare a list to store each quarter's forecasts and a list for row labels
forecasts_all_quarters = []
row_labels = []

# Loop over each forecast month, get the forecasts, and store the results
for fm in forecast_months:
    # Use the forecast_month string as the row label
    row_labels.append(fm)
    
    # Run the forecast function for this quarter
    forecasts_dict = DFM_function.get_forecasts(
        forecast_month = fm,
        q_var = q_var,
        additional_factors = additional_factors,
        factor_multiplicities = factor_multiplicities,
        factor_orders = factor_orders,
        start = start
    )
    
    # Obtain the correct ordering of vintages
    vintages_order = DFM_function.vintage_dates(fm)
    # Extract the forecast value for each vintage in that order
    quarter_forecasts = [forecasts_dict[vint] for vint in vintages_order]
    forecasts_all_quarters.append(quarter_forecasts)
    
# Create a DataFrame with rows labeled by the forecast_month strings and columns as vintage names
results = pd.DataFrame(forecasts_all_quarters, index=row_labels, columns=vintage_col_names)

# Construct the output file name
factors_str = "_".join([
    f"{factor.replace(' ', '_')}_{factor_multiplicities[factor]}_{factor_orders[factor]}"
    for factor in factor_multiplicities])
file_name = f"forecasts_{q_var}_{factors_str}.csv"

# Save the CSV file in a subfolder 'forecasts'
os.makedirs("forecasts", exist_ok=True)
output_path = os.path.join("forecasts", file_name)
results.to_csv(output_path, index=True)
# Out:
# EM start iterations, llf=-9237.2
# EM iteration 10, llf=-9021.8, convergence criterion=0.000117
# EM iteration 20, llf=-9019.8, convergence criterion=2.5309e-06
# EM converged at iteration 28, llf=-9019.7, convergence criterion=9.6795e-07 < tolerance=1e-06
# EM start iterations, llf=-9250.1
# EM iteration 10, llf=-9033.9, convergence criterion=0.00011675
# EM iteration 20, llf=-9031.9, convergence criterion=2.521e-06
# EM converged at iteration 28, llf=-9031.8, convergence criterion=9.6366e-07 < tolerance=1e-06
# EM start iterations, llf=-9290.1
# EM iteration 10, llf=-9071.8, convergence criterion=0.00011586
# EM iteration 20, llf=-9069.9, convergence criterion=2.4808e-06
# EM converged at iteration 29, llf=-9069.8, convergence criterion=9.3709e-07 < tolerance=1e-06
# EM start iterations, llf=-9298.3
# EM iteration 10, llf=-9080.2, convergence criterion=0.0001159
# EM iteration 20, llf=-9078.2, convergence criterion=2.4924e-06
# EM converged at iteration 29, llf=-9078.1, convergence criterion=9.3663e-07 < tolerance=1e-06
# EM start iterations, llf=-9347.7
# EM iteration 10, llf=-9123.5, convergence criterion=0.00011451
# EM iteration 20, llf=-9121.7, convergence criterion=2.2705e-06
# EM converged at iteration 29, llf=-9121.6, convergence criterion=9.4103e-07 < tolerance=1e-06
# EM start iterations, llf=-9356.4
# EM iteration 10, llf=-9131, convergence criterion=0.00011322
# EM iteration 20, llf=-9129.3, convergence criterion=2.2301e-06
# EM converged at iteration 29, llf=-9129.2, convergence criterion=9.3942e-07 < tolerance=1e-06
# EM start iterations, llf=-9398.3
# EM iteration 10, llf=-9174.9, convergence criterion=0.00012119
# EM iteration 20, llf=-9173, convergence criterion=2.3806e-06
# EM converged at iteration 28, llf=-9172.9, convergence criterion=9.9884e-07 < tolerance=1e-06
# EM start iterations, llf=-9398.3
# EM iteration 10, llf=-9174.9, convergence criterion=0.00012119
# EM iteration 20, llf=-9173, convergence criterion=2.3806e-06
# EM converged at iteration 28, llf=-9172.9, convergence criterion=9.9884e-07 < tolerance=1e-06
# EM start iterations, llf=-9403
# EM iteration 10, llf=-9178.9, convergence criterion=0.00011748
# EM iteration 20, llf=-9177.1, convergence criterion=2.299e-06
# EM converged at iteration 29, llf=-9177, convergence criterion=9.4737e-07 < tolerance=1e-06
# EM start iterations, llf=-9441.9
# EM iteration 10, llf=-9214.5, convergence criterion=0.00011203
# EM iteration 20, llf=-9212.9, convergence criterion=2.3017e-06
# EM iteration 30, llf=-9212.7, convergence criterion=9.4413e-07
# EM converged at iteration 30, llf=-9212.7, convergence criterion=9.4413e-07 < tolerance=1e-06
# EM start iterations, llf=-9449.3
# EM iteration 10, llf=-9220.7, convergence criterion=0.00010734
# EM iteration 20, llf=-9219.2, convergence criterion=2.1746e-06
# EM converged at iteration 29, llf=-9219.1, convergence criterion=9.578e-07 < tolerance=1e-06
# EM start iterations, llf=-9480.8
# EM iteration 10, llf=-9246.5, convergence criterion=9.7207e-05
# EM iteration 20, llf=-9245.2, convergence criterion=2.1909e-06
# EM iteration 30, llf=-9245.1, convergence criterion=9.4938e-07
# EM converged at iteration 30, llf=-9245.1, convergence criterion=9.4938e-07 < tolerance=1e-06
# EM start iterations, llf=-9491.7
# EM iteration 10, llf=-9257.7, convergence criterion=9.7788e-05
# EM iteration 20, llf=-9256.3, convergence criterion=2.1648e-06
# EM converged at iteration 29, llf=-9256.2, convergence criterion=9.9741e-07 < tolerance=1e-06
# EM start iterations, llf=-9524.1
# EM iteration 10, llf=-9285.9, convergence criterion=7.8838e-05
# EM iteration 20, llf=-9284.9, convergence criterion=1.9718e-06
# EM converged at iteration 28, llf=-9284.8, convergence criterion=9.9988e-07 < tolerance=1e-06
# EM start iterations, llf=-9524.1
# EM iteration 10, llf=-9285.9, convergence criterion=7.8838e-05
# EM iteration 20, llf=-9284.9, convergence criterion=1.9718e-06
# EM converged at iteration 28, llf=-9284.8, convergence criterion=9.9988e-07 < tolerance=1e-06
# EM start iterations, llf=-9534.2
# EM iteration 10, llf=-9293.8, convergence criterion=7.5146e-05
# EM iteration 20, llf=-9292.8, convergence criterion=2.0342e-06
# EM converged at iteration 29, llf=-9292.7, convergence criterion=9.7119e-07 < tolerance=1e-06
# EM start iterations, llf=-9563.6
# EM iteration 10, llf=-9325, convergence criterion=7.7911e-05
# EM iteration 20, llf=-9324, convergence criterion=1.9422e-06
# EM converged at iteration 28, llf=-9323.9, convergence criterion=9.9882e-07 < tolerance=1e-06
# EM start iterations, llf=-9576.7
# EM iteration 10, llf=-9339, convergence criterion=7.8052e-05
# EM iteration 20, llf=-9338.1, convergence criterion=1.4276e-06
# EM converged at iteration 24, llf=-9338.1, convergence criterion=9.3823e-07 < tolerance=1e-06
# EM start iterations, llf=-9602.9
# EM iteration 10, llf=-9360.5, convergence criterion=7.0867e-05
# EM iteration 20, llf=-9359.7, convergence criterion=1.4707e-06
# EM converged at iteration 24, llf=-9359.7, convergence criterion=9.8453e-07 < tolerance=1e-06
# EM start iterations, llf=-9614.1
# EM iteration 10, llf=-9372.9, convergence criterion=7.7676e-05
# EM iteration 20, llf=-9372, convergence criterion=1.4719e-06
# EM converged at iteration 24, llf=-9371.9, convergence criterion=9.7664e-07 < tolerance=1e-06
# EM start iterations, llf=-9680.9
# EM iteration 10, llf=-9442.2, convergence criterion=9.9717e-05
# EM iteration 20, llf=-9440.8, convergence criterion=1.4085e-06
# EM converged at iteration 23, llf=-9440.8, convergence criterion=9.5595e-07 < tolerance=1e-06
# EM start iterations, llf=-9680.9
# EM iteration 10, llf=-9442.2, convergence criterion=9.9717e-05
# EM iteration 20, llf=-9440.8, convergence criterion=1.4085e-06
# EM converged at iteration 23, llf=-9440.8, convergence criterion=9.5595e-07 < tolerance=1e-06
# EM start iterations, llf=-9664.3
# EM iteration 10, llf=-9420.9, convergence criterion=6.0435e-05
# EM iteration 20, llf=-9420.2, convergence criterion=1.4924e-06
# EM converged at iteration 25, llf=-9420.1, convergence criterion=9.1915e-07 < tolerance=1e-06
# EM start iterations, llf=-9704.8
# EM iteration 10, llf=-9473.9, convergence criterion=5.6287e-05
# EM iteration 20, llf=-9473.2, convergence criterion=1.2948e-06
# EM converged at iteration 23, llf=-9473.1, convergence criterion=9.3882e-07 < tolerance=1e-06
# EM start iterations, llf=-9725.1
# EM iteration 10, llf=-9501.8, convergence criterion=9.0401e-05
# EM iteration 20, llf=-9500.4, convergence criterion=1.5646e-06
# EM converged at iteration 23, llf=-9500.3, convergence criterion=9.9542e-07 < tolerance=1e-06
# EM start iterations, llf=-9776.8
# EM iteration 10, llf=-9573.7, convergence criterion=8.7771e-05
# EM iteration 20, llf=-9571.4, convergence criterion=5.4623e-06
# EM converged at iteration 29, llf=-9571.2, convergence criterion=8.6249e-07 < tolerance=1e-06
# EM start iterations, llf=-9775.7
# EM iteration 10, llf=-9571.2, convergence criterion=9.5495e-05
# EM iteration 20, llf=-9568.6, convergence criterion=5.4011e-06
# EM converged at iteration 28, llf=-9568.5, convergence criterion=9.342e-07 < tolerance=1e-06
# EM start iterations, llf=-9785.8
# EM iteration 10, llf=-9587.1, convergence criterion=8.8659e-05
# EM iteration 20, llf=-9584.8, convergence criterion=4.9708e-06
# EM converged at iteration 28, llf=-9584.6, convergence criterion=9.3826e-07 < tolerance=1e-06
# EM start iterations, llf=-9785.8
# EM iteration 10, llf=-9587.1, convergence criterion=8.8659e-05
# EM iteration 20, llf=-9584.8, convergence criterion=4.9708e-06
# EM converged at iteration 28, llf=-9584.6, convergence criterion=9.3826e-07 < tolerance=1e-06
# EM start iterations, llf=-9792.5
# EM iteration 10, llf=-9602.4, convergence criterion=8.5981e-05
# EM iteration 20, llf=-9600.1, convergence criterion=5.1789e-06
# EM converged at iteration 29, llf=-9600, convergence criterion=8.764e-07 < tolerance=1e-06
# EM start iterations, llf=-9834.1
# EM iteration 10, llf=-9647.9, convergence criterion=9.9079e-05
# EM iteration 20, llf=-9645.2, convergence criterion=6.5073e-06
# EM iteration 30, llf=-9645, convergence criterion=8.9596e-07
# EM converged at iteration 30, llf=-9645, convergence criterion=8.9596e-07 < tolerance=1e-06
# EM start iterations, llf=-9837.6
# EM iteration 10, llf=-9658.5, convergence criterion=0.00010476
# EM iteration 20, llf=-9655.6, convergence criterion=7.0959e-06
# EM iteration 30, llf=-9655.4, convergence criterion=9.0347e-07
# EM converged at iteration 30, llf=-9655.4, convergence criterion=9.0347e-07 < tolerance=1e-06
# EM start iterations, llf=-9881.1
# EM iteration 10, llf=-9712.3, convergence criterion=9.4599e-05
# EM iteration 20, llf=-9709.6, convergence criterion=6.2262e-06
# EM converged at iteration 29, llf=-9709.4, convergence criterion=9.2601e-07 < tolerance=1e-06
# EM start iterations, llf=-9914.2
# EM iteration 10, llf=-9751.9, convergence criterion=8.968e-05
# EM iteration 20, llf=-9749, convergence criterion=7.9175e-06
# EM iteration 30, llf=-9748.7, convergence criterion=9.734e-07
# EM converged at iteration 30, llf=-9748.7, convergence criterion=9.734e-07 < tolerance=1e-06
# EM start iterations, llf=-9947
# EM iteration 10, llf=-9776.2, convergence criterion=7.8417e-05
# EM iteration 20, llf=-9773.7, convergence criterion=6.6554e-06
# EM iteration 30, llf=-9773.4, convergence criterion=9.9164e-07
# EM converged at iteration 30, llf=-9773.4, convergence criterion=9.9164e-07 < tolerance=1e-06
# EM start iterations, llf=-9947
# EM iteration 10, llf=-9776.2, convergence criterion=7.8417e-05
# EM iteration 20, llf=-9773.7, convergence criterion=6.6554e-06
# EM iteration 30, llf=-9773.4, convergence criterion=9.9164e-07
# EM converged at iteration 30, llf=-9773.4, convergence criterion=9.9164e-07 < tolerance=1e-06
# EM start iterations, llf=-9955.7
# EM iteration 10, llf=-9775.5, convergence criterion=9.6558e-05
# EM iteration 20, llf=-9772.7, convergence criterion=6.2164e-06
# EM converged at iteration 29, llf=-9772.5, convergence criterion=9.0782e-07 < tolerance=1e-06
# EM start iterations, llf=-9993.1
# EM iteration 10, llf=-9814.2, convergence criterion=0.00010317
# EM iteration 20, llf=-9811.4, convergence criterion=5.8382e-06
# EM converged at iteration 29, llf=-9811.3, convergence criterion=8.6389e-07 < tolerance=1e-06
# EM start iterations, llf=-9998.9
# EM iteration 10, llf=-9818.5, convergence criterion=0.00010574
# EM iteration 20, llf=-9815.6, convergence criterion=6.361e-06
# EM iteration 30, llf=-9815.4, convergence criterion=8.6876e-07
# EM converged at iteration 30, llf=-9815.4, convergence criterion=8.6876e-07 < tolerance=1e-06
# EM start iterations, llf=-10039
# EM iteration 10, llf=-9858.2, convergence criterion=9.7402e-05
# EM iteration 20, llf=-9855.7, convergence criterion=5.3371e-06
# EM converged at iteration 28, llf=-9855.5, convergence criterion=9.928e-07 < tolerance=1e-06
# EM start iterations, llf=-10047
# EM iteration 10, llf=-9866.5, convergence criterion=0.00010251
# EM iteration 20, llf=-9863.7, convergence criterion=5.9045e-06
# EM converged at iteration 29, llf=-9863.5, convergence criterion=9.2045e-07 < tolerance=1e-06
# EM start iterations, llf=-10082
# EM iteration 10, llf=-9898, convergence criterion=0.00010318
# EM iteration 20, llf=-9895.3, convergence criterion=5.6045e-06
# EM converged at iteration 29, llf=-9895.1, convergence criterion=8.9362e-07 < tolerance=1e-06
# EM start iterations, llf=-10082
# EM iteration 10, llf=-9898, convergence criterion=0.00010318
# EM iteration 20, llf=-9895.3, convergence criterion=5.6045e-06
# EM converged at iteration 29, llf=-9895.1, convergence criterion=8.9362e-07 < tolerance=1e-06
# EM start iterations, llf=-10087
# EM iteration 10, llf=-9904.2, convergence criterion=0.0001012
# EM iteration 20, llf=-9901.5, convergence criterion=5.5681e-06
# EM converged at iteration 29, llf=-9901.3, convergence criterion=8.9007e-07 < tolerance=1e-06
# EM start iterations, llf=-10124
# EM iteration 10, llf=-9938, convergence criterion=9.9911e-05
# EM iteration 20, llf=-9935.5, convergence criterion=5.1319e-06
# EM converged at iteration 28, llf=-9935.3, convergence criterion=9.8732e-07 < tolerance=1e-06
# EM start iterations, llf=-10132
# EM iteration 10, llf=-9946.6, convergence criterion=9.8589e-05
# EM iteration 20, llf=-9944.1, convergence criterion=4.9941e-06
# EM converged at iteration 28, llf=-9943.9, convergence criterion=9.2012e-07 < tolerance=1e-06
# EM start iterations, llf=-10161
# EM iteration 10, llf=-9970, convergence criterion=9.8134e-05
# EM iteration 20, llf=-9967.6, convergence criterion=4.8342e-06
# EM converged at iteration 28, llf=-9967.4, convergence criterion=9.0083e-07 < tolerance=1e-06
# EM start iterations, llf=-10172
# EM iteration 10, llf=-9980, convergence criterion=9.9079e-05
# EM iteration 20, llf=-9977.5, convergence criterion=4.8646e-06
# EM converged at iteration 28, llf=-9977.4, convergence criterion=9.0271e-07 < tolerance=1e-06
# EM start iterations, llf=-10218
# EM iteration 10, llf=-10034, convergence criterion=9.4583e-05
# EM iteration 20, llf=-10031, convergence criterion=4.6392e-06
# EM converged at iteration 28, llf=-10031, convergence criterion=8.748e-07 < tolerance=1e-06
# EM start iterations, llf=-10218
# EM iteration 10, llf=-10034, convergence criterion=9.4583e-05
# EM iteration 20, llf=-10031, convergence criterion=4.6392e-06
# EM converged at iteration 28, llf=-10031, convergence criterion=8.748e-07 < tolerance=1e-06
# EM start iterations, llf=-10229
# EM iteration 10, llf=-10048, convergence criterion=9.4569e-05
# EM iteration 20, llf=-10046, convergence criterion=4.6938e-06
# EM converged at iteration 28, llf=-10045, convergence criterion=8.6899e-07 < tolerance=1e-06
# EM start iterations, llf=-10268
# EM iteration 10, llf=-10084, convergence criterion=9.5213e-05
# EM iteration 20, llf=-10082, convergence criterion=4.8485e-06
# EM converged at iteration 28, llf=-10082, convergence criterion=9.1122e-07 < tolerance=1e-06
# EM start iterations, llf=-10277
# EM iteration 10, llf=-10093, convergence criterion=9.5716e-05
# EM iteration 20, llf=-10091, convergence criterion=4.946e-06
# EM converged at iteration 28, llf=-10091, convergence criterion=9.4357e-07 < tolerance=1e-06
# EM start iterations, llf=-10316
# EM iteration 10, llf=-10129, convergence criterion=9.2851e-05
# EM iteration 20, llf=-10126, convergence criterion=4.6358e-06
# EM converged at iteration 28, llf=-10126, convergence criterion=9.1014e-07 < tolerance=1e-06
# EM start iterations, llf=-10325
# EM iteration 10, llf=-10138, convergence criterion=9.0307e-05
# EM iteration 20, llf=-10136, convergence criterion=4.4641e-06
# EM converged at iteration 28, llf=-10135, convergence criterion=8.8428e-07 < tolerance=1e-06
# EM start iterations, llf=-10362
# EM iteration 10, llf=-10175, convergence criterion=8.7925e-05
# EM iteration 20, llf=-10173, convergence criterion=4.278e-06
# EM converged at iteration 28, llf=-10173, convergence criterion=8.6313e-07 < tolerance=1e-06
# EM start iterations, llf=-10362
# EM iteration 10, llf=-10175, convergence criterion=8.7925e-05
# EM iteration 20, llf=-10173, convergence criterion=4.278e-06
# EM converged at iteration 28, llf=-10173, convergence criterion=8.6313e-07 < tolerance=1e-06
# EM start iterations, llf=-10373
# EM iteration 10, llf=-10187, convergence criterion=8.679e-05
# EM iteration 20, llf=-10185, convergence criterion=4.1253e-06
# EM converged at iteration 27, llf=-10185, convergence criterion=9.7163e-07 < tolerance=1e-06
# EM start iterations, llf=-10410
# EM iteration 10, llf=-10222, convergence criterion=8.7477e-05
# EM iteration 20, llf=-10220, convergence criterion=3.9978e-06
# EM converged at iteration 27, llf=-10220, convergence criterion=9.4207e-07 < tolerance=1e-06
# EM start iterations, llf=-10417
# EM iteration 10, llf=-10227, convergence criterion=8.7002e-05
# EM iteration 20, llf=-10224, convergence criterion=4.1018e-06
# EM converged at iteration 27, llf=-10224, convergence criterion=9.6916e-07 < tolerance=1e-06
# EM start iterations, llf=-10449
# EM iteration 10, llf=-10258, convergence criterion=8.9374e-05
# EM iteration 20, llf=-10255, convergence criterion=4.3093e-06
# EM converged at iteration 28, llf=-10255, convergence criterion=8.6986e-07 < tolerance=1e-06
# EM start iterations, llf=-10510
# EM iteration 10, llf=-10328, convergence criterion=9.3467e-05
# EM iteration 20, llf=-10325, convergence criterion=4.6684e-06
# EM converged at iteration 28, llf=-10325, convergence criterion=9.0769e-07 < tolerance=1e-06
# EM start iterations, llf=-10549
# EM iteration 10, llf=-10364, convergence criterion=9.1169e-05
# EM iteration 20, llf=-10362, convergence criterion=4.2107e-06
# EM converged at iteration 27, llf=-10361, convergence criterion=9.7245e-07 < tolerance=1e-06
# EM start iterations, llf=-10549
# EM iteration 10, llf=-10364, convergence criterion=9.1169e-05
# EM iteration 20, llf=-10362, convergence criterion=4.2107e-06
# EM converged at iteration 27, llf=-10361, convergence criterion=9.7245e-07 < tolerance=1e-06
# EM start iterations, llf=-10557
# EM iteration 10, llf=-10371, convergence criterion=9.2905e-05
# EM iteration 20, llf=-10368, convergence criterion=4.3838e-06
# EM converged at iteration 27, llf=-10368, convergence criterion=9.9477e-07 < tolerance=1e-06
# EM start iterations, llf=-10605
# EM iteration 10, llf=-10427, convergence criterion=9.4402e-05
# EM iteration 20, llf=-10424, convergence criterion=5.0099e-06
# EM converged at iteration 29, llf=-10424, convergence criterion=8.7591e-07 < tolerance=1e-06
# EM start iterations, llf=-10624
# EM iteration 10, llf=-10457, convergence criterion=7.099e-05
# EM iteration 20, llf=-10455, convergence criterion=7.6967e-06
# EM iteration 30, llf=-10454, convergence criterion=1.3806e-06
# EM converged at iteration 34, llf=-10454, convergence criterion=9.2637e-07 < tolerance=1e-06
# EM start iterations, llf=-10668
# EM iteration 10, llf=-10513, convergence criterion=2.5265e-05
# EM iteration 20, llf=-10511, convergence criterion=6.1381e-06
# EM iteration 30, llf=-10511, convergence criterion=2.3227e-06
# EM iteration 40, llf=-10511, convergence criterion=1.2143e-06
# EM converged at iteration 44, llf=-10511, convergence criterion=9.9249e-07 < tolerance=1e-06
# EM start iterations, llf=-10674
# EM iteration 10, llf=-10517, convergence criterion=3.9926e-05
# EM iteration 20, llf=-10515, convergence criterion=8.7962e-06
# EM iteration 30, llf=-10515, convergence criterion=2.4541e-06
# EM iteration 40, llf=-10515, convergence criterion=1.061e-06
# EM converged at iteration 41, llf=-10515, convergence criterion=9.9615e-07 < tolerance=1e-06
# EM start iterations, llf=-10713
# EM iteration 10, llf=-10552, convergence criterion=4.9313e-05
# EM iteration 20, llf=-10550, convergence criterion=1.0474e-05
# EM iteration 30, llf=-10549, convergence criterion=2.4525e-06
# EM iteration 40, llf=-10549, convergence criterion=9.5195e-07
# EM converged at iteration 40, llf=-10549, convergence criterion=9.5195e-07 < tolerance=1e-06
# EM start iterations, llf=-10713
# EM iteration 10, llf=-10552, convergence criterion=4.9313e-05
# EM iteration 20, llf=-10550, convergence criterion=1.0474e-05
# EM iteration 30, llf=-10549, convergence criterion=2.4525e-06
# EM iteration 40, llf=-10549, convergence criterion=9.5195e-07
# EM converged at iteration 40, llf=-10549, convergence criterion=9.5195e-07 < tolerance=1e-06
# EM start iterations, llf=-10725
# EM iteration 10, llf=-10566, convergence criterion=4.537e-05
# EM iteration 20, llf=-10563, convergence criterion=1.1584e-05
# EM iteration 30, llf=-10563, convergence criterion=2.9453e-06
# EM iteration 40, llf=-10562, convergence criterion=1.0751e-06
# EM converged at iteration 41, llf=-10562, convergence criterion=9.9685e-07 < tolerance=1e-06
# EM start iterations, llf=-10761
# EM iteration 10, llf=-10604, convergence criterion=3.3645e-05
# EM iteration 20, llf=-10602, convergence criterion=1.0317e-05
# EM iteration 30, llf=-10601, convergence criterion=3.3049e-06
# EM iteration 40, llf=-10601, convergence criterion=1.3395e-06
# EM converged at iteration 45, llf=-10601, convergence criterion=9.5835e-07 < tolerance=1e-06
# EM start iterations, llf=-10767
# EM iteration 10, llf=-10611, convergence criterion=3.3336e-05
# EM iteration 20, llf=-10609, convergence criterion=1.1553e-05
# EM iteration 30, llf=-10608, convergence criterion=3.8771e-06
# EM iteration 40, llf=-10608, convergence criterion=1.5252e-06
# EM converged at iteration 47, llf=-10607, convergence criterion=9.4577e-07 < tolerance=1e-06
# EM start iterations, llf=-10814
# EM iteration 10, llf=-10656, convergence criterion=4.5711e-05
# EM iteration 20, llf=-10653, convergence criterion=1.3613e-05
# EM iteration 30, llf=-10652, convergence criterion=3.629e-06
# EM iteration 40, llf=-10652, convergence criterion=1.2655e-06
# EM converged at iteration 44, llf=-10652, convergence criterion=9.383e-07 < tolerance=1e-06
# EM start iterations, llf=-10826
# EM iteration 10, llf=-10665, convergence criterion=5.4903e-05
# EM iteration 20, llf=-10662, convergence criterion=1.364e-05
# EM iteration 30, llf=-10661, convergence criterion=3.0177e-06
# EM iteration 40, llf=-10661, convergence criterion=1.023e-06
# EM converged at iteration 41, llf=-10661, convergence criterion=9.4706e-07 < tolerance=1e-06
# EM start iterations, llf=-10868
# EM iteration 10, llf=-10708, convergence criterion=4.9865e-05
# EM iteration 20, llf=-10705, convergence criterion=1.4104e-05
# EM iteration 30, llf=-10704, convergence criterion=3.5421e-06
# EM iteration 40, llf=-10704, convergence criterion=1.2314e-06
# EM converged at iteration 43, llf=-10704, convergence criterion=9.8479e-07 < tolerance=1e-06
# EM start iterations, llf=-10868
# EM iteration 10, llf=-10708, convergence criterion=4.9865e-05
# EM iteration 20, llf=-10705, convergence criterion=1.4104e-05
# EM iteration 30, llf=-10704, convergence criterion=3.5421e-06
# EM iteration 40, llf=-10704, convergence criterion=1.2314e-06
# EM converged at iteration 43, llf=-10704, convergence criterion=9.8479e-07 < tolerance=1e-06
# EM start iterations, llf=-10878
# EM iteration 10, llf=-10721, convergence criterion=3.2569e-05
# EM iteration 20, llf=-10719, convergence criterion=1.1285e-05
# EM iteration 30, llf=-10718, convergence criterion=4.0482e-06
# EM iteration 40, llf=-10718, convergence criterion=1.7038e-06
# EM converged at iteration 49, llf=-10718, convergence criterion=9.7008e-07 < tolerance=1e-06
# EM start iterations, llf=-10912
# EM iteration 10, llf=-10756, convergence criterion=2.3835e-05
# EM iteration 20, llf=-10755, convergence criterion=8.5039e-06
# EM iteration 30, llf=-10754, convergence criterion=3.5951e-06
# EM iteration 40, llf=-10754, convergence criterion=1.786e-06
# EM iteration 50, llf=-10754, convergence criterion=1.0528e-06
# EM converged at iteration 52, llf=-10754, convergence criterion=9.6309e-07 < tolerance=1e-06
# EM start iterations, llf=-10920
# EM iteration 10, llf=-10764, convergence criterion=3.3019e-05
# EM iteration 20, llf=-10762, convergence criterion=1.1148e-05
# EM iteration 30, llf=-10761, convergence criterion=3.8993e-06
# EM iteration 40, llf=-10761, convergence criterion=1.6529e-06
# EM converged at iteration 49, llf=-10761, convergence criterion=9.6091e-07 < tolerance=1e-06
# EM start iterations, llf=-10955
# EM iteration 10, llf=-10797, convergence criterion=4.0231e-05
# EM iteration 20, llf=-10794, convergence criterion=1.3166e-05
# EM iteration 30, llf=-10794, convergence criterion=4.0759e-06
# EM iteration 40, llf=-10793, convergence criterion=1.5492e-06
# EM converged at iteration 47, llf=-10793, convergence criterion=9.6539e-07 < tolerance=1e-06
# EM start iterations, llf=-10966
# EM iteration 10, llf=-10809, convergence criterion=3.0818e-05
# EM iteration 20, llf=-10807, convergence criterion=1.1295e-05
# EM iteration 30, llf=-10806, convergence criterion=4.2752e-06
# EM iteration 40, llf=-10806, convergence criterion=1.8499e-06
# EM iteration 50, llf=-10805, convergence criterion=1.0059e-06
# EM converged at iteration 51, llf=-10805, convergence criterion=9.5712e-07 < tolerance=1e-06
# EM start iterations, llf=-11003
# EM iteration 10, llf=-10848, convergence criterion=1.7891e-05
# EM iteration 20, llf=-10847, convergence criterion=7.1492e-06
# EM iteration 30, llf=-10847, convergence criterion=3.575e-06
# EM iteration 40, llf=-10846, convergence criterion=1.997e-06
# EM iteration 50, llf=-10846, convergence criterion=1.2368e-06
# EM converged at iteration 56, llf=-10846, convergence criterion=9.6953e-07 < tolerance=1e-06
# EM start iterations, llf=-11003
# EM iteration 10, llf=-10848, convergence criterion=1.7891e-05
# EM iteration 20, llf=-10847, convergence criterion=7.1492e-06
# EM iteration 30, llf=-10847, convergence criterion=3.575e-06
# EM iteration 40, llf=-10846, convergence criterion=1.997e-06
# EM iteration 50, llf=-10846, convergence criterion=1.2368e-06
# EM converged at iteration 56, llf=-10846, convergence criterion=9.6953e-07 < tolerance=1e-06
# EM start iterations, llf=-11016
# EM iteration 10, llf=-10860, convergence criterion=2.5252e-05
# EM iteration 20, llf=-10858, convergence criterion=1.0099e-05
# EM iteration 30, llf=-10857, convergence criterion=4.4085e-06
# EM iteration 40, llf=-10857, convergence criterion=2.0816e-06
# EM iteration 50, llf=-10857, convergence criterion=1.1451e-06
# EM converged at iteration 53, llf=-10857, convergence criterion=9.8762e-07 < tolerance=1e-06
# EM start iterations, llf=-11045
# EM iteration 10, llf=-10885, convergence criterion=5.7296e-05
# EM iteration 20, llf=-10882, convergence criterion=1.5495e-05
# EM iteration 30, llf=-10881, convergence criterion=3.3732e-06
# EM iteration 40, llf=-10881, convergence criterion=1.058e-06
# EM converged at iteration 41, llf=-10881, convergence criterion=9.7328e-07 < tolerance=1e-06
# EM start iterations, llf=-11054
# EM iteration 10, llf=-10890, convergence criterion=9.0868e-05
# EM iteration 20, llf=-10885, convergence criterion=1.5597e-05
# EM iteration 30, llf=-10885, convergence criterion=2.2092e-06
# EM converged at iteration 36, llf=-10885, convergence criterion=9.7876e-07 < tolerance=1e-06
# EM start iterations, llf=-11079
# EM iteration 10, llf=-10909, convergence criterion=0.00012935
# EM iteration 20, llf=-10904, convergence criterion=1.3456e-05
# EM iteration 30, llf=-10903, convergence criterion=1.5442e-06
# EM converged at iteration 33, llf=-10903, convergence criterion=9.7954e-07 < tolerance=1e-06
# EM start iterations, llf=-11083
# EM iteration 10, llf=-10921, convergence criterion=9.901e-05
# EM iteration 20, llf=-10916, convergence criterion=1.6622e-05
# EM iteration 30, llf=-10915, convergence criterion=2.237e-06
# EM converged at iteration 36, llf=-10915, convergence criterion=9.3804e-07 < tolerance=1e-06
# EM start iterations, llf=-11118
# EM iteration 10, llf=-10963, convergence criterion=5.199e-05
# EM iteration 20, llf=-10960, convergence criterion=1.4447e-05
# EM iteration 30, llf=-10959, convergence criterion=3.4859e-06
# EM iteration 40, llf=-10959, convergence criterion=1.1527e-06
# EM converged at iteration 42, llf=-10959, convergence criterion=9.8184e-07 < tolerance=1e-06
# EM start iterations, llf=-11118
# EM iteration 10, llf=-10963, convergence criterion=5.199e-05
# EM iteration 20, llf=-10960, convergence criterion=1.4447e-05
# EM iteration 30, llf=-10959, convergence criterion=3.4859e-06
# EM iteration 40, llf=-10959, convergence criterion=1.1527e-06
# EM converged at iteration 42, llf=-10959, convergence criterion=9.8184e-07 < tolerance=1e-06
# EM start iterations, llf=-11129
# EM iteration 10, llf=-10974, convergence criterion=5.0288e-05
# EM iteration 20, llf=-10971, convergence criterion=1.4045e-05
# EM iteration 30, llf=-10970, convergence criterion=3.4758e-06
# EM iteration 40, llf=-10970, convergence criterion=1.1732e-06
# EM converged at iteration 43, llf=-10970, convergence criterion=9.3138e-07 < tolerance=1e-06
# EM start iterations, llf=-11171
# EM iteration 10, llf=-11014, convergence criterion=5.5433e-05
# EM iteration 20, llf=-11011, convergence criterion=1.4452e-05
# EM iteration 30, llf=-11010, convergence criterion=3.2721e-06
# EM iteration 40, llf=-11010, convergence criterion=1.0671e-06
# EM converged at iteration 41, llf=-11010, convergence criterion=9.8343e-07 < tolerance=1e-06
# EM start iterations, llf=-11178
# EM iteration 10, llf=-11021, convergence criterion=5.9815e-05
# EM iteration 20, llf=-11017, convergence criterion=1.4715e-05
# EM iteration 30, llf=-11016, convergence criterion=3.1053e-06
# EM iteration 40, llf=-11016, convergence criterion=1.0002e-06
# EM converged at iteration 41, llf=-11016, convergence criterion=9.2299e-07 < tolerance=1e-06
# EM start iterations, llf=-11223
# EM iteration 10, llf=-11065, convergence criterion=5.9914e-05
# EM iteration 20, llf=-11062, convergence criterion=1.4587e-05
# EM iteration 30, llf=-11061, convergence criterion=3.0826e-06
# EM iteration 40, llf=-11061, convergence criterion=1.0027e-06
# EM converged at iteration 41, llf=-11061, convergence criterion=9.2607e-07 < tolerance=1e-06
# EM start iterations, llf=-11233
# EM iteration 10, llf=-11075, convergence criterion=5.7869e-05
# EM iteration 20, llf=-11072, convergence criterion=1.4527e-05
# EM iteration 30, llf=-11071, convergence criterion=3.171e-06
# EM iteration 40, llf=-11071, convergence criterion=1.0353e-06
# EM converged at iteration 41, llf=-11071, convergence criterion=9.5553e-07 < tolerance=1e-06
# EM start iterations, llf=-11273
# EM iteration 10, llf=-11114, convergence criterion=6.0142e-05
# EM iteration 20, llf=-11111, convergence criterion=1.4942e-05
# EM iteration 30, llf=-11110, convergence criterion=3.1665e-06
# EM iteration 40, llf=-11110, convergence criterion=1.0206e-06
# EM converged at iteration 41, llf=-11110, convergence criterion=9.4185e-07 < tolerance=1e-06
# EM start iterations, llf=-11273
# EM iteration 10, llf=-11114, convergence criterion=6.0142e-05
# EM iteration 20, llf=-11111, convergence criterion=1.4942e-05
# EM iteration 30, llf=-11110, convergence criterion=3.1665e-06
# EM iteration 40, llf=-11110, convergence criterion=1.0206e-06
# EM converged at iteration 41, llf=-11110, convergence criterion=9.4185e-07 < tolerance=1e-06
# EM start iterations, llf=-11283
# EM iteration 10, llf=-11124, convergence criterion=6.1711e-05
# EM iteration 20, llf=-11121, convergence criterion=1.504e-05
# EM iteration 30, llf=-11120, convergence criterion=3.1049e-06
# EM iteration 40, llf=-11120, convergence criterion=9.9002e-07
# EM converged at iteration 40, llf=-11120, convergence criterion=9.9002e-07 < tolerance=1e-06
# EM start iterations, llf=-11316
# EM iteration 10, llf=-11156, convergence criterion=6.6743e-05
# EM iteration 20, llf=-11152, convergence criterion=1.4268e-05
# EM iteration 30, llf=-11151, convergence criterion=2.7258e-06
# EM converged at iteration 39, llf=-11151, convergence criterion=9.9195e-07 < tolerance=1e-06
# EM start iterations, llf=-11328
# EM iteration 10, llf=-11169, convergence criterion=5.6508e-05
# EM iteration 20, llf=-11165, convergence criterion=1.3987e-05
# EM iteration 30, llf=-11165, convergence criterion=3.1196e-06
# EM iteration 40, llf=-11164, convergence criterion=1.0716e-06
# EM converged at iteration 41, llf=-11164, convergence criterion=9.9324e-07 < tolerance=1e-06
# EM start iterations, llf=-11355
# EM iteration 10, llf=-11198, convergence criterion=5.8551e-05
# EM iteration 20, llf=-11195, convergence criterion=1.5343e-05
# EM iteration 30, llf=-11194, convergence criterion=3.375e-06
# EM iteration 40, llf=-11194, convergence criterion=1.0936e-06
# EM converged at iteration 42, llf=-11194, convergence criterion=9.335e-07 < tolerance=1e-06
# EM start iterations, llf=-11361
# EM iteration 10, llf=-11201, convergence criterion=9.4526e-05
# EM iteration 20, llf=-11196, convergence criterion=1.6119e-05
# EM iteration 30, llf=-11195, convergence criterion=2.2245e-06
# EM converged at iteration 36, llf=-11195, convergence criterion=9.2984e-07 < tolerance=1e-06
# EM start iterations, llf=-11390
# EM iteration 10, llf=-11225, convergence criterion=0.00010917
# EM iteration 20, llf=-11219, convergence criterion=1.5192e-05
# EM iteration 30, llf=-11219, convergence criterion=1.8467e-06
# EM converged at iteration 34, llf=-11219, convergence criterion=9.7437e-07 < tolerance=1e-06
# EM start iterations, llf=-11390
# EM iteration 10, llf=-11225, convergence criterion=0.00010917
# EM iteration 20, llf=-11219, convergence criterion=1.5192e-05
# EM iteration 30, llf=-11219, convergence criterion=1.8467e-06
# EM converged at iteration 34, llf=-11219, convergence criterion=9.7437e-07 < tolerance=1e-06
# EM start iterations, llf=-11404
# EM iteration 10, llf=-11242, convergence criterion=7.5926e-05
# EM iteration 20, llf=-11238, convergence criterion=1.7125e-05
# EM iteration 30, llf=-11237, convergence criterion=2.906e-06
# EM converged at iteration 38, llf=-11237, convergence criterion=9.632e-07 < tolerance=1e-06
# EM start iterations, llf=-11459
# EM iteration 10, llf=-11297, convergence criterion=6.6361e-05
# EM iteration 20, llf=-11293, convergence criterion=1.7422e-05
# EM iteration 30, llf=-11292, convergence criterion=3.408e-06
# EM iteration 40, llf=-11292, convergence criterion=9.5587e-07
# EM converged at iteration 40, llf=-11292, convergence criterion=9.5587e-07 < tolerance=1e-06
# EM start iterations, llf=-11465
# EM iteration 10, llf=-11304, convergence criterion=6.7162e-05
# EM iteration 20, llf=-11300, convergence criterion=1.7971e-05
# EM iteration 30, llf=-11299, convergence criterion=3.509e-06
# EM iteration 40, llf=-11299, convergence criterion=9.6278e-07
# EM converged at iteration 40, llf=-11299, convergence criterion=9.6278e-07 < tolerance=1e-06
# EM start iterations, llf=-11510
# EM iteration 10, llf=-11351, convergence criterion=4.994e-05
# EM iteration 20, llf=-11348, convergence criterion=1.6249e-05
# EM iteration 30, llf=-11347, convergence criterion=4.3157e-06
# EM iteration 40, llf=-11346, convergence criterion=1.3345e-06
# EM converged at iteration 44, llf=-11346, convergence criterion=9.3684e-07 < tolerance=1e-06
# EM start iterations, llf=-11518
# EM iteration 10, llf=-11357, convergence criterion=6.0016e-05
# EM iteration 20, llf=-11353, convergence criterion=1.797e-05
# EM iteration 30, llf=-11352, convergence criterion=3.9832e-06
# EM iteration 40, llf=-11352, convergence criterion=1.1036e-06
# EM converged at iteration 41, llf=-11352, convergence criterion=9.995e-07 < tolerance=1e-06
# EM start iterations, llf=-11560
# EM iteration 10, llf=-11400, convergence criterion=4.9942e-05
# EM iteration 20, llf=-11397, convergence criterion=1.6592e-05
# EM iteration 30, llf=-11396, convergence criterion=4.487e-06
# EM iteration 40, llf=-11395, convergence criterion=1.381e-06
# EM converged at iteration 44, llf=-11395, convergence criterion=9.6227e-07 < tolerance=1e-06
# EM start iterations, llf=-11560
# EM iteration 10, llf=-11400, convergence criterion=4.9942e-05
# EM iteration 20, llf=-11397, convergence criterion=1.6592e-05
# EM iteration 30, llf=-11396, convergence criterion=4.487e-06
# EM iteration 40, llf=-11395, convergence criterion=1.381e-06
# EM converged at iteration 44, llf=-11395, convergence criterion=9.6227e-07 < tolerance=1e-06
# EM start iterations, llf=-11568
# EM iteration 10, llf=-11407, convergence criterion=5.8116e-05
# EM iteration 20, llf=-11404, convergence criterion=1.7836e-05
# EM iteration 30, llf=-11403, convergence criterion=4.159e-06
# EM iteration 40, llf=-11402, convergence criterion=1.1749e-06
# EM converged at iteration 42, llf=-11402, convergence criterion=9.6768e-07 < tolerance=1e-06
# EM start iterations, llf=-11610
# EM iteration 10, llf=-11449, convergence criterion=6.1122e-05
# EM iteration 20, llf=-11445, convergence criterion=1.7923e-05
# EM iteration 30, llf=-11444, convergence criterion=3.9062e-06
# EM iteration 40, llf=-11443, convergence criterion=1.0665e-06
# EM converged at iteration 41, llf=-11443, convergence criterion=9.6469e-07 < tolerance=1e-06
# EM start iterations, llf=-11620
# EM iteration 10, llf=-11457, convergence criterion=6.8754e-05
# EM iteration 20, llf=-11453, convergence criterion=1.7605e-05
# EM iteration 30, llf=-11452, convergence criterion=3.314e-06
# EM converged at iteration 39, llf=-11452, convergence criterion=9.732e-07 < tolerance=1e-06
# EM start iterations, llf=-11655
# EM iteration 10, llf=-11492, convergence criterion=6.2499e-05
# EM iteration 20, llf=-11488, convergence criterion=1.5729e-05
# EM iteration 30, llf=-11488, convergence criterion=3.1147e-06
# EM converged at iteration 39, llf=-11487, convergence criterion=9.9673e-07 < tolerance=1e-06
# EM start iterations, llf=-11666
# EM iteration 10, llf=-11506, convergence criterion=4.1428e-05
# EM iteration 20, llf=-11504, convergence criterion=1.2637e-05
# EM iteration 30, llf=-11503, convergence criterion=3.6672e-06
# EM iteration 40, llf=-11503, convergence criterion=1.3456e-06
# EM converged at iteration 45, llf=-11503, convergence criterion=9.3656e-07 < tolerance=1e-06
# EM start iterations, llf=-11705
# EM iteration 10, llf=-11544, convergence criterion=3.8599e-05
# EM iteration 20, llf=-11542, convergence criterion=1.1779e-05
# EM iteration 30, llf=-11541, convergence criterion=3.6225e-06
# EM iteration 40, llf=-11541, convergence criterion=1.4231e-06
# EM converged at iteration 46, llf=-11541, convergence criterion=9.539e-07 < tolerance=1e-06
# EM start iterations, llf=-11705
# EM iteration 10, llf=-11544, convergence criterion=3.8599e-05
# EM iteration 20, llf=-11542, convergence criterion=1.1779e-05
# EM iteration 30, llf=-11541, convergence criterion=3.6225e-06
# EM iteration 40, llf=-11541, convergence criterion=1.4231e-06
# EM converged at iteration 46, llf=-11541, convergence criterion=9.539e-07 < tolerance=1e-06
# EM start iterations, llf=-11711
# EM iteration 10, llf=-11551, convergence criterion=4.0982e-05
# EM iteration 20, llf=-11548, convergence criterion=1.21e-05
# EM iteration 30, llf=-11548, convergence criterion=3.5163e-06
# EM iteration 40, llf=-11547, convergence criterion=1.3368e-06
# EM converged at iteration 45, llf=-11547, convergence criterion=9.4679e-07 < tolerance=1e-06
# EM start iterations, llf=-11748
# EM iteration 10, llf=-11586, convergence criterion=5.0887e-05
# EM iteration 20, llf=-11583, convergence criterion=1.351e-05
# EM iteration 30, llf=-11582, convergence criterion=3.2064e-06
# EM iteration 40, llf=-11582, convergence criterion=1.0767e-06
# EM converged at iteration 41, llf=-11582, convergence criterion=9.9278e-07 < tolerance=1e-06
# EM start iterations, llf=-11755
# EM iteration 10, llf=-11594, convergence criterion=4.9673e-05
# EM iteration 20, llf=-11591, convergence criterion=1.3626e-05
# EM iteration 30, llf=-11590, convergence criterion=3.3058e-06
# EM iteration 40, llf=-11590, convergence criterion=1.0979e-06
# EM converged at iteration 42, llf=-11590, convergence criterion=9.3389e-07 < tolerance=1e-06
# EM start iterations, llf=-11790
# EM iteration 10, llf=-11627, convergence criterion=5.9626e-05
# EM iteration 20, llf=-11624, convergence criterion=1.5174e-05
# EM iteration 30, llf=-11623, convergence criterion=3.099e-06
# EM iteration 40, llf=-11623, convergence criterion=9.2314e-07
# EM converged at iteration 40, llf=-11623, convergence criterion=9.2314e-07 < tolerance=1e-06
# EM start iterations, llf=-11804
# EM iteration 10, llf=-11642, convergence criterion=5.4911e-05
# EM iteration 20, llf=-11639, convergence criterion=1.4956e-05
# EM iteration 30, llf=-11638, convergence criterion=3.3076e-06
# EM iteration 40, llf=-11638, convergence criterion=1.0027e-06
# EM converged at iteration 41, llf=-11638, convergence criterion=9.1734e-07 < tolerance=1e-06
# EM start iterations, llf=-11846
# EM iteration 10, llf=-11687, convergence criterion=2.3832e-05
# EM iteration 20, llf=-11685, convergence criterion=8.2631e-06
# EM iteration 30, llf=-11685, convergence criterion=3.3787e-06
# EM iteration 40, llf=-11685, convergence criterion=1.6089e-06
# EM converged at iteration 49, llf=-11684, convergence criterion=9.5927e-07 < tolerance=1e-06
# EM start iterations, llf=-11846
# EM iteration 10, llf=-11687, convergence criterion=2.3832e-05
# EM iteration 20, llf=-11685, convergence criterion=8.2631e-06
# EM iteration 30, llf=-11685, convergence criterion=3.3787e-06
# EM iteration 40, llf=-11685, convergence criterion=1.6089e-06
# EM converged at iteration 49, llf=-11684, convergence criterion=9.5927e-07 < tolerance=1e-06
# EM start iterations, llf=-11851
# EM iteration 10, llf=-11690, convergence criterion=3.8173e-05
# EM iteration 20, llf=-11687, convergence criterion=1.1891e-05
# EM iteration 30, llf=-11686, convergence criterion=3.5938e-06
# EM iteration 40, llf=-11686, convergence criterion=1.3088e-06
# EM converged at iteration 44, llf=-11686, convergence criterion=9.5899e-07 < tolerance=1e-06
# EM start iterations, llf=-11889
# EM iteration 10, llf=-11726, convergence criterion=4.7651e-05
# EM iteration 20, llf=-11723, convergence criterion=1.3411e-05
# EM iteration 30, llf=-11722, convergence criterion=3.3822e-06
# EM iteration 40, llf=-11722, convergence criterion=1.1191e-06
# EM converged at iteration 42, llf=-11722, convergence criterion=9.4717e-07 < tolerance=1e-06
# EM start iterations, llf=-11900
# EM iteration 10, llf=-11739, convergence criterion=3.1737e-05
# EM iteration 20, llf=-11737, convergence criterion=1.0419e-05
# EM iteration 30, llf=-11737, convergence criterion=3.6418e-06
# EM iteration 40, llf=-11736, convergence criterion=1.5191e-06
# EM converged at iteration 47, llf=-11736, convergence criterion=9.5955e-07 < tolerance=1e-06
# EM start iterations, llf=-11940
# EM iteration 10, llf=-11779, convergence criterion=3.4934e-05
# EM iteration 20, llf=-11776, convergence criterion=1.1196e-05
# EM iteration 30, llf=-11776, convergence criterion=3.6891e-06
# EM iteration 40, llf=-11775, convergence criterion=1.4729e-06
# EM converged at iteration 46, llf=-11775, convergence criterion=9.7641e-07 < tolerance=1e-06
# EM start iterations, llf=-11947
# EM iteration 10, llf=-11785, convergence criterion=3.8228e-05
# EM iteration 20, llf=-11783, convergence criterion=1.1798e-05
# EM iteration 30, llf=-11782, convergence criterion=3.6125e-06
# EM iteration 40, llf=-11782, convergence criterion=1.3686e-06
# EM converged at iteration 45, llf=-11782, convergence criterion=9.5452e-07 < tolerance=1e-06
# EM start iterations, llf=-11981
# EM iteration 10, llf=-11816, convergence criterion=4.7719e-05
# EM iteration 20, llf=-11813, convergence criterion=1.3244e-05
# EM iteration 30, llf=-11812, convergence criterion=3.3185e-06
# EM iteration 40, llf=-11812, convergence criterion=1.0941e-06
# EM converged at iteration 42, llf=-11812, convergence criterion=9.2567e-07 < tolerance=1e-06
# EM start iterations, llf=-11981
# EM iteration 10, llf=-11816, convergence criterion=4.7719e-05
# EM iteration 20, llf=-11813, convergence criterion=1.3244e-05
# EM iteration 30, llf=-11812, convergence criterion=3.3185e-06
# EM iteration 40, llf=-11812, convergence criterion=1.0941e-06
# EM converged at iteration 42, llf=-11812, convergence criterion=9.2567e-07 < tolerance=1e-06
# EM start iterations, llf=-11990
# EM iteration 10, llf=-11825, convergence criterion=4.7864e-05
# EM iteration 20, llf=-11822, convergence criterion=1.3329e-05
# EM iteration 30, llf=-11822, convergence criterion=3.3356e-06
# EM iteration 40, llf=-11821, convergence criterion=1.0988e-06
# EM converged at iteration 42, llf=-11821, convergence criterion=9.2974e-07 < tolerance=1e-06
# EM start iterations, llf=-12030
# EM iteration 10, llf=-11865, convergence criterion=4.5839e-05
# EM iteration 20, llf=-11862, convergence criterion=1.2913e-05
# EM iteration 30, llf=-11862, convergence criterion=3.3605e-06
# EM iteration 40, llf=-11861, convergence criterion=1.1478e-06
# EM converged at iteration 42, llf=-11861, convergence criterion=9.7565e-07 < tolerance=1e-06
# EM start iterations, llf=-12042
# EM iteration 10, llf=-11878, convergence criterion=4.5642e-05
# EM iteration 20, llf=-11875, convergence criterion=1.2885e-05
# EM iteration 30, llf=-11874, convergence criterion=3.3507e-06
# EM iteration 40, llf=-11874, convergence criterion=1.147e-06
# EM converged at iteration 42, llf=-11874, convergence criterion=9.7558e-07 < tolerance=1e-06
# EM start iterations, llf=-12078
# EM iteration 10, llf=-11913, convergence criterion=4.606e-05
# EM iteration 20, llf=-11910, convergence criterion=1.2871e-05
# EM iteration 30, llf=-11909, convergence criterion=3.3172e-06
# EM iteration 40, llf=-11909, convergence criterion=1.1397e-06
# EM converged at iteration 42, llf=-11909, convergence criterion=9.7099e-07 < tolerance=1e-06
# EM start iterations, llf=-12085
# EM iteration 10, llf=-11920, convergence criterion=4.7432e-05
# EM iteration 20, llf=-11917, convergence criterion=1.2791e-05
# EM iteration 30, llf=-11916, convergence criterion=3.191e-06
# EM iteration 40, llf=-11916, convergence criterion=1.0939e-06
# EM converged at iteration 42, llf=-11916, convergence criterion=9.3389e-07 < tolerance=1e-06
# EM start iterations, llf=-12118
# EM iteration 10, llf=-11952, convergence criterion=5.1437e-05
# EM iteration 20, llf=-11949, convergence criterion=1.3029e-05
# EM iteration 30, llf=-11948, convergence criterion=2.9976e-06
# EM iteration 40, llf=-11948, convergence criterion=9.9666e-07
# EM converged at iteration 40, llf=-11948, convergence criterion=9.9666e-07 < tolerance=1e-06
# EM start iterations, llf=-12118
# EM iteration 10, llf=-11952, convergence criterion=5.1437e-05
# EM iteration 20, llf=-11949, convergence criterion=1.3029e-05
# EM iteration 30, llf=-11948, convergence criterion=2.9976e-06
# EM iteration 40, llf=-11948, convergence criterion=9.9666e-07
# EM converged at iteration 40, llf=-11948, convergence criterion=9.9666e-07 < tolerance=1e-06
# EM start iterations, llf=-12130
# EM iteration 10, llf=-11964, convergence criterion=4.7439e-05
# EM iteration 20, llf=-11961, convergence criterion=1.266e-05
# EM iteration 30, llf=-11960, convergence criterion=3.1404e-06
# EM iteration 40, llf=-11960, convergence criterion=1.0788e-06
# EM converged at iteration 41, llf=-11960, convergence criterion=9.951e-07 < tolerance=1e-06
# EM start iterations, llf=-12158
# EM iteration 10, llf=-11991, convergence criterion=5.4648e-05
# EM iteration 20, llf=-11987, convergence criterion=1.3156e-05
# EM iteration 30, llf=-11987, convergence criterion=2.8536e-06
# EM iteration 40, llf=-11986, convergence criterion=9.4555e-07
# EM converged at iteration 40, llf=-11986, convergence criterion=9.4555e-07 < tolerance=1e-06
# EM start iterations, llf=-12168
# EM iteration 10, llf=-12000, convergence criterion=5.7827e-05
# EM iteration 20, llf=-11996, convergence criterion=1.3361e-05
# EM iteration 30, llf=-11996, convergence criterion=2.7349e-06
# EM converged at iteration 39, llf=-11996, convergence criterion=9.6774e-07 < tolerance=1e-06
# EM start iterations, llf=-12214
# EM iteration 10, llf=-12043, convergence criterion=6.8913e-05
# EM iteration 20, llf=-12039, convergence criterion=1.3703e-05
# EM iteration 30, llf=-12038, convergence criterion=2.3644e-06
# EM converged at iteration 37, llf=-12038, convergence criterion=9.5982e-07 < tolerance=1e-06
# EM start iterations, llf=-12226
# EM iteration 10, llf=-12055, convergence criterion=6.1688e-05
# EM iteration 20, llf=-12052, convergence criterion=1.3272e-05
# EM iteration 30, llf=-12051, convergence criterion=2.5634e-06
# EM converged at iteration 38, llf=-12051, convergence criterion=9.8753e-07 < tolerance=1e-06
# EM start iterations, llf=-12267
# EM iteration 10, llf=-12095, convergence criterion=6.1589e-05
# EM iteration 20, llf=-12092, convergence criterion=1.3246e-05
# EM iteration 30, llf=-12091, convergence criterion=2.5681e-06
# EM converged at iteration 38, llf=-12091, convergence criterion=9.9238e-07 < tolerance=1e-06
# EM start iterations, llf=-12267
# EM iteration 10, llf=-12095, convergence criterion=6.1589e-05
# EM iteration 20, llf=-12092, convergence criterion=1.3246e-05
# EM iteration 30, llf=-12091, convergence criterion=2.5681e-06
# EM converged at iteration 38, llf=-12091, convergence criterion=9.9238e-07 < tolerance=1e-06
# EM start iterations, llf=-12278
# EM iteration 10, llf=-12108, convergence criterion=5.8859e-05
# EM iteration 20, llf=-12104, convergence criterion=1.3142e-05
# EM iteration 30, llf=-12104, convergence criterion=2.6616e-06
# EM converged at iteration 39, llf=-12103, convergence criterion=9.4665e-07 < tolerance=1e-06
# EM start iterations, llf=-12318
# EM iteration 10, llf=-12147, convergence criterion=6.0304e-05
# EM iteration 20, llf=-12143, convergence criterion=1.3014e-05
# EM iteration 30, llf=-12142, convergence criterion=2.5509e-06
# EM converged at iteration 38, llf=-12142, convergence criterion=9.797e-07 < tolerance=1e-06
# EM start iterations, llf=-12329
# EM iteration 10, llf=-12157, convergence criterion=6.2901e-05
# EM iteration 20, llf=-12153, convergence criterion=1.2797e-05
# EM iteration 30, llf=-12153, convergence criterion=2.4005e-06
# EM converged at iteration 38, llf=-12152, convergence criterion=9.2215e-07 < tolerance=1e-06
# EM start iterations, llf=-12369
# EM iteration 10, llf=-12198, convergence criterion=4.8621e-05
# ...
# EM start iterations, llf=-14337
# EM iteration 10, llf=-14138, convergence criterion=7.8245e-05
# EM iteration 20, llf=-14134, convergence criterion=6.6721e-06
# EM iteration 30, llf=-14134, convergence criterion=1.213e-06
# EM converged at iteration 32, llf=-14134, convergence criterion=9.9302e-07 < tolerance=1e-06
# EM start iterations, llf=-14376
# EM iteration 10, llf=-14175, convergence criterion=8.156e-05
# EM iteration 20, llf=-14171, convergence criterion=6.6964e-06
# EM iteration 30, llf=-14171, convergence criterion=1.144e-06
# EM converged at iteration 32, llf=-14171, convergence criterion=9.2923e-07 < tolerance=1e-06
# EM start iterations, llf=-14384
# EM iteration 10, llf=-14184, convergence criterion=7.8294e-05
# EM iteration 20, llf=-14180, convergence criterion=7.058e-06
# EM iteration 30, llf=-14180, convergence criterion=1.2261e-06
# EM converged at iteration 32, llf=-14180, convergence criterion=9.9327e-07 < tolerance=1e-06
# EM start iterations, llf=-14416
# EM iteration 10, llf=-14217, convergence criterion=7.5324e-05
# EM iteration 20, llf=-14213, convergence criterion=6.9381e-06
# EM iteration 30, llf=-14213, convergence criterion=1.2479e-06
# EM converged at iteration 33, llf=-14213, convergence criterion=9.2657e-07 < tolerance=1e-06
# EM start iterations, llf=-14416
# EM iteration 10, llf=-14217, convergence criterion=7.5324e-05
# EM iteration 20, llf=-14213, convergence criterion=6.9381e-06
# EM iteration 30, llf=-14213, convergence criterion=1.2479e-06
# EM converged at iteration 33, llf=-14213, convergence criterion=9.2657e-07 < tolerance=1e-06
# EM start iterations, llf=-14430
# EM iteration 10, llf=-14230, convergence criterion=7.335e-05
# EM iteration 20, llf=-14226, convergence criterion=6.8764e-06
# EM iteration 30, llf=-14226, convergence criterion=1.2702e-06
# EM converged at iteration 33, llf=-14226, convergence criterion=9.4758e-07 < tolerance=1e-06
# EM start iterations, llf=-14472
# EM iteration 10, llf=-14272, convergence criterion=7.0671e-05
# EM iteration 20, llf=-14269, convergence criterion=6.4097e-06
# EM iteration 30, llf=-14268, convergence criterion=1.2517e-06
# EM converged at iteration 33, llf=-14268, convergence criterion=9.4751e-07 < tolerance=1e-06
# EM start iterations, llf=-14479
# EM iteration 10, llf=-14275, convergence criterion=7.8098e-05
# EM iteration 20, llf=-14272, convergence criterion=5.691e-06
# EM iteration 30, llf=-14272, convergence criterion=1.054e-06
# EM converged at iteration 31, llf=-14272, convergence criterion=9.5394e-07 < tolerance=1e-06
# EM start iterations, llf=-14510
# EM iteration 10, llf=-14304, convergence criterion=8.154e-05
# EM iteration 20, llf=-14301, convergence criterion=5.4946e-06
# EM iteration 30, llf=-14300, convergence criterion=9.8692e-07
# EM converged at iteration 30, llf=-14300, convergence criterion=9.8692e-07 < tolerance=1e-06
# EM start iterations, llf=-14524
# EM iteration 10, llf=-14321, convergence criterion=7.6766e-05
# EM iteration 20, llf=-14318, convergence criterion=6.0824e-06
# EM iteration 30, llf=-14317, convergence criterion=1.1207e-06
# EM converged at iteration 32, llf=-14317, convergence criterion=9.2157e-07 < tolerance=1e-06
# EM start iterations, llf=-14355
# EM iteration 10, llf=-14153, convergence criterion=9.3063e-05
# EM iteration 20, llf=-14150, convergence criterion=4.8922e-06
# EM converged at iteration 28, llf=-14149, convergence criterion=9.8523e-07 < tolerance=1e-06
# EM start iterations, llf=-14355
# EM iteration 10, llf=-14153, convergence criterion=9.3063e-05
# EM iteration 20, llf=-14150, convergence criterion=4.8922e-06
# EM converged at iteration 28, llf=-14149, convergence criterion=9.8523e-07 < tolerance=1e-06
# EM start iterations, llf=-14362
# EM iteration 10, llf=-14165, convergence criterion=9.1416e-05
# EM iteration 20, llf=-14161, convergence criterion=5.4465e-06
# EM converged at iteration 29, llf=-14161, convergence criterion=9.671e-07 < tolerance=1e-06
# EM start iterations, llf=-14404
# EM iteration 10, llf=-14208, convergence criterion=8.6657e-05
# EM iteration 20, llf=-14205, convergence criterion=5.5381e-06
# EM iteration 30, llf=-14205, convergence criterion=9.3405e-07
# EM converged at iteration 30, llf=-14205, convergence criterion=9.3405e-07 < tolerance=1e-06
# EM start iterations, llf=-14416
# EM iteration 10, llf=-14219, convergence criterion=8.9065e-05
# EM iteration 20, llf=-14215, convergence criterion=5.3585e-06
# EM converged at iteration 29, llf=-14215, convergence criterion=9.8509e-07 < tolerance=1e-06
# EM start iterations, llf=-14462
# EM iteration 10, llf=-14264, convergence criterion=8.9569e-05
# EM iteration 20, llf=-14260, convergence criterion=5.2474e-06
# EM converged at iteration 29, llf=-14260, convergence criterion=9.4264e-07 < tolerance=1e-06
# EM start iterations, llf=-14467
# EM iteration 10, llf=-14270, convergence criterion=8.8929e-05
# EM iteration 20, llf=-14267, convergence criterion=5.4346e-06
# EM converged at iteration 29, llf=-14267, convergence criterion=9.7883e-07 < tolerance=1e-06
# EM start iterations, llf=-14513
# EM iteration 10, llf=-14314, convergence criterion=9.0018e-05
# EM iteration 20, llf=-14311, convergence criterion=5.1988e-06
# EM converged at iteration 29, llf=-14311, convergence criterion=9.0056e-07 < tolerance=1e-06
# EM start iterations, llf=-14513
# EM iteration 10, llf=-14314, convergence criterion=9.0018e-05
# EM iteration 20, llf=-14311, convergence criterion=5.1988e-06
# EM converged at iteration 29, llf=-14311, convergence criterion=9.0056e-07 < tolerance=1e-06
# EM start iterations, llf=-14518
# EM iteration 10, llf=-14320, convergence criterion=8.9952e-05
# EM iteration 20, llf=-14316, convergence criterion=5.2056e-06
# EM converged at iteration 29, llf=-14316, convergence criterion=9.0452e-07 < tolerance=1e-06
# EM start iterations, llf=-14558
# EM iteration 10, llf=-14358, convergence criterion=9.321e-05
# EM iteration 20, llf=-14354, convergence criterion=5.371e-06
# EM converged at iteration 29, llf=-14354, convergence criterion=8.8521e-07 < tolerance=1e-06
# EM start iterations, llf=-14566
# EM iteration 10, llf=-14367, convergence criterion=9.3012e-05
# EM iteration 20, llf=-14363, convergence criterion=5.4314e-06
# EM converged at iteration 29, llf=-14362, convergence criterion=9.0107e-07 < tolerance=1e-06
# EM start iterations, llf=-14607
# EM iteration 10, llf=-14406, convergence criterion=9.2411e-05
# EM iteration 20, llf=-14403, convergence criterion=5.3226e-06
# EM converged at iteration 29, llf=-14402, convergence criterion=8.9422e-07 < tolerance=1e-06
# EM start iterations, llf=-14615
# EM iteration 10, llf=-14414, convergence criterion=9.2293e-05
# EM iteration 20, llf=-14410, convergence criterion=5.4034e-06
# EM converged at iteration 29, llf=-14410, convergence criterion=9.0549e-07 < tolerance=1e-06
# EM start iterations, llf=-14656
# EM iteration 10, llf=-14454, convergence criterion=9.4112e-05
# EM iteration 20, llf=-14450, convergence criterion=5.3562e-06
# EM converged at iteration 29, llf=-14450, convergence criterion=8.8385e-07 < tolerance=1e-06
# EM start iterations, llf=-14656
# EM iteration 10, llf=-14454, convergence criterion=9.4112e-05
# EM iteration 20, llf=-14450, convergence criterion=5.3562e-06
# EM converged at iteration 29, llf=-14450, convergence criterion=8.8385e-07 < tolerance=1e-06
# EM start iterations, llf=-14661
# EM iteration 10, llf=-14457, convergence criterion=9.4726e-05
# EM iteration 20, llf=-14454, convergence criterion=5.1196e-06
# EM converged at iteration 28, llf=-14453, convergence criterion=9.6153e-07 < tolerance=1e-06
# EM start iterations, llf=-14705
# EM iteration 10, llf=-14503, convergence criterion=9.3889e-05
# EM iteration 20, llf=-14499, convergence criterion=5.295e-06
# EM converged at iteration 29, llf=-14499, convergence criterion=8.7424e-07 < tolerance=1e-06
# EM start iterations, llf=-14711
# EM iteration 10, llf=-14507, convergence criterion=9.5462e-05
# EM iteration 20, llf=-14503, convergence criterion=5.0438e-06
# EM converged at iteration 28, llf=-14503, convergence criterion=9.4321e-07 < tolerance=1e-06
# EM start iterations, llf=-14748
# EM iteration 10, llf=-14542, convergence criterion=9.508e-05
# EM iteration 20, llf=-14539, convergence criterion=4.9015e-06
# EM converged at iteration 28, llf=-14538, convergence criterion=9.1983e-07 < tolerance=1e-06
# EM start iterations, llf=-14759
# EM iteration 10, llf=-14553, convergence criterion=9.3749e-05
# EM iteration 20, llf=-14549, convergence criterion=4.7614e-06
# EM converged at iteration 28, llf=-14549, convergence criterion=9.0694e-07 < tolerance=1e-06
# EM start iterations, llf=-14794
# EM iteration 10, llf=-14587, convergence criterion=9.3165e-05
# EM iteration 20, llf=-14583, convergence criterion=4.7252e-06
# EM converged at iteration 28, llf=-14583, convergence criterion=8.995e-07 < tolerance=1e-06
# EM start iterations, llf=-14794
# EM iteration 10, llf=-14587, convergence criterion=9.3165e-05
# EM iteration 20, llf=-14583, convergence criterion=4.7252e-06
# EM converged at iteration 28, llf=-14583, convergence criterion=8.995e-07 < tolerance=1e-06
# EM start iterations, llf=-14804
# EM iteration 10, llf=-14598, convergence criterion=9.1482e-05
# EM iteration 20, llf=-14595, convergence criterion=4.7184e-06
# EM converged at iteration 28, llf=-14594, convergence criterion=9.2132e-07 < tolerance=1e-06
# EM start iterations, llf=-14839
# EM iteration 10, llf=-14633, convergence criterion=9.3722e-05
# EM iteration 20, llf=-14629, convergence criterion=4.7896e-06
# EM converged at iteration 28, llf=-14629, convergence criterion=9.1897e-07 < tolerance=1e-06
# EM start iterations, llf=-14848
# EM iteration 10, llf=-14641, convergence criterion=9.3437e-05
# EM iteration 20, llf=-14637, convergence criterion=4.7695e-06
# EM converged at iteration 28, llf=-14637, convergence criterion=9.1837e-07 < tolerance=1e-06
# EM start iterations, llf=-14888
# EM iteration 10, llf=-14679, convergence criterion=9.4549e-05
# EM iteration 20, llf=-14676, convergence criterion=4.7629e-06
# EM converged at iteration 28, llf=-14676, convergence criterion=9.0095e-07 < tolerance=1e-06
# EM start iterations, llf=-14897
# EM iteration 10, llf=-14691, convergence criterion=9.3007e-05
# EM iteration 20, llf=-14687, convergence criterion=4.7834e-06
# EM converged at iteration 28, llf=-14687, convergence criterion=9.1753e-07 < tolerance=1e-06
# EM start iterations, llf=-14935
# EM iteration 10, llf=-14729, convergence criterion=8.9379e-05
# EM iteration 20, llf=-14725, convergence criterion=4.7889e-06
# EM converged at iteration 28, llf=-14725, convergence criterion=9.6095e-07 < tolerance=1e-06
# EM start iterations, llf=-14935
# EM iteration 10, llf=-14729, convergence criterion=8.9379e-05
# EM iteration 20, llf=-14725, convergence criterion=4.7889e-06
# EM converged at iteration 28, llf=-14725, convergence criterion=9.6095e-07 < tolerance=1e-06
# EM start iterations, llf=-14942
# EM iteration 10, llf=-14738, convergence criterion=8.8284e-05
# EM iteration 20, llf=-14734, convergence criterion=4.9206e-06
# EM converged at iteration 28, llf=-14734, convergence criterion=9.9647e-07 < tolerance=1e-06
# EM start iterations, llf=-14986
# EM iteration 10, llf=-14781, convergence criterion=8.7361e-05
# EM iteration 20, llf=-14777, convergence criterion=4.9518e-06
# EM converged at iteration 29, llf=-14777, convergence criterion=8.8846e-07 < tolerance=1e-06
# EM start iterations, llf=-14995
# EM iteration 10, llf=-14790, convergence criterion=8.711e-05
# EM iteration 20, llf=-14786, convergence criterion=4.8972e-06
# EM converged at iteration 29, llf=-14786, convergence criterion=8.7962e-07 < tolerance=1e-06
# EM start iterations, llf=-15033
# EM iteration 10, llf=-14827, convergence criterion=8.7791e-05
# EM iteration 20, llf=-14823, convergence criterion=4.8496e-06
# EM converged at iteration 28, llf=-14823, convergence criterion=9.8673e-07 < tolerance=1e-06
# EM start iterations, llf=-15042
# EM iteration 10, llf=-14835, convergence criterion=8.8241e-05
# EM iteration 20, llf=-14832, convergence criterion=4.7763e-06
# EM converged at iteration 28, llf=-14831, convergence criterion=9.6753e-07 < tolerance=1e-06
# EM start iterations, llf=-15081
# EM iteration 10, llf=-14872, convergence criterion=8.9858e-05
# EM iteration 20, llf=-14868, convergence criterion=4.6048e-06
# EM converged at iteration 28, llf=-14868, convergence criterion=9.1485e-07 < tolerance=1e-06
# EM start iterations, llf=-15081
# EM iteration 10, llf=-14872, convergence criterion=8.9858e-05
# EM iteration 20, llf=-14868, convergence criterion=4.6048e-06
# EM converged at iteration 28, llf=-14868, convergence criterion=9.1485e-07 < tolerance=1e-06
# EM start iterations, llf=-15088
# EM iteration 10, llf=-14881, convergence criterion=8.8759e-05
# EM iteration 20, llf=-14877, convergence criterion=4.8678e-06
# EM converged at iteration 28, llf=-14877, convergence criterion=9.7e-07 < tolerance=1e-06
# EM start iterations, llf=-15131
# EM iteration 10, llf=-14925, convergence criterion=8.4385e-05
# EM iteration 20, llf=-14921, convergence criterion=4.7402e-06
# EM converged at iteration 28, llf=-14921, convergence criterion=9.9387e-07 < tolerance=1e-06
# EM start iterations, llf=-15140
# EM iteration 10, llf=-14933, convergence criterion=8.4576e-05
# EM iteration 20, llf=-14930, convergence criterion=4.7363e-06
# EM converged at iteration 28, llf=-14929, convergence criterion=9.8398e-07 < tolerance=1e-06
# EM start iterations, llf=-15179
# EM iteration 10, llf=-14971, convergence criterion=8.5326e-05
# EM iteration 20, llf=-14968, convergence criterion=4.7102e-06
# EM converged at iteration 28, llf=-14967, convergence criterion=9.6695e-07 < tolerance=1e-06
# EM start iterations, llf=-15185
# EM iteration 10, llf=-14977, convergence criterion=8.5137e-05
# EM iteration 20, llf=-14974, convergence criterion=4.6696e-06
# EM converged at iteration 28, llf=-14973, convergence criterion=9.5831e-07 < tolerance=1e-06
# EM start iterations, llf=-15219
# EM iteration 10, llf=-15009, convergence criterion=8.6135e-05
# EM iteration 20, llf=-15005, convergence criterion=4.5471e-06
# EM converged at iteration 28, llf=-15005, convergence criterion=9.2686e-07 < tolerance=1e-06
# EM start iterations, llf=-15219
# EM iteration 10, llf=-15009, convergence criterion=8.6135e-05
# EM iteration 20, llf=-15005, convergence criterion=4.5471e-06
# EM converged at iteration 28, llf=-15005, convergence criterion=9.2686e-07 < tolerance=1e-06
# EM start iterations, llf=-14940
# EM iteration 10, llf=-14730, convergence criterion=9.9878e-05
# EM iteration 20, llf=-14726, convergence criterion=5.2702e-06
# EM converged at iteration 29, llf=-14726, convergence criterion=9.1768e-07 < tolerance=1e-06
# EM start iterations, llf=-14981
# EM iteration 10, llf=-14769, convergence criterion=0.00010051
# EM iteration 20, llf=-14765, convergence criterion=5.2585e-06
# EM iteration 30, llf=-14765, convergence criterion=9.0587e-07
# EM converged at iteration 30, llf=-14765, convergence criterion=9.0587e-07 < tolerance=1e-06
# EM start iterations, llf=-14995
# EM iteration 10, llf=-14784, convergence criterion=9.9558e-05
# EM iteration 20, llf=-14780, convergence criterion=5.3101e-06
# EM iteration 30, llf=-14780, convergence criterion=9.3677e-07
# EM converged at iteration 30, llf=-14780, convergence criterion=9.3677e-07 < tolerance=1e-06
# EM start iterations, llf=-15035
# EM iteration 10, llf=-14822, convergence criterion=9.9361e-05
# EM iteration 20, llf=-14818, convergence criterion=5.1666e-06
# EM iteration 30, llf=-14818, convergence criterion=8.9831e-07
# EM converged at iteration 30, llf=-14818, convergence criterion=8.9831e-07 < tolerance=1e-06
# EM start iterations, llf=-15039
# EM iteration 10, llf=-14826, convergence criterion=9.8718e-05
# EM iteration 20, llf=-14822, convergence criterion=5.1369e-06
# EM iteration 30, llf=-14822, convergence criterion=9.0319e-07
# EM converged at iteration 30, llf=-14822, convergence criterion=9.0319e-07 < tolerance=1e-06
# EM start iterations, llf=-15080
# EM iteration 10, llf=-14867, convergence criterion=9.8105e-05
# EM iteration 20, llf=-14863, convergence criterion=5.1238e-06
# EM iteration 30, llf=-14863, convergence criterion=9.3783e-07
# EM converged at iteration 30, llf=-14863, convergence criterion=9.3783e-07 < tolerance=1e-06
